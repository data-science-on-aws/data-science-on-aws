# %%
import time
import uuid
import boto3
import sagemaker

sess = sagemaker.Session()
region = boto3.Session().region_name
bucket = sess.default_bucket()
role = sagemaker.get_execution_role()

# %%
#model_training_s3_uri = 's3://dsoaws/nyc-taxi-orig-cleaned-dropped-parquet-per-year-multiple-files/'

model_training_s3_uri = 's3://dsoaws/nyc-taxi-orig-cleaned-dropped-parquet-all-years-multiple-files-1TB/'

# %% [markdown]
# ### Configure the algorithm and training job
#
# The Training Job hyperparameters are set. For more information on XGBoost Hyperparameters,
# see https://xgboost.readthedocs.io/en/latest/parameter.html.

# %%
container = sagemaker.image_uris.retrieve("xgboost", region, "1.5-1")

output_content_type = "parquet"

train_content_type = (
    "application/x-parquet" if output_content_type.upper() == "PARQUET"
    else "text/csv"
)
train_input = sagemaker.inputs.TrainingInput(
    s3_data=model_training_s3_uri,
    content_type=train_content_type,
    distribution='ShardedByS3Key',
    input_mode='FastFile'
)

hyperparameters = {
    "eta": "0.2",
    "gamma": "4",
    "max_depth": "5",
    "min_child_weight": "6",
    "num_round": "50",
    "objective": "reg:squarederror",
    "subsample": "0.7"
}
# Out:
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.

# %% [markdown]
# ### Start the Training Job
#
# The TrainingJob configurations are set using the SageMaker Python SDK Estimator, and which is fit using
# the training data from the Processing Job that was run earlier.

# %%
estimator = sagemaker.estimator.Estimator(
    container,
    role,
    hyperparameters=hyperparameters,
    instance_count=6,
    instance_type="ml.m5.24xlarge",
    volume_size=200,
)

# %%
import time
import sagemaker

# m5.24xlarge (6 incl leader node) - 12.85 minutes
training_job_results = estimator.fit({"train": train_input})
print(training_job_results)
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2023-03-08-01-26-56-469
# 2023-03-08 01:26:56 Starting - Starting the training job...
# 2023-03-08 01:27:13 Starting - Preparing the instances for training......
# 2023-03-08 01:28:26 Downloading - Downloading input data......
# 2023-03-08 01:29:02 Training - Training image download completed. Training in progress...[2023-03-08 01:29:28.748 ip-10-0-234-157.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-03-08 01:29:28.806 ip-10-0-234-157.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-03-08:01:29:29:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-03-08:01:29:29:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-03-08:01:29:29:INFO] No GPUs detected (normal if no gpus installed)
# [2023-03-08:01:29:29:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-03-08:01:29:29:INFO] Determined 0 GPU(s) available on the instance.
# [2023-03-08:01:29:29:INFO] files path: /opt/ml/input/data/train/01/1
# [2023-03-08 01:29:35.256 ip-10-0-226-16.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-03-08 01:29:35.311 ip-10-0-226-16.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-03-08:01:29:35:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-03-08:01:29:35:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-03-08:01:29:35:INFO] No GPUs detected (normal if no gpus installed)
# [2023-03-08:01:29:35:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-03-08:01:29:35:INFO] Determined 0 GPU(s) available on the instance.
# [2023-03-08:01:29:35:INFO] files path: /opt/ml/input/data/train/01/1
# [2023-03-08 01:29:34.412 ip-10-0-232-205.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-03-08 01:29:34.468 ip-10-0-232-205.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-03-08:01:29:34:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-03-08:01:29:34:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-03-08:01:29:34:INFO] No GPUs detected (normal if no gpus installed)
# [2023-03-08:01:29:34:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-03-08:01:29:34:INFO] Determined 0 GPU(s) available on the instance.
# [2023-03-08:01:29:34:INFO] files path: /opt/ml/input/data/train/01/1
# [2023-03-08 01:29:34.041 ip-10-0-221-44.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-03-08 01:29:34.098 ip-10-0-221-44.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-03-08:01:29:34:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-03-08:01:29:34:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-03-08:01:29:34:INFO] No GPUs detected (normal if no gpus installed)
# [2023-03-08:01:29:34:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-03-08:01:29:34:INFO] Determined 0 GPU(s) available on the instance.
# [2023-03-08:01:29:34:INFO] files path: /opt/ml/input/data/train/01/1
# [2023-03-08 01:29:35.957 ip-10-0-209-18.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-03-08 01:29:36.013 ip-10-0-209-18.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-03-08:01:29:36:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-03-08:01:29:36:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-03-08:01:29:36:INFO] No GPUs detected (normal if no gpus installed)
# [2023-03-08:01:29:36:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-03-08:01:29:36:INFO] Determined 0 GPU(s) available on the instance.
# [2023-03-08:01:29:36:INFO] files path: /opt/ml/input/data/train/01/1
# [2023-03-08 01:29:35.962 ip-10-0-217-75.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-03-08 01:29:36.018 ip-10-0-217-75.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-03-08:01:29:36:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-03-08:01:29:36:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-03-08:01:29:36:INFO] No GPUs detected (normal if no gpus installed)
# [2023-03-08:01:29:36:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-03-08:01:29:36:INFO] Determined 0 GPU(s) available on the instance.
# [2023-03-08:01:29:36:INFO] files path: /opt/ml/input/data/train/01/1
# [2023-03-08:01:29:52:INFO] Distributed node training with 6 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6']
# [2023-03-08:01:29:52:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-08:01:29:52:INFO] Sleeping for 3 sec before retrying
# [2023-03-08:01:29:55:INFO] Failed to connect to RabitTracker on attempt 1
# [2023-03-08:01:29:55:INFO] Sleeping for 3 sec before retrying
# [2023-03-08:01:29:57:INFO] Distributed node training with 6 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6']
# [2023-03-08:01:29:57:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-08:01:29:57:INFO] Sleeping for 3 sec before retrying
# [2023-03-08:01:29:57:INFO] Distributed node training with 6 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6']
# [2023-03-08:01:29:57:INFO] start listen on algo-1:9099
# [2023-03-08:01:29:57:INFO] Rabit slave environment: {'DMLC_TRACKER_URI': 'algo-1', 'DMLC_TRACKER_PORT': 9099}
# [2023-03-08:01:29:57:INFO] Connected to RabitTracker.
# [2023-03-08:01:29:57:INFO] No data received from connection ('10.0.221.44', 39418). Closing.
# [2023-03-08:01:29:58:INFO] Distributed node training with 6 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6']
# [2023-03-08:01:29:58:INFO] Connected to RabitTracker.
# [2023-03-08:01:29:58:INFO] Connected to RabitTracker.
# [2023-03-08:01:29:58:INFO] No data received from connection ('10.0.226.16', 39512). Closing.
# [2023-03-08:01:29:58:INFO] No data received from connection ('10.0.234.157', 35824). Closing.
# [2023-03-08:01:29:59:INFO] No data received from connection ('10.0.209.18', 55522). Closing.
# [2023-03-08:01:29:59:INFO] Distributed node training with 6 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6']
# [2023-03-08:01:29:59:INFO] Connected to RabitTracker.
# [2023-03-08:01:29:59:INFO] Distributed node training with 6 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6']
# [2023-03-08:01:29:59:INFO] Connected to RabitTracker.
# [2023-03-08:01:29:59:INFO] No data received from connection ('10.0.217.75', 54086). Closing.
# [01:30:00] task NULL got new rank 0
# [2023-03-08:01:30:00:INFO] Connected to RabitTracker.
# [01:30:01] task NULL got new rank 4
# [01:30:00] task NULL got new rank 1
# [01:30:01] task NULL got new rank 5
# [2023-03-08:01:30:01:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-08:01:30:01:INFO] Sleeping for 3 sec before retrying
# [2023-03-08:01:30:00:INFO] No data received from connection ('10.0.232.205', 45508). Closing.
# [2023-03-08:01:30:00:INFO] Recieve start signal from 10.0.209.18; assign rank 0
# [2023-03-08:01:30:00:INFO] Recieve start signal from 10.0.217.75; assign rank 1
# [01:30:00] task NULL got new rank 2
# [2023-03-08:01:30:01:INFO] Recieve start signal from 10.0.221.44; assign rank 2
# [2023-03-08:01:30:01:INFO] Recieve start signal from 10.0.226.16; assign rank 3
# [2023-03-08:01:30:01:INFO] Recieve start signal from 10.0.232.205; assign rank 4
# [2023-03-08:01:30:01:INFO] Recieve start signal from 10.0.234.157; assign rank 5
# [2023-03-08:01:30:01:INFO] @tracker All of 6 nodes getting started
# [2023-03-08:01:30:01:INFO] @tracker All nodes finishes job
# [2023-03-08:01:30:01:INFO] @tracker 0.09325671195983887 secs between node start and job finish
# [2023-03-08:01:30:01:INFO] start listen on algo-1:9100
# [2023-03-08:01:30:01:INFO] Rabit slave environment: {'DMLC_TRACKER_URI': 'algo-1', 'DMLC_TRACKER_PORT': 9100}
# [2023-03-08:01:30:01:INFO] Connected to RabitTracker.
# [2023-03-08:01:30:01:INFO] No data received from connection ('10.0.221.44', 43548). Closing.
# [01:30:01] task NULL got new rank 3
# [2023-03-08:01:30:01:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-08:01:30:01:INFO] Sleeping for 3 sec before retrying
# [2023-03-08:01:30:01:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-08:01:30:01:INFO] Sleeping for 3 sec before retrying
# [2023-03-08:01:30:01:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-08:01:30:01:INFO] Sleeping for 3 sec before retrying
# [2023-03-08:01:30:01:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-08:01:30:01:INFO] Sleeping for 3 sec before retrying
# [2023-03-08:01:30:04:INFO] Connected to RabitTracker.
# [2023-03-08:01:30:04:INFO] No data received from connection ('10.0.234.157', 41682). Closing.
# [2023-03-08:01:30:04:INFO] No data received from connection ('10.0.232.205', 42660). Closing.
# [2023-03-08:01:30:04:INFO] No data received from connection ('10.0.226.16', 48888). Closing.
# [2023-03-08:01:30:04:INFO] No data received from connection ('10.0.217.75', 34364). Closing.
# [2023-03-08:01:30:04:INFO] No data received from connection ('10.0.209.18', 57290). Closing.
# [2023-03-08:01:30:04:INFO] Recieve start signal from 10.0.209.18; assign rank 0
# [2023-03-08:01:30:04:INFO] Recieve start signal from 10.0.217.75; assign rank 1
# [01:30:04] task NULL got new rank 2
# [2023-03-08:01:30:04:INFO] Connected to RabitTracker.
# [01:30:04] task NULL got new rank 3
# [2023-03-08:01:30:04:INFO] Train matrix has 177190682 rows and 11 columns
# [2023-03-08 01:30:04.882 ip-10-0-226-16.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-03-08 01:30:04.883 ip-10-0-226-16.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-03-08 01:30:04.883 ip-10-0-226-16.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-03-08 01:30:04.884 ip-10-0-226-16.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-03-08:01:30:04:INFO] Debug hook created from config
# [2023-03-08:01:30:04:INFO] Connected to RabitTracker.
# [01:30:04] task NULL got new rank 0
# [2023-03-08:01:30:04:INFO] Connected to RabitTracker.
# [01:30:04] task NULL got new rank 4
# [2023-03-08:01:30:04:INFO] Train matrix has 173767590 rows and 11 columns
# [2023-03-08 01:30:04.973 ip-10-0-232-205.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-03-08 01:30:04.973 ip-10-0-232-205.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-03-08 01:30:04.974 ip-10-0-232-205.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-03-08 01:30:04.974 ip-10-0-232-205.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-03-08:01:30:04:INFO] Debug hook created from config
# [2023-03-08:01:30:04:INFO] Connected to RabitTracker.
# [01:30:04] task NULL got new rank 1
# [2023-03-08:01:30:04:INFO] Train matrix has 176943097 rows and 11 columns
# [2023-03-08 01:30:04.791 ip-10-0-217-75.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-03-08 01:30:04.791 ip-10-0-217-75.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-03-08 01:30:04.792 ip-10-0-217-75.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-03-08 01:30:04.792 ip-10-0-217-75.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-03-08:01:30:04:INFO] Debug hook created from config
# [01:30:04] task NULL got new rank 5
# [2023-03-08:01:30:04:INFO] Train matrix has 175586441 rows and 11 columns
# [2023-03-08 01:30:04.972 ip-10-0-234-157.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-03-08 01:30:04.973 ip-10-0-234-157.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-03-08 01:30:04.974 ip-10-0-234-157.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-03-08 01:30:04.974 ip-10-0-234-157.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-03-08:01:30:04:INFO] Debug hook created from config
# [2023-03-08:01:30:04:INFO] Recieve start signal from 10.0.221.44; assign rank 2
# [2023-03-08:01:30:04:INFO] Recieve start signal from 10.0.226.16; assign rank 3
# [2023-03-08:01:30:04:INFO] Train matrix has 176997254 rows and 11 columns
# [2023-03-08 01:30:04.792 ip-10-0-221-44.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-03-08 01:30:04.793 ip-10-0-221-44.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-03-08 01:30:04.794 ip-10-0-221-44.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-03-08 01:30:04.794 ip-10-0-221-44.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-03-08:01:30:04:INFO] Debug hook created from config
# [2023-03-08:01:30:04:INFO] Recieve start signal from 10.0.232.205; assign rank 4
# [2023-03-08:01:30:04:INFO] Recieve start signal from 10.0.234.157; assign rank 5
# [2023-03-08:01:30:04:INFO] @tracker All of 6 nodes getting started
# [2023-03-08:01:30:04:INFO] Train matrix has 173553701 rows and 11 columns
# [2023-03-08 01:30:04.972 ip-10-0-209-18.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-03-08 01:30:04.972 ip-10-0-209-18.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-03-08 01:30:04.973 ip-10-0-209-18.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-03-08 01:30:04.973 ip-10-0-209-18.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-03-08:01:30:04:INFO] Debug hook created from config
# [2023-03-08 01:31:44.882 ip-10-0-234-157.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-03-08 01:31:44.881 ip-10-0-209-18.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-03-08 01:31:44.882 ip-10-0-226-16.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-03-08 01:31:44.882 ip-10-0-232-205.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-03-08 01:31:44.881 ip-10-0-217-75.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-03-08 01:31:44.882 ip-10-0-221-44.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-03-08:01:31:44:INFO] [0]#011train-rmse:174.50900
# [2023-03-08:01:33:00:INFO] [1]#011train-rmse:174.23169
# [2023-03-08:01:34:19:INFO] [2]#011train-rmse:173.93199
# [2023-03-08:01:35:40:INFO] [3]#011train-rmse:173.82228
# [2023-03-08:01:36:59:INFO] [4]#011train-rmse:173.75270
# [2023-03-08:01:38:17:INFO] [5]#011train-rmse:173.15164
# [2023-03-08:01:39:33:INFO] [6]#011train-rmse:173.10152
# [2023-03-08:01:40:50:INFO] [7]#011train-rmse:173.08040
# [2023-03-08:01:42:06:INFO] [8]#011train-rmse:172.79385
# [2023-03-08:01:43:23:INFO] [9]#011train-rmse:172.77164
# [2023-03-08:01:44:42:INFO] [10]#011train-rmse:172.76537
# [2023-03-08:01:45:57:INFO] [11]#011train-rmse:172.42575
# [2023-03-08:01:47:15:INFO] [12]#011train-rmse:172.41199
# [2023-03-08:01:48:32:INFO] [13]#011train-rmse:172.22177
# [2023-03-08:01:49:51:INFO] [14]#011train-rmse:172.21637
# [2023-03-08:01:51:04:INFO] [15]#011train-rmse:172.17129
# [2023-03-08:01:52:22:INFO] [16]#011train-rmse:171.91502
# [2023-03-08:01:53:38:INFO] [17]#011train-rmse:171.74776
# [2023-03-08:01:54:55:INFO] [18]#011train-rmse:171.74143
# [2023-03-08:01:56:14:INFO] [19]#011train-rmse:171.57094
# [2023-03-08:01:57:30:INFO] [20]#011train-rmse:171.56313
# [2023-03-08:01:58:47:INFO] [21]#011train-rmse:171.47495
# [2023-03-08:02:00:02:INFO] [22]#011train-rmse:171.32224
# [2023-03-08:02:01:17:INFO] [23]#011train-rmse:171.30710
# [2023-03-08:02:02:33:INFO] [24]#011train-rmse:171.24438
# [2023-03-08:02:03:48:INFO] [25]#011train-rmse:171.24345
# [2023-03-08:02:05:04:INFO] [26]#011train-rmse:171.12303
# [2023-03-08:02:06:21:INFO] [27]#011train-rmse:171.04047
# [2023-03-08:02:07:35:INFO] [28]#011train-rmse:171.00120
# [2023-03-08:02:08:49:INFO] [29]#011train-rmse:170.98387
# [2023-03-08:02:10:06:INFO] [30]#011train-rmse:170.97020
# [2023-03-08:02:11:23:INFO] [31]#011train-rmse:170.97063
# [2023-03-08:02:12:41:INFO] [32]#011train-rmse:170.85886
# [2023-03-08:02:13:55:INFO] [33]#011train-rmse:170.85790
# [2023-03-08:02:15:07:INFO] [34]#011train-rmse:170.83569
# [2023-03-08:02:16:23:INFO] [35]#011train-rmse:170.82143
# [2023-03-08:02:17:39:INFO] [36]#011train-rmse:170.81871
# [2023-03-08:02:18:54:INFO] [37]#011train-rmse:170.81168
# [2023-03-08:02:20:08:INFO] [38]#011train-rmse:170.76479
# [2023-03-08:02:21:22:INFO] [39]#011train-rmse:170.51862
# [2023-03-08:02:22:31:INFO] [40]#011train-rmse:170.46173
# [2023-03-08:02:23:48:INFO] [41]#011train-rmse:170.46175
# [2023-03-08:02:25:02:INFO] [42]#011train-rmse:170.41437
# [2023-03-08:02:26:15:INFO] [43]#011train-rmse:170.39058
# [2023-03-08:02:27:34:INFO] [44]#011train-rmse:170.33353
# [2023-03-08:02:28:50:INFO] [45]#011train-rmse:170.33170
# [2023-03-08:02:30:06:INFO] [46]#011train-rmse:170.27132
# [2023-03-08:02:31:23:INFO] [47]#011train-rmse:170.26213
# [2023-03-08:02:32:35:INFO] [48]#011train-rmse:170.26175
#
# 2023-03-08 02:34:12 Uploading - Uploading generated training model
# 2023-03-08 02:34:12 Completed - Training job completed
# [2023-03-08:02:33:49:INFO] [49]#011train-rmse:170.26036
# [2023-03-08:02:33:49:INFO] @tracker All nodes finishes job
# [2023-03-08:02:33:49:INFO] @tracker 3824.87996506691 secs between node start and job finish
# Training seconds: 23670
# Billable seconds: 23670
# None
