# %%
# !pip install -q torch==1.5.0
# !pip install -q transformers

# %%
from bertviz import model_view
from transformers import DistilBertModel, DistilBertTokenizer

# %%
# %%javascript
# require.config({
#   paths: {
#       d3: '//cdnjs.cloudflare.com/ajax/libs/d3/5.7.0/d3.min',
#     jquery: '//ajax.googleapis.com/ajax/libs/jquery/2.0.0/jquery.min',
#   }
# });

# %%
def show_model_view(model, tokenizer, text):
    inputs = tokenizer.encode_plus(text, return_tensors='pt', add_special_tokens=True)
    input_ids = inputs['input_ids']
    attention = model(input_ids)[-1]
    input_id_list = input_ids[0].tolist() # Batch index 0
    tokens = tokenizer.convert_ids_to_tokens(input_id_list)
    model_view(attention, tokens)

# %%
model_version = 'distilbert-base-uncased'
do_lower_case = True
model = DistilBertModel.from_pretrained(model_version, output_attentions=True)
tokenizer = DistilBertTokenizer.from_pretrained(model_version, do_lower_case=do_lower_case)

# text_5 = """I loved it!  I will recommend this to everyone."""
# show_model_view(model, tokenizer, text_5)

text_1 = """Really bad.  I hope they don't make this anymore."""
show_model_view(model, tokenizer, text_1)
# Out:
#           <div id='vis'></div>

# %%
# Out:
#           <div id='vis'></div>
