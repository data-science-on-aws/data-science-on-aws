# %% [markdown]
# # Contextual Bandits with Amazon SageMaker RL
#
# We demonstrate how you can manage your own contextual multi-armed bandit workflow on SageMaker using the built-in [Vowpal Wabbit (VW)](https://github.com/VowpalWabbit/vowpal_wabbit) container to train and deploy contextual bandit models. We show how to train these models that interact with a live environment (using a simulated client application) and continuously update the model with efficient exploration.
#
# ### Why Contextual Bandits?
#
# Wherever we look to personalize content for a user (content layout, ads, search, product recommendations, etc.), contextual bandits come in handy. Traditional personalization methods collect a training dataset, build a model and deploy it for generating recommendations. However, the training algorithm does not inform us on how to collect this dataset, especially in a production system where generating poor recommendations lead to loss of revenue. Contextual bandit algorithms help us collect this data in a strategic manner by trading off between exploiting known information and exploring recommendations which may yield higher benefits. The collected data is used to update the personalization model in an online manner. Therefore, contextual bandits help us train a personalization model while minimizing the impact of poor recommendations.
#
# ### What does this notebook contain?
#
# To implement the exploration-exploitation strategy, we need an iterative training and deployment system that: (1) recommends an action using the contextual bandit model based on user context, (2) captures the implicit feedback over time and (3) continuously trains the model with incremental interaction data. In this notebook, we show how to setup the infrastructure needed for such an iterative learning system. While the example demonstrates a bandits application, these continual learning systems are useful more generally in dynamic scenarios where models need to be continually updated to capture the recent trends in the data (e.g. tracking fraud behaviors based on detection mechanisms or tracking user interests over time).
#
# In a typical supervised learning setup, the model is trained with a SageMaker training job and it is hosted behind a SageMaker hosting endpoint. The client application calls the endpoint for inference and receives a response. In bandits, the client application also sends the reward (a score assigned to each recommendation generated by the model) back for subsequent model training. These rewards will be part of the dataset for the subsequent model training.

# %% [markdown]
# # Based on this blog post:
#
# https://aws.amazon.com/blogs/machine-learning/power-contextual-bandits-using-continual-learning-with-amazon-sagemaker-rl/

# %% [markdown]
# ![](../../../img/multi_armed_bandit_maximize_reward.png)

# %% [markdown]
# ![](../../../img/multi_armed_bandit_traffic_shift.png)

# %% [markdown]
# The contextual bandit training workflow is controlled by an experiment manager provided with this example. The client application (say a recommender system application) pings the SageMaker hosting endpoint that is serving the bandits model. The application sends the state (user features) as input and receives an action (recommendation) as a response. The client application sends the recommended action to the user and stores the received reward in S3. The SageMaker hosted endpoint also stores inference data (state and action) in S3. The experiment manager joins the inference data with rewards as they become available. The joined data is used to update the model with a SageMaker training job. The updated model is evaluated offline and deployed to SageMaker hosting endpoint if the model evaluation score improves upon prior models.
#
# Below is an overview of the subsequent cells in the notebook:
# * Configuration: this includes details related to SageMaker and other AWS resources needed for the bandits application.
# * IAM role setup: this creates appropriate execution role and shows how to add more permissions to the role, needed for specific AWS resources.
# * Client application (Environment): this shows the simulated client application.
# * Step-by-step bandits model development:
#  1. Model Initialization (random or warm-start)
#  2. Deploy the First Model
#  3. Initialize the Client Application
#  4. Reward Ingestion
#  5. Model Re-training and Re-deployment
# * Bandits model deployment with the end-to-end loop.
# * Visualization
# * Cleanup

# %% [markdown]
# #### Local Mode
#
# To facilitate experimentation, we provide a `local_mode` that runs the contextual bandit example using the SageMaker Notebook instance itself instead of SageMaker training and hosting instances. The workflow remains the same in `local_mode`, but runs much faster for small datasets. Hence, it is a useful tool for experimentation and debugging. However, it will not scale to production use cases with high throughput and large datasets.
#
# In `local_mode`, the training, evaluation and hosting is done with the SageMaker VW docker container. The join is not handled by SageMaker, and is done inside the client application. The rest of the textual explanation assumes that the notebook is run in SageMaker mode.

# %%
import boto3
import sagemaker
import pandas as pd

sess   = sagemaker.Session()
bucket = sess.default_bucket()
role = sagemaker.get_execution_role()
region = boto3.Session().region_name

sm = boto3.Session().client(service_name='sagemaker', region_name=region)

# %%
import yaml
import sys
import numpy as np
import time
import sagemaker

sys.path.append('common')
sys.path.append('common/sagemaker_rl')

from markdown_helper import *
from IPython.display import Markdown

# %% [markdown]
# ### Configuration
#
# The configuration for the bandits application can be specified in a `config.yaml` file as can be seen below. It configures the AWS resources needed. The DynamoDB tables are used to store metadata related to experiments, models and data joins. The `private_resource` specifices the SageMaker instance types and counts used for training, evaluation and hosting. The SageMaker container image is used for the bandits application. This config file also contains algorithm and SageMaker-specific setups.  Note that all the data generated and used for the bandits application will be stored in `s3://sagemaker-{REGION}-{AWS_ACCOUNT_ID}/{experiment_id}/`.
#
# Please make sure that the `num_arms` parameter in the config is equal to the number of actions in the client application (which is defined in the cell below).
#
# The Docker image is defined here:  https://github.com/aws/sagemaker-rl-container/blob/master/vw/docker/8.7.0/Dockerfile

# %%
# !pygmentize 'config.yaml'
# Out:
# resource:
#   shared_resource:
#     # cloud formation stack
#     resources_cf_stack_name: "BanditsSharedResourceStack"
#     # Dynamo table for status of an experiment
#     experiment_db:
#       table_name: "BanditsExperimentTable"
#     # Dynamo table for status of all models trained
#     model_db:
#       table_name: "BanditsModelTable"
#     # Dynamo table for status of all joining job for reward ingestion
#     join_db:
#       table_name: "BanditsJoinTable"
#     iam_role:
#       role_name: "BanditsIAMRole"
#   private_resource:
#     hosting_fleet:
#       instance_type: "ml.t2.medium"
#       instance_count: 1
#     training_fleet:
#       instance_type: "ml.c5.4xlarge"
#     evaluation_fleet:
#       instance_type: "ml.c5.4xlarge"
# # Vowpal Wabbit container
# image: "462105765813.dkr.ecr.{AWS_REGION}.amazonaws.com/sagemaker-rl-vw-container:vw-8.7.0-cpu"
# # Vowpal Wabbit algorithm parameters
# algor:
#   algorithms_parameters:
#     exploration_policy: "egreedy" # supports "egreedy", "bag", "cover"
#     epsilon: 0.001 # used if egreedy is the exploration policy
#     num_policies: 3 # used if bag or cover is the exploration policy
#     num_arms: 2
#     cfa_type: "dr" # supports "dr", "ips"
# # use local mode?
# local_mode: true
# # if true, use the same endpoint with updated model
# soft_deployment: true

# %%
config_file = 'config.yaml'
with open(config_file, 'r') as yaml_file:
    config = yaml.load(yaml_file)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:3: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   app.launch_new_instance()

# %% [markdown]
# # Additional permissions for the IAM role
# IAM role requires additional permissions for [AWS CloudFormation](https://aws.amazon.com/cloudformation/), [Amazon DynamoDB](https://aws.amazon.com/dynamodb/), [Amazon Kinesis Data Firehose](https://aws.amazon.com/kinesis/data-firehose/) and [Amazon Athena](https://aws.amazon.com/athena/). Make sure the SageMaker role you are using has the permissions.

# %%
# display(Markdown(generate_help_for_experiment_manager_permissions(sagemaker_role)))

# %% [markdown]
# ### Client application (Environment)
# The client application simulates a live environment that uses the SageMaker bandits model to serve recommendations to users. The logic of reward generation resides in the client application. We simulate the online learning loop with feedback.  The data consists of 5 classes, and if the agent selects the right class, then reward is 1.  Otherwise, the agent obtains a reward 0.
#
# The workflow of the client application is as follows:
# - The client application picks a context at random, which is sent to the SageMaker endpoint for retrieving an action.
# - SageMaker endpoint returns an action, associated probability and `event_id`.
# - Since this simulator was generated from the dataset, we know the true class for that context.
# - The application reports the reward to the experiment manager using S3, along with the corresponding `event_id`.
#
# `event_id` is a unique identifier for each interaction. It is used to join inference data `<state, action, action probability>` with the rewards.
#
# In a later cell of this notebook, where there exists a hosted endpoint, we illustrate how the client application interacts with the endpoint and gets the recommended action.

# %% [markdown]
# ### Step-by-step bandits model development
#
# [**ExperimentManager**](./common/sagemaker_rl/orchestrator/workflow/manager/experiment_manager.py) is the top level class for all the Bandits/RL and continual learning workflows. Similar to the estimators in the [Sagemaker Python SDK](https://github.com/aws/sagemaker-python-sdk), `ExperimentManager` contains methods for training, deployment and evaluation. It keeps track of the job status and reflects current progress in the workflow.
#
# Start the application using the `ExperimentManager` class

# %%
import time

timestamp = int(time.time())

experiment_name = 'bandits-{}'.format(timestamp)

# %% [markdown]
# # `ExperimentManager` will create a AWS CloudFormation Stack of additional resources needed for the Bandit experiment.

# %%
from orchestrator.workflow.manager.experiment_manager import ExperimentManager

bandits_experiment = ExperimentManager(config, experiment_id=experiment_name)
# Out:
# INFO:orchestrator.resource_manager:Using Resources in CloudFormation stack named: BanditsSharedResourceStack for Shared Resources.

# %%
try:
    bandits_experiment.clean_resource(experiment_id=bandits_experiment.experiment_id)
    bandits_experiment.clean_table_records(experiment_id=bandits_experiment.experiment_id)
except:
    print('Ignore any errors.  Errors are OK.')
# Out:
# INFO:orchestrator:Deleting hosting endpoint 'bandits-1597616270'...
# WARNING:orchestrator.clients.ddb.experiment_db_client:Deleting experiment record...

# %%
bandits_experiment = ExperimentManager(config, experiment_id=experiment_name)
# Out:
# INFO:orchestrator.resource_manager:Using Resources in CloudFormation stack named: BanditsSharedResourceStack for Shared Resources.

# %% [markdown]
# # Initialize the Bandit Model (aka. Warm Start)

# %%
# !pip install -q wrapt --upgrade --ignore-installed
# !pip install -q transformers==2.8.0
# !pip install -q tensorflow==2.1.0

# %%
# from transformers import DistilBertTokenizer

# tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')

# %%
import pandas as pd
import time
import uuid
import boto3
from urllib.parse import urlparse
import datetime
import json
import io
import numpy as np

# def remove_underrepresented_classes(features, labels, thresh=0.0005):
#     """Removes classes when number of datapoints fraction is below a threshold."""
#     total_count = labels.shape[0]
#     unique, counts = np.unique(labels, return_counts=True)
#     ratios = counts.astype('float') / total_count
#     vals_and_ratios = dict(zip(unique, ratios))
#     print('Unique classes and their ratio of total: %s' % vals_and_ratios)
#     keep = [vals_and_ratios[v] >= thresh for v in labels]
#     return features[keep], labels[np.array(keep)]

# def safe_std(values):
#     """Remove zero std values for ones."""
#     return np.array([val if val != 0.0 else 1.0 for val in values])

# def create_bandit_contexts_and_labels(contexts, labels, num_actions=None):
#     print('Contexts: {}'.format(contexts))
#     print('Labels: {}'.format(labels))
#     """Normalize contexts and encode deterministic rewards."""
#     if num_actions is None:
#         num_actions = np.max(labels) + 1
#     print('Num Actions {}'.format(num_actions))

#     num_contexts = contexts.shape[0]
#     print('Num Contexts {}'.format(num_contexts))

#     # Due to random subsampling in small problems, some features may be constant
#     sstd = safe_std(np.std(contexts, axis=0, keepdims=True)[0, :])
#     print('sstd: {}'.format(sstd))
    
#     # Normalize features
#     print('contexts before {}'.format(contexts))
#     contexts_after = ((contexts - np.mean(contexts, axis=0, keepdims=True)) / sstd)
#     print('contexts after {}'.format(contexts_after))
    
#     # One hot encode labels as rewards
#     rewards = np.zeros((num_contexts, num_actions))
#     rewards[np.arange(num_contexts), labels] = 1.0

#     print('Contexts {}'.format(contexts_after))
#     return contexts_after, rewards, (np.ones(num_contexts), labels)

# %%
# import numpy as np
# import pandas as pd
# import boto3
# from src.io_utils import parse_s3_uri
# import csv

# # Generate a batch of experiences for warm starting the policy.
# def generate_sample_warm_start_data(data, batch_size=50):
#     num_actions = 2
    
#     ############
#     # TODO:  Factor this code out
#     data = pd.read_csv(data, header=0).to_numpy()
# #    df = pd.read_csv(data, 
# #                     delimiter='\t', 
# #                     quoting=csv.QUOTE_NONE,
# #                     compression='gzip')
# #    df_scrubbed = df[['review_body', 'star_rating']].sample(n=100)
# #    df_scrubbed = df_scrubbed.reset_index()
# #    df_scrubbed.shape
# #    data = df_scrubbed.to_numpy()
    
#     print('data {}'.format(data))
    
#     # Last column is label, the rest are the features    
#     contexts = data[:, :-1]
#     labels = data[:, -1].astype(int) - 1  # convert to 0 based index

#     # TODO:  Convert raw text into tokens
    
#     print('Contexts before remove underrepresented {}'.format(contexts))
#     print('Labels before remove underrepresented {}'.format(labels))

#     contexts_without_underrepresented_classes, labels_without_underrepresented_classes = remove_underrepresented_classes(contexts, labels)
    
#     print('Contexts after remove underrepresented {}'.format(contexts_without_underrepresented_classes))
#     print('Labels after remove underrepresented {}'.format(labels_without_underrepresented_classes))
    
#     bandit_context, bandit_labels, _ = create_bandit_contexts_and_labels(contexts_without_underrepresented_classes, 
#                                                                          labels_without_underrepresented_classes, 
#                                                                          num_actions)

#     joined_data_buffer = []
#     for i in range(0, batch_size):
#         context_index_i = np.random.choice(bandit_context.shape[0])
#         context_i = bandit_context[context_index_i]
#         action = np.random.choice(num_actions) + 1 # random action
#         action_prob = 1 / num_actions # probability of picking a random action
#         reward = 1 if bandit_labels[context_index_i][action-1] == 1 else 0

#         json_blob = {
#                      "reward": reward,
#                      "event_id": 'not-apply-to-warm-start',
#                      "action": action,
#                      "action_prob": action_prob,
#                      "model_id": 'not-apply-to-warm-start',
#                      "observation": context_i.tolist(),
#                      "sample_prob": np.random.uniform(0.0, 1.0)
#         }

#         joined_data_buffer.append(json_blob)

#     print('joined_data_buffer {}'.format(joined_data_buffer))

#     return joined_data_buffer

# # def download_historical_data_from_s3(data_s3_prefix):
# #     """Download the warm start data from S3."""
# #     s3_client = boto3.client('s3')
# #     bucket, prefix, _ = parse_s3_uri(data_s3_prefix)

# #     results = s3_client.list_objects_v2(Bucket=bucket, Prefix=prefix)
# #     contents = results.get('Contents')
# #     key = contents[0].get('Key')
    
# #     data_file_name = 'statlog_warm_start.data'
# #     s3_client.download_file(bucket, key, data_file_name)

# # def evaluate_historical_data(data_file):
# #     """Calculate policy value of the logged policy."""
# #     # Assume logged data comes from same policy 
# #     # so no need for counterfactual analysis
# #     offline_data = pd.read_csv(data_file, sep=",")
# #     offline_data_mean = offline_data['reward'].mean()
# #     offline_data_cost = 1 - offline_data_mean
# #     offline_data_cost
# #     return offline_data_cost

# %% [markdown]
# To start a new experiment, we need to initialize the first model. In the case where historical data is available and is in the format of `<state, action, action probability, reward>`, we can warm start by learning the bandit model offline. Otherwise, we can initiate a random bandit model.  Let's generate a batch of randomly selected samples with size `batch_size`.

# %% [markdown]
# # Load Warm Start Data from Local Disk

# %%
# batch_size = 10

# generated_sample_warm_start_data_buffer = generate_sample_warm_start_data(data='./data/historical_reviews_and_star_ratings.csv',
#                                                                           batch_size=batch_size)
# print(generated_sample_warm_start_data_buffer)

# %% [markdown]
# # Ingest Warm Start Data (into S3)
#
# During ingestion, we split the batch into train and validation sets using the parameter `ratio`.  For example, if `ratio=0.90`, then 90% is used for training and 10% for validation.

# %%
# bandits_experiment.ingest_joined_data(generated_sample_warm_start_data_buffer,
#                                       ratio=0.9)

# %%
# print('Ingested warm start data here\n{}'.format(bandits_experiment.last_joined_job_train_data))

# %%
# !aws s3 ls --recursive s3://sagemaker-us-east-1-835319576252/bandits-1597538280/joined_data/bandits-1597538280-join-job-id-1597538297/train
# !aws s3 cp s3://$bucket/bandits-1597538280/joined_data/bandits-1597538280-join-job-id-1597538297/train/local-joined-data-1597538298.csv .

# %%
# bandits_experiment._jsonify()

# %%
# !cat ./local-joined-data-1597538298.csv

# %%
#print(bandits_experiment.last_joined_job_train_data)

# %%
bandits_experiment.initialize_first_model() # input_data_s3_prefix=bandits_experiment.last_joined_job_train_data)
# Out:
# INFO:orchestrator:Next Model name would be bandits-1597616270-model-id-1597616291
# INFO:orchestrator:Start training job for model 'bandits-1597616270-model-id-1597616291''
# INFO:orchestrator:Training job will be executed in 'local' mode
# WARNING:sagemaker.estimator:Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# Creating tmpagbc2cxt_algo-1-8d3b6_1 ...
# Attaching to tmpagbc2cxt_algo-1-8d3b6_12mdone
# algo-1-8d3b6_1  | 2020-08-16 22:18:13,548 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-8d3b6_1  | 2020-08-16 22:18:13,560 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-8d3b6_1  | 2020-08-16 22:18:13,572 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-8d3b6_1  | 2020-08-16 22:18:13,581 sagemaker-containers INFO     Invoking user script
# algo-1-8d3b6_1  |
# algo-1-8d3b6_1  | Training Env:
# algo-1-8d3b6_1  |
# algo-1-8d3b6_1  | {
# algo-1-8d3b6_1  |     "additional_framework_parameters": {
# algo-1-8d3b6_1  |         "sagemaker_estimator": "RLEstimator"
# algo-1-8d3b6_1  |     },
# algo-1-8d3b6_1  |     "channel_input_dirs": {},
# algo-1-8d3b6_1  |     "current_host": "algo-1-8d3b6",
# algo-1-8d3b6_1  |     "framework_module": null,
# algo-1-8d3b6_1  |     "hosts": [
# algo-1-8d3b6_1  |         "algo-1-8d3b6"
# algo-1-8d3b6_1  |     ],
# algo-1-8d3b6_1  |     "hyperparameters": {
# algo-1-8d3b6_1  |         "exploration_policy": "egreedy",
# algo-1-8d3b6_1  |         "epsilon": 0.001,
# algo-1-8d3b6_1  |         "num_policies": 3,
# algo-1-8d3b6_1  |         "num_arms": 2,
# algo-1-8d3b6_1  |         "cfa_type": "dr"
# algo-1-8d3b6_1  |     },
# algo-1-8d3b6_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-8d3b6_1  |     "input_data_config": {},
# algo-1-8d3b6_1  |     "input_dir": "/opt/ml/input",
# algo-1-8d3b6_1  |     "is_master": true,
# algo-1-8d3b6_1  |     "job_name": "bandits-1597616270-model-id-1597616291",
# algo-1-8d3b6_1  |     "log_level": 20,
# algo-1-8d3b6_1  |     "master_hostname": "algo-1-8d3b6",
# algo-1-8d3b6_1  |     "model_dir": "/opt/ml/model",
# algo-1-8d3b6_1  |     "module_dir": "s3://sagemaker-us-east-1-835319576252/bandits-1597616270/training_jobs/bandits-1597616270-model-id-1597616291/source/sourcedir.tar.gz",
# algo-1-8d3b6_1  |     "module_name": "train-vw",
# algo-1-8d3b6_1  |     "network_interface_name": "eth0",
# algo-1-8d3b6_1  |     "num_cpus": 8,
# algo-1-8d3b6_1  |     "num_gpus": 0,
# algo-1-8d3b6_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-8d3b6_1  |     "output_dir": "/opt/ml/output",
# algo-1-8d3b6_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-1-8d3b6_1  |     "resource_config": {
# algo-1-8d3b6_1  |         "current_host": "algo-1-8d3b6",
# algo-1-8d3b6_1  |         "hosts": [
# algo-1-8d3b6_1  |             "algo-1-8d3b6"
# algo-1-8d3b6_1  |         ]
# algo-1-8d3b6_1  |     },
# algo-1-8d3b6_1  |     "user_entry_point": "train-vw.py"
# algo-1-8d3b6_1  | }
# algo-1-8d3b6_1  |
# algo-1-8d3b6_1  | Environment variables:
# algo-1-8d3b6_1  |
# algo-1-8d3b6_1  | SM_HOSTS=["algo-1-8d3b6"]
# algo-1-8d3b6_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-1-8d3b6_1  | SM_HPS={"cfa_type":"dr","epsilon":0.001,"exploration_policy":"egreedy","num_arms":2,"num_policies":3}
# algo-1-8d3b6_1  | SM_USER_ENTRY_POINT=train-vw.py
# algo-1-8d3b6_1  | SM_FRAMEWORK_PARAMS={"sagemaker_estimator":"RLEstimator"}
# algo-1-8d3b6_1  | SM_RESOURCE_CONFIG={"current_host":"algo-1-8d3b6","hosts":["algo-1-8d3b6"]}
# algo-1-8d3b6_1  | SM_INPUT_DATA_CONFIG={}
# algo-1-8d3b6_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-8d3b6_1  | SM_CHANNELS=[]
# algo-1-8d3b6_1  | SM_CURRENT_HOST=algo-1-8d3b6
# algo-1-8d3b6_1  | SM_MODULE_NAME=train-vw
# algo-1-8d3b6_1  | SM_LOG_LEVEL=20
# algo-1-8d3b6_1  | SM_FRAMEWORK_MODULE=
# algo-1-8d3b6_1  | SM_INPUT_DIR=/opt/ml/input
# algo-1-8d3b6_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-8d3b6_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-8d3b6_1  | SM_NUM_CPUS=8
# algo-1-8d3b6_1  | SM_NUM_GPUS=0
# algo-1-8d3b6_1  | SM_MODEL_DIR=/opt/ml/model
# algo-1-8d3b6_1  | SM_MODULE_DIR=s3://sagemaker-us-east-1-835319576252/bandits-1597616270/training_jobs/bandits-1597616270-model-id-1597616291/source/sourcedir.tar.gz
# algo-1-8d3b6_1  | SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_estimator":"RLEstimator"},"channel_input_dirs":{},"current_host":"algo-1-8d3b6","framework_module":null,"hosts":["algo-1-8d3b6"],"hyperparameters":{"cfa_type":"dr","epsilon":0.001,"exploration_policy":"egreedy","num_arms":2,"num_policies":3},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"bandits-1597616270-model-id-1597616291","log_level":20,"master_hostname":"algo-1-8d3b6","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-835319576252/bandits-1597616270/training_jobs/bandits-1597616270-model-id-1597616291/source/sourcedir.tar.gz","module_name":"train-vw","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-8d3b6","hosts":["algo-1-8d3b6"]},"user_entry_point":"train-vw.py"}
# algo-1-8d3b6_1  | SM_USER_ARGS=["--cfa_type","dr","--epsilon","0.001","--exploration_policy","egreedy","--num_arms","2","--num_policies","3"]
# algo-1-8d3b6_1  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# algo-1-8d3b6_1  | SM_HP_EXPLORATION_POLICY=egreedy
# algo-1-8d3b6_1  | SM_HP_EPSILON=0.001
# algo-1-8d3b6_1  | SM_HP_NUM_POLICIES=3
# algo-1-8d3b6_1  | SM_HP_NUM_ARMS=2
# algo-1-8d3b6_1  | SM_HP_CFA_TYPE=dr
# algo-1-8d3b6_1  | PYTHONPATH=/opt/ml/code:/usr/local/bin:/vowpal_wabbit/python:/vowpal_wabbit/build/python:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# algo-1-8d3b6_1  |
# algo-1-8d3b6_1  | Invoking script with the following command:
# algo-1-8d3b6_1  |
# algo-1-8d3b6_1  | /usr/bin/python train-vw.py --cfa_type dr --epsilon 0.001 --exploration_policy egreedy --num_arms 2 --num_policies 3
# algo-1-8d3b6_1  |
# algo-1-8d3b6_1  |
# algo-1-8d3b6_1  | INFO:root:channels []
# algo-1-8d3b6_1  | INFO:root:hps: {'cfa_type': 'dr', 'epsilon': 0.001, 'exploration_policy': 'egreedy', 'num_arms': 2, 'num_policies': 3}
# algo-1-8d3b6_1  | INFO:root:No training data found. Saving a randomly initialized model!
# algo-1-8d3b6_1  | INFO:VW CLI:creating an instance of VWModel
# algo-1-8d3b6_1  | INFO:VW CLI:successfully created VWModel
# algo-1-8d3b6_1  | INFO:VW CLI:command: ['vw', '--cb_explore', '2', '--epsilon', '0.001', '-f', '/opt/ml/model/vw.model', '-p', '/dev/stdout']
# algo-1-8d3b6_1  | INFO:VW CLI:Started VW process!
# algo-1-8d3b6_1  | 2020-08-16 22:18:14,017 sagemaker-containers INFO     Reporting training SUCCESS
# WARNING:sagemaker.local.image:Failed to delete: /tmp/tmpagbc2cxt/algo-1-8d3b6 Please remove it manually.
# tmpagbc2cxt_algo-1-8d3b6_1 exited with code 0
# Aborting on container exit...
# ===== Job Complete =====

# %% [markdown]
# # Check Experiment State
# `training_state`: `TRAINED`
#
# Remember the `last_trained_model_id`.

# %%
bandits_experiment._jsonify()
# Out:
# {'experiment_id': 'bandits-1597616270',
#  'training_workflow_metadata': {'last_trained_model_id': 'bandits-1597616270-model-id-1597616291',
#   'next_model_to_train_id': None,
#   'training_state': <TrainingState.TRAINED: 'TRAINED'>},
#  'hosting_workflow_metadata': {'last_hosted_model_id': None,
#   'hosting_endpoint': None,
#   'hosting_state': None,
#   'next_model_to_host_id': None},
#  'joining_workflow_metadata': {'joining_state': None,
#   'next_join_job_id': None,
#   'last_joined_job_id': None},
#  'evaluation_workflow_metadata': {'evaluation_state': None,
#   'last_evaluation_job_id': None,
#   'next_evaluation_job_id': None}}

# %% [markdown]
# # Evaluate current model against historical model
#
# After every training cycle, we evaluate if the newly trained model is better than the one currently deployed. Using the evaluation dataset, we evaluate how the new model would perform compared to the model that is currently deployed. SageMaker RL supports offline evaluation by performing counterfactual analysis (CFA). By default, we apply [**doubly robust (DR) estimation**](https://arxiv.org/pdf/1103.4601.pdf) method. The bandit policy tries to minimize the cost (1-reward) value in this case, so a smaller evaluation score indicates better policy performance.

# %%
# # evaluate the current model
# bandits_experiment.evaluate_model(
#     input_data_s3_prefix=bandits_experiment.last_joined_job_eval_data,
#     evaluate_model_id=bandits_experiment.last_trained_model_id)

# eval_score_last_trained_model = bandits_experiment.get_eval_score(
#     evaluate_model_id=bandits_experiment.last_trained_model_id,
#     eval_data_path=bandits_experiment.last_joined_job_eval_data
# )

# %%
# # WHAT IS THIS
# print(bandits_experiment.last_joined_job_eval_data)

# %%
# # get baseline performance from the historical (warm start) data
# download_historical_data_from_s3(data_s3_prefix=bandits_experiment.last_joined_job_eval_data)
# baseline_score = evaluate_historical_data(data_file='statlog_warm_start.data')
# baseline_score

# %% [markdown]
# # Check Experiment State
# `TRAINED` => `EVALUATED`
#
# The model just trained appears in both `last_trained_model_id` and `last_evaluation_job_id`.

# %%
# bandits_experiment._jsonify()

# %% [markdown]
# # Deploy the Bandit Model

# %% [markdown]
# Once training and evaluation is done, we can deploy the model.

# %%
import boto3
account_id = boto3.client('sts').get_caller_identity().get('Account')
region = boto3.session.Session().region_name

# !$(aws ecr get-login --region $region --registry-ids $account_id --no-include-email)
# Out:
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded

# %%
# Check the model_id of the last model trained.
print('Deploying newly-trained bandit model: {}'.format(bandits_experiment.last_trained_model_id))
# Out:
# Deploying newly-trained bandit model: bandits-1597616270-model-id-1597616291

# %%
print('Deploying bandit model_id {}'.format(bandits_experiment.last_trained_model_id))

bandits_experiment.deploy_model(model_id=bandits_experiment.last_trained_model_id)
# Out:
# Deploying bandit model_id bandits-1597616270-model-id-1597616291
# INFO:orchestrator:Model 'bandits-1597616270-model-id-1597616291' is ready to deploy.
# WARNING:sagemaker:Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fb83d092828>: Failed to establish a new connection: [Errno 111] Connection refused',)': /ping
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fb83d092908>: Failed to establish a new connection: [Errno 111] Connection refused',)': /ping
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fb83d0925c0>: Failed to establish a new connection: [Errno 111] Connection refused',)': /ping
# Attaching to tmp6z5ug40e_algo-1-z1mdo_1
# algo-1-z1mdo_1  | 17:C 16 Aug 2020 22:18:34.721 # oO0OoO0OoO0Oo Redis is starting oO0OoO0OoO0Oo
# algo-1-z1mdo_1  | 17:C 16 Aug 2020 22:18:34.721 # Redis version=5.0.6, bits=64, commit=00000000, modified=0, pid=17, just started
# algo-1-z1mdo_1  | 17:C 16 Aug 2020 22:18:34.721 # Configuration loaded
# algo-1-z1mdo_1  | 17:M 16 Aug 2020 22:18:34.722 # You requested maxclients of 10000 requiring at least 10032 max file descriptors.
# algo-1-z1mdo_1  | 17:M 16 Aug 2020 22:18:34.722 # Server can't set maximum open files to 10032 because of OS error: Operation not permitted.
# algo-1-z1mdo_1  | 17:M 16 Aug 2020 22:18:34.722 # Current maximum open files is 4096. maxclients has been reduced to 4064 to compensate for low ulimit. If you need higher maxclients increase 'ulimit -n'.
# algo-1-z1mdo_1  | 17:M 16 Aug 2020 22:18:34.723 # WARNING: The TCP backlog setting of 511 cannot be enforced because /proc/sys/net/core/somaxconn is set to the lower value of 128.
# algo-1-z1mdo_1  | 17:M 16 Aug 2020 22:18:34.723 # Server initialized
# algo-1-z1mdo_1  | 17:M 16 Aug 2020 22:18:34.723 # WARNING overcommit_memory is set to 0! Background save may fail under low memory condition. To fix this issue add 'vm.overcommit_memory = 1' to /etc/sysctl.conf and then reboot or run the command 'sysctl vm.overcommit_memory=1' for this to take effect.
# algo-1-z1mdo_1  | 17:M 16 Aug 2020 22:18:34.723 # WARNING you have Transparent Huge Pages (THP) support enabled in your kernel. This will create latency and memory usage issues with Redis. To fix this issue run the command 'echo never > /sys/kernel/mm/transparent_hugepage/enabled' as root, and add it to your /etc/rc.local in order to retain the setting after a reboot. Redis must be restarted after THP is disabled.
# algo-1-z1mdo_1  | [08/16/2020 22:18:37 INFO 140087938000640] Redis server started successfully!
# algo-1-z1mdo_1  | [08/16/2020 22:18:37 INFO 140087938000640] Starting gunicorn...
# algo-1-z1mdo_1  | [08/16/2020 22:18:37 INFO 140087938000640] Started server process with PID: 23
# algo-1-z1mdo_1  | [08/16/2020 22:18:37 INFO 140087938000640] Started gunicorn.
# algo-1-z1mdo_1  | [08/16/2020 22:18:37 WARNING 140087938000640] Loggers have already been setup.
# algo-1-z1mdo_1  | [08/16/2020 22:18:37 INFO 140087938000640 integration.py:348] worker started
# algo-1-z1mdo_1  | [08/16/2020 22:18:37 INFO 140087938000640] loading entry points
# algo-1-z1mdo_1  | [08/16/2020 22:18:37 INFO 140087938000640] Number of server workers: 8
# algo-1-z1mdo_1  | [2020-08-16 22:18:37 +0000] [23] [INFO] Starting gunicorn 19.9.0
# algo-1-z1mdo_1  | [2020-08-16 22:18:37 +0000] [23] [INFO] Listening at: http://0.0.0.0:8080 (23)
# algo-1-z1mdo_1  | [2020-08-16 22:18:37 +0000] [23] [INFO] Using worker: sync
# algo-1-z1mdo_1  | [2020-08-16 22:18:37 +0000] [24] [INFO] Booting worker with pid: 24
# algo-1-z1mdo_1  | [08/16/2020 22:18:37 INFO 140087938000640] creating an instance of VWModel
# algo-1-z1mdo_1  | [08/16/2020 22:18:37 INFO 140087938000640] successfully created VWModel
# algo-1-z1mdo_1  | [08/16/2020 22:18:37 INFO 140087938000640] command: ['vw', '--cb_explore', '2', '--epsilon', '0.001', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/model/vw.model']
# algo-1-z1mdo_1  | [08/16/2020 22:18:37 INFO 140087938000640] Loaded weights successfully for Model ID:bandits-1597616270-model-id-1597616291
# algo-1-z1mdo_1  | [08/16/2020 22:18:37 INFO 140087938000640] Started VW process!
# algo-1-z1mdo_1  | [2020-08-16 22:18:37 +0000] [27] [INFO] Booting worker with pid: 27
# algo-1-z1mdo_1  | [08/16/2020 22:18:37 INFO 140087938000640] creating an instance of VWModel
# algo-1-z1mdo_1  | [08/16/2020 22:18:37 INFO 140087938000640] successfully created VWModel
# algo-1-z1mdo_1  | [08/16/2020 22:18:37 INFO 140087938000640] command: ['vw', '--cb_explore', '2', '--epsilon', '0.001', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/model/vw.model']
# algo-1-z1mdo_1  | [08/16/2020 22:18:37 INFO 140087938000640] Loaded weights successfully for Model ID:bandits-1597616270-model-id-1597616291
# algo-1-z1mdo_1  | [08/16/2020 22:18:37 INFO 140087938000640] Started VW process!
# algo-1-z1mdo_1  | [2020-08-16 22:18:38 +0000] [30] [INFO] Booting worker with pid: 30
# algo-1-z1mdo_1  | [08/16/2020 22:18:38 INFO 140087938000640] creating an instance of VWModel
# algo-1-z1mdo_1  | [08/16/2020 22:18:38 INFO 140087938000640] successfully created VWModel
# algo-1-z1mdo_1  | [08/16/2020 22:18:38 INFO 140087938000640] command: ['vw', '--cb_explore', '2', '--epsilon', '0.001', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/model/vw.model']
# algo-1-z1mdo_1  | [08/16/2020 22:18:38 INFO 140087938000640] Loaded weights successfully for Model ID:bandits-1597616270-model-id-1597616291
# algo-1-z1mdo_1  | [08/16/2020 22:18:38 INFO 140087938000640] Started VW process!
# !algo-1-z1mdo_1  | [2020-08-16 22:18:38 +0000] [33] [INFO] Booting worker with pid: 33
# algo-1-z1mdo_1  | [08/16/2020 22:18:38 INFO 140087938000640] creating an instance of VWModel
# algo-1-z1mdo_1  | [08/16/2020 22:18:38 INFO 140087938000640] successfully created VWModel
# algo-1-z1mdo_1  | [08/16/2020 22:18:38 INFO 140087938000640] command: ['vw', '--cb_explore', '2', '--epsilon', '0.001', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/model/vw.model']
# algo-1-z1mdo_1  | [08/16/2020 22:18:38 INFO 140087938000640] Loaded weights successfully for Model ID:bandits-1597616270-model-id-1597616291
# algo-1-z1mdo_1  | [08/16/2020 22:18:38 INFO 140087938000640] Started VW process!

# %% [markdown]
# # Check Experiment State
# `hosting_state`: `DEPLOYED`
#
# The `last_trained_model_id` and `last_hosted_model_id` are now the same as we just deployed the bandit model.

# %%
bandits_experiment._jsonify()
# Out:
# {'experiment_id': 'bandits-1597616270',
#  'training_workflow_metadata': {'next_model_to_train_id': None,
#   'last_trained_model_id': 'bandits-1597616270-model-id-1597616291',
#   'training_state': 'TRAINED'},
#  'hosting_workflow_metadata': {'hosting_endpoint': 'local:arn-does-not-matter',
#   'hosting_state': <HostingState.DEPLOYED: 'DEPLOYED'>,
#   'last_hosted_model_id': 'bandits-1597616270-model-id-1597616291',
#   'next_model_to_host_id': None},
#  'joining_workflow_metadata': {'joining_state': None,
#   'next_join_job_id': None,
#   'last_joined_job_id': None},
#  'evaluation_workflow_metadata': {'evaluation_state': None,
#   'last_evaluation_job_id': None,
#   'next_evaluation_job_id': None}}

# %% [markdown]
# # Initialize the Client Application

# %% [markdown]
# Now that the last trained model is hosted, client application can send out the state, hit the endpoint, and receive the recommended action. There are 2 models that we want to test:  model1 and model2.  This translates to 2 actions that the bandit model will predict.

# %%
# %store -r step_functions_pipeline_endpoint_name

# %%
print(step_functions_pipeline_endpoint_name)
# Out:
# training-pipeline-2020-08-14-14-25-27

# %%
client = boto3.client('sagemaker')
waiter = client.get_waiter('endpoint_in_service')
waiter.wait(EndpointName=step_functions_pipeline_endpoint_name)

# %%
import json
from sagemaker.tensorflow.serving import Predictor

model1 = Predictor(endpoint_name=step_functions_pipeline_endpoint_name,
                   sagemaker_session=sess,
                   content_type='application/json',
                   model_name='saved_model',
                   model_version=0)

# %%
reviews = ["This is not good."]

model1_predicted_classes = model1.predict(reviews)

for predicted_class, review in zip(model1_predicted_classes, reviews):
    print('[Predicted Star Rating: {}]'.format(predicted_class), review)
# Out:
# [Predicted Star Rating: 2] This is not good.

# %%
# %store -r step_functions_pipeline_endpoint_name_random

# %%
print(step_functions_pipeline_endpoint_name_random)
# Out:
# training-pipeline-2020-08-15-05-04-23

# %%
client = boto3.client('sagemaker')
waiter = client.get_waiter('endpoint_in_service')
waiter.wait(EndpointName=step_functions_pipeline_endpoint_name_random)

# %%
import json
from sagemaker.tensorflow.serving import Predictor

model2 = Predictor(endpoint_name=step_functions_pipeline_endpoint_name_random,
                   sagemaker_session=sess,
                   content_type='application/json',
                   model_name='saved_model',
                   model_version=0)

# %%
reviews = ["This is not good."]

model2_predicted_classes = model2.predict(reviews)

for predicted_class, review in zip(model2_predicted_classes, reviews):
    print('[Predicted Star Rating: {}]'.format(predicted_class), review)
# Out:
# [Predicted Star Rating: 1] This is not good.

# %%
import csv
import numpy as np

# Application simulation
class Simulation():
    def __init__(self, data, bandit_model, bert_model_map):
        self.bandit_model = bandit_model
        self.bert_model_map = bert_model_map
        
        self.num_actions = 2

        ############
        # TODO:  Factor this code out
#        data = pd.read_csv(data_file_path, header=0).to_numpy()
        df_reviews = pd.read_csv(data, 
                                 delimiter='\t', 
                                 quoting=csv.QUOTE_NONE,
                                 compression='gzip')
        df_scrubbed = df_reviews[['review_body', 'star_rating']].sample(n=100)
        df_scrubbed = df_scrubbed.reset_index()
        df_scrubbed.shape
        np_reviews = df_scrubbed.to_numpy()

        np_reviews = np.delete(np_reviews, 0, 1)
#        print('np_reviews {}'.format(np_reviews))
        
        # Last column is label, the rest are the features    
        contexts = np_reviews[:, :-1]
#        labels = data[:, -1].astype(int) - 1  # convert to 0 based index
        labels = np_reviews[:, -1] #.astype(int)

#        contexts, labels = remove_underrepresented_classes(contexts, labels)
#        self.contexts, self.labels, _ = create_bandit_contexts_and_labels(context, labels, self.num_actions)
        self.contexts = contexts
        self.labels = labels

        print(self.contexts)
        print(self.labels)        
        
        self.opt_rewards = [1]        
        self.rewards_buffer = []
        self.joined_data_buffer = []

#     def choose_random_context(self):
#         context_index = np.random.choice(self.contexts.shape[0])
#         context = self.contexts[context_index]
#         return context_index, context    
    
    def get_reward(self, 
                   context_index, 
                   action, 
                   event_id, 
                   bandit_model_id, 
                   action_prob, 
                   sample_prob, 
                   local_mode):
        print('context_index {}'.format(context_index))       
        context = self.contexts[context_index]
        print('context {}'.format(context))
        label = self.labels[context_index]
        print('label {}'.format(label))
        print('action {}'.format(action))
        print('event_id {}'.format(event_id))
        print('bandit_model_id {}'.format(bandit_model_id))
        print('action_prob {}'.format(action_prob))
        print('self.labels {}'.format(self.labels))
#        print('self.labels[context_index][action-1] {}'.format(self.labels[context_index][action-1]))
#        print('self.labels[context_index][action] {}'.format(self.labels[context_index][action]))
        
#        reward = 1 if self.labels[context_index][action-1] == 1 else 0

        # TODO:  Invoke bert model and assign reward

#        if self.labels[context_index]

        bert_model = self.bert_model_map[action]
        print(type(context))
        import base64
        context_as_str = base64.binascii.b2a_base64(context).decode("ascii")
        print(type(context_as_str))
        bert_predicted_class = bert_model.predict([context_as_str])
        print('bert_predicted_class {}'.format(bert_predicted_class))
        
        if bert_predicted_class[0] == label:
            reward = 1
        else:
            reward = -1
        print('reward {}'.format(reward))

        if local_mode:
            json_blob = {"reward": reward,
                         "event_id": event_id,
                         "action": action,
                         "action_prob": action_prob,
                         "model_id": bandit_model_id,
                         "observation": self.contexts[context_index], #.tolist(),
                         "sample_prob": sample_prob}
            self.joined_data_buffer.append(json_blob)
        else:
            json_blob = {"reward": reward, "event_id": event_id}
            self.rewards_buffer.append(json_blob)
        
        return reward
    
    def clear_buffer(self):
        self.rewards_buffer.clear()
        self.joined_data_buffer.clear()

# %%
bandit_model = bandits_experiment.predictor

sim_app = Simulation(data='./data/amazon_reviews_us_Digital_Software_v1_00.tsv.gz',
                     bandit_model=bandit_model,
                     bert_model_map={
                                     1: model1,
                                     2: model2
                                    }
                    )
# Out:
# [['Would not take any emails I have so made one up and was the only way could get product to download. Not impressed.']
#  ['QuickBooks is the easy answer to your small business financial records.<br />Less time spend on keeping books allows more time to be spent taking care of<br />clients.  Growing the business has never been easier.']
#  ["I love Quicken because it organizes s much personal finance information.  Most accounts can be downloaded right into the program.  I gave 3 stars for this product because the business side is lacking.  It now allows you to see your dealings in an app on your smartphone but the program is very bare bones on the business side and not super user friendly.  It's not as close to QuickBoQuick books as I imagined it would be."]
#  ['This new version has a lot of the same as previous versions that can be printed as pre-made cards, banners, calendars, posters, etc. But, now every individual item must be downloaded and often times there are additional charges; $0.99 and up per item. Where before there were thousands of projects and clip art that were included with the software download. I was able to make what I wanted to make, a calendar with additional birthdates and pictures, it just took longer to find something that worked that did not have an additional charge attached to it. I am quite impressed with the updates of this new version in way of built-in page borders so your text or pictures did not shift off the page during printing; also that the text and pictures I add in a calendar, do not overlap the lines for that month! Much more user friendly.']
#  ["This years version is mostly trouble free - no crashes but if your are new to this product make sure you look at the forms as there can be incorrect entries from either the interview process or the easy step. Importing from Intuit's  Quicken product be very careful for schedule E,C when you print from quicken and you must verify the entries that import to Turbotax which loads different numbers. I eventually selected to enter myself from the quicken print copy. Still playing with the entries of business expenses as the interview and step by step placed incorrect entries in the form result was the same. It aggregated some of my expenses as other when there were actual lines the net effect was the same  but I was looking for accuracy.  I have been using this product for over a decade. Additional notes on TT -It has problems with K-1's - If you have values in lines 1,2,3 it says they are mutually exclusive. The work around is to enter the line 1 data as one K1 and line 2 as another k1,etc. Works out ok lists on schedule E and C correctly when you do this. TT needs to have a check box screen for the variations like do you have data in line 1,2,3  and than handle each one correctly. 1099-t does not ask about additional data to reconcile - it is one the form version . so if you have  no value in box 1 and have reconciliation data on the 1099-t enter on the form as the easy step does not ask."]
#  ['It was ok.']
#  ['I bought this program with some trepidation as previous tax software which I have used just were not fully applicable to our tax situation.  My husband is a pastor, and we can attest that this is the first software we have seen which is set up for the various issues clergy face.<br /><br />We found also that TurboTax is quite intuitive, helping us maximize our deductions, and saved us several hundred dollars over the tax preparation company we used last year.']
#  ['No easy way to get photos and videos out of this service.']
#  ["Used in the last few years and it was good software, however this year had nothing but trouble. I had a rental property that I sold in Jan. of 2014 and took a huge loss on the property.  Tax Act didn't even ask me anything about the sale price of the home.  I have to report the sale on schedule E, but the software does not help at all.<br /><br />Another issue was that I could not register with TaxACT so as to get my State Software to download. I tried numerous times to register, but it wouldn't let me.  I called tech support at TaxACT and they told me that the problem is that I bought the software from Amazon and not them.  I was told to get a refund from Amazon and purchase it from them.<br /><br />I did get a refund from Amazon, but chose to buy H&R Block Premium through Amazon instead because of the rental property sale that I had trouble with when using TaxACT Deluxe."]
#  ['Been using NIS for more than 6 years now.  No virus infection at all..']
#  ['I have used QUICKEN for 15 years. Over time it has gotten more difficult to use. For example, there should be a simple button for \\\\"Write Checks\\\\" since this happens all the time. Instead it is buried in a menu under \\\\"TOOLS\\\\" - not intuitive. However, I have to have financial check writing and finance tracking software. I wish the developers would make improvements to simplify rather than complicate it\'s use for just writing checks and tracking spending.']
#  ['It is very useful and I recommend it.  I needed larger letters.']
#  ['Excellent.']
#  ["I've tried anti-virus products from Trend Micro, Norton, AVG, and McAfee, but Avast is my favorite yet. It does not hog up system resources as some of those other products do, so it never seems to slow down my PC or laptop. I also like how Avast seems to update its virus definitions on a daily basis. One of my friends who specializes in computer security said that he thinks Avast is the best product out there. I don't have all the tech knowledge that he does, but I'll take his word for it."]
#  ['I was told this could be used when you have a business, Schedule C.. Not true.  Turbotax is a loser for 2014.  Requesting refund.']
#  ["An update on this review. Amazon Executive Customer service elevated the priority of this issue, and it was completely resolved.  Thus, I am able to obtain the selected licensed program, and the Amazon downloader functions correctly on OS X Snow Leopard.  Apple should learn from Amazon's great response how to create customer delight!    Original review (just for reference):       The latest downloader from Amazon will not launch under Snow Leopard, v10.6.8!  The help pages provided by Amazon lead to a dead-end.  Someone from Amazon needs to fix this situation immediately.  Thus, when you purchase the program, you cannot obtain it via the download.  It would certainly help if someone actually tested the software before deploying it.  Last year's downloader launches, but Amazon has changed the gateway, causing it to refer you to this year's version for 2013, which doesn't work either!  Such poor quality from an American icon, Amazon.com!"]
#  ['Software provides what I wanted.<br /><br />The dowmload process, however, was a major, major undertaking. It required several calls to Amazon, to Microsoft and more to get a real person to assist in the download. It was a tiresome process.  It was far from being user friendly']
#  ['I never could figure out how to file my estimate payments electronically.']
#  ["Well...I presume this product to be Microsoft's revenge.  Word is a shell of the PC version, and the only reason this expensive little box gets 2 stars is Outlook.  It should be noted, however, that Outlook doesn't measure up to Windows compatible versions either.  If you can get by with native iOS tools, do it."]
#  ["I've had mixed experiences with Intuit products in general. Many of the times I experience issues with them locking up, not saving, corrupting files, and so forth. With this product, I did not experience that.<br /><br />I purchased this software for a couple business returns I needed to file and was surprised at how easy it was to navigate through the various sections that needed to be filled out. The results were good and the return printed appropriately. The eFile worked well, too, and the return was accepted by the IRS within 8 hours.<br /><br />I plan on purchasing the product again for my 2014 business returns. I wish they would include the personal 1040 return preparation feature with this, especially for the money you're paying. Unfortunately, you have to buy that separately, AND pay additional money to be able to prepare a state tax return with your federal.<br /><br />All in all, I'd give the software a 4-star. There are improvements that could be made; there are features that should be added; but as it is, it does what it's designed to do and it doesn't take very long to get the hang of it, get your information entered, and get the returns submitted."]
#  ['The software was received by download. H&R Block tax software was chosen because it handles our two state returns properly. TurboTax never properly attributed the tax we paid in another state and in the next year, even after I informed them, they did not correct the problem.']
#  ["I've used Norton for years. I've tried others but never had the same results. Good price for 1/3 as I can use them as needed."]
#  ["Ever since my husband and I found avast! antivirus a few years ago, we have not used anything  else. Our computers have been clean since the first day and we have 3 teenage boys. We have used the free and the pay and are happy with both. We won't use anything else."]
#  ['Great product.  Easy to use.  Wonderful for demos and instruction!']
#  ['Great stuff!!!!!']
#  ["Every couple of years Intuit makes me buy a newer copy of Quickbooks. They do this by taking away functions of the program that are crucial until you purchase a newer version of the software. (Emailing especially).<br />This new version has crashed every time I've tried to use it.  It doesn't recognize my imported templates. If I send an email it shuts down. Every year they make dramatic changes to the program and you have to relearn how to use it every time.<br />For the $160-$399 price tag on these software programs they should be flawless. ."]
#  ['This company needs to upgrade their customer support, which has been unable to resolve my issues, so the upgrade is for naught at this juncture.']
#  ["The norton 360 from amazon was a great price but it sure slows down the computer.  After turning on the computer it takes a long time before you can do anything that doesn't freeze the screen , when you go onto the internet or you just want to play one of your own games.  It does find problems but they aren't very easy to fix."]
#  ['Easy, fast, and accurate.']
#  ['I purchased this product almost a month ago.  I have had a support ticket open since the day I bought it and is still unresolved!  I cannot use the mobile app and it will not connect to my bank for automatic updates.  I get \\\\"Unexpected Error, Not your fault\\\\".  I have been told by customer service that they are working on it, but the issue on their help webpage says it has been going on since April of 2013!  I would never have bought this if the mobile part was not functional.  Horrible customer service, Intuit.']
#  ['Free download for you to edit documents.  Better than spending a lot on Office or Word.  Not too fancy, but gets a project done']
#  ['Its work']
#  ['I have been using Quicken for over 15 years very successfully.  This version crashes and crashes and wipes out files.  Very frustrating.']
#  ["this is a good open office , and its free need I say more &#34; if  your looking for a good free word processor this one for you'"]
#  ['Outlook 2013 is a disaster - very UN-user friendly.  Spend hours trying to figure out.  Still can\'t bring up any of my contact lists to choose from.  You first have to enter a name before it will bring up what it calls \\\\"frequent contacts\\\\" which is an ever-changing assortment of names based upon previous e-mail sent.  Won\'t allow you to do \\\\"bcc\\\\" until you have entered a name in the \\\\"to\\\\" field, etc., etc., etc. Commands are hidden behind the \'ribbon\', etc.  I\'m moving to another service ASAP to get my e-mail life back!']
#  ["I now run several businesses in the UK. I use an accountant I have known for many years and have always been happy with their service. I have had very little need for such software, especially given the price of accounting software packages. I am not a computer whiz and sometimes find complicated Microsoft software packages difficult to use.<br /><br />I reviewed Quickbooks Premier 2012 previously and my review is virtually identical to that one. I received this software free of charge via the Amazon Vine programme. In truth I would not have bought such software, given my relationship with my accountant. I therefore used this opportunity to try the software without any risk or guilt. As this is the second tine of using I am getting used to how the programme works and the ultimate ease of use.<br /><br />It was simplicity itself to install. The software gives you a comprehensive and easy to use accounting package. Whilst my area of business pertains to the service sector and does require the holding of stock, the software can easily handle business situations where stock control is necessary. It can easily track sales, expenses and profits and can create professional looking invoices using PDF's for emails. It can automatically calculate VAT and creates an Efile so you can send it directly to HMRC. It works with all Office programmes so there is great compatibility, so allowing greater ease of use. It also allows you to create budgets and cash flow projections. In short this software can handle virtually anything a small to medium sized business can throw at it. It also includes payroll software free for 12 months, which allows you to calculate wages, NI, Tax for your employees.<br /><br />A final note on this particular package, there is a difference between Quickbooks Pro 2013 and Premier 2013 software. The Premier software contains additional Time Saving Tools such as, the ability to create budgets and cash flow forecasts, it allows you to create back orders and so automatically set stock aside for order fulfillment, track unbilled expenses and allow you to set different prices on the same item depending upon client or job. All of these time saving options work in the same intuitive way as the rest of the package.<br /><br />Whilst I am a stick in the mud and like the reassurance that my accountant brings, this software is the next best thing. It is easy to use and does virtually everything you will require. A great product at a great price, compared to other accounting software packages."]
#  ["I not only have PC MATIC  but I also have VIPRE voted by PC Mag as one of the top 5 best Antivirus programs out there. I was comparing both of them and have to say that PC MATIC not only does just as good a job as VIPRE but PC MATIC has several other benefits that VIPRE does not have, so for the money and what you get with PC MATIC it's a No-Brainer for me I'm renewing my PC MATIC subscription and letting VIPRE expire."]
#  ['I needed a full service solution and needed better support options for obtaining my data, so I switched from Invoice2Go! to QB online... been using it now for just over 3 months and very happy.']
#  ['Great software and have no issues from the installation or updates. I left the software scan my drives at least once or twice a month.']
#  ["We use this software every year and it does a good job of guiding you through the process (NY Fed & State). We are hesitant to recommend for doing taxes when there are non-basic (house sale, death, inheritance, etc... ) tax issues as we haven't done anything like that. I'm not saying it wouldn't guide you through it, it's just we never have used it for that. I probably would want to sit down with a good tax preparer and make sure those are covered completely.<br /><br />I did have an experience with helping a family member recently who had her tax preparer make a 10K mistake and it is costing her + penalties. For that, I can say we have NOT had any issues with the software making any mistakes on our returns. Just sometimes a little buggy but they do send out patches and updates."]
#  ['Beware of doing business with AVG.  Hidden in the fine print is that you are agreeing to AUTO UPDATE FOR ANNUAL CHARGES EVERY YEAR WITHOUT THEIR NOTIFYING YOU ! ! !  Do not believe that their Anti Virus is any good.  Why should I pay for a NONE WORKING ANTI VIRUS SOFTWARE  when I can get it for free and have it not work ! ! !  Contrary to the STAR RATING its not worth even one star ! ! !']
#  ["I used  this software 1 time.<br />One month later, I had to use it again. AfterIi had done 5 or 6 pages, I decided to continue the next day. The next day,the program would not open. Instead of opening in 2013, the program would open in Word 2007. So I called Amazon. Amazon suggested that I called Microsoft. I spend 2 hours on the phone with Microsoft, first with a representative, next with a Supervisor and third with a technician.<br />They told me to enter a key, I did so three times to no avail. The technician didn't know if he was coming or going. He tried different things that did not work. There came a moment when he found no better excuse than to put the blame on my computer saying that my computer might have a virus. I know for sure that my computers are all virus free and told him so. Finally the alleged technician asked me if I would allow him to control the computer remotely. He inspected my computer for about 20 minutes, found nothing wrong, and nothing he could do to help me. In the end he told me he was going to send me a large file because he thought that MIGHT solve the problem. The file took some 45 minutes to download and after that I could open the program and finish my job.<br />That was the LAST time I could use the program. The next time I tried to use it, I wrote one or two paragraphs but when I tried to save and close the document, the document &#34;could not be saved&#34;. Instead, the two paragraphs that I had written were magically transferred to Word 2007 and I was, once again, asked for a product Key.<br />I tried to copy and paste from word 2007 to another program that I often use. But, alas, word 2007 did not allow me to &#34;copy&#34; anything either.<br /><br />I decided to call Amazon. Amazon did not help at all and the person I talked to tried to manipulate me and make me feel stupid saying that I am the ONLY person that has ever had problems with this program.<br /><br />All in all, the program could never be used again. I asked for a refund, but both Microsoft and Amazon (shame on them!) refused to give me one. Microsoft put the blame on Amazon and Amazon said the product was not theirs, so they could not grant a refund.<br />I have been buying from Amazon on a monthly basis for over 14 years. I have been refunded hundreds of times for products that were not &#34;theirs&#34;. What does &#34;theirs&#34; mean in this case? Nothing but a very convenient term to rip people off.<br /><br />Conclusion: I will never us another Microsoft program and I will never download anything else from Amazon.com<br /><br />NOTE: I suggest downloading a very good FREE program, very similar to Microsoft Word but without the bugs: AbiWord 2.8"]
#  ["This software no longer provides Schedule C, and there are problems calculating the housing allowance. I've used it several years in a row with no problem, until this year. No longer recommended."]
#  ['A+']
#  ["I would recommend this product to anyone who wants to keep their personal computer running virus free - or for just cleaning off whatever viruses are bogging it down.  It is easy to upload, and easy to use.  It's actually the only antivirus I have on my computer and I've never had a problem.  I've even used it on my kids computers to clean off viruses other antivirus software leave behind.<br />I feel it's as good as anything out there - and it's free!  What more can you want?"]
#  ["I bought this primarily to track expenses now that I'm entering retirement.  I've been using Mint.com and PersonalCapital.com (free, online tools) to do this - and they work great, but I bought Quicken as I'm a little uncomfortable having all my financial information on someone's website.  Anyway, both Mint and PersonalCapital report all my account balances accurately while Quicken 2014 does not.  The online help system and forum are useless.  I believe I've wasted my money on this product.  Quicken was a favorite of mine in previous years for balancing my checkbook, but Intuit appears to have broken Quicken, with the online functionality.  (Actually Mint.com has been recently purchased by Intuit - I hope they don't break that.)"]
#  ['Would be kind of nice IF I COULD ACTUALLY GET IT TO DOWNLOAD! OR EVEN GET ASSISTANCE FROM ANYONE at MICROSOFT to Correct this $100 Purchase for FREE MONEY TO MICROSOFT! Such a Joke!  Half a mind to report to BBB and any other format I can.  Will be reversing this credit card purchase!']
#  ['Love this software. So easy to use and really does not take that long if you have all your forms ready to go. Will definitely purchase again next year.']
#  ["I. Hate. Quicken.<br /><br />This is the single most annoying, frustrating software package that I have ever used. It takes FOREVER to download new transactions, update stock prices, and update Quicken Mobile. The desktop software is prone to skip a few transactions when downloading, so your balances never match online balances and you have to find missing transactions manually. Quicken will sometimes make errors in the transactions that can be maddening to try and fix. I have rebuilt my files several times and reinstalled Quicken twice in two months. ALWAYS MAKE A BACKUP OF YOUR FILE.<br /><br />Quicken Mobile is a copy of Mint.com's mobile app, but far more useless and prone to crash. You can't do anything worthwhile on the mobile app except check balances that have been uploaded by the desktop software, because the mobile app won't pull information from banks by itself.<br /><br />If there was another alternative to personal financial software that was more powerful and useful than Mint.com, I would use it in a heartbeat, even if I lost all of my prior data. Why did you have to leave me, Microsoft Money?<br /><br />I. Hate. Quicken."]
#  ['il kie it']
#  ["Keep in mind I am not well versed in other artistic programs like Photoshop and the like, but I am however, pretty well in touch with the Sketchbook programs. This Chchristmas I received a Intuos Pen and Touch tablet that came with a free download for Sketchbook Autodesk Express and was elated, at first. However, as I began using it I realized it was missing some of the key features I had grown to love, especially in the layer section. It was limited to five layers maximum, as well as no merging, no transparent lock, and no other features like overlay or screen. I was a bit put off by that considering even my little cheap Sketchbook mobile app on my Kindle Fire has those features. Regardless I set off in search of better and found this, keeping in mind that at the time the price of this was only 19.99, 66% off it's usual full price, I loved it.<br /><br />It has all the features and more I can ask for. All the paintbrushes and copics look exactly like the real deal despite it being digital and I had all the layer features and more. I really enjoy it, and though I'm not a very skilled artist, I believe it will help me hone my skills very well. :D"]
#  ['Been using Quicken forever. This upgrade is nice and easy to use.']
#  ["I love Norton Internet Security - it seems to do a good job protecting me on the Internet. My complaint is this - I had 35 days remaining on my subscription.  In the past when I purchased a renewal Norton added the new subscription onto the old remaining time. This time they blew away my remaining 35 days and only gave me a year.  Their web site say this happens when you don't go through the programs renewal prompt's. I bought this through Amazon and was directed to the Norton site to download. So beware!  No one warned me of this! I would have waited 34 days before renewing!  UPDATE - I contacted Norton Support via online chat and they easily fixed my problem and gave me back the missing 35 days.  So I am happy - I really like Norton and have used it for so many years., I seem to have less virus problems than my friends who use other software.  No complaints - so I  changed my rating to 5 stars.  Thank you to Norton support for reading & acting on my review!"]
#  ['Only lasts for a month and constantly reminds you that it is going to expire.']
#  ['Great product.  I have been using the software for a dozen years and will continue using year after year.  I recommend using this product.']
#  ['I owned the 11 version and upgraded to get the new options. My creative photos are unlimited with Elements 12!']
#  ['I downloaded this and installed, tried to use it and it constantly locked up so I deleted it and bought something else that works great...total waste of my money']
#  ["The product worked fine, until I had re refresh my PC and re install.  When I attempted to re-install, the system no longer recognized m account...so I wasted my weekend trying to just get logged in.  Tech support and Customer service are outsourced and useless.  Save the headache of dealing with these guys...they don't deserve to be considered professional."]
#  ["This was recommended by my daughter's work place and internet security is very important for them so I know it must be a good product."]
#  ['have used HR Block for over 10 years.  Love it.']
#  ['Adobe photoshop elements 9 is a gr8 program to use for those who want to raise there fotos up another notch.']
#  ["This has nothing to do with the Access system, which i guess will be what it is.  But the seller, which is not Amazon, since it by passes Amazon's download system.  I hope it is not Microsoft either.  It is perhaps a service.  It has a lausy way to confirm who you are.<br />  ''Call us overprotective, but we need to verify that xxxxxxx is yours''<br />I received all the advertising and no confirmation email. Even after I pressed the ''resend email'' button several times, nothing.  Only advertising.  Very frustrating.<br /><br />Who is the pirate here.<br /><br />I will return it, or flush it down the cybernetic toilet, if Amazon does not take it back.  So sad"]
#  ["Been a quicken user since 1996 so I have a significant amount of history in this application..<br /><br />Last time I upgraded was to 2012. Tried upgrading to 2013 without a hitch. Data was converted to the new format..<br /><br />Unfortunately data entry is... Slow.. Horribly slow.. The application is not responsive at all.. Downloaded all of the patches.. Still do not notice a difference in performance..<br /><br />I'm currently running the windows version of Quicken on an I7-2600K desktop with 16 GB of Ram...<br /><br />So I really don't expect applications to run slow on my desktop.. Unfortunately Quicken 2013 performs like each transaction is a pain to record. Like it is searching for something.<br /><br />Application Prompts stay on the screen for extended periods, sometime requiring responses to be recorded multiple times.<br />The Reconcile Screen, works best when you use a mouse to mark transaction as reconciled. If I use the keyboard and space bar, the application response slows considerably.. Counter intuitive as most applications perform better when using short cuts rather then the mouse.<br /><br />Tried the iPad application which is supposed to support data sharing between desktop and ipad.. Wasn't happy that my budgets setup on my desktop were not currently supported..<br /><br />May switch to Mint, (same company) as this web-app may be the best alternative at this time.. Hope Quicken gets its act together soon as the application options are slim in this area..<br /><br />Updated: Restarted my process by recreating a file from scratch. Application runs a lot quicker. Apparently the issue is that it doesn't perform well with a lot of data. The common thread is that a lot of the frustrated users are long time users with history. I don't use the product as much as I did prior although I still use it for balancing my checkbook."]
#  ['Love is so far still trying to learn all the tricks. love to be able to make my photos look professional.']
#  ['it works grate i love it']
#  ['It made filing our taxes easy by following the step by step instructions.']
#  ["Easy to use and appears to be complete.  My only complaint is that they call it 2015 and it went on sale in mid 2014.  Since you don't get updates, on way of nothing how up to date it really is."]
#  ["I wish I'd known this before upgrading. I do my payroll with PNC Bank and it downloads fine with Quicken 2011 but 2014 doesn't and they aren't going to fix it. You have to buy Quickbooks."]
#  ['Downloaded quick and easy to install. Use to use another tax product, but it kept getting more expensive and more difficult to use.']
#  ["Zero Stars...the idea of unlimited cloud storage for my photos is very attractive and more than worth the cost of Prime membership.  What beggars belief, however, is the execution of this...this app would fail a programming 101 course it's so inept.  No desktop integration, constantly redirecting to the browser (where the functionality is equally poor), limited coverage of industry RAW file formats...who knew Olympus was a major camera manufacturer?  clearly not Amazon...slow upload speeds, poor performance on rendering image previews on web interface.  Once the photos are on there, the interface is also awful.  Very disappointed so far...really want to like this, but the software and basic functionality is undermining a terrific idea....can only hope Amazon has some grand plan waiting in the wings, otherwise I'll not be hanging around for very long."]
#  ['Fantastic, sometime a little too strict, I would rather pause the protection, now and then, instead of the virus issues..']
#  ['Thanks so much!']
#  ["This is a lot better than the previous version I used 2 years ago, which I swore I would not use again.  However, with Turbo Tax's price increases and the more recent reviews of this product, I decided to try it again and I was very pleased."]
#  ['I\'ve used Quicken for almost 20 years, including the last 6 yrs on a Mac. I\'ve used Quickbooks in my business for 10 years. I\'ve always been happy with Intuit\'s products... until now. They should honestly be ashamed.   You know how every software program has an \\\\"Options\\\\" selection somewhere in the menu? Not here. I suppose that wouldn\'t be so bad if they\'d just made a couple of intelligent choices in their setup.   The far bigger problem is that there is apparently no turning back. Prior to this program Quicken used their QIF format for data files. Converting to this program changes your data files to QFX format, which apparently no other programs can read and convert. So once you\'ve had a chance to use this program and realize what a load of &$%# it is, trying a replacement like iBank or Money is basically out of the question.  If you are dead set in ignoring the vast majority of reviews that explain what a pathetic program this is, be sure you have saved (Exported) your old data files in every possible format offered!']
#  ['I bought Quicken 2011 because I was buying a house and wanted software to keep track of tax deductions. But I was horrified at the numerous software bugs which 1) lose transactions of particular types, leaving my accounts out of balance; 2) degrade operations over time, leaving me with fewer and fewer on-line accounts to access; 3) result in unexpected on-line fees from my bank (BofA); 4) can\'t match my loan payments with the loan payment schedule, so I\'m constantly manually entering payments, deleting the duplicate payment, and then removing the associated payment reminders (and many similar bugs). Then I was told that the 2012 version had many bug fixes. So I paid NEARLY FULL PRICE for the upgrade (it would have been cheaper to buy a totally new version here on Amazon; so live and learn...)  But did they fix the bugs that were annoying me? NO!!!! WHAT A RIPOFF PRODUCT!!!! I could go on and on with various annoying habits of this software, but I WANT OUT!!!!  Unfortunately, Microsoft discontinued Money and there just aren\'t any \\\\"name brand\\\\" competitors; which is probably why Intuit gets away with selling this Piece-o-S***!']
#  ["After almost fourteen years ( began using 1997 ) Quicken has finally pushed me over the edge. I will NOT buy another version.  Quicken Deluxe 2014 (QD2014) is the MOST frustrating interface I have EVER used. Whenever I get done using QD2014 it is Wild Turkey time to calm my nerves.<br />INSTALL:<br />I have to admit the upgrade from QD2011 to QD2014 was actually painless but that is about the only pain-free step I have encountered.  After importing && converting my backup QDF from 2011 to 2014 I noticed my system was incredibly slow. Quicken has grabbed half the CPU & RAM. Opening & closing the software did nothing to resolve that issue, a reboot was necessary to resolve that problem. After rebooting and opening QD2014 I do have to admit that opening QD2014 did seem noticeably faster than QD2011 but that is where any noticeable gains end.<br />APPLICATION:<br />Entering the GUI I noticed no differences between QD2011 & QD2014. Then I began to use the GUI and that is where the frustration began. Below is a list of every irritation I have encountered thus far.<br />- Alt+Tab from QD2014 to any other application and QD2014 looses focus on the field you are on and moves focus to the toolbar.<br />- Virtually NONE of the keyboard shortcuts work any longer. i.e.;Ctrl+C, Ctrl+P, etc. They are listed but they do not work. Delete ( Ctrl+D ) works but that is all I have found.<br />- None of the transactions edits work ( Edit >> Transaction >> Copy, Paste, etc. ) when using a mouse gesture. When tried they simply change focus to the transaction behind the pop-up menu. If I click Edit, then finish navigating with the arrows on the keyboard, the Transaction Edits will work.<br />- When entering memorized fields ( Payee, Category, etc. ) the keyboard usage is changed.  Atl+Down Arrow used to bring up menu. The only thing the Alt key does any more is remove focus so you have to use the mouse to put it back on your field.<br />- The Category fields do not remember the last category any longer with a consistent logic. For example having multiple sub-classes under Auto for fuel, repair, etc only returns the update to the high level Auto. Most times the category history is simply alphabetized with focus set to the first alphabetic choice. For example, when entering a transaction for a restraunt we frequent the category choice always defaults to Gift: Birthday and not Dining because I once bought a gift card for a Birthday gift. QD2011 defaulted to last usage.<br />- Many pop-up screens have a Red-X in the top right corner to close the pop-up screen, but the Red-X is never enabled.<br />- Most areas of the register require the user to click two times to set focus. The first click generates of flash of some sort, the second click sets the focus. I think the first click flash opens the pop-up menu for the field, then the second click sets focus.<br />- If you change an amount for a register entry that has split transaction entries the interface goes haywire. I have an entry for my car note as a scheduled payment, Quicken prompts me with the principle plus calculated interest amount. I generally accept the calculated amount. If I pay extra in a month and I go into QD2014 and change the entered amount, and hit 'Enter' QD2014 says the split items do not match, click ok to edit the split. QD2014 now brings up the split amount for the next transaction in the register.<br /><br />I went to a few Quicken support sites and I read that Quicken was claiming that some of actions are new features. WTCuss?!  Who decided that? I can see if they wanted Quicken to operate differently and adding that option in the application ( Edit >> Preferences >> Setup ) but the Setup Switch does virtually nothing.<br />After years of small annoyances this release has pushed me over the edge & I've started looking for a replacement.<br />Goodbye Intuit. Goodbye Quicken."]
#  ['I was a Quicken fan from the early days, so when H&B was created I though it was the perfect home business solution. It worked ok on a PC but it fails miserably on a virtual PC running on VM WARE.<br />I was about to upgrade and try it again since the product is selling for close to half off on Amazon and at Costco.<br /><br />These reviews have stopped me cold.']
#  ['It is typical Quicken.  Very useful for my family budget, but could be a bit more user-friendly in some of its functions.  It is sometimes hard to know where to find the place to click for the desired action such as repeating scheduled transactions, adjusting a loan payment, etc.<br /><br />Overall though, there is not much else on the market that does what Quicken will do so I deal with the quirks.']
#  ['Works as well or better than the old Turbo Tax used in the past']
#  ['I had been using Turbo-tax  for 10 years. Tried this on a whim and glad I did. This was smother to use, less entry strokes, brought in all the past data from Turbo Tax and gave me hints on tax strategy.']
#  ['Awesome in every way.']
#  ["Use this at least once a week just to clean out all the junk that accumulates.  It's hard to believe that many cookies can nest inside your computer without even realizing it.  Easy to use, cleans well."]
#  ["I want my Norton 360 back!  This is basically junk. It doesn't scan your hard drive, it only scans files that are downloaded from the internet. Any anti-virus software can do that, including the FREE Windows Defender. Norton 360 scanned, got rid of old cookies, did performance cleanup, etc., this version does nothing - AND you have to turn it on manually!  If I forget to launch it, the Windows &#34;unprotected&#34; message blinks and I have to manually click on it to turn it on. I've had Norton since my first Apple II and this will be the last version I purchase."]
#  ["It's taking me a while to learn the idiosyncrasies of the program, but overall, I'm satisfied with it."]
#  ["Norton 360 is the best virus protection out there. It is protection plus. Wouldn't start a computer without it!!!! Jack"]
#  ["I had to find a copy of TurboTax in the last minutes. Found this download copy at Amazon. the price is great, download was fast. I can't say anything bad about it. will order/download from Amazon next year !!"]
#  ["Free isn't really free.  Way to many catches and hoops to jump through.  Had to renew my &#34;not free&#34; Norton instead"]
#  ["Avast makes a great free product! In December I needed antivirus protection for a Win XP machine when my Norton Security subscription ended. I used another product for my Windows 7 machines, but spotted this free version and it's perfect for this use. As a matter of fact, I am so impressed with it I will definitely evaluate the paid versions when my other service subscription expires.<br /><br />It seems to function well, doesn't take up a lot of resources and the offers to upgrade or add features are entirely reasonable and don't interfere with the operation or get in your way. This is how to win customers from a free version!"]
#  ['In my experience, the Free version of Avast is better than the pay versions of McAfee and Norton!<br />The pay version of Avast is far superior to anything else on the market!']
#  ["I found this free antivirus years ago. It quickly identified and removed several threats. I've been using it ever since and my computers run great. It continues to be a great antivirus. I will never use another. I highly recommend."]
#  ['It works, but to many pop-ups for me, it wants you to buy the premium addition and will never let you forget it when this is installed, Adios.']
#  ["I switched from Turbo Tax this year and don't think H&R Block is as user friendly."]
#  ['Works just fine.']
#  ['Easy and works very well. Simple download and setup.']
#  ['Downloaded in very short time & no problems with conversion from 2012 to 2013<br />Some nice new features with mobile applications']
#  ['Yyyhy']
#  ["I started using Webroot last year.  It's my favorite security software.  It downloads and installs with no problems, works completely unnoticed in the background, and always catches any virus that shows up.  It also scans and cleans up your PC super quick.  The only time it seeks your attention is when it detects a virus, detects a webpage that may be trouble, or when your subscription has less than 30 days left.  I never pay full price for it, and never will for any security software."]
#  ["I was looking for a simple converter to convert WAV to MP3.  The description indicated that this software would do it simply.  Not so!  It won't even simply import an audio file much less convert it.  It may be great for video and may actually do my conversion, but it is not user friendly at all.  If your task is as simple as mine there are several easier softwares to use.  They sell on amazon but take hours to recognize the sale of their downloaded product.  Normally I'm pretty easy to please,  but their support was unreachable.  Not even a FAQ list that was worth anything.  Buy something else or get some freeware."]
#  ['Did my taxes (state & fed) OK.  As with most tax software, a bit tedious but since it can import prior year that helps.  I need schedule &#34;C&#34; so had to get premium ... it should be included with deluxe version but ...']
#  ["Great service - best online asset for home users.  I've used it for years and am thankful for Avast!  I recommend it!"]]
# [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]

# %% [markdown]
# Make sure that `num_arms` specified in `config.yaml` is equal to the total unique actions in the simulation application.

# %%
print('num_actions {}'.format(sim_app.num_actions))
print('config num_actions {}'.format(bandits_experiment.config["algor"]["algorithms_parameters"]["num_arms"]))

assert sim_app.num_actions == bandits_experiment.config["algor"]["algorithms_parameters"]["num_arms"]
# Out:
# num_actions 2
# config num_actions 2

# %%
import time

# context = sim_app.choose_random_context()
# print(type('Type {}'.format(context)))
# print(context)

review_body = 'foo'
action, event_id, bandit_model_id, action_prob, sample_prob = bandit_model.get_action(obs=review_body) # obs=context)

# Check prediction response by uncommenting the lines below
print('event ID: {}\naction-bert-model-id: {}\naction-probability: {}\nbandit-model-id: {}\n'.format(event_id, action, action_prob, bandit_model_id))
# Out:
# event ID: 152898010924890051113667195582138155010
# action-bert-model-id: 1
# action-probability: 0.9995
# bandit-model-id: bandits-1597616270-model-id-1597616291

# %%
import time

# context = sim_app.choose_random_context()
# print(type('Type {}'.format(context)))
# print(context)

review_body = 'bar'
action, event_id, bandit_model_id, action_prob, sample_prob = bandit_model.get_action(obs=review_body) # obs=context)

# Check prediction response by uncommenting the lines below
print('event ID: {}\naction-bert-model-id: {}\naction-probability: {}\nbandit-model-id: {}\n'.format(event_id, action, action_prob, bandit_model_id))
# Out:
# event ID: 152903366748676015383627109492069629954
# action-bert-model-id: 1
# action-probability: 0.9995
# bandit-model-id: bandits-1597616270-model-id-1597616291

# %% [markdown]
# # Ingest Reward

# %% [markdown]
# Client application generates a reward after receiving the recommended action and stores the tuple `<eventID, reward>` in S3. In this case, reward is 1 if predicted action is the true class, and 0 otherwise. SageMaker hosting endpoint saves all the inferences `<eventID, state, action, action probability>` to S3 using [**Kinesis Firehose**](https://aws.amazon.com/kinesis/data-firehose/). The `ExperimentManager` joins the reward with state, action and action probability using [**Amazon Athena**](https://aws.amazon.com/athena/).

# %%
local_mode = bandits_experiment.local_mode
batch_size = 100 # collect 500 data instances
print("Collecting batch of experience data...")

# Generate experiences and log them
for i in range(batch_size):
#     user_id, user_context = sim_app.choose_random_context()
#     print('User ID {}'.format(user_id))
#     print('User Context {}'.format(user_context.tolist()))    
#    review_body = 'foo'
    review_index = np.random.choice(100)
    review_body = sim_app.contexts[0]
    action, event_id, bandit_model_id, action_prob, sample_prob = bandit_model.get_action(obs=review_body) #obs=user_context.tolist())
    print('Action (bert model to invoke) {}'.format(action))
    print('Event ID {}'.format(event_id))
    print('Bandit Model ID {}'.format(bandit_model_id))
    print('Action Probability {}'.format(action_prob))
    print('Sample Probability {}'.format(sample_prob))
    
    reward = sim_app.get_reward(context_index=review_index, 
                                action=action, 
                                event_id=event_id, 
                                bandit_model_id=bandit_model_id, 
                                action_prob=action_prob, 
                                sample_prob=sample_prob, 
                                local_mode=local_mode)
# Out:
# Collecting batch of experience data...
# Action (bert model to invoke) 1
# Event ID 157316401546014168694818913395288440834
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.7426008290027138
# context_index 24
# context ['Great stuff!!!!!']
# label 5
# action 1
# event_id 157316401546014168694818913395288440834
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 157476310123261583835314090956570099714
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.012282591918139296
# context_index 54
# context ['Great product.  I have been using the software for a dozen years and will continue using year after year.  I recommend using this product.']
# label 5
# action 1
# event_id 157476310123261583835314090956570099714
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 157638393513570015531613595146017439746
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.1244501866085519
# context_index 57
# context ["The product worked fine, until I had re refresh my PC and re install.  When I attempted to re-install, the system no longer recognized m account...so I wasted my weekend trying to just get logged in.  Tech support and Customer service are outsourced and useless.  Save the headache of dealing with these guys...they don't deserve to be considered professional."]
# label 1
# action 1
# event_id 157638393513570015531613595146017439746
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 157815916888189227062548561487048343554
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.467966749187397
# context_index 43
# context ['A+']
# label 5
# action 1
# event_id 157815916888189227062548561487048343554
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 157942573405629405460293112499102941186
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.17047001083549185
# context_index 55
# context ['I owned the 11 version and upgraded to get the new options. My creative photos are unlimited with Elements 12!']
# label 5
# action 1
# event_id 157942573405629405460293112499102941186
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 158161786639363622882549651549963026434
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.14587282980011906
# context_index 45
# context ["I bought this primarily to track expenses now that I'm entering retirement.  I've been using Mint.com and PersonalCapital.com (free, online tools) to do this - and they work great, but I bought Quicken as I'm a little uncomfortable having all my financial information on someone's website.  Anyway, both Mint and PersonalCapital report all my account balances accurately while Quicken 2014 does not.  The online help system and forum are useless.  I believe I've wasted my money on this product.  Quicken was a favorite of mine in previous years for balancing my checkbook, but Intuit appears to have broken Quicken, with the online functionality.  (Actually Mint.com has been recently purchased by Intuit - I hope they don't break that.)"]
# label 1
# action 1
# event_id 158161786639363622882549651549963026434
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 158260175340700336907546818169248284674
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.0351625791771738
# context_index 81
# context ["Use this at least once a week just to clean out all the junk that accumulates.  It's hard to believe that many cookies can nest inside your computer without even realizing it.  Easy to use, cleans well."]
# label 5
# action 1
# event_id 158260175340700336907546818169248284674
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 158370354777182423753646215777171406850
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.6658375877145338
# context_index 42
# context ["This software no longer provides Schedule C, and there are problems calculating the housing allowance. I've used it several years in a row with no problem, until this year. No longer recommended."]
# label 2
# action 1
# event_id 158370354777182423753646215777171406850
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward 1
# Action (bert model to invoke) 1
# Event ID 158501291199961622708788626408745336834
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.5440510840221134
# context_index 36
# context ["I not only have PC MATIC  but I also have VIPRE voted by PC Mag as one of the top 5 best Antivirus programs out there. I was comparing both of them and have to say that PC MATIC not only does just as good a job as VIPRE but PC MATIC has several other benefits that VIPRE does not have, so for the money and what you get with PC MATIC it's a No-Brainer for me I'm renewing my PC MATIC subscription and letting VIPRE expire."]
# label 5
# action 1
# event_id 158501291199961622708788626408745336834
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 158624139219629740422945205879944904706
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.37647727445392865
# context_index 39
# context ["We use this software every year and it does a good job of guiding you through the process (NY Fed & State). We are hesitant to recommend for doing taxes when there are non-basic (house sale, death, inheritance, etc... ) tax issues as we haven't done anything like that. I'm not saying it wouldn't guide you through it, it's just we never have used it for that. I probably would want to sit down with a good tax preparer and make sure those are covered completely.<br /><br />I did have an experience with helping a family member recently who had her tax preparer make a 10K mistake and it is costing her + penalties. For that, I can say we have NOT had any issues with the software making any mistakes on our returns. Just sometimes a little buggy but they do send out patches and updates."]
# label 5
# action 1
# event_id 158624139219629740422945205879944904706
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 158763148992169142916469958418006933506
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.5202982375146669
# context_index 99
# context ["Great service - best online asset for home users.  I've used it for years and am thankful for Avast!  I recommend it!"]
# label 5
# action 1
# event_id 158763148992169142916469958418006933506
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 159077445528299979258416795398110838786
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.7864370694864601
# context_index 81
# context ["Use this at least once a week just to clean out all the junk that accumulates.  It's hard to believe that many cookies can nest inside your computer without even realizing it.  Easy to use, cleans well."]
# label 5
# action 1
# event_id 159077445528299979258416795398110838786
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 159211321315908457422865486288191094786
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.3099385935144684
# context_index 74
# context ['I bought Quicken 2011 because I was buying a house and wanted software to keep track of tax deductions. But I was horrified at the numerous software bugs which 1) lose transactions of particular types, leaving my accounts out of balance; 2) degrade operations over time, leaving me with fewer and fewer on-line accounts to access; 3) result in unexpected on-line fees from my bank (BofA); 4) can\'t match my loan payments with the loan payment schedule, so I\'m constantly manually entering payments, deleting the duplicate payment, and then removing the associated payment reminders (and many similar bugs). Then I was told that the 2012 version had many bug fixes. So I paid NEARLY FULL PRICE for the upgrade (it would have been cheaper to buy a totally new version here on Amazon; so live and learn...)  But did they fix the bugs that were annoying me? NO!!!! WHAT A RIPOFF PRODUCT!!!! I could go on and on with various annoying habits of this software, but I WANT OUT!!!!  Unfortunately, Microsoft discontinued Money and there just aren\'t any \\\\"name brand\\\\" competitors; which is probably why Intuit gets away with selling this Piece-o-S***!']
# label 1
# action 1
# event_id 159211321315908457422865486288191094786
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 159332078504367823698295438170974715906
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.9183465645132565
# context_index 65
# context ['It made filing our taxes easy by following the step by step instructions.']
# label 5
# action 1
# event_id 159332078504367823698295438170974715906
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 159510058233203117388694793208321933314
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.10472198181158321
# context_index 18
# context ["Well...I presume this product to be Microsoft's revenge.  Word is a shell of the PC version, and the only reason this expensive little box gets 2 stars is Outlook.  It should be noted, however, that Outlook doesn't measure up to Windows compatible versions either.  If you can get by with native iOS tools, do it."]
# label 2
# action 1
# event_id 159510058233203117388694793208321933314
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward 1
# Action (bert model to invoke) 1
# Event ID 159644155067385010353502904049590206466
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.5389145480395857
# context_index 25
# context ["Every couple of years Intuit makes me buy a newer copy of Quickbooks. They do this by taking away functions of the program that are crucial until you purchase a newer version of the software. (Emailing especially).<br />This new version has crashed every time I've tried to use it.  It doesn't recognize my imported templates. If I send an email it shuts down. Every year they make dramatic changes to the program and you have to relearn how to use it every time.<br />For the $160-$399 price tag on these software programs they should be flawless. ."]
# label 1
# action 1
# event_id 159644155067385010353502904049590206466
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 159795750233539803737054391044163108866
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.2972819478419799
# context_index 71
# context ['Thanks so much!']
# label 5
# action 1
# event_id 159795750233539803737054391044163108866
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 159912091244220624915449344823588421634
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.6386422749182094
# context_index 81
# context ["Use this at least once a week just to clean out all the junk that accumulates.  It's hard to believe that many cookies can nest inside your computer without even realizing it.  Easy to use, cleans well."]
# label 5
# action 1
# event_id 159912091244220624915449344823588421634
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 160036202160799220000289631421789765634
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.7672284514590547
# context_index 8
# context ["Used in the last few years and it was good software, however this year had nothing but trouble. I had a rental property that I sold in Jan. of 2014 and took a huge loss on the property.  Tax Act didn't even ask me anything about the sale price of the home.  I have to report the sale on schedule E, but the software does not help at all.<br /><br />Another issue was that I could not register with TaxACT so as to get my State Software to download. I tried numerous times to register, but it wouldn't let me.  I called tech support at TaxACT and they told me that the problem is that I bought the software from Amazon and not them.  I was told to get a refund from Amazon and purchase it from them.<br /><br />I did get a refund from Amazon, but chose to buy H&R Block Premium through Amazon instead because of the rental property sale that I had trouble with when using TaxACT Deluxe."]
# label 1
# action 1
# event_id 160036202160799220000289631421789765634
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 160178762147300886678781950664266350594
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.32572588793615864
# context_index 16
# context ['Software provides what I wanted.<br /><br />The dowmload process, however, was a major, major undertaking. It required several calls to Amazon, to Microsoft and more to get a real person to assist in the download. It was a tiresome process.  It was far from being user friendly']
# label 4
# action 1
# event_id 160178762147300886678781950664266350594
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 160326385605668839991089873300608909314
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.5743943938576627
# context_index 20
# context ['The software was received by download. H&R Block tax software was chosen because it handles our two state returns properly. TurboTax never properly attributed the tax we paid in another state and in the next year, even after I informed them, they did not correct the problem.']
# label 5
# action 1
# event_id 160326385605668839991089873300608909314
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 160460876203818428849655824055310352386
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.6822048196314678
# context_index 29
# context ['I purchased this product almost a month ago.  I have had a support ticket open since the day I bought it and is still unresolved!  I cannot use the mobile app and it will not connect to my bank for automatic updates.  I get \\\\"Unexpected Error, Not your fault\\\\".  I have been told by customer service that they are working on it, but the issue on their help webpage says it has been going on since April of 2013!  I would never have bought this if the mobile part was not functional.  Horrible customer service, Intuit.']
# label 1
# action 1
# event_id 160460876203818428849655824055310352386
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 160613679599451564764355612595125878786
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.1721004995030152
# context_index 53
# context ['Only lasts for a month and constantly reminds you that it is going to expire.']
# label 2
# action 1
# event_id 160613679599451564764355612595125878786
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward 1
# Action (bert model to invoke) 1
# Event ID 160883408709604877131119329232286777346
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.3061791257800286
# context_index 60
# context ['Adobe photoshop elements 9 is a gr8 program to use for those who want to raise there fotos up another notch.']
# label 4
# action 1
# event_id 160883408709604877131119329232286777346
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 161012909518079317615988570661862899714
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.3647865115953087
# context_index 6
# context ['I bought this program with some trepidation as previous tax software which I have used just were not fully applicable to our tax situation.  My husband is a pastor, and we can attest that this is the first software we have seen which is set up for the various issues clergy face.<br /><br />We found also that TurboTax is quite intuitive, helping us maximize our deductions, and saved us several hundred dollars over the tax preparation company we used last year.']
# label 5
# action 1
# event_id 161012909518079317615988570661862899714
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 161146681516794902094155014009368215554
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.966207663935557
# context_index 77
# context ['It is typical Quicken.  Very useful for my family budget, but could be a bit more user-friendly in some of its functions.  It is sometimes hard to know where to find the place to click for the desired action such as repeating scheduled transactions, adjusting a loan payment, etc.<br /><br />Overall though, there is not much else on the market that does what Quicken will do so I deal with the quirks.']
# label 4
# action 1
# event_id 161146681516794902094155014009368215554
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 161287228315687081318686615263633342466
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.4631507368732376
# context_index 39
# context ["We use this software every year and it does a good job of guiding you through the process (NY Fed & State). We are hesitant to recommend for doing taxes when there are non-basic (house sale, death, inheritance, etc... ) tax issues as we haven't done anything like that. I'm not saying it wouldn't guide you through it, it's just we never have used it for that. I probably would want to sit down with a good tax preparer and make sure those are covered completely.<br /><br />I did have an experience with helping a family member recently who had her tax preparer make a 10K mistake and it is costing her + penalties. For that, I can say we have NOT had any issues with the software making any mistakes on our returns. Just sometimes a little buggy but they do send out patches and updates."]
# label 5
# action 1
# event_id 161287228315687081318686615263633342466
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 161445372481755303789526050637574438914
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.6288809477536559
# context_index 94
# context ['Downloaded in very short time & no problems with conversion from 2012 to 2013<br />Some nice new features with mobile applications']
# label 4
# action 1
# event_id 161445372481755303789526050637574438914
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 161598854070459561809813173877171421186
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.5564463918680774
# context_index 29
# context ['I purchased this product almost a month ago.  I have had a support ticket open since the day I bought it and is still unresolved!  I cannot use the mobile app and it will not connect to my bank for automatic updates.  I get \\\\"Unexpected Error, Not your fault\\\\".  I have been told by customer service that they are working on it, but the issue on their help webpage says it has been going on since April of 2013!  I would never have bought this if the mobile part was not functional.  Horrible customer service, Intuit.']
# label 1
# action 1
# event_id 161598854070459561809813173877171421186
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 161736601738370112069582527296538017794
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.8733444362221723
# context_index 12
# context ['Excellent.']
# label 5
# action 1
# event_id 161736601738370112069582527296538017794
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 161862802693875833447648531584149225474
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.5962490302893584
# context_index 22
# context ["Ever since my husband and I found avast! antivirus a few years ago, we have not used anything  else. Our computers have been clean since the first day and we have 3 teenage boys. We have used the free and the pay and are happy with both. We won't use anything else."]
# label 5
# action 1
# event_id 161862802693875833447648531584149225474
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 161982027609672173853646958290499928066
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.06318729110936439
# context_index 96
# context ["I started using Webroot last year.  It's my favorite security software.  It downloads and installs with no problems, works completely unnoticed in the background, and always catches any virus that shows up.  It also scans and cleans up your PC super quick.  The only time it seeks your attention is when it detects a virus, detects a webpage that may be trouble, or when your subscription has less than 30 days left.  I never pay full price for it, and never will for any security software."]
# label 5
# action 1
# event_id 161982027609672173853646958290499928066
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 162105370013074380574412587512383012866
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.6672823549573156
# context_index 7
# context ['No easy way to get photos and videos out of this service.']
# label 1
# action 1
# event_id 162105370013074380574412587512383012866
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 162282576475043535047734563524341530626
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.9553163185636144
# context_index 97
# context ["I was looking for a simple converter to convert WAV to MP3.  The description indicated that this software would do it simply.  Not so!  It won't even simply import an audio file much less convert it.  It may be great for video and may actually do my conversion, but it is not user friendly at all.  If your task is as simple as mine there are several easier softwares to use.  They sell on amazon but take hours to recognize the sale of their downloaded product.  Normally I'm pretty easy to please,  but their support was unreachable.  Not even a FAQ list that was worth anything.  Buy something else or get some freeware."]
# label 2
# action 1
# event_id 162282576475043535047734563524341530626
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward 1
# Action (bert model to invoke) 1
# Event ID 162577874890085075944169844600594366466
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.9804903404861974
# context_index 8
# context ["Used in the last few years and it was good software, however this year had nothing but trouble. I had a rental property that I sold in Jan. of 2014 and took a huge loss on the property.  Tax Act didn't even ask me anything about the sale price of the home.  I have to report the sale on schedule E, but the software does not help at all.<br /><br />Another issue was that I could not register with TaxACT so as to get my State Software to download. I tried numerous times to register, but it wouldn't let me.  I called tech support at TaxACT and they told me that the problem is that I bought the software from Amazon and not them.  I was told to get a refund from Amazon and purchase it from them.<br /><br />I did get a refund from Amazon, but chose to buy H&R Block Premium through Amazon instead because of the rental property sale that I had trouble with when using TaxACT Deluxe."]
# label 1
# action 1
# event_id 162577874890085075944169844600594366466
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 162735391569106185444313073070015381506
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.9247819118146299
# context_index 26
# context ['This company needs to upgrade their customer support, which has been unable to resolve my issues, so the upgrade is for naught at this juncture.']
# label 4
# action 1
# event_id 162735391569106185444313073070015381506
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 162869310932204046454147440409268322306
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.8679909521636693
# context_index 66
# context ["Easy to use and appears to be complete.  My only complaint is that they call it 2015 and it went on sale in mid 2014.  Since you don't get updates, on way of nothing how up to date it really is."]
# label 4
# action 1
# event_id 162869310932204046454147440409268322306
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 163009365724207012094285051792035282946
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.4880304469798926
# context_index 66
# context ["Easy to use and appears to be complete.  My only complaint is that they call it 2015 and it went on sale in mid 2014.  Since you don't get updates, on way of nothing how up to date it really is."]
# label 4
# action 1
# event_id 163009365724207012094285051792035282946
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 163177552059873917572772002825248047106
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.6411380887677466
# context_index 36
# context ["I not only have PC MATIC  but I also have VIPRE voted by PC Mag as one of the top 5 best Antivirus programs out there. I was comparing both of them and have to say that PC MATIC not only does just as good a job as VIPRE but PC MATIC has several other benefits that VIPRE does not have, so for the money and what you get with PC MATIC it's a No-Brainer for me I'm renewing my PC MATIC subscription and letting VIPRE expire."]
# label 5
# action 1
# event_id 163177552059873917572772002825248047106
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 163339624358239597272326860071813382146
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.2012159633463776
# context_index 49
# context ['il kie it']
# label 5
# action 1
# event_id 163339624358239597272326860071813382146
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 163478984319257312814223776074135896066
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.49362908017646556
# context_index 77
# context ['It is typical Quicken.  Very useful for my family budget, but could be a bit more user-friendly in some of its functions.  It is sometimes hard to know where to find the place to click for the desired action such as repeating scheduled transactions, adjusting a loan payment, etc.<br /><br />Overall though, there is not much else on the market that does what Quicken will do so I deal with the quirks.']
# label 4
# action 1
# event_id 163478984319257312814223776074135896066
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 163612665205586005888401986846098325506
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.9037564494136645
# context_index 40
# context ['Beware of doing business with AVG.  Hidden in the fine print is that you are agreeing to AUTO UPDATE FOR ANNUAL CHARGES EVERY YEAR WITHOUT THEIR NOTIFYING YOU ! ! !  Do not believe that their Anti Virus is any good.  Why should I pay for a NONE WORKING ANTI VIRUS SOFTWARE  when I can get it for free and have it not work ! ! !  Contrary to the STAR RATING its not worth even one star ! ! !']
# label 1
# action 1
# event_id 163612665205586005888401986846098325506
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 163746949018231432514189284487522811906
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.9638787218173226
# context_index 67
# context ["I wish I'd known this before upgrading. I do my payroll with PNC Bank and it downloads fine with Quicken 2011 but 2014 doesn't and they aren't going to fix it. You have to buy Quickbooks."]
# label 1
# action 1
# event_id 163746949018231432514189284487522811906
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 163900639769284728186612586756015521794
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.2323707051031445
# context_index 62
# context ["Been a quicken user since 1996 so I have a significant amount of history in this application..<br /><br />Last time I upgraded was to 2012. Tried upgrading to 2013 without a hitch. Data was converted to the new format..<br /><br />Unfortunately data entry is... Slow.. Horribly slow.. The application is not responsive at all.. Downloaded all of the patches.. Still do not notice a difference in performance..<br /><br />I'm currently running the windows version of Quicken on an I7-2600K desktop with 16 GB of Ram...<br /><br />So I really don't expect applications to run slow on my desktop.. Unfortunately Quicken 2013 performs like each transaction is a pain to record. Like it is searching for something.<br /><br />Application Prompts stay on the screen for extended periods, sometime requiring responses to be recorded multiple times.<br />The Reconcile Screen, works best when you use a mouse to mark transaction as reconciled. If I use the keyboard and space bar, the application response slows considerably.. Counter intuitive as most applications perform better when using short cuts rather then the mouse.<br /><br />Tried the iPad application which is supposed to support data sharing between desktop and ipad.. Wasn't happy that my budgets setup on my desktop were not currently supported..<br /><br />May switch to Mint, (same company) as this web-app may be the best alternative at this time.. Hope Quicken gets its act together soon as the application options are slim in this area..<br /><br />Updated: Restarted my process by recreating a file from scratch. Application runs a lot quicker. Apparently the issue is that it doesn't perform well with a lot of data. The common thread is that a lot of the frustrated users are long time users with history. I don't use the product as much as I did prior although I still use it for balancing my checkbook."]
# label 1
# action 1
# event_id 163900639769284728186612586756015521794
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 164022372256424645059158465281665400834
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.5292013533530866
# context_index 92
# context ['Works just fine.']
# label 5
# action 1
# event_id 164022372256424645059158465281665400834
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 164311753120007995551956268406996598786
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.11982691082269281
# context_index 27
# context ["The norton 360 from amazon was a great price but it sure slows down the computer.  After turning on the computer it takes a long time before you can do anything that doesn't freeze the screen , when you go onto the internet or you just want to play one of your own games.  It does find problems but they aren't very easy to fix."]
# label 3
# action 1
# event_id 164311753120007995551956268406996598786
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 164453489925901139023505016542211473410
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.25478318594616656
# context_index 37
# context ['I needed a full service solution and needed better support options for obtaining my data, so I switched from Invoice2Go! to QB online... been using it now for just over 3 months and very happy.']
# label 5
# action 1
# event_id 164453489925901139023505016542211473410
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 164627768907265391427171351327256215554
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.37814700645799904
# context_index 32
# ...
# Sample Probability 0.8924644377830685
# context_index 3
# context ['This new version has a lot of the same as previous versions that can be printed as pre-made cards, banners, calendars, posters, etc. But, now every individual item must be downloaded and often times there are additional charges; $0.99 and up per item. Where before there were thousands of projects and clip art that were included with the software download. I was able to make what I wanted to make, a calendar with additional birthdates and pictures, it just took longer to find something that worked that did not have an additional charge attached to it. I am quite impressed with the updates of this new version in way of built-in page borders so your text or pictures did not shift off the page during printing; also that the text and pictures I add in a calendar, do not overlap the lines for that month! Much more user friendly.']
# label 3
# action 1
# event_id 170310703592365554106785698926549925890
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 170438120700165869442433764113798791170
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.058193990522788286
# context_index 76
# context ['I was a Quicken fan from the early days, so when H&B was created I though it was the perfect home business solution. It worked ok on a PC but it fails miserably on a virtual PC running on VM WARE.<br />I was about to upgrade and try it again since the product is selling for close to half off on Amazon and at Costco.<br /><br />These reviews have stopped me cold.']
# label 1
# action 1
# event_id 170438120700165869442433764113798791170
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 170568100046741896084378044734452662274
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.7831408656570714
# context_index 53
# context ['Only lasts for a month and constantly reminds you that it is going to expire.']
# label 2
# action 1
# event_id 170568100046741896084378044734452662274
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward 1
# Action (bert model to invoke) 1
# Event ID 170696042437259680994965914896041115650
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.4963414918079375
# context_index 27
# context ["The norton 360 from amazon was a great price but it sure slows down the computer.  After turning on the computer it takes a long time before you can do anything that doesn't freeze the screen , when you go onto the internet or you just want to play one of your own games.  It does find problems but they aren't very easy to fix."]
# label 3
# action 1
# event_id 170696042437259680994965914896041115650
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 170834372432164711101212705165898022914
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.12203556277835415
# context_index 66
# context ["Easy to use and appears to be complete.  My only complaint is that they call it 2015 and it went on sale in mid 2014.  Since you don't get updates, on way of nothing how up to date it really is."]
# label 4
# action 1
# event_id 170834372432164711101212705165898022914
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 170958402536017541635690056010381262850
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.29290193707452905
# context_index 60
# context ['Adobe photoshop elements 9 is a gr8 program to use for those who want to raise there fotos up another notch.']
# label 4
# action 1
# event_id 170958402536017541635690056010381262850
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 171235984741639267884334635062788227074
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.716759651185954
# context_index 59
# context ['have used HR Block for over 10 years.  Love it.']
# label 5
# action 1
# event_id 171235984741639267884334635062788227074
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 171406059876700513423891225844888240130
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.738769370487238
# context_index 38
# context ['Great software and have no issues from the installation or updates. I left the software scan my drives at least once or twice a month.']
# label 5
# action 1
# event_id 171406059876700513423891225844888240130
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 171532145159088963976762933897220718594
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.8535905447699147
# context_index 2
# context ["I love Quicken because it organizes s much personal finance information.  Most accounts can be downloaded right into the program.  I gave 3 stars for this product because the business side is lacking.  It now allows you to see your dealings in an app on your smartphone but the program is very bare bones on the business side and not super user friendly.  It's not as close to QuickBoQuick books as I imagined it would be."]
# label 3
# action 1
# event_id 171532145159088963976762933897220718594
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 171677911509327582932997663863367401474
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.4080227830170954
# context_index 89
# context ["I found this free antivirus years ago. It quickly identified and removed several threats. I've been using it ever since and my computers run great. It continues to be a great antivirus. I will never use another. I highly recommend."]
# label 5
# action 1
# event_id 171677911509327582932997663863367401474
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 171820263125761837096282112085254602754
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.08964227126818392
# context_index 37
# context ['I needed a full service solution and needed better support options for obtaining my data, so I switched from Invoice2Go! to QB online... been using it now for just over 3 months and very happy.']
# label 5
# action 1
# event_id 171820263125761837096282112085254602754
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 171996649576248968930589844800489521154
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.29059485960506726
# context_index 19
# context ["I've had mixed experiences with Intuit products in general. Many of the times I experience issues with them locking up, not saving, corrupting files, and so forth. With this product, I did not experience that.<br /><br />I purchased this software for a couple business returns I needed to file and was surprised at how easy it was to navigate through the various sections that needed to be filled out. The results were good and the return printed appropriately. The eFile worked well, too, and the return was accepted by the IRS within 8 hours.<br /><br />I plan on purchasing the product again for my 2014 business returns. I wish they would include the personal 1040 return preparation feature with this, especially for the money you're paying. Unfortunately, you have to buy that separately, AND pay additional money to be able to prepare a state tax return with your federal.<br /><br />All in all, I'd give the software a 4-star. There are improvements that could be made; there are features that should be added; but as it is, it does what it's designed to do and it doesn't take very long to get the hang of it, get your information entered, and get the returns submitted."]
# label 4
# action 1
# event_id 171996649576248968930589844800489521154
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 172112810739000882734916145315551772674
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.8471828843060805
# context_index 22
# context ["Ever since my husband and I found avast! antivirus a few years ago, we have not used anything  else. Our computers have been clean since the first day and we have 3 teenage boys. We have used the free and the pay and are happy with both. We won't use anything else."]
# label 5
# action 1
# event_id 172112810739000882734916145315551772674
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 172246822799048885430905346984388984834
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.5152461358052678
# context_index 16
# context ['Software provides what I wanted.<br /><br />The dowmload process, however, was a major, major undertaking. It required several calls to Amazon, to Microsoft and more to get a real person to assist in the download. It was a tiresome process.  It was far from being user friendly']
# label 4
# action 1
# event_id 172246822799048885430905346984388984834
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 172387821990749021105067223527881572354
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.32303445684616394
# context_index 3
# context ['This new version has a lot of the same as previous versions that can be printed as pre-made cards, banners, calendars, posters, etc. But, now every individual item must be downloaded and often times there are additional charges; $0.99 and up per item. Where before there were thousands of projects and clip art that were included with the software download. I was able to make what I wanted to make, a calendar with additional birthdates and pictures, it just took longer to find something that worked that did not have an additional charge attached to it. I am quite impressed with the updates of this new version in way of built-in page borders so your text or pictures did not shift off the page during printing; also that the text and pictures I add in a calendar, do not overlap the lines for that month! Much more user friendly.']
# label 3
# action 1
# event_id 172387821990749021105067223527881572354
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1
# Action (bert model to invoke) 1
# Event ID 172524554745897763641266921459539902466
# Bandit Model ID bandits-1597616270-model-id-1597616291
# Action Probability 0.9995
# Sample Probability 0.128476156433594
# context_index 21
# context ["I've used Norton for years. I've tried others but never had the same results. Good price for 1/3 as I can use them as needed."]
# label 4
# action 1
# event_id 172524554745897763641266921459539902466
# bandit_model_id bandits-1597616270-model-id-1597616291
# action_prob 0.9995
# self.labels [1 5 3 3 4 2 5 1 1 5 2 5 5 5 1 5 4 4 2 4 5 4 5 5 5 1 4 3 5 1 5 5 1 5 1 4 5
#  5 5 5 1 1 2 5 5 1 1 5 1 5 5 5 5 2 5 5 1 1 5 5 4 1 1 5 5 5 4 1 5 1 4 5 5 1
#  1 1 1 4 5 5 5 5 1 4 5 5 1 5 5 5 3 3 5 5 4 2 5 2 4 5]
# <class 'numpy.ndarray'>
# <class 'str'>
# bert_predicted_class [2]
# reward -1

# %%
# Join (observation, action) with rewards (can be delayed) and upload the data to S3
if local_mode:
    print(sim_app.joined_data_buffer)
    bandits_experiment.ingest_joined_data(sim_app.joined_data_buffer)
else:
    print("Waiting for firehose to flush data to s3...")
    time.sleep(60) # Wait for firehose to flush data to S3
    rewards_s3_prefix = bandits_experiment.ingest_rewards(sim_app.rewards_buffer)
    bandits_experiment.join(rewards_s3_prefix)
# Out:
# [{'reward': -1, 'event_id': 157316401546014168694818913395288440834, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['Great stuff!!!!!'], dtype=object), 'sample_prob': 0.7426008290027138}, {'reward': -1, 'event_id': 157476310123261583835314090956570099714, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['Great product.  I have been using the software for a dozen years and will continue using year after year.  I recommend using this product.'],
#       dtype=object), 'sample_prob': 0.012282591918139296}, {'reward': -1, 'event_id': 157638393513570015531613595146017439746, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["The product worked fine, until I had re refresh my PC and re install.  When I attempted to re-install, the system no longer recognized m account...so I wasted my weekend trying to just get logged in.  Tech support and Customer service are outsourced and useless.  Save the headache of dealing with these guys...they don't deserve to be considered professional."],
#       dtype=object), 'sample_prob': 0.1244501866085519}, {'reward': -1, 'event_id': 157815916888189227062548561487048343554, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['A+'], dtype=object), 'sample_prob': 0.467966749187397}, {'reward': -1, 'event_id': 157942573405629405460293112499102941186, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['I owned the 11 version and upgraded to get the new options. My creative photos are unlimited with Elements 12!'],
#       dtype=object), 'sample_prob': 0.17047001083549185}, {'reward': -1, 'event_id': 158161786639363622882549651549963026434, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["I bought this primarily to track expenses now that I'm entering retirement.  I've been using Mint.com and PersonalCapital.com (free, online tools) to do this - and they work great, but I bought Quicken as I'm a little uncomfortable having all my financial information on someone's website.  Anyway, both Mint and PersonalCapital report all my account balances accurately while Quicken 2014 does not.  The online help system and forum are useless.  I believe I've wasted my money on this product.  Quicken was a favorite of mine in previous years for balancing my checkbook, but Intuit appears to have broken Quicken, with the online functionality.  (Actually Mint.com has been recently purchased by Intuit - I hope they don't break that.)"],
#       dtype=object), 'sample_prob': 0.14587282980011906}, {'reward': -1, 'event_id': 158260175340700336907546818169248284674, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["Use this at least once a week just to clean out all the junk that accumulates.  It's hard to believe that many cookies can nest inside your computer without even realizing it.  Easy to use, cleans well."],
#       dtype=object), 'sample_prob': 0.0351625791771738}, {'reward': 1, 'event_id': 158370354777182423753646215777171406850, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["This software no longer provides Schedule C, and there are problems calculating the housing allowance. I've used it several years in a row with no problem, until this year. No longer recommended."],
#       dtype=object), 'sample_prob': 0.6658375877145338}, {'reward': -1, 'event_id': 158501291199961622708788626408745336834, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["I not only have PC MATIC  but I also have VIPRE voted by PC Mag as one of the top 5 best Antivirus programs out there. I was comparing both of them and have to say that PC MATIC not only does just as good a job as VIPRE but PC MATIC has several other benefits that VIPRE does not have, so for the money and what you get with PC MATIC it's a No-Brainer for me I'm renewing my PC MATIC subscription and letting VIPRE expire."],
#       dtype=object), 'sample_prob': 0.5440510840221134}, {'reward': -1, 'event_id': 158624139219629740422945205879944904706, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["We use this software every year and it does a good job of guiding you through the process (NY Fed & State). We are hesitant to recommend for doing taxes when there are non-basic (house sale, death, inheritance, etc... ) tax issues as we haven't done anything like that. I'm not saying it wouldn't guide you through it, it's just we never have used it for that. I probably would want to sit down with a good tax preparer and make sure those are covered completely.<br /><br />I did have an experience with helping a family member recently who had her tax preparer make a 10K mistake and it is costing her + penalties. For that, I can say we have NOT had any issues with the software making any mistakes on our returns. Just sometimes a little buggy but they do send out patches and updates."],
#       dtype=object), 'sample_prob': 0.37647727445392865}, {'reward': -1, 'event_id': 158763148992169142916469958418006933506, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["Great service - best online asset for home users.  I've used it for years and am thankful for Avast!  I recommend it!"],
#       dtype=object), 'sample_prob': 0.5202982375146669}, {'reward': -1, 'event_id': 159077445528299979258416795398110838786, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["Use this at least once a week just to clean out all the junk that accumulates.  It's hard to believe that many cookies can nest inside your computer without even realizing it.  Easy to use, cleans well."],
#       dtype=object), 'sample_prob': 0.7864370694864601}, {'reward': -1, 'event_id': 159211321315908457422865486288191094786, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['I bought Quicken 2011 because I was buying a house and wanted software to keep track of tax deductions. But I was horrified at the numerous software bugs which 1) lose transactions of particular types, leaving my accounts out of balance; 2) degrade operations over time, leaving me with fewer and fewer on-line accounts to access; 3) result in unexpected on-line fees from my bank (BofA); 4) can\'t match my loan payments with the loan payment schedule, so I\'m constantly manually entering payments, deleting the duplicate payment, and then removing the associated payment reminders (and many similar bugs). Then I was told that the 2012 version had many bug fixes. So I paid NEARLY FULL PRICE for the upgrade (it would have been cheaper to buy a totally new version here on Amazon; so live and learn...)  But did they fix the bugs that were annoying me? NO!!!! WHAT A RIPOFF PRODUCT!!!! I could go on and on with various annoying habits of this software, but I WANT OUT!!!!  Unfortunately, Microsoft discontinued Money and there just aren\'t any \\\\"name brand\\\\" competitors; which is probably why Intuit gets away with selling this Piece-o-S***!'],
#       dtype=object), 'sample_prob': 0.3099385935144684}, {'reward': -1, 'event_id': 159332078504367823698295438170974715906, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['It made filing our taxes easy by following the step by step instructions.'],
#       dtype=object), 'sample_prob': 0.9183465645132565}, {'reward': 1, 'event_id': 159510058233203117388694793208321933314, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["Well...I presume this product to be Microsoft's revenge.  Word is a shell of the PC version, and the only reason this expensive little box gets 2 stars is Outlook.  It should be noted, however, that Outlook doesn't measure up to Windows compatible versions either.  If you can get by with native iOS tools, do it."],
#       dtype=object), 'sample_prob': 0.10472198181158321}, {'reward': -1, 'event_id': 159644155067385010353502904049590206466, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["Every couple of years Intuit makes me buy a newer copy of Quickbooks. They do this by taking away functions of the program that are crucial until you purchase a newer version of the software. (Emailing especially).<br />This new version has crashed every time I've tried to use it.  It doesn't recognize my imported templates. If I send an email it shuts down. Every year they make dramatic changes to the program and you have to relearn how to use it every time.<br />For the $160-$399 price tag on these software programs they should be flawless. ."],
#       dtype=object), 'sample_prob': 0.5389145480395857}, {'reward': -1, 'event_id': 159795750233539803737054391044163108866, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['Thanks so much!'], dtype=object), 'sample_prob': 0.2972819478419799}, {'reward': -1, 'event_id': 159912091244220624915449344823588421634, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["Use this at least once a week just to clean out all the junk that accumulates.  It's hard to believe that many cookies can nest inside your computer without even realizing it.  Easy to use, cleans well."],
#       dtype=object), 'sample_prob': 0.6386422749182094}, {'reward': -1, 'event_id': 160036202160799220000289631421789765634, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["Used in the last few years and it was good software, however this year had nothing but trouble. I had a rental property that I sold in Jan. of 2014 and took a huge loss on the property.  Tax Act didn't even ask me anything about the sale price of the home.  I have to report the sale on schedule E, but the software does not help at all.<br /><br />Another issue was that I could not register with TaxACT so as to get my State Software to download. I tried numerous times to register, but it wouldn't let me.  I called tech support at TaxACT and they told me that the problem is that I bought the software from Amazon and not them.  I was told to get a refund from Amazon and purchase it from them.<br /><br />I did get a refund from Amazon, but chose to buy H&R Block Premium through Amazon instead because of the rental property sale that I had trouble with when using TaxACT Deluxe."],
#       dtype=object), 'sample_prob': 0.7672284514590547}, {'reward': -1, 'event_id': 160178762147300886678781950664266350594, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['Software provides what I wanted.<br /><br />The dowmload process, however, was a major, major undertaking. It required several calls to Amazon, to Microsoft and more to get a real person to assist in the download. It was a tiresome process.  It was far from being user friendly'],
#       dtype=object), 'sample_prob': 0.32572588793615864}, {'reward': -1, 'event_id': 160326385605668839991089873300608909314, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['The software was received by download. H&R Block tax software was chosen because it handles our two state returns properly. TurboTax never properly attributed the tax we paid in another state and in the next year, even after I informed them, they did not correct the problem.'],
#       dtype=object), 'sample_prob': 0.5743943938576627}, {'reward': -1, 'event_id': 160460876203818428849655824055310352386, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['I purchased this product almost a month ago.  I have had a support ticket open since the day I bought it and is still unresolved!  I cannot use the mobile app and it will not connect to my bank for automatic updates.  I get \\\\"Unexpected Error, Not your fault\\\\".  I have been told by customer service that they are working on it, but the issue on their help webpage says it has been going on since April of 2013!  I would never have bought this if the mobile part was not functional.  Horrible customer service, Intuit.'],
#       dtype=object), 'sample_prob': 0.6822048196314678}, {'reward': 1, 'event_id': 160613679599451564764355612595125878786, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['Only lasts for a month and constantly reminds you that it is going to expire.'],
#       dtype=object), 'sample_prob': 0.1721004995030152}, {'reward': -1, 'event_id': 160883408709604877131119329232286777346, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['Adobe photoshop elements 9 is a gr8 program to use for those who want to raise there fotos up another notch.'],
#       dtype=object), 'sample_prob': 0.3061791257800286}, {'reward': -1, 'event_id': 161012909518079317615988570661862899714, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['I bought this program with some trepidation as previous tax software which I have used just were not fully applicable to our tax situation.  My husband is a pastor, and we can attest that this is the first software we have seen which is set up for the various issues clergy face.<br /><br />We found also that TurboTax is quite intuitive, helping us maximize our deductions, and saved us several hundred dollars over the tax preparation company we used last year.'],
#       dtype=object), 'sample_prob': 0.3647865115953087}, {'reward': -1, 'event_id': 161146681516794902094155014009368215554, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['It is typical Quicken.  Very useful for my family budget, but could be a bit more user-friendly in some of its functions.  It is sometimes hard to know where to find the place to click for the desired action such as repeating scheduled transactions, adjusting a loan payment, etc.<br /><br />Overall though, there is not much else on the market that does what Quicken will do so I deal with the quirks.'],
#       dtype=object), 'sample_prob': 0.966207663935557}, {'reward': -1, 'event_id': 161287228315687081318686615263633342466, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["We use this software every year and it does a good job of guiding you through the process (NY Fed & State). We are hesitant to recommend for doing taxes when there are non-basic (house sale, death, inheritance, etc... ) tax issues as we haven't done anything like that. I'm not saying it wouldn't guide you through it, it's just we never have used it for that. I probably would want to sit down with a good tax preparer and make sure those are covered completely.<br /><br />I did have an experience with helping a family member recently who had her tax preparer make a 10K mistake and it is costing her + penalties. For that, I can say we have NOT had any issues with the software making any mistakes on our returns. Just sometimes a little buggy but they do send out patches and updates."],
#       dtype=object), 'sample_prob': 0.4631507368732376}, {'reward': -1, 'event_id': 161445372481755303789526050637574438914, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['Downloaded in very short time & no problems with conversion from 2012 to 2013<br />Some nice new features with mobile applications'],
#       dtype=object), 'sample_prob': 0.6288809477536559}, {'reward': -1, 'event_id': 161598854070459561809813173877171421186, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['I purchased this product almost a month ago.  I have had a support ticket open since the day I bought it and is still unresolved!  I cannot use the mobile app and it will not connect to my bank for automatic updates.  I get \\\\"Unexpected Error, Not your fault\\\\".  I have been told by customer service that they are working on it, but the issue on their help webpage says it has been going on since April of 2013!  I would never have bought this if the mobile part was not functional.  Horrible customer service, Intuit.'],
#       dtype=object), 'sample_prob': 0.5564463918680774}, {'reward': -1, 'event_id': 161736601738370112069582527296538017794, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['Excellent.'], dtype=object), 'sample_prob': 0.8733444362221723}, {'reward': -1, 'event_id': 161862802693875833447648531584149225474, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["Ever since my husband and I found avast! antivirus a few years ago, we have not used anything  else. Our computers have been clean since the first day and we have 3 teenage boys. We have used the free and the pay and are happy with both. We won't use anything else."],
#       dtype=object), 'sample_prob': 0.5962490302893584}, {'reward': -1, 'event_id': 161982027609672173853646958290499928066, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["I started using Webroot last year.  It's my favorite security software.  It downloads and installs with no problems, works completely unnoticed in the background, and always catches any virus that shows up.  It also scans and cleans up your PC super quick.  The only time it seeks your attention is when it detects a virus, detects a webpage that may be trouble, or when your subscription has less than 30 days left.  I never pay full price for it, and never will for any security software."],
#       dtype=object), 'sample_prob': 0.06318729110936439}, {'reward': -1, 'event_id': 162105370013074380574412587512383012866, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['No easy way to get photos and videos out of this service.'],
#       dtype=object), 'sample_prob': 0.6672823549573156}, {'reward': 1, 'event_id': 162282576475043535047734563524341530626, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["I was looking for a simple converter to convert WAV to MP3.  The description indicated that this software would do it simply.  Not so!  It won't even simply import an audio file much less convert it.  It may be great for video and may actually do my conversion, but it is not user friendly at all.  If your task is as simple as mine there are several easier softwares to use.  They sell on amazon but take hours to recognize the sale of their downloaded product.  Normally I'm pretty easy to please,  but their support was unreachable.  Not even a FAQ list that was worth anything.  Buy something else or get some freeware."],
#       dtype=object), 'sample_prob': 0.9553163185636144}, {'reward': -1, 'event_id': 162577874890085075944169844600594366466, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["Used in the last few years and it was good software, however this year had nothing but trouble. I had a rental property that I sold in Jan. of 2014 and took a huge loss on the property.  Tax Act didn't even ask me anything about the sale price of the home.  I have to report the sale on schedule E, but the software does not help at all.<br /><br />Another issue was that I could not register with TaxACT so as to get my State Software to download. I tried numerous times to register, but it wouldn't let me.  I called tech support at TaxACT and they told me that the problem is that I bought the software from Amazon and not them.  I was told to get a refund from Amazon and purchase it from them.<br /><br />I did get a refund from Amazon, but chose to buy H&R Block Premium through Amazon instead because of the rental property sale that I had trouble with when using TaxACT Deluxe."],
#       dtype=object), 'sample_prob': 0.9804903404861974}, {'reward': -1, 'event_id': 162735391569106185444313073070015381506, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['This company needs to upgrade their customer support, which has been unable to resolve my issues, so the upgrade is for naught at this juncture.'],
#       dtype=object), 'sample_prob': 0.9247819118146299}, {'reward': -1, 'event_id': 162869310932204046454147440409268322306, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["Easy to use and appears to be complete.  My only complaint is that they call it 2015 and it went on sale in mid 2014.  Since you don't get updates, on way of nothing how up to date it really is."],
#       dtype=object), 'sample_prob': 0.8679909521636693}, {'reward': -1, 'event_id': 163009365724207012094285051792035282946, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["Easy to use and appears to be complete.  My only complaint is that they call it 2015 and it went on sale in mid 2014.  Since you don't get updates, on way of nothing how up to date it really is."],
#       dtype=object), 'sample_prob': 0.4880304469798926}, {'reward': -1, 'event_id': 163177552059873917572772002825248047106, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["I not only have PC MATIC  but I also have VIPRE voted by PC Mag as one of the top 5 best Antivirus programs out there. I was comparing both of them and have to say that PC MATIC not only does just as good a job as VIPRE but PC MATIC has several other benefits that VIPRE does not have, so for the money and what you get with PC MATIC it's a No-Brainer for me I'm renewing my PC MATIC subscription and letting VIPRE expire."],
#       dtype=object), 'sample_prob': 0.6411380887677466}, {'reward': -1, 'event_id': 163339624358239597272326860071813382146, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['il kie it'], dtype=object), 'sample_prob': 0.2012159633463776}, {'reward': -1, 'event_id': 163478984319257312814223776074135896066, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['It is typical Quicken.  Very useful for my family budget, but could be a bit more user-friendly in some of its functions.  It is sometimes hard to know where to find the place to click for the desired action such as repeating scheduled transactions, adjusting a loan payment, etc.<br /><br />Overall though, there is not much else on the market that does what Quicken will do so I deal with the quirks.'],
#       dtype=object), 'sample_prob': 0.49362908017646556}, {'reward': -1, 'event_id': 163612665205586005888401986846098325506, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['Beware of doing business with AVG.  Hidden in the fine print is that you are agreeing to AUTO UPDATE FOR ANNUAL CHARGES EVERY YEAR WITHOUT THEIR NOTIFYING YOU ! ! !  Do not believe that their Anti Virus is any good.  Why should I pay for a NONE WORKING ANTI VIRUS SOFTWARE  when I can get it for free and have it not work ! ! !  Contrary to the STAR RATING its not worth even one star ! ! !'],
#       dtype=object), 'sample_prob': 0.9037564494136645}, {'reward': -1, 'event_id': 163746949018231432514189284487522811906, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["I wish I'd known this before upgrading. I do my payroll with PNC Bank and it downloads fine with Quicken 2011 but 2014 doesn't and they aren't going to fix it. You have to buy Quickbooks."],
#       dtype=object), 'sample_prob': 0.9638787218173226}, {'reward': -1, 'event_id': 163900639769284728186612586756015521794, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["Been a quicken user since 1996 so I have a significant amount of history in this application..<br /><br />Last time I upgraded was to 2012. Tried upgrading to 2013 without a hitch. Data was converted to the new format..<br /><br />Unfortunately data entry is... Slow.. Horribly slow.. The application is not responsive at all.. Downloaded all of the patches.. Still do not notice a difference in performance..<br /><br />I'm currently running the windows version of Quicken on an I7-2600K desktop with 16 GB of Ram...<br /><br />So I really don't expect applications to run slow on my desktop.. Unfortunately Quicken 2013 performs like each transaction is a pain to record. Like it is searching for something.<br /><br />Application Prompts stay on the screen for extended periods, sometime requiring responses to be recorded multiple times.<br />The Reconcile Screen, works best when you use a mouse to mark transaction as reconciled. If I use the keyboard and space bar, the application response slows considerably.. Counter intuitive as most applications perform better when using short cuts rather then the mouse.<br /><br />Tried the iPad application which is supposed to support data sharing between desktop and ipad.. Wasn't happy that my budgets setup on my desktop were not currently supported..<br /><br />May switch to Mint, (same company) as this web-app may be the best alternative at this time.. Hope Quicken gets its act together soon as the application options are slim in this area..<br /><br />Updated: Restarted my process by recreating a file from scratch. Application runs a lot quicker. Apparently the issue is that it doesn't perform well with a lot of data. The common thread is that a lot of the frustrated users are long time users with history. I don't use the product as much as I did prior although I still use it for balancing my checkbook."],
#       dtype=object), 'sample_prob': 0.2323707051031445}, {'reward': -1, 'event_id': 164022372256424645059158465281665400834, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['Works just fine.'], dtype=object), 'sample_prob': 0.5292013533530866}, {'reward': -1, 'event_id': 164311753120007995551956268406996598786, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["The norton 360 from amazon was a great price but it sure slows down the computer.  After turning on the computer it takes a long time before you can do anything that doesn't freeze the screen , when you go onto the internet or you just want to play one of your own games.  It does find problems but they aren't very easy to fix."],
#       dtype=object), 'sample_prob': 0.11982691082269281}, {'reward': -1, 'event_id': 164453489925901139023505016542211473410, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['I needed a full service solution and needed better support options for obtaining my data, so I switched from Invoice2Go! to QB online... been using it now for just over 3 months and very happy.'],
#       dtype=object), 'sample_prob': 0.25478318594616656}, {'reward': -1, 'event_id': 164627768907265391427171351327256215554, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['I have been using Quicken for over 15 years very successfully.  This version crashes and crashes and wipes out files.  Very frustrating.'],
#       dtype=object), 'sample_prob': 0.37814700645799904}, {'reward': -1, 'event_id': 164825745824319285441618410599183679490, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['I was told this could be used when you have a business, Schedule C.. Not true.  Turbotax is a loser for 2014.  Requesting refund.'],
#       dtype=object), 'sample_prob': 0.8479479995695084}, {'reward': -1, 'event_id': 164971648446997428930132241682976079874, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['Great stuff!!!!!'], dtype=object), 'sample_prob': 0.4121385018226529}, {'reward': -1, 'event_id': 165114632304168546925212246163535822850, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['In my experience, the Free version of Avast is better than the pay versions of McAfee and Norton!<br />The pay version of Avast is far superior to anything else on the market!'],
#       dtype=object), 'sample_prob': 0.005265048815173867}, {'reward': -1, 'event_id': 165224625554468725247736739165226795010, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["Free isn't really free.  Way to many catches and hoops to jump through.  Had to renew my &#34;not free&#34; Norton instead"],
#       dtype=object), 'sample_prob': 0.3547556213302926}, {'reward': -1, 'event_id': 165331441755452081570323731054509293570, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["I've had mixed experiences with Intuit products in general. Many of the times I experience issues with them locking up, not saving, corrupting files, and so forth. With this product, I did not experience that.<br /><br />I purchased this software for a couple business returns I needed to file and was surprised at how easy it was to navigate through the various sections that needed to be filled out. The results were good and the return printed appropriately. The eFile worked well, too, and the return was accepted by the IRS within 8 hours.<br /><br />I plan on purchasing the product again for my 2014 business returns. I wish they would include the personal 1040 return preparation feature with this, especially for the money you're paying. Unfortunately, you have to buy that separately, AND pay additional money to be able to prepare a state tax return with your federal.<br /><br />All in all, I'd give the software a 4-star. There are improvements that could be made; there are features that should be added; but as it is, it does what it's designed to do and it doesn't take very long to get the hang of it, get your information entered, and get the returns submitted."],
#       dtype=object), 'sample_prob': 0.8301652994581463}, {'reward': -1, 'event_id': 165442894388505772641946697135765454850, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['This new version has a lot of the same as previous versions that can be printed as pre-made cards, banners, calendars, posters, etc. But, now every individual item must be downloaded and often times there are additional charges; $0.99 and up per item. Where before there were thousands of projects and clip art that were included with the software download. I was able to make what I wanted to make, a calendar with additional birthdates and pictures, it just took longer to find something that worked that did not have an additional charge attached to it. I am quite impressed with the updates of this new version in way of built-in page borders so your text or pictures did not shift off the page during printing; also that the text and pictures I add in a calendar, do not overlap the lines for that month! Much more user friendly.'],
#       dtype=object), 'sample_prob': 0.8394179805863505}, {'reward': -1, 'event_id': 165560827885253130536384815112159100930, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['I was told this could be used when you have a business, Schedule C.. Not true.  Turbotax is a loser for 2014.  Requesting refund.'],
#       dtype=object), 'sample_prob': 0.0025561261381875644}, {'reward': -1, 'event_id': 165690548948019360678970100557483737090, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["This years version is mostly trouble free - no crashes but if your are new to this product make sure you look at the forms as there can be incorrect entries from either the interview process or the easy step. Importing from Intuit's  Quicken product be very careful for schedule E,C when you print from quicken and you must verify the entries that import to Turbotax which loads different numbers. I eventually selected to enter myself from the quicken print copy. Still playing with the entries of business expenses as the interview and step by step placed incorrect entries in the form result was the same. It aggregated some of my expenses as other when there were actual lines the net effect was the same  but I was looking for accuracy.  I have been using this product for over a decade. Additional notes on TT -It has problems with K-1's - If you have values in lines 1,2,3 it says they are mutually exclusive. The work around is to enter the line 1 data as one K1 and line 2 as another k1,etc. Works out ok lists on schedule E and C correctly when you do this. TT needs to have a check box screen for the variations like do you have data in line 1,2,3  and than handle each one correctly. 1099-t does not ask about additional data to reconcile - it is one the form version . so if you have  no value in box 1 and have reconciliation data on the 1099-t enter on the form as the easy step does not ask."],
#       dtype=object), 'sample_prob': 0.004388504531432913}, {'reward': -1, 'event_id': 165823298903438511147920177526918479874, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['il kie it'], dtype=object), 'sample_prob': 0.9904476042609042}, {'reward': -1, 'event_id': 166115562879855755720225625869873446914, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['Easy and works very well. Simple download and setup.'],
#       dtype=object), 'sample_prob': 0.7561618579315595}, {'reward': -1, 'event_id': 166259784280925346521877281728988577794, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['Great stuff!!!!!'], dtype=object), 'sample_prob': 0.5520837128565483}, {'reward': -1, 'event_id': 166402720601198955955973170305229258754, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['Would be kind of nice IF I COULD ACTUALLY GET IT TO DOWNLOAD! OR EVEN GET ASSISTANCE FROM ANYONE at MICROSOFT to Correct this $100 Purchase for FREE MONEY TO MICROSOFT! Such a Joke!  Half a mind to report to BBB and any other format I can.  Will be reversing this credit card purchase!'],
#       dtype=object), 'sample_prob': 0.7391030431747478}, {'reward': -1, 'event_id': 166546483271207589163990009428034322434, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["This is a lot better than the previous version I used 2 years ago, which I swore I would not use again.  However, with Turbo Tax's price increases and the more recent reviews of this product, I decided to try it again and I was very pleased."],
#       dtype=object), 'sample_prob': 0.10928534966726045}, {'reward': -1, 'event_id': 166690158790237456686737205547280498690, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["I've had mixed experiences with Intuit products in general. Many of the times I experience issues with them locking up, not saving, corrupting files, and so forth. With this product, I did not experience that.<br /><br />I purchased this software for a couple business returns I needed to file and was surprised at how easy it was to navigate through the various sections that needed to be filled out. The results were good and the return printed appropriately. The eFile worked well, too, and the return was accepted by the IRS within 8 hours.<br /><br />I plan on purchasing the product again for my 2014 business returns. I wish they would include the personal 1040 return preparation feature with this, especially for the money you're paying. Unfortunately, you have to buy that separately, AND pay additional money to be able to prepare a state tax return with your federal.<br /><br />All in all, I'd give the software a 4-star. There are improvements that could be made; there are features that should be added; but as it is, it does what it's designed to do and it doesn't take very long to get the hang of it, get your information entered, and get the returns submitted."],
#       dtype=object), 'sample_prob': 0.5138767828043073}, {'reward': -1, 'event_id': 166864018654622008635177820601665585154, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['Love is so far still trying to learn all the tricks. love to be able to make my photos look professional.'],
#       dtype=object), 'sample_prob': 0.28163238749384223}, {'reward': -1, 'event_id': 167003728011836412082803524132809080834, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["The norton 360 from amazon was a great price but it sure slows down the computer.  After turning on the computer it takes a long time before you can do anything that doesn't freeze the screen , when you go onto the internet or you just want to play one of your own games.  It does find problems but they aren't very easy to fix."],
#       dtype=object), 'sample_prob': 0.5244799583720304}, {'reward': -1, 'event_id': 167137602214881639961965463152010330114, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['Works just fine.'], dtype=object), 'sample_prob': 0.9591012327133626}, {'reward': -1, 'event_id': 167260678411657798754556778066220285954, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['It is typical Quicken.  Very useful for my family budget, but could be a bit more user-friendly in some of its functions.  It is sometimes hard to know where to find the place to click for the desired action such as repeating scheduled transactions, adjusting a loan payment, etc.<br /><br />Overall though, there is not much else on the market that does what Quicken will do so I deal with the quirks.'],
#       dtype=object), 'sample_prob': 0.7837974008199194}, {'reward': -1, 'event_id': 167388861655789627023229222706631278594, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["Great service - best online asset for home users.  I've used it for years and am thankful for Avast!  I recommend it!"],
#       dtype=object), 'sample_prob': 0.638309642827643}, {'reward': -1, 'event_id': 167523589146145133529307044194177646594, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['It made filing our taxes easy by following the step by step instructions.'],
#       dtype=object), 'sample_prob': 0.01620892988628342}, {'reward': 1, 'event_id': 167831576743694959004908841233082875906, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['I have used QUICKEN for 15 years. Over time it has gotten more difficult to use. For example, there should be a simple button for \\\\"Write Checks\\\\" since this happens all the time. Instead it is buried in a menu under \\\\"TOOLS\\\\" - not intuitive. However, I have to have financial check writing and finance tracking software. I wish the developers would make improvements to simplify rather than complicate it\'s use for just writing checks and tracking spending.'],
#       dtype=object), 'sample_prob': 0.3712867397585917}, {'reward': -1, 'event_id': 167997281653311917724342362469771116546, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["I now run several businesses in the UK. I use an accountant I have known for many years and have always been happy with their service. I have had very little need for such software, especially given the price of accounting software packages. I am not a computer whiz and sometimes find complicated Microsoft software packages difficult to use.<br /><br />I reviewed Quickbooks Premier 2012 previously and my review is virtually identical to that one. I received this software free of charge via the Amazon Vine programme. In truth I would not have bought such software, given my relationship with my accountant. I therefore used this opportunity to try the software without any risk or guilt. As this is the second tine of using I am getting used to how the programme works and the ultimate ease of use.<br /><br />It was simplicity itself to install. The software gives you a comprehensive and easy to use accounting package. Whilst my area of business pertains to the service sector and does require the holding of stock, the software can easily handle business situations where stock control is necessary. It can easily track sales, expenses and profits and can create professional looking invoices using PDF's for emails. It can automatically calculate VAT and creates an Efile so you can send it directly to HMRC. It works with all Office programmes so there is great compatibility, so allowing greater ease of use. It also allows you to create budgets and cash flow projections. In short this software can handle virtually anything a small to medium sized business can throw at it. It also includes payroll software free for 12 months, which allows you to calculate wages, NI, Tax for your employees.<br /><br />A final note on this particular package, there is a difference between Quickbooks Pro 2013 and Premier 2013 software. The Premier software contains additional Time Saving Tools such as, the ability to create budgets and cash flow forecasts, it allows you to create back orders and so automatically set stock aside for order fulfillment, track unbilled expenses and allow you to set different prices on the same item depending upon client or job. All of these time saving options work in the same intuitive way as the rest of the package.<br /><br />Whilst I am a stick in the mud and like the reassurance that my accountant brings, this software is the next best thing. It is easy to use and does virtually everything you will require. A great product at a great price, compared to other accounting software packages."],
#       dtype=object), 'sample_prob': 0.4217501054882882}, {'reward': -1, 'event_id': 168126596275604449688018259071063949314, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["It's taking me a while to learn the idiosyncrasies of the program, but overall, I'm satisfied with it."],
#       dtype=object), 'sample_prob': 0.19563832798586367}, {'reward': -1, 'event_id': 168275332097374103271625995064469225474, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["I bought this primarily to track expenses now that I'm entering retirement.  I've been using Mint.com and PersonalCapital.com (free, online tools) to do this - and they work great, but I bought Quicken as I'm a little uncomfortable having all my financial information on someone's website.  Anyway, both Mint and PersonalCapital report all my account balances accurately while Quicken 2014 does not.  The online help system and forum are useless.  I believe I've wasted my money on this product.  Quicken was a favorite of mine in previous years for balancing my checkbook, but Intuit appears to have broken Quicken, with the online functionality.  (Actually Mint.com has been recently purchased by Intuit - I hope they don't break that.)"],
#       dtype=object), 'sample_prob': 0.31101750506955694}, {'reward': -1, 'event_id': 168418883228188823399363169319713374210, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['il kie it'], dtype=object), 'sample_prob': 0.7465161204956415}, {'reward': -1, 'event_id': 168547208290731552204320056520633090050, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['Great product.  I have been using the software for a dozen years and will continue using year after year.  I recommend using this product.'],
#       dtype=object), 'sample_prob': 0.41891037039402645}, {'reward': -1, 'event_id': 168682398473556142014129424304849420290, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['I purchased this product almost a month ago.  I have had a support ticket open since the day I bought it and is still unresolved!  I cannot use the mobile app and it will not connect to my bank for automatic updates.  I get \\\\"Unexpected Error, Not your fault\\\\".  I have been told by customer service that they are working on it, but the issue on their help webpage says it has been going on since April of 2013!  I would never have bought this if the mobile part was not functional.  Horrible customer service, Intuit.'],
#       dtype=object), 'sample_prob': 0.2922809720682499}, {'reward': -1, 'event_id': 168855763161924979810460079709544906754, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['Great product.  I have been using the software for a dozen years and will continue using year after year.  I recommend using this product.'],
# ...
#       dtype=object), 'sample_prob': 0.5357490895966253}, {'reward': -1, 'event_id': 169780522197607724584547093713372971010, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['Would be kind of nice IF I COULD ACTUALLY GET IT TO DOWNLOAD! OR EVEN GET ASSISTANCE FROM ANYONE at MICROSOFT to Correct this $100 Purchase for FREE MONEY TO MICROSOFT! Such a Joke!  Half a mind to report to BBB and any other format I can.  Will be reversing this credit card purchase!'],
#       dtype=object), 'sample_prob': 0.03685295246984732}, {'reward': -1, 'event_id': 169913087551408216816851987386514669570, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["After almost fourteen years ( began using 1997 ) Quicken has finally pushed me over the edge. I will NOT buy another version.  Quicken Deluxe 2014 (QD2014) is the MOST frustrating interface I have EVER used. Whenever I get done using QD2014 it is Wild Turkey time to calm my nerves.<br />INSTALL:<br />I have to admit the upgrade from QD2011 to QD2014 was actually painless but that is about the only pain-free step I have encountered.  After importing && converting my backup QDF from 2011 to 2014 I noticed my system was incredibly slow. Quicken has grabbed half the CPU & RAM. Opening & closing the software did nothing to resolve that issue, a reboot was necessary to resolve that problem. After rebooting and opening QD2014 I do have to admit that opening QD2014 did seem noticeably faster than QD2011 but that is where any noticeable gains end.<br />APPLICATION:<br />Entering the GUI I noticed no differences between QD2011 & QD2014. Then I began to use the GUI and that is where the frustration began. Below is a list of every irritation I have encountered thus far.<br />- Alt+Tab from QD2014 to any other application and QD2014 looses focus on the field you are on and moves focus to the toolbar.<br />- Virtually NONE of the keyboard shortcuts work any longer. i.e.;Ctrl+C, Ctrl+P, etc. They are listed but they do not work. Delete ( Ctrl+D ) works but that is all I have found.<br />- None of the transactions edits work ( Edit >> Transaction >> Copy, Paste, etc. ) when using a mouse gesture. When tried they simply change focus to the transaction behind the pop-up menu. If I click Edit, then finish navigating with the arrows on the keyboard, the Transaction Edits will work.<br />- When entering memorized fields ( Payee, Category, etc. ) the keyboard usage is changed.  Atl+Down Arrow used to bring up menu. The only thing the Alt key does any more is remove focus so you have to use the mouse to put it back on your field.<br />- The Category fields do not remember the last category any longer with a consistent logic. For example having multiple sub-classes under Auto for fuel, repair, etc only returns the update to the high level Auto. Most times the category history is simply alphabetized with focus set to the first alphabetic choice. For example, when entering a transaction for a restraunt we frequent the category choice always defaults to Gift: Birthday and not Dining because I once bought a gift card for a Birthday gift. QD2011 defaulted to last usage.<br />- Many pop-up screens have a Red-X in the top right corner to close the pop-up screen, but the Red-X is never enabled.<br />- Most areas of the register require the user to click two times to set focus. The first click generates of flash of some sort, the second click sets the focus. I think the first click flash opens the pop-up menu for the field, then the second click sets focus.<br />- If you change an amount for a register entry that has split transaction entries the interface goes haywire. I have an entry for my car note as a scheduled payment, Quicken prompts me with the principle plus calculated interest amount. I generally accept the calculated amount. If I pay extra in a month and I go into QD2014 and change the entered amount, and hit 'Enter' QD2014 says the split items do not match, click ok to edit the split. QD2014 now brings up the split amount for the next transaction in the register.<br /><br />I went to a few Quicken support sites and I read that Quicken was claiming that some of actions are new features. WTCuss?!  Who decided that? I can see if they wanted Quicken to operate differently and adding that option in the application ( Edit >> Preferences >> Setup ) but the Setup Switch does virtually nothing.<br />After years of small a ...
#       dtype=object), 'sample_prob': 0.5908689716217284}, {'reward': -1, 'event_id': 170049419412054637175766078139055341570, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["The product worked fine, until I had re refresh my PC and re install.  When I attempted to re-install, the system no longer recognized m account...so I wasted my weekend trying to just get logged in.  Tech support and Customer service are outsourced and useless.  Save the headache of dealing with these guys...they don't deserve to be considered professional."],
#       dtype=object), 'sample_prob': 0.03260422922426209}, {'reward': -1, 'event_id': 170175589468576977990740420944525918210, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["I wish I'd known this before upgrading. I do my payroll with PNC Bank and it downloads fine with Quicken 2011 but 2014 doesn't and they aren't going to fix it. You have to buy Quickbooks."],
#       dtype=object), 'sample_prob': 0.6811981448779456}, {'reward': -1, 'event_id': 170310703592365554106785698926549925890, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['This new version has a lot of the same as previous versions that can be printed as pre-made cards, banners, calendars, posters, etc. But, now every individual item must be downloaded and often times there are additional charges; $0.99 and up per item. Where before there were thousands of projects and clip art that were included with the software download. I was able to make what I wanted to make, a calendar with additional birthdates and pictures, it just took longer to find something that worked that did not have an additional charge attached to it. I am quite impressed with the updates of this new version in way of built-in page borders so your text or pictures did not shift off the page during printing; also that the text and pictures I add in a calendar, do not overlap the lines for that month! Much more user friendly.'],
#       dtype=object), 'sample_prob': 0.8924644377830685}, {'reward': -1, 'event_id': 170438120700165869442433764113798791170, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['I was a Quicken fan from the early days, so when H&B was created I though it was the perfect home business solution. It worked ok on a PC but it fails miserably on a virtual PC running on VM WARE.<br />I was about to upgrade and try it again since the product is selling for close to half off on Amazon and at Costco.<br /><br />These reviews have stopped me cold.'],
#       dtype=object), 'sample_prob': 0.058193990522788286}, {'reward': 1, 'event_id': 170568100046741896084378044734452662274, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['Only lasts for a month and constantly reminds you that it is going to expire.'],
#       dtype=object), 'sample_prob': 0.7831408656570714}, {'reward': -1, 'event_id': 170696042437259680994965914896041115650, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["The norton 360 from amazon was a great price but it sure slows down the computer.  After turning on the computer it takes a long time before you can do anything that doesn't freeze the screen , when you go onto the internet or you just want to play one of your own games.  It does find problems but they aren't very easy to fix."],
#       dtype=object), 'sample_prob': 0.4963414918079375}, {'reward': -1, 'event_id': 170834372432164711101212705165898022914, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["Easy to use and appears to be complete.  My only complaint is that they call it 2015 and it went on sale in mid 2014.  Since you don't get updates, on way of nothing how up to date it really is."],
#       dtype=object), 'sample_prob': 0.12203556277835415}, {'reward': -1, 'event_id': 170958402536017541635690056010381262850, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['Adobe photoshop elements 9 is a gr8 program to use for those who want to raise there fotos up another notch.'],
#       dtype=object), 'sample_prob': 0.29290193707452905}, {'reward': -1, 'event_id': 171235984741639267884334635062788227074, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['have used HR Block for over 10 years.  Love it.'], dtype=object), 'sample_prob': 0.716759651185954}, {'reward': -1, 'event_id': 171406059876700513423891225844888240130, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['Great software and have no issues from the installation or updates. I left the software scan my drives at least once or twice a month.'],
#       dtype=object), 'sample_prob': 0.738769370487238}, {'reward': -1, 'event_id': 171532145159088963976762933897220718594, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["I love Quicken because it organizes s much personal finance information.  Most accounts can be downloaded right into the program.  I gave 3 stars for this product because the business side is lacking.  It now allows you to see your dealings in an app on your smartphone but the program is very bare bones on the business side and not super user friendly.  It's not as close to QuickBoQuick books as I imagined it would be."],
#       dtype=object), 'sample_prob': 0.8535905447699147}, {'reward': -1, 'event_id': 171677911509327582932997663863367401474, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["I found this free antivirus years ago. It quickly identified and removed several threats. I've been using it ever since and my computers run great. It continues to be a great antivirus. I will never use another. I highly recommend."],
#       dtype=object), 'sample_prob': 0.4080227830170954}, {'reward': -1, 'event_id': 171820263125761837096282112085254602754, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['I needed a full service solution and needed better support options for obtaining my data, so I switched from Invoice2Go! to QB online... been using it now for just over 3 months and very happy.'],
#       dtype=object), 'sample_prob': 0.08964227126818392}, {'reward': -1, 'event_id': 171996649576248968930589844800489521154, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["I've had mixed experiences with Intuit products in general. Many of the times I experience issues with them locking up, not saving, corrupting files, and so forth. With this product, I did not experience that.<br /><br />I purchased this software for a couple business returns I needed to file and was surprised at how easy it was to navigate through the various sections that needed to be filled out. The results were good and the return printed appropriately. The eFile worked well, too, and the return was accepted by the IRS within 8 hours.<br /><br />I plan on purchasing the product again for my 2014 business returns. I wish they would include the personal 1040 return preparation feature with this, especially for the money you're paying. Unfortunately, you have to buy that separately, AND pay additional money to be able to prepare a state tax return with your federal.<br /><br />All in all, I'd give the software a 4-star. There are improvements that could be made; there are features that should be added; but as it is, it does what it's designed to do and it doesn't take very long to get the hang of it, get your information entered, and get the returns submitted."],
#       dtype=object), 'sample_prob': 0.29059485960506726}, {'reward': -1, 'event_id': 172112810739000882734916145315551772674, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["Ever since my husband and I found avast! antivirus a few years ago, we have not used anything  else. Our computers have been clean since the first day and we have 3 teenage boys. We have used the free and the pay and are happy with both. We won't use anything else."],
#       dtype=object), 'sample_prob': 0.8471828843060805}, {'reward': -1, 'event_id': 172246822799048885430905346984388984834, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['Software provides what I wanted.<br /><br />The dowmload process, however, was a major, major undertaking. It required several calls to Amazon, to Microsoft and more to get a real person to assist in the download. It was a tiresome process.  It was far from being user friendly'],
#       dtype=object), 'sample_prob': 0.5152461358052678}, {'reward': -1, 'event_id': 172387821990749021105067223527881572354, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(['This new version has a lot of the same as previous versions that can be printed as pre-made cards, banners, calendars, posters, etc. But, now every individual item must be downloaded and often times there are additional charges; $0.99 and up per item. Where before there were thousands of projects and clip art that were included with the software download. I was able to make what I wanted to make, a calendar with additional birthdates and pictures, it just took longer to find something that worked that did not have an additional charge attached to it. I am quite impressed with the updates of this new version in way of built-in page borders so your text or pictures did not shift off the page during printing; also that the text and pictures I add in a calendar, do not overlap the lines for that month! Much more user friendly.'],
#       dtype=object), 'sample_prob': 0.32303445684616394}, {'reward': -1, 'event_id': 172524554745897763641266921459539902466, 'action': 1, 'action_prob': 0.9995, 'model_id': 'bandits-1597616270-model-id-1597616291', 'observation': array(["I've used Norton for years. I've tried others but never had the same results. Good price for 1/3 as I can use them as needed."],
#       dtype=object), 'sample_prob': 0.128476156433594}]
# INFO:orchestrator:Successfully create S3 bucket 'sagemaker-us-east-1-835319576252' for athena queries
# INFO:orchestrator:Started dummy local joining job...
# INFO:orchestrator:Splitting data into train/evaluation set with ratio of 0.8
# INFO:orchestrator:Joined data will be stored under s3://sagemaker-us-east-1-835319576252/bandits-1597616270/joined_data/bandits-1597616270-join-job-id-1597616350
# INFO:orchestrator:_upload_data_buffer_as_joined_data_format put s3://sagemaker-us-east-1-835319576252/bandits-1597616270/joined_data/bandits-1597616270-join-job-id-1597616350/train/local-joined-data-1597616350.csv
# INFO:orchestrator:_upload_data_buffer_as_joined_data_format put s3://sagemaker-us-east-1-835319576252/bandits-1597616270/joined_data/bandits-1597616270-join-job-id-1597616350/eval/local-joined-data-1597616350.csv

# %% [markdown]
# # Reset the Simulator

# %%
sim_app.clear_buffer()

# %% [markdown]
# # Check Experiment Status
# `joining_state`:  `SUCCEEDED`

# %%
bandits_experiment._jsonify()
# Out:
# {'experiment_id': 'bandits-1597616270',
#  'training_workflow_metadata': {'next_model_to_train_id': None,
#   'last_trained_model_id': 'bandits-1597616270-model-id-1597616291',
#   'training_state': 'TRAINED'},
#  'hosting_workflow_metadata': {'hosting_endpoint': 'local:arn-does-not-matter',
#   'hosting_state': 'DEPLOYED',
#   'last_hosted_model_id': 'bandits-1597616270-model-id-1597616291',
#   'next_model_to_host_id': None},
#  'joining_workflow_metadata': {'joining_state': 'SUCCEEDED',
#   'last_joined_job_id': 'bandits-1597616270-join-job-id-1597616350',
#   'next_join_job_id': None},
#  'evaluation_workflow_metadata': {'evaluation_state': None,
#   'last_evaluation_job_id': None,
#   'next_evaluation_job_id': None}}

# %%
bandits_experiment.last_joined_job_train_data
# Out:
# 's3://sagemaker-us-east-1-835319576252/bandits-1597616270/joined_data/bandits-1597616270-join-job-id-1597616350/train'

# %%
# !aws s3 ls --recursive $bandits_experiment.last_joined_job_train_data
# !aws s3 cp --recursive $bandits_experiment.last_joined_job_train_data ./last_joined_job_train_data/
# Out:
# 2020-08-16 22:19:11      44544 bandits-1597616270/joined_data/bandits-1597616270-join-job-id-1597616350/train/local-joined-data-1597616350.csv
# download: s3://sagemaker-us-east-1-835319576252/bandits-1597616270/joined_data/bandits-1597616270-join-job-id-1597616350/train/local-joined-data-1597616350.csv to last_joined_job_train_data/local-joined-data-1597616350.csv

# %%
# !cat ./last_joined_job_train_data/local-joined-data-1597616350.csv

# %% [markdown]
# # Re-train and Re-deploy

# %% [markdown]
# Now we can train a new model with newly collected experiences, and host the resulting model.

# %%
bandits_experiment.train_next_model(input_data_s3_prefix=bandits_experiment.last_joined_job_train_data)
# Out:
# INFO:orchestrator:Use last trained model bandits-1597616270-model-id-1597616291 as pre-trained model for training
# INFO:orchestrator:Starting training job for ModelId 'bandits-1597616270-model-id-1597616385''
# INFO:orchestrator:Training job will be executed in 'local' mode
# WARNING:sagemaker.estimator:Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# WARNING:sagemaker:'s3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# WARNING:sagemaker:'s3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# Creating tmpt_nxmiq7_algo-1-ifzgj_1 ...
# Attaching to tmpt_nxmiq7_algo-1-ifzgj_12mdone
# algo-1-ifzgj_1  | 2020-08-16 22:19:48,073 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-ifzgj_1  | 2020-08-16 22:19:48,085 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-ifzgj_1  | 2020-08-16 22:19:48,097 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-ifzgj_1  | 2020-08-16 22:19:48,106 sagemaker-containers INFO     Invoking user script
# algo-1-ifzgj_1  |
# algo-1-ifzgj_1  | Training Env:
# algo-1-ifzgj_1  |
# algo-1-ifzgj_1  | {
# algo-1-ifzgj_1  |     "additional_framework_parameters": {
# algo-1-ifzgj_1  |         "sagemaker_estimator": "RLEstimator"
# algo-1-ifzgj_1  |     },
# algo-1-ifzgj_1  |     "channel_input_dirs": {
# algo-1-ifzgj_1  |         "training": "/opt/ml/input/data/training",
# algo-1-ifzgj_1  |         "pretrained_model": "/opt/ml/input/data/pretrained_model"
# algo-1-ifzgj_1  |     },
# algo-1-ifzgj_1  |     "current_host": "algo-1-ifzgj",
# algo-1-ifzgj_1  |     "framework_module": null,
# algo-1-ifzgj_1  |     "hosts": [
# algo-1-ifzgj_1  |         "algo-1-ifzgj"
# algo-1-ifzgj_1  |     ],
# algo-1-ifzgj_1  |     "hyperparameters": {
# algo-1-ifzgj_1  |         "exploration_policy": "egreedy",
# algo-1-ifzgj_1  |         "epsilon": 0.001,
# algo-1-ifzgj_1  |         "num_policies": 3,
# algo-1-ifzgj_1  |         "num_arms": 2,
# algo-1-ifzgj_1  |         "cfa_type": "dr"
# algo-1-ifzgj_1  |     },
# algo-1-ifzgj_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-ifzgj_1  |     "input_data_config": {
# algo-1-ifzgj_1  |         "training": {
# algo-1-ifzgj_1  |             "TrainingInputMode": "File"
# algo-1-ifzgj_1  |         },
# algo-1-ifzgj_1  |         "pretrained_model": {
# algo-1-ifzgj_1  |             "TrainingInputMode": "File",
# algo-1-ifzgj_1  |             "ContentType": "application/x-sagemaker-model"
# algo-1-ifzgj_1  |         }
# algo-1-ifzgj_1  |     },
# algo-1-ifzgj_1  |     "input_dir": "/opt/ml/input",
# algo-1-ifzgj_1  |     "is_master": true,
# algo-1-ifzgj_1  |     "job_name": "bandits-1597616270-model-id-1597616385",
# algo-1-ifzgj_1  |     "log_level": 20,
# algo-1-ifzgj_1  |     "master_hostname": "algo-1-ifzgj",
# algo-1-ifzgj_1  |     "model_dir": "/opt/ml/model",
# algo-1-ifzgj_1  |     "module_dir": "s3://sagemaker-us-east-1-835319576252/bandits-1597616270/training_jobs/bandits-1597616270-model-id-1597616385/source/sourcedir.tar.gz",
# algo-1-ifzgj_1  |     "module_name": "train-vw",
# algo-1-ifzgj_1  |     "network_interface_name": "eth0",
# algo-1-ifzgj_1  |     "num_cpus": 8,
# algo-1-ifzgj_1  |     "num_gpus": 0,
# algo-1-ifzgj_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-ifzgj_1  |     "output_dir": "/opt/ml/output",
# algo-1-ifzgj_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-1-ifzgj_1  |     "resource_config": {
# algo-1-ifzgj_1  |         "current_host": "algo-1-ifzgj",
# algo-1-ifzgj_1  |         "hosts": [
# algo-1-ifzgj_1  |             "algo-1-ifzgj"
# algo-1-ifzgj_1  |         ]
# algo-1-ifzgj_1  |     },
# algo-1-ifzgj_1  |     "user_entry_point": "train-vw.py"
# algo-1-ifzgj_1  | }
# algo-1-ifzgj_1  |
# algo-1-ifzgj_1  | Environment variables:
# algo-1-ifzgj_1  |
# algo-1-ifzgj_1  | SM_HOSTS=["algo-1-ifzgj"]
# algo-1-ifzgj_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-1-ifzgj_1  | SM_HPS={"cfa_type":"dr","epsilon":0.001,"exploration_policy":"egreedy","num_arms":2,"num_policies":3}
# algo-1-ifzgj_1  | SM_USER_ENTRY_POINT=train-vw.py
# algo-1-ifzgj_1  | SM_FRAMEWORK_PARAMS={"sagemaker_estimator":"RLEstimator"}
# algo-1-ifzgj_1  | SM_RESOURCE_CONFIG={"current_host":"algo-1-ifzgj","hosts":["algo-1-ifzgj"]}
# algo-1-ifzgj_1  | SM_INPUT_DATA_CONFIG={"pretrained_model":{"ContentType":"application/x-sagemaker-model","TrainingInputMode":"File"},"training":{"TrainingInputMode":"File"}}
# algo-1-ifzgj_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-ifzgj_1  | SM_CHANNELS=["pretrained_model","training"]
# algo-1-ifzgj_1  | SM_CURRENT_HOST=algo-1-ifzgj
# algo-1-ifzgj_1  | SM_MODULE_NAME=train-vw
# algo-1-ifzgj_1  | SM_LOG_LEVEL=20
# algo-1-ifzgj_1  | SM_FRAMEWORK_MODULE=
# algo-1-ifzgj_1  | SM_INPUT_DIR=/opt/ml/input
# algo-1-ifzgj_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-ifzgj_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-ifzgj_1  | SM_NUM_CPUS=8
# algo-1-ifzgj_1  | SM_NUM_GPUS=0
# algo-1-ifzgj_1  | SM_MODEL_DIR=/opt/ml/model
# algo-1-ifzgj_1  | SM_MODULE_DIR=s3://sagemaker-us-east-1-835319576252/bandits-1597616270/training_jobs/bandits-1597616270-model-id-1597616385/source/sourcedir.tar.gz
# algo-1-ifzgj_1  | SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_estimator":"RLEstimator"},"channel_input_dirs":{"pretrained_model":"/opt/ml/input/data/pretrained_model","training":"/opt/ml/input/data/training"},"current_host":"algo-1-ifzgj","framework_module":null,"hosts":["algo-1-ifzgj"],"hyperparameters":{"cfa_type":"dr","epsilon":0.001,"exploration_policy":"egreedy","num_arms":2,"num_policies":3},"input_config_dir":"/opt/ml/input/config","input_data_config":{"pretrained_model":{"ContentType":"application/x-sagemaker-model","TrainingInputMode":"File"},"training":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"bandits-1597616270-model-id-1597616385","log_level":20,"master_hostname":"algo-1-ifzgj","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-835319576252/bandits-1597616270/training_jobs/bandits-1597616270-model-id-1597616385/source/sourcedir.tar.gz","module_name":"train-vw","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-ifzgj","hosts":["algo-1-ifzgj"]},"user_entry_point":"train-vw.py"}
# algo-1-ifzgj_1  | SM_USER_ARGS=["--cfa_type","dr","--epsilon","0.001","--exploration_policy","egreedy","--num_arms","2","--num_policies","3"]
# algo-1-ifzgj_1  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# algo-1-ifzgj_1  | SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# algo-1-ifzgj_1  | SM_CHANNEL_PRETRAINED_MODEL=/opt/ml/input/data/pretrained_model
# algo-1-ifzgj_1  | SM_HP_EXPLORATION_POLICY=egreedy
# algo-1-ifzgj_1  | SM_HP_EPSILON=0.001
# algo-1-ifzgj_1  | SM_HP_NUM_POLICIES=3
# algo-1-ifzgj_1  | SM_HP_NUM_ARMS=2
# algo-1-ifzgj_1  | SM_HP_CFA_TYPE=dr
# algo-1-ifzgj_1  | PYTHONPATH=/opt/ml/code:/usr/local/bin:/vowpal_wabbit/python:/vowpal_wabbit/build/python:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# algo-1-ifzgj_1  |
# algo-1-ifzgj_1  | Invoking script with the following command:
# algo-1-ifzgj_1  |
# algo-1-ifzgj_1  | /usr/bin/python train-vw.py --cfa_type dr --epsilon 0.001 --exploration_policy egreedy --num_arms 2 --num_policies 3
# algo-1-ifzgj_1  |
# algo-1-ifzgj_1  |
# algo-1-ifzgj_1  | INFO:root:channels ['pretrained_model', 'training']
# algo-1-ifzgj_1  | INFO:root:hps: {'cfa_type': 'dr', 'epsilon': 0.001, 'exploration_policy': 'egreedy', 'num_arms': 2, 'num_policies': 3}
# algo-1-ifzgj_1  | INFO:root:Loading model from /opt/ml/input/data/pretrained_model/vw.model
# algo-1-ifzgj_1  | INFO:VW CLI:creating an instance of VWModel
# algo-1-ifzgj_1  | INFO:VW CLI:successfully created VWModel
# algo-1-ifzgj_1  | INFO:VW CLI:command: ['vw', '--cb_explore', '2', '--epsilon', '0.001', '-i', '/opt/ml/input/data/pretrained_model/vw.model', '-f', '/opt/ml/model/vw.model', '--save_resume', '-p', '/dev/stdout']
# algo-1-ifzgj_1  | INFO:VW CLI:Started VW process!
# algo-1-ifzgj_1  | INFO:root:Processing training data: [PosixPath('/opt/ml/input/data/training/local-joined-data-1597616350.csv')]
# algo-1-ifzgj_1  | Traceback (most recent call last):
# algo-1-ifzgj_1  |   File "train-vw.py", line 95, in <module>
# algo-1-ifzgj_1  |     main()
# algo-1-ifzgj_1  |   File "train-vw.py", line 78, in main
# algo-1-ifzgj_1  |     for experience in data_iterator:
# algo-1-ifzgj_1  |   File "/opt/ml/code/io_utils.py", line 34, in get_iterator
# algo-1-ifzgj_1  |     for df in reader:
# algo-1-ifzgj_1  |   File "/usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py", line 1007, in __next__
# algo-1-ifzgj_1  |     return self.get_chunk()
# algo-1-ifzgj_1  |   File "/usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py", line 1070, in get_chunk
# algo-1-ifzgj_1  |     return self.read(nrows=size)
# algo-1-ifzgj_1  |   File "/usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py", line 1036, in read
# algo-1-ifzgj_1  |     ret = self._engine.read(nrows)
# algo-1-ifzgj_1  |   File "/usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py", line 1848, in read
# algo-1-ifzgj_1  |     data = self._reader.read(nrows)
# algo-1-ifzgj_1  |   File "pandas/_libs/parsers.pyx", line 876, in pandas._libs.parsers.TextReader.read
# algo-1-ifzgj_1  |   File "pandas/_libs/parsers.pyx", line 903, in pandas._libs.parsers.TextReader._read_low_memory
# algo-1-ifzgj_1  |   File "pandas/_libs/parsers.pyx", line 945, in pandas._libs.parsers.TextReader._read_rows
# algo-1-ifzgj_1  |   File "pandas/_libs/parsers.pyx", line 932, in pandas._libs.parsers.TextReader._tokenize_rows
# algo-1-ifzgj_1  |   File "pandas/_libs/parsers.pyx", line 2112, in pandas._libs.parsers.raise_parser_error
# algo-1-ifzgj_1  | pandas.errors.ParserError: Error tokenizing data. C error: Expected 7 fields in line 4, saw 9
# algo-1-ifzgj_1  |
# algo-1-ifzgj_1  | 2020-08-16 22:19:48,540 sagemaker-containers ERROR    ExecuteUserScriptError:
# algo-1-ifzgj_1  | Command "/usr/bin/python train-vw.py --cfa_type dr --epsilon 0.001 --exploration_policy egreedy --num_arms 2 --num_policies 3"
# WARNING:sagemaker.local.image:Failed to delete: /tmp/tmpt_nxmiq7/algo-1-ifzgj Please remove it manually.
# ERROR:orchestrator:Failed to run: ['docker-compose', '-f', '/tmp/tmpt_nxmiq7/docker-compose.yaml', 'up', '--build', '--abort-on-container-exit'], Process exited with code: 1
# tmpt_nxmiq7_algo-1-ifzgj_1 exited with code 1
# Aborting on container exit...
# WARNING:orchestrator:Looks like SageMaker Job was not submitted successfully. Failing Training Job with ModelId bandits-1597616270-model-id-1597616385
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-13aba3342f6f> in <module>
# ----> 1 bandits_experiment.train_next_model(input_data_s3_prefix=bandits_experiment.last_joined_job_train_data)
#
# ~/SageMaker/workshop/09_deploy/wip/mab/bert_reynolds/common/sagemaker_rl/orchestrator/workflow/manager/experiment_manager.py in train_next_model(self, wait, input_data_s3_prefix, input_model_id)
#    1594                 self._sync_experiment_state_with_ddb()
#    1595                 logger.debug("Waiting for experiment table training status to be updated...")
# -> 1596                 time.sleep(2 * (2**num_retries))
#    1597                 trained_state = self.experiment_record._training_state == TrainingState.TRAINED \
#    1598                                 and self.experiment_record._last_trained_model_id == next_model_to_train_id \
#
# KeyboardInterrupt:

# %%
bandits_experiment.last_trained_model_id

# %%
bandits_experiment.deploy_model(model_id=bandits_experiment.last_trained_model_id)

# %%
bandits_experiment.last_hosted_model_id

# %% [markdown]
# # Continuously Deploy New Bandit Models

# %% [markdown]
# The above cells explained the individual steps in the training workflow. To train a model to convergence, we will continually train the model based on data collected with client application interactions. We demonstrate the continual training loop in a single cell below.
#
# We include the evaluation step at each step before deployment to compare the model just trained (`last_trained_model_id`) against the model that is currently hosted (`last_hosted_model_id`). If you want the loops to finish faster, you can set `do_evaluation=False` in the cell below.
#
# Details of each joining and training job can be tracked in `join_db` and `model_db` respectively. `model_db` also stores the evaluation scores. When you have multiple experiments, you can check their status in `experiment_db`.

# %%
do_evaluation = True

# You can also monitor your loop progress on CloudWatch Dashboard 
display(Markdown(bandits_experiment.get_cloudwatch_dashboard_details()))

# %%
start_time = time.time()
total_loops = 2 # Increase for higher accuracy
batch_size = 10 # Model will be trained after every `batch_size` number of data instances
rewards_list = []

local_mode = bandits_experiment.local_mode
for loop_no in range(total_loops):
    print(f"""
    #############
    #### Loop {loop_no+1}
    #############
    """)
    
    # Generate experiences and log them
    for i in range(batch_size):
        user_id, user_context = sim_app.choose_random_context()
        action, event_id, bandit_model_id, action_prob, sample_prob = bandit_model.get_action(obs=user_context.tolist())
        reward = sim_app.get_reward(user_id, action, event_id, bandit_model_id, action_prob, sample_prob, local_mode)
        rewards_list.append(reward)
        
    # Publish rewards sum for this batch to CloudWatch for monitoring 
    bandits_experiment.cw_logger.publish_rewards_for_simulation(
        bandits_experiment.experiment_id,
        sum(rewards_list[-batch_size:])/batch_size
    )
    
    # Join the events and rewards data to use for the next bandit-model training job
    if local_mode:
        bandits_experiment.ingest_joined_data(sim_app.joined_data_buffer,
                                              ratio=0.85)
    else:
        # Kinesis Firehose => S3 => Athena
        print("Waiting for firehose to flush data to s3...")
        time.sleep(60) 
        rewards_s3_prefix = bandits_experiment.ingest_rewards(sim_app.rewards_buffer)
        bandits_experiment.join(rewards_s3_prefix, ratio=0.85)
    
    # Train 
    bandits_experiment.train_next_model(
        input_data_s3_prefix=bandits_experiment.last_joined_job_train_data)

    # Deply the new bandit model
    if do_evaluation:
        # Evaluate against the currently-deployed bandit model
        bandits_experiment.evaluate_model(
            input_data_s3_prefix=bandits_experiment.last_joined_job_eval_data,
            evaluate_model_id=bandits_experiment.last_trained_model_id)
        eval_score_last_trained_model = bandits_experiment.get_eval_score(
            evaluate_model_id=bandits_experiment.last_trained_model_id,
            eval_data_path=bandits_experiment.last_joined_job_eval_data)

        bandits_experiment.evaluate_model(
            input_data_s3_prefix=bandits_experiment.last_joined_job_eval_data,
            evaluate_model_id=bandits_experiment.last_hosted_model_id)

        eval_score_last_hosted_model = bandits_experiment.get_eval_score(
            evaluate_model_id=bandits_experiment.last_hosted_model_id, 
            eval_data_path=bandits_experiment.last_joined_job_eval_data)
    
        # Deploy
        if eval_score_last_trained_model <= eval_score_last_hosted_model:
            bandits_experiment.deploy_model(model_id=bandits_experiment.last_trained_model_id)
        else:
            print('Not deploying model in loop {}'.format(loop_no))
    else:
        # Just deploy the new bandit model without evaluating against previous model
        bandits_experiment.deploy_model(model_id=bandits_experiment.last_trained_model_id)
    
    sim_app.clear_buffer()

print(f"Total time taken to complete {total_loops} loops: {time.time() - start_time}")

# %% [markdown]
# # Visualize the Bandit Rewards

# %% [markdown]
# You can visualize the bandit-model training performance by plotting the rolling mean reward across client interactions.
#
# Here rolling mean reward is calculated on the last `rolling_window` number of data instances, where each data instance corresponds to a single client interaction.

# %%
# %%time

import matplotlib.pyplot as plt
from pylab import rcParams
import pandas as pd
# %matplotlib inline

def get_mean_reward(reward_lst, batch_size=batch_size):
    mean_rew=list()
    for r in range(len(reward_lst)):
        mean_rew.append(sum(reward_lst[:r+1]) * 1.0 / ((r+1)*batch_size))
    return mean_rew

rcParams['figure.figsize'] = 15, 10
lwd = 5
cmap = plt.get_cmap('tab20')
colors=plt.cm.tab20(np.linspace(0, 1, 20))

rolling_window = 100
rewards_df = pd.DataFrame(rewards_list, columns=['bandit']).rolling(rolling_window).mean()
rewards_df['oracle'] = sum(sim_app.opt_rewards) / len(sim_app.opt_rewards)

rewards_df.plot(y=['bandit','oracle'],linewidth=lwd)
plt.legend(loc=4, prop={'size': 20})
plt.tick_params(axis='both', which='major', labelsize=15)
plt.xlabel('Data instances (models were updated every %s data instances)' % batch_size, size=20)
plt.ylabel('Rolling Mean Reward', size=30)
plt.grid()
plt.show()

# %% [markdown]
# #### Get mean rewards

# %%
rewards_df.bandit.mean()

# %% [markdown]
# ### Clean up

# %% [markdown]
# We have three DynamoDB tables (experiment, join, model) from the bandits application above (e.g. `experiment_id='bandits-...'`). To better maintain them, we should remove the related records if the experiment has finished. Besides, having an endpoint running will incur costs. Therefore, we delete these components as part of the clean up process.
#
# > Only execute the clean up cells below when you've finished the current experiment and want to deprecate everything associated with it. After the cleanup, the Cloudwatch metrics will not be populated anymore.

# %%
try:
    bandits_experiment.clean_resource(experiment_id=bandits_experiment.experiment_id)
    bandits_experiment.clean_table_records(experiment_id=bandits_experiment.experiment_id)
except:
    print('Ignore any errors.  Errors are OK.')
# Out:
# Ignore any errors.  Errors are OK.
