# %%
# !pip install boto3
# Out:
# Requirement already satisfied: boto3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (1.11.13)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3) (0.3.3)
# Requirement already satisfied: botocore<1.15.0,>=1.14.13 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3) (1.14.13)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3) (0.9.4)
# Requirement already satisfied: docutils<0.16,>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.15.0,>=1.14.13->boto3) (0.14)
# Requirement already satisfied: urllib3<1.26,>=1.20; python_version != "3.4" in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.15.0,>=1.14.13->boto3) (1.23)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.15.0,>=1.14.13->boto3) (2.7.3)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.15.0,>=1.14.13->boto3) (1.11.0)
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import boto3
import sagemaker
import pandas as pd

sess   = sagemaker.Session()
bucket = sess.default_bucket()
role = sagemaker.get_execution_role()
region = boto3.Session().region_name

sm = boto3.Session().client(service_name='sagemaker', region_name=region)

# %%
max_candidates = 25

job_config = {
    'CompletionCriteria': {
      'MaxRuntimePerTrainingJobInSeconds': 600,
      'MaxCandidates': max_candidates,
      'MaxAutoMLJobRuntimeInSeconds': 3600
    },
}

input_data_config = [{
      'DataSource': {
        'S3DataSource': {
          'S3DataType': 'S3Prefix',
          'S3Uri': 's3://{}/{}/input'.format(bucket, prefix)
        }
      },
      'TargetAttributeName': 'is_positive_sentiment'
    }
]

output_data_config = {
    'S3OutputPath': 's3://{}/{}/output'.format(bucket, prefix)
}

#problem_type = 'Regression'

#auto_ml_job_objective = {
#    'MetricName': 'MSE'
#}

# %% [markdown]
# ## Launching the SageMaker AutoPilot job
#
# We can now launch the job by calling the `create_auto_ml_job` API.

# %%
from time import gmtime, strftime, sleep
timestamp_suffix = strftime('%d-%H-%M-%S', gmtime())

auto_ml_job_name = 'automl-dm-' + timestamp_suffix
print('AutoMLJobName: ' + auto_ml_job_name)
# Out:
# AutoMLJobName: automl-dm-23-06-15-57

# %%
sm.create_auto_ml_job(AutoMLJobName=auto_ml_job_name,
                      InputDataConfig=input_data_config,
                      OutputDataConfig=output_data_config,
                      AutoMLJobConfig=job_config,
#                      ProblemType=problem_type,
#                      AutoMLJobObjective=auto_ml_job_objective,
                      RoleArn=role)
# Out:
# {'AutoMLJobArn': 'arn:aws:sagemaker:us-east-1:835319576252:automl-job/automl-dm-23-06-15-57',
#  'ResponseMetadata': {'RequestId': 'db4c52c6-4d06-4605-bbf3-1fa4f397646c',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'db4c52c6-4d06-4605-bbf3-1fa4f397646c',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '92',
#    'date': 'Sun, 23 Feb 2020 06:15:56 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ### Tracking the progress of the AutoPilot job
# SageMaker AutoPilot job consists of four high-level steps :
# * Data Preprocessing, where the dataset is split into train and validation sets.
# * Recommending Pipelines, where the dataset is analyzed and SageMaker AutoPilot comes up with a list of ML pipelines that should be tried out on the dataset.
# * Automatic Feature Engineering, where SageMaker AutoPilot performs feature transformation on individual features of the dataset as well as at an aggregate level.
# * ML pipeline selection and hyperparameter tuning, where the top performing pipeline is selected along with the optimal hyperparameters for the training algorithm (the last stage of the pipeline).

# %%
# Sleep for a bit to ensure the AutoML job above has time to start
import time
time.sleep(3)

job = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
job_status = job['AutoMLJobStatus']
job_sec_status = job['AutoMLJobSecondaryStatus']

if job_status not in ('Stopped', 'Failed'):
    while job_status in ('InProgress') and job_sec_status in ('AnalyzingData'):
        job = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
        job_status = job['AutoMLJobStatus']
        job_sec_status = job['AutoMLJobSecondaryStatus']
        print(job_status, job_sec_status)
        sleep(30)
    print("Data analysis complete")
    
print(job)
# Out:
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress FeatureEngineering
# Data analysis complete
# {'AutoMLJobName': 'automl-dm-23-06-15-57', 'AutoMLJobArn': 'arn:aws:sagemaker:us-east-1:835319576252:automl-job/automl-dm-23-06-15-57', 'InputDataConfig': [{'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/input'}}, 'TargetAttributeName': 'is_positive_sentiment'}], 'OutputDataConfig': {'S3OutputPath': 's3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output'}, 'RoleArn': 'arn:aws:iam::835319576252:role/service-role/AmazonSageMaker-ExecutionRole-20191006T135881', 'AutoMLJobConfig': {'CompletionCriteria': {'MaxCandidates': 25, 'MaxRuntimePerTrainingJobInSeconds': 600, 'MaxAutoMLJobRuntimeInSeconds': 3600}}, 'CreationTime': datetime.datetime(2020, 2, 23, 6, 15, 57, 625000, tzinfo=tzlocal()), 'LastModifiedTime': datetime.datetime(2020, 2, 23, 6, 23, 44, 863000, tzinfo=tzlocal()), 'AutoMLJobStatus': 'InProgress', 'AutoMLJobSecondaryStatus': 'FeatureEngineering', 'GenerateCandidateDefinitionsOnly': False, 'AutoMLJobArtifacts': {'CandidateDefinitionNotebookLocation': 's3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb', 'DataExplorationNotebookLocation': 's3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb'}, 'ResolvedAttributes': {'AutoMLJobObjective': {'MetricName': 'Accuracy'}, 'ProblemType': 'BinaryClassification', 'CompletionCriteria': {'MaxCandidates': 25, 'MaxRuntimePerTrainingJobInSeconds': 600, 'MaxAutoMLJobRuntimeInSeconds': 3600}}, 'ResponseMetadata': {'RequestId': '36cf6f50-a032-40df-a8e2-369b20796803', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '36cf6f50-a032-40df-a8e2-369b20796803', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1687', 'date': 'Sun, 23 Feb 2020 06:24:01 GMT'}, 'RetryAttempts': 0}}

# %%
job = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
job_status = job['AutoMLJobStatus']
job_sec_status = job['AutoMLJobSecondaryStatus']
print(job_status)
print(job_sec_status)
if job_status not in ('Stopped', 'Failed'):
    while job_status in ('InProgress') and job_sec_status in ('FeatureEngineering'):
        job = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
        job_status = job['AutoMLJobStatus']
        job_sec_status = job['AutoMLJobSecondaryStatus']
        print(job_status, job_sec_status)
        sleep(30)
    print("Feature engineering complete")
    
print(job)
# Out:
# InProgress
# FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress FeatureEngineering
# InProgress ModelTuning
# Feature engineering complete
# {'AutoMLJobName': 'automl-dm-23-06-15-57', 'AutoMLJobArn': 'arn:aws:sagemaker:us-east-1:835319576252:automl-job/automl-dm-23-06-15-57', 'InputDataConfig': [{'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/input'}}, 'TargetAttributeName': 'is_positive_sentiment'}], 'OutputDataConfig': {'S3OutputPath': 's3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output'}, 'RoleArn': 'arn:aws:iam::835319576252:role/service-role/AmazonSageMaker-ExecutionRole-20191006T135881', 'AutoMLJobConfig': {'CompletionCriteria': {'MaxCandidates': 25, 'MaxRuntimePerTrainingJobInSeconds': 600, 'MaxAutoMLJobRuntimeInSeconds': 3600}}, 'CreationTime': datetime.datetime(2020, 2, 23, 6, 15, 57, 625000, tzinfo=tzlocal()), 'LastModifiedTime': datetime.datetime(2020, 2, 23, 6, 40, 4, 960000, tzinfo=tzlocal()), 'AutoMLJobStatus': 'InProgress', 'AutoMLJobSecondaryStatus': 'ModelTuning', 'GenerateCandidateDefinitionsOnly': False, 'AutoMLJobArtifacts': {'CandidateDefinitionNotebookLocation': 's3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb', 'DataExplorationNotebookLocation': 's3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb'}, 'ResolvedAttributes': {'AutoMLJobObjective': {'MetricName': 'Accuracy'}, 'ProblemType': 'BinaryClassification', 'CompletionCriteria': {'MaxCandidates': 25, 'MaxRuntimePerTrainingJobInSeconds': 600, 'MaxAutoMLJobRuntimeInSeconds': 3600}}, 'ResponseMetadata': {'RequestId': '495d49a2-6b2f-443d-b8a5-0e6d4cdbc7fb', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '495d49a2-6b2f-443d-b8a5-0e6d4cdbc7fb', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1679', 'date': 'Sun, 23 Feb 2020 06:40:05 GMT'}, 'RetryAttempts': 0}}

# %%
job = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
job_status = job['AutoMLJobStatus']
job_sec_status = job['AutoMLJobSecondaryStatus']
print(job_status)
print(job_sec_status)
if job_status not in ('Stopped', 'Failed'):
    while job_status in ('InProgress') and job_sec_status in ('ModelTuning'):
        job = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
        job_status = job['AutoMLJobStatus']
        job_sec_status = job['AutoMLJobSecondaryStatus']
        print(job_status, job_sec_status)
        sleep(30)
    print("Model tuning complete")
    
print(job)
# Out:
# InProgress
# ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# Completed MaxCandidatesReached
# Model tuning complete
# {'AutoMLJobName': 'automl-dm-23-06-15-57', 'AutoMLJobArn': 'arn:aws:sagemaker:us-east-1:835319576252:automl-job/automl-dm-23-06-15-57', 'InputDataConfig': [{'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/input'}}, 'TargetAttributeName': 'is_positive_sentiment'}], 'OutputDataConfig': {'S3OutputPath': 's3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output'}, 'RoleArn': 'arn:aws:iam::835319576252:role/service-role/AmazonSageMaker-ExecutionRole-20191006T135881', 'AutoMLJobConfig': {'CompletionCriteria': {'MaxCandidates': 25, 'MaxRuntimePerTrainingJobInSeconds': 600, 'MaxAutoMLJobRuntimeInSeconds': 3600}}, 'CreationTime': datetime.datetime(2020, 2, 23, 6, 15, 57, 625000, tzinfo=tzlocal()), 'EndTime': datetime.datetime(2020, 2, 23, 6, 49, 21, 995000, tzinfo=tzlocal()), 'LastModifiedTime': datetime.datetime(2020, 2, 23, 6, 49, 22, 23000, tzinfo=tzlocal()), 'BestCandidate': {'CandidateName': 'tuning-job-1-c43b4a2c9b5945c7bd-023-45c91245', 'FinalAutoMLJobObjectiveMetric': {'MetricName': 'validation:accuracy', 'Value': 0.8139100074768066}, 'ObjectiveStatus': 'Succeeded', 'CandidateSteps': [{'CandidateStepType': 'AWS::SageMaker::ProcessingJob', 'CandidateStepArn': 'arn:aws:sagemaker:us-east-1:835319576252:processing-job/db-1-f068ce5d99184a55b5b97cb12879bd3eea77451833b44b0ab019da7f96', 'CandidateStepName': 'db-1-f068ce5d99184a55b5b97cb12879bd3eea77451833b44b0ab019da7f96'}, {'CandidateStepType': 'AWS::SageMaker::TrainingJob', 'CandidateStepArn': 'arn:aws:sagemaker:us-east-1:835319576252:training-job/automl-dm--dpp4-1-01941bd2159c4b9aae49a0516bdc64555fa315f4c3244', 'CandidateStepName': 'automl-dm--dpp4-1-01941bd2159c4b9aae49a0516bdc64555fa315f4c3244'}, {'CandidateStepType': 'AWS::SageMaker::TransformJob', 'CandidateStepArn': 'arn:aws:sagemaker:us-east-1:835319576252:transform-job/automl-dm--dpp4-rpb-1-d2c1b8dc94c04efc8dca220db121ad11774e8b7dc', 'CandidateStepName': 'automl-dm--dpp4-rpb-1-d2c1b8dc94c04efc8dca220db121ad11774e8b7dc'}, {'CandidateStepType': 'AWS::SageMaker::TrainingJob', 'CandidateStepArn': 'arn:aws:sagemaker:us-east-1:835319576252:training-job/tuning-job-1-c43b4a2c9b5945c7bd-023-45c91245', 'CandidateStepName': 'tuning-job-1-c43b4a2c9b5945c7bd-023-45c91245'}], 'CandidateStatus': 'Completed', 'InferenceContainers': [{'Image': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:0.1.0-cpu-py3', 'ModelDataUrl': 's3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/data-processor-models/automl-dm--dpp4-1-01941bd2159c4b9aae49a0516bdc64555fa315f4c3244/output/model.tar.gz', 'Environment': {'AUTOML_SPARSE_ENCODE_RECORDIO_PROTOBUF': '1', 'AUTOML_TRANSFORM_MODE': 'feature-transform', 'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'application/x-recordio-protobuf', 'SAGEMAKER_PROGRAM': 'sagemaker_serve', 'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}}, {'Image': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:0.90-1-cpu-py3', 'ModelDataUrl': 's3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/tuning/automl-dm--dpp4-xgb/tuning-job-1-c43b4a2c9b5945c7bd-023-45c91245/output/model.tar.gz', 'Environment': {'MAX_CONTENT_LENGTH': '20971520', 'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv'}}, {'Image': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:0.1.0-cpu-py3', 'ModelDataUrl': 's3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/data-processor-models/automl-dm--dpp4-1-01941bd2159c4b9aae49a0516bdc64555fa315f4c3244/output/model.tar.gz', 'Environment': {'AUTOML_TRANSFORM_MODE': 'inverse-label-transform', 'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv', 'SAGEMAKER_PROGRAM': 'sagemaker_serve', 'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}}], 'CreationTime': datetime.datetime(2020, 2, 23, 6, 49, 21, 112000, tzinfo=tzlocal()), 'LastModi ...

# %% [markdown]
# ### Viewing all candidates explored by SageMaker AutoPilot
# Once model tuning is complete, you can view all the candidates (pipeline evaluations with different hyperparameter combinations) that were explored by AutoML and sort them by their final performance metric.

# %%
candidates = sm.list_candidates_for_auto_ml_job(AutoMLJobName=auto_ml_job_name, 
                                                SortBy='FinalObjectiveMetricValue')['Candidates']
for index, candidate in enumerate(candidates):
    print(str(index) + "  " 
        + candidate['CandidateName'] + "  " 
        + str(candidate['FinalAutoMLJobObjectiveMetric']['Value']))
# Out:
# 0  tuning-job-1-c43b4a2c9b5945c7bd-023-45c91245  0.8139100074768066
# 1  tuning-job-1-c43b4a2c9b5945c7bd-012-8f35692a  0.7875940203666687
# 2  tuning-job-1-c43b4a2c9b5945c7bd-013-72cc9de2  0.7832080125808716
# 3  tuning-job-1-c43b4a2c9b5945c7bd-015-5cb268b7  0.7807019948959351
# 4  tuning-job-1-c43b4a2c9b5945c7bd-014-2099c358  0.7725560069084167
# 5  tuning-job-1-c43b4a2c9b5945c7bd-017-c1fed961  0.7468670010566711
# 6  tuning-job-1-c43b4a2c9b5945c7bd-004-d614d66c  0.7286970019340515
# 7  tuning-job-1-c43b4a2c9b5945c7bd-018-06cee4be  0.7218049764633179
# 8  tuning-job-1-c43b4a2c9b5945c7bd-003-13632f8b  0.7205510139465332
# 9  tuning-job-1-c43b4a2c9b5945c7bd-005-872927dd  0.7130330204963684

# %% [markdown]
# ## Inspect SageMaker AutoPilot trials with Amazon SageMaker Experiments
# SageMaker AutoPilot automatically creates a new experiment, and pushes information for each trial.

# %%
from sagemaker.analytics import ExperimentAnalytics, TrainingJobAnalytics

exp = ExperimentAnalytics(
    sagemaker_session=sess, 
    experiment_name=auto_ml_job_name + '-aws-auto-ml-job',
)

df = exp.dataframe()
df
# Out:
#                                    TrialComponentName  \
# 0   tuning-job-1-c43b4a2c9b5945c7bd-022-494b13d9-a...
# 1   tuning-job-1-c43b4a2c9b5945c7bd-026-c1634eff-a...
# 2   tuning-job-1-c43b4a2c9b5945c7bd-025-f0f5d554-a...
# 3   tuning-job-1-c43b4a2c9b5945c7bd-023-45c91245-a...
# 4   tuning-job-1-c43b4a2c9b5945c7bd-024-6600b7cb-a...
# 5   tuning-job-1-c43b4a2c9b5945c7bd-021-1047c0c4-a...
# 6   tuning-job-1-c43b4a2c9b5945c7bd-012-8f35692a-a...
# 7   tuning-job-1-c43b4a2c9b5945c7bd-017-c1fed961-a...
# 8   tuning-job-1-c43b4a2c9b5945c7bd-018-06cee4be-a...
# 9   tuning-job-1-c43b4a2c9b5945c7bd-019-1f6b2f1c-a...
# 10  tuning-job-1-c43b4a2c9b5945c7bd-020-5a214875-a...
# 11  tuning-job-1-c43b4a2c9b5945c7bd-016-d40f4d0e-a...
# 12  tuning-job-1-c43b4a2c9b5945c7bd-015-5cb268b7-a...
# 13  tuning-job-1-c43b4a2c9b5945c7bd-014-2099c358-a...
# 14  tuning-job-1-c43b4a2c9b5945c7bd-013-72cc9de2-a...
# 15  tuning-job-1-c43b4a2c9b5945c7bd-007-340c167c-a...
# 16  tuning-job-1-c43b4a2c9b5945c7bd-011-710c5733-a...
# 17  tuning-job-1-c43b4a2c9b5945c7bd-010-1553cbc4-a...
# 18  tuning-job-1-c43b4a2c9b5945c7bd-008-55776b79-a...
# 19  tuning-job-1-c43b4a2c9b5945c7bd-006-8fc748fa-a...
# 20  tuning-job-1-c43b4a2c9b5945c7bd-004-d614d66c-a...
# 21  tuning-job-1-c43b4a2c9b5945c7bd-001-bd4a7455-a...
# 22  tuning-job-1-c43b4a2c9b5945c7bd-005-872927dd-a...
# 23  tuning-job-1-c43b4a2c9b5945c7bd-002-1293d8c6-a...
# 24  tuning-job-1-c43b4a2c9b5945c7bd-003-13632f8b-a...
# 25  tuning-job-1-c43b4a2c9b5945c7bd-009-50609798-a...
# 26  automl-dm--dpp6-rpb-1-e5f2c51198214370ac39bd33...
# 27  automl-dm--dpp7-rpb-1-045a54d812b84d2f9682081e...
# 28  automl-dm--dpp8-rpb-1-8d98f09facc0402ba222ed3b...
arn:aws:sagemaker:us-east-1:835319576252:trans...
# 27  arn:aws:sagemaker:us-east-1:835319576252:trans...
# 28  arn:aws:sagemaker:us-east-1:835319576252:trans...
# 29  arn:aws:sagemaker:us-east-1:835319576252:trans...
# 30  arn:aws:sagemaker:us-east-1:835319576252:train...
# 31  arn:aws:sagemaker:us-east-1:835319576252:train...
# 32  arn:aws:sagemaker:us-east-1:835319576252:train...
# 33  arn:aws:sagemaker:us-east-1:835319576252:train...
# 34  arn:aws:sagemaker:us-east-1:835319576252:trans...
# 35  arn:aws:sagemaker:us-east-1:835319576252:trans...
# 36  arn:aws:sagemaker:us-east-1:835319576252:trans...
# 37  arn:aws:sagemaker:us-east-1:835319576252:trans...
# 38  arn:aws:sagemaker:us-east-1:835319576252:trans...
# 39  arn:aws:sagemaker:us-east-1:835319576252:train...
# 40  arn:aws:sagemaker:us-east-1:835319576252:train...
# 41  arn:aws:sagemaker:us-east-1:835319576252:train...
# 42  arn:aws:sagemaker:us-east-1:835319576252:train...
# 43  arn:aws:sagemaker:us-east-1:835319576252:train...
# 44  arn:aws:sagemaker:us-east-1:835319576252:proce...
#
#                                    SageMaker.ImageUri  \
# 0   382416733822.dkr.ecr.us-east-1.amazonaws.com/l...
# 1   683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 2   683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 3   683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 4   683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 5   683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 6   683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 7   683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 8   683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 9   382416733822.dkr.ecr.us-east-1.amazonaws.com/l...
# 10  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 11  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 12  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 13  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 14  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 15  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 16  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 17  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 18  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 19  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 20  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 21  382416733822.dkr.ecr.us-east-1.amazonaws.com/l...
# 22  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 23  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 24  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 25  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 31  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 32  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 33  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 40  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 41  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 42  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 43  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 44                                                NaN
#
#     SageMaker.InstanceCount SageMaker.InstanceType  SageMaker.VolumeSizeInGB  \
# 0                       1.0          ml.m5.4xlarge                      50.0
# 1                       1.0          ml.m5.4xlarge                      50.0
# 2                       1.0          ml.m5.4xlarge                      50.0
# 3                       1.0          ml.m5.4xlarge                      50.0
# 4                       1.0          ml.m5.4xlarge                      50.0
# 5                       1.0          ml.m5.4xlarge                      50.0
# 6                       1.0          ml.m5.4xlarge                      50.0
# 7                       1.0          ml.m5.4xlarge                      50.0
# 8                       1.0          ml.m5.4xlarge                      50.0
# 9                       1.0          ml.m5.4xlarge                      50.0
# 10                      1.0          ml.m5.4xlarge                      50.0
# 11                      1.0          ml.m5.4xlarge                      50.0
# 12                      1.0          ml.m5.4xlarge                      50.0
# 13                      1.0          ml.m5.4xlarge                      50.0
# 14                      1.0          ml.m5.4xlarge                      50.0
# 15                      1.0          ml.m5.4xlarge                      50.0
# 16                      1.0          ml.m5.4xlarge                      50.0
# 17                      1.0          ml.m5.4xlarge                      50.0
# 18                      1.0          ml.m5.4xlarge                      50.0
# 19                      1.0          ml.m5.4xlarge                      50.0
# 20                      1.0          ml.m5.4xlarge                      50.0
# 21                      1.0          ml.m5.4xlarge                      50.0
# 22                      1.0          ml.m5.4xlarge                      50.0
# 23                      1.0          ml.m5.4xlarge                      50.0
# 24                      1.0          ml.m5.4xlarge                      50.0
# 25                      1.0          ml.m5.4xlarge                      50.0
# 26                      1.0          ml.m5.4xlarge                       NaN
# 27                      1.0          ml.m5.4xlarge                       NaN
# 28                      1.0          ml.m5.4xlarge                       NaN
# 29                      1.0          ml.m5.4xlarge                       NaN
# 30                      1.0          ml.m5.4xlarge                      50.0
# 31                      1.0          ml.m5.4xlarge                      50.0
# 32                      1.0          ml.m5.4xlarge                      50.0
# 33                      1.0          ml.m5.4xlarge                      50.0
# 34                      1.0          ml.m5.4xlarge                       NaN
# 35                      1.0          ml.m5.4xlarge                       NaN
# 36                      1.0          ml.m5.4xlarge                       NaN
# 37                      1.0          ml.m5.4xlarge                       NaN
# 38                      1.0          ml.m5.4xlarge                       NaN
# 39                      1.0          ml.m5.4xlarge                      50.0
# 40                      1.0          ml.m5.4xlarge                      50.0
# 41                      1.0          ml.m5.4xlarge                      50.0
# 42                      1.0          ml.m5.4xlarge                      50.0
# 43                      1.0          ml.m5.4xlarge                      50.0
# 44                      1.0          ml.m5.2xlarge                     250.0
#
#                      _tuning_objective_metric  \
# 0   validation:binary_classification_accuracy
# 1                         validation:accuracy
# 2                         validation:accuracy
# 3                         validation:accuracy
# 4                         validation:accuracy
# 5                         validation:accuracy
# 6                         validation:accuracy
# 7                         validation:accuracy
# 8                         validation:accuracy
# 9   validation:binary_classification_accuracy
# 10                        validation:accuracy
# 11                        validation:accuracy
# 12                        validation:accuracy
# 13                        validation:accuracy
# 14                        validation:accuracy
# 15                        validation:accuracy
# 16                        validation:accuracy
# 17                        validation:accuracy
# 18                        validation:accuracy
# 19                        validation:accuracy
# 20                        validation:accuracy
# 21  validation:binary_classification_accuracy
# 22                        validation:accuracy
# 23                        validation:accuracy
# 24                        validation:accuracy
# 25                        validation:accuracy
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                                        NaN
# 30                                        NaN
# 31                                        NaN
# 32                                        NaN
# 33                                        NaN
# 34                                        NaN
# 35                                        NaN
# 36                                        NaN
# 37                                        NaN
# 38                                        NaN
# 39                                        NaN
# 40                                        NaN
# 41                                        NaN
# 42                                        NaN
# 43                                        NaN
# 44                                        NaN
#
#    binary_classifier_model_selection_criteria        l1  \
# 0                               loss_function  0.011840
# 1                                         NaN       NaN
# 2                                         NaN       NaN
# 3                                         NaN       NaN
# 4                                         NaN       NaN
# 5                                         NaN       NaN
# 6                                         NaN       NaN
# 7                                         NaN       NaN
# 8                                         NaN       NaN
# 9                               loss_function  0.625144
# 10                                        NaN       NaN
# 11                                        NaN       NaN
# 12                                        NaN       NaN
# 13                                        NaN       NaN
# 14                                        NaN       NaN
# 15                                        NaN       NaN
# 16                                        NaN       NaN
# 17                                        NaN       NaN
# 18                                        NaN       NaN
# 19                                        NaN       NaN
# 20                                        NaN       NaN
# 21                              loss_function  0.000484
# 22                                        NaN       NaN
# 23                                        NaN       NaN
# 24                                        NaN       NaN
# 25                                        NaN       NaN
# 26                                        NaN       NaN
# 27                                        NaN       NaN
# 28                                        NaN       NaN
# 29                                        NaN       NaN
# 30                                        NaN       NaN
# 31                                        NaN       NaN
# 32                                        NaN       NaN
# 33                                        NaN       NaN
# 34                                        NaN       NaN
# 35                                        NaN       NaN
# 36                                        NaN       NaN
# 37                                        NaN       NaN
# 38                                        NaN       NaN
# 39                                        NaN       NaN
# 40                                        NaN       NaN
# 41                                        NaN       NaN
# 42                                        NaN       NaN
# 43                                        NaN       NaN
# 44                                        NaN       NaN
#
#             ...            train:accuracy - Count  \
# 0           ...                               NaN
# 1           ...                               2.0
# 2           ...                               0.0
# 3           ...                              23.0
# 4           ...                               4.0
# 5           ...                               4.0
# 6           ...                               0.0
# 7           ...                               2.0
# 8           ...                              26.0
# 9           ...                               NaN
# 10          ...                               6.0
# 11          ...                               0.0
# 12          ...                               0.0
# 13          ...                              18.0
# 14          ...                              26.0
# 15          ...                               9.0
# 16          ...                               0.0
# 17          ...                               9.0
# 18          ...                               9.0
# 19          ...                               5.0
# 20          ...                               9.0
# 21          ...                               NaN
# 22          ...                               0.0
# 23          ...                               4.0
# 24          ...                               2.0
# 25          ...                               NaN
# 26          ...                               NaN
# 27          ...                               NaN
# 28          ...                               NaN
# 29          ...                               NaN
# 30          ...                               NaN
# 31          ...                               NaN
# 32          ...                               NaN
# 33          ...                               NaN
# 34          ...                               NaN
# 35          ...                               NaN
# 36          ...                               NaN
# 37          ...                               NaN
# 38          ...                               NaN
# 39          ...                               NaN
# 40          ...                               NaN
# 41          ...                               NaN
# 42          ...                               NaN
# 43          ...                               NaN
# 44          ...                               NaN
#
#                                   SageMaker.ModelName  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26  automl-dm-23-06-15-57-automl-dm--dpp6-model-18...
# 27  automl-dm-23-06-15-57-automl-dm--dpp7-model-9c...
# 28  automl-dm-23-06-15-57-automl-dm--dpp8-model-97...
# 29  automl-dm-23-06-15-57-automl-dm--dpp5-model-67...
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34  automl-dm-23-06-15-57-automl-dm--dpp4-model-4b...
# 35  automl-dm-23-06-15-57-automl-dm--dpp2-model-f1...
# 36  automl-dm-23-06-15-57-automl-dm--dpp3-model-cb...
# 37  automl-dm-23-06-15-57-automl-dm--dpp1-model-bd...
# 38  automl-dm-23-06-15-57-automl-dm--dpp0-model-0d...
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
#
#                        SageMaker.ModelPrimary.DataUrl  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26  s3://sagemaker-us-east-1-835319576252/xgboost-...
# 27  s3://sagemaker-us-east-1-835319576252/xgboost-...
# 28  s3://sagemaker-us-east-1-835319576252/xgboost-...
# 29  s3://sagemaker-us-east-1-835319576252/xgboost-...
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34  s3://sagemaker-us-east-1-835319576252/xgboost-...
# 35  s3://sagemaker-us-east-1-835319576252/xgboost-...
# 36  s3://sagemaker-us-east-1-835319576252/xgboost-...
# 37  s3://sagemaker-us-east-1-835319576252/xgboost-...
# 38  s3://sagemaker-us-east-1-835319576252/xgboost-...
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
#
#                          SageMaker.ModelPrimary.Image  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 27  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 28  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 29  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 35  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 36  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 37  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 38  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
#
#                   processor_module                  sagemaker_program  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
# 5                              NaN                                NaN
# 6                              NaN                                NaN
# 7                              NaN                                NaN
# 8                              NaN                                NaN
# 9                              NaN                                NaN
# 10                             NaN                                NaN
# 11                             NaN                                NaN
# 12                             NaN                                NaN
# 13                             NaN                                NaN
# 14                             NaN                                NaN
# 15                             NaN                                NaN
# 16                             NaN                                NaN
# 17                             NaN                                NaN
# 18                             NaN                                NaN
# 19                             NaN                                NaN
# 20                             NaN                                NaN
# 21                             NaN                                NaN
# 22                             NaN                                NaN
# 23                             NaN                                NaN
# 24                             NaN                                NaN
# 25                             NaN                                NaN
# 26                             NaN                                NaN
# 27                             NaN                                NaN
# 28                             NaN                                NaN
# 29                             NaN                                NaN
# 30  candidate_data_processors.dpp8  candidate_data_processors.trainer
# 31  candidate_data_processors.dpp7  candidate_data_processors.trainer
# 32  candidate_data_processors.dpp6  candidate_data_processors.trainer
# 33  candidate_data_processors.dpp5  candidate_data_processors.trainer
# 34                             NaN                                NaN
# 35                             NaN                                NaN
# 36                             NaN                                NaN
# 37                             NaN                                NaN
# 38                             NaN                                NaN
# 39  candidate_data_processors.dpp2  candidate_data_processors.trainer
# 40  candidate_data_processors.dpp4  candidate_data_processors.trainer
# 41  candidate_data_processors.dpp3  candidate_data_processors.trainer
# 42  candidate_data_processors.dpp0  candidate_data_processors.trainer
# 43  candidate_data_processors.dpp1  candidate_data_processors.trainer
# 44                             NaN                                NaN
#
#     sagemaker_submit_directory  input_channel_mode               job_name  \
# 0                          NaN                 NaN                    NaN
# 1                          NaN                 NaN                    NaN
# 2                          NaN                 NaN                    NaN
# 3                          NaN                 NaN                    NaN
# 4                          NaN                 NaN                    NaN
# 5                          NaN                 NaN                    NaN
# 6                          NaN                 NaN                    NaN
# 7                          NaN                 NaN                    NaN
# 8                          NaN                 NaN                    NaN
# 9                          NaN                 NaN                    NaN
# 10                         NaN                 NaN                    NaN
# 11                         NaN                 NaN                    NaN
# 12                         NaN                 NaN                    NaN
# 13                         NaN                 NaN                    NaN
# 14                         NaN                 NaN                    NaN
# 15                         NaN                 NaN                    NaN
# 16                         NaN                 NaN                    NaN
# 17                         NaN                 NaN                    NaN
# 18                         NaN                 NaN                    NaN
# 19                         NaN                 NaN                    NaN
# 20                         NaN                 NaN                    NaN
# 21                         NaN                 NaN                    NaN
# 22                         NaN                 NaN                    NaN
# 23                         NaN                 NaN                    NaN
# 24                         NaN                 NaN                    NaN
# 25                         NaN                 NaN                    NaN
# 26                         NaN                 NaN                    NaN
# 27                         NaN                 NaN                    NaN
# 28                         NaN                 NaN                    NaN
# 29                         NaN                 NaN                    NaN
# 30     /opt/ml/input/data/code                 NaN                    NaN
# 31     /opt/ml/input/data/code                 NaN                    NaN
# 32     /opt/ml/input/data/code                 NaN                    NaN
# 33     /opt/ml/input/data/code                 NaN                    NaN
# 34                         NaN                 NaN                    NaN
# 35                         NaN                 NaN                    NaN
# 36                         NaN                 NaN                    NaN
# 37                         NaN                 NaN                    NaN
# 38                         NaN                 NaN                    NaN
# 39     /opt/ml/input/data/code                 NaN                    NaN
# 40     /opt/ml/input/data/code                 NaN                    NaN
# 41     /opt/ml/input/data/code                 NaN                    NaN
# 42     /opt/ml/input/data/code                 NaN                    NaN
# 43     /opt/ml/input/data/code                 NaN                    NaN
# 44                         NaN                Pipe  automl-dm-23-06-15-57
#
#                 label_col
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
# 9                     NaN
# 10                    NaN
# 11                    NaN
# 12                    NaN
# 13                    NaN
# 14                    NaN
# 15                    NaN
# 16                    NaN
# 17                    NaN
# 18                    NaN
# 19                    NaN
# 20                    NaN
# 21                    NaN
# 22                    NaN
# 23                    NaN
# 24                    NaN
# 25                    NaN
# 26                    NaN
# 27                    NaN
# 28                    NaN
# 29                    NaN
# 30                    NaN
# 31                    NaN
# 32                    NaN
# 33                    NaN
# 34                    NaN
# 35                    NaN
# 36                    NaN
# 37                    NaN
# 38                    NaN
# 39                    NaN
# 40                    NaN
# 41                    NaN
# 42                    NaN
# 43                    NaN
# 44  is_positive_sentiment
#
# [45 rows x 120 columns]

# %% [markdown]
# ## Viewing notebooks generated by SageMaker AutoPilot
# Once data analysis is complete, SageMaker AutoPilot generates two notebooks:
# * Data exploration,
# * Candidate definition.

# %%
job = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
print(job)
# Out:
# {'AutoMLJobName': 'automl-dm-23-06-15-57', 'AutoMLJobArn': 'arn:aws:sagemaker:us-east-1:835319576252:automl-job/automl-dm-23-06-15-57', 'InputDataConfig': [{'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/input'}}, 'TargetAttributeName': 'is_positive_sentiment'}], 'OutputDataConfig': {'S3OutputPath': 's3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output'}, 'RoleArn': 'arn:aws:iam::835319576252:role/service-role/AmazonSageMaker-ExecutionRole-20191006T135881', 'AutoMLJobConfig': {'CompletionCriteria': {'MaxCandidates': 25, 'MaxRuntimePerTrainingJobInSeconds': 600, 'MaxAutoMLJobRuntimeInSeconds': 3600}}, 'CreationTime': datetime.datetime(2020, 2, 23, 6, 15, 57, 625000, tzinfo=tzlocal()), 'EndTime': datetime.datetime(2020, 2, 23, 6, 49, 21, 995000, tzinfo=tzlocal()), 'LastModifiedTime': datetime.datetime(2020, 2, 23, 6, 49, 22, 23000, tzinfo=tzlocal()), 'BestCandidate': {'CandidateName': 'tuning-job-1-c43b4a2c9b5945c7bd-023-45c91245', 'FinalAutoMLJobObjectiveMetric': {'MetricName': 'validation:accuracy', 'Value': 0.8139100074768066}, 'ObjectiveStatus': 'Succeeded', 'CandidateSteps': [{'CandidateStepType': 'AWS::SageMaker::ProcessingJob', 'CandidateStepArn': 'arn:aws:sagemaker:us-east-1:835319576252:processing-job/db-1-f068ce5d99184a55b5b97cb12879bd3eea77451833b44b0ab019da7f96', 'CandidateStepName': 'db-1-f068ce5d99184a55b5b97cb12879bd3eea77451833b44b0ab019da7f96'}, {'CandidateStepType': 'AWS::SageMaker::TrainingJob', 'CandidateStepArn': 'arn:aws:sagemaker:us-east-1:835319576252:training-job/automl-dm--dpp4-1-01941bd2159c4b9aae49a0516bdc64555fa315f4c3244', 'CandidateStepName': 'automl-dm--dpp4-1-01941bd2159c4b9aae49a0516bdc64555fa315f4c3244'}, {'CandidateStepType': 'AWS::SageMaker::TransformJob', 'CandidateStepArn': 'arn:aws:sagemaker:us-east-1:835319576252:transform-job/automl-dm--dpp4-rpb-1-d2c1b8dc94c04efc8dca220db121ad11774e8b7dc', 'CandidateStepName': 'automl-dm--dpp4-rpb-1-d2c1b8dc94c04efc8dca220db121ad11774e8b7dc'}, {'CandidateStepType': 'AWS::SageMaker::TrainingJob', 'CandidateStepArn': 'arn:aws:sagemaker:us-east-1:835319576252:training-job/tuning-job-1-c43b4a2c9b5945c7bd-023-45c91245', 'CandidateStepName': 'tuning-job-1-c43b4a2c9b5945c7bd-023-45c91245'}], 'CandidateStatus': 'Completed', 'InferenceContainers': [{'Image': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:0.1.0-cpu-py3', 'ModelDataUrl': 's3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/data-processor-models/automl-dm--dpp4-1-01941bd2159c4b9aae49a0516bdc64555fa315f4c3244/output/model.tar.gz', 'Environment': {'AUTOML_SPARSE_ENCODE_RECORDIO_PROTOBUF': '1', 'AUTOML_TRANSFORM_MODE': 'feature-transform', 'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'application/x-recordio-protobuf', 'SAGEMAKER_PROGRAM': 'sagemaker_serve', 'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}}, {'Image': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:0.90-1-cpu-py3', 'ModelDataUrl': 's3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/tuning/automl-dm--dpp4-xgb/tuning-job-1-c43b4a2c9b5945c7bd-023-45c91245/output/model.tar.gz', 'Environment': {'MAX_CONTENT_LENGTH': '20971520', 'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv'}}, {'Image': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:0.1.0-cpu-py3', 'ModelDataUrl': 's3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/data-processor-models/automl-dm--dpp4-1-01941bd2159c4b9aae49a0516bdc64555fa315f4c3244/output/model.tar.gz', 'Environment': {'AUTOML_TRANSFORM_MODE': 'inverse-label-transform', 'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv', 'SAGEMAKER_PROGRAM': 'sagemaker_serve', 'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}}], 'CreationTime': datetime.datetime(2020, 2, 23, 6, 49, 21, 112000, tzinfo=tzlocal()), 'LastModi ...

# %% [markdown]
# ### Let's copy all of the generated resources including the two notebooks.

# %%
generated_resources = job['AutoMLJobArtifacts']['DataExplorationNotebookLocation'].rstrip('notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb')
generated_resources
# Out:
# 's3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d'

# %%
# !rm -rf ./generated_module
# !rm -rf ./notebooks
# !aws s3 cp --recursive $generated_resources .
# Out:
# download: s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/generated_module/README.md to generated_module/README.md
# download: s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/generated_module/candidate_data_processors/dpp4.py to generated_module/candidate_data_processors/dpp4.py
# download: s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/generated_module/candidate_data_processors/dpp1.py to generated_module/candidate_data_processors/dpp1.py
# download: s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/generated_module/MANIFEST.in to generated_module/MANIFEST.in
# download: s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/generated_module/candidate_data_processors/dpp8.py to generated_module/candidate_data_processors/dpp8.py
# download: s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/generated_module/candidate_data_processors/dpp3.py to generated_module/candidate_data_processors/dpp3.py
# download: s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/generated_module/candidate_data_processors/dpp2.py to generated_module/candidate_data_processors/dpp2.py
# download: s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/generated_module/candidate_data_processors/dpp5.py to generated_module/candidate_data_processors/dpp5.py
# download: s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/generated_module/candidate_data_processors/dpp7.py to generated_module/candidate_data_processors/dpp7.py
# download: s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/generated_module/candidate_data_processors/trainer.py to generated_module/candidate_data_processors/trainer.py
# download: s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/generated_module/candidate_data_processors/sagemaker_serve.py to generated_module/candidate_data_processors/sagemaker_serve.py
# download: s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/generated_module/setup.py to generated_module/setup.py
# download: s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb to notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb
# download: s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/notebooks/sagemaker_automl/common.py to notebooks/sagemaker_automl/common.py
# download: s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/generated_module/candidate_data_processors/dpp0.py to generated_module/candidate_data_processors/dpp0.py
# download: s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/notebooks/sagemaker_automl/config.py to notebooks/sagemaker_automl/config.py
# download: s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb to notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb
# download: s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/notebooks/sagemaker_automl/local_candidate.py to notebooks/sagemaker_automl/local_candidate.py
# download: s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/notebooks/sagemaker_automl/__init__.py to notebooks/sagemaker_automl/__init__.py
# download: s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/notebooks/sagemaker_automl/README.md to notebooks/sagemaker_automl/README.md
# download: s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/notebooks/sagemaker_automl/interactive_runner.py to notebooks/sagemaker_automl/interactive_runner.py
# download: s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/notebooks/sagemaker_automl/steps.py to notebooks/sagemaker_automl/steps.py
# download: s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/sagemaker-automl-candidates/pr-1-a56204c6fd1b45cc849463c433d836530f503293e50441ad8fc088983d/generated_module/candidate_data_processors/dpp6.py to generated_module/candidate_data_processors/dpp6.py

# %% [markdown]
# ### In the file view, open the `notebooks/` and `generated_module/` folders.  Lots of useful information in there!

# %% [markdown]
# ## Deploying the best candidate
# Now that we have successfully completed the AutoML job on our dataset and visualized the trials, we can create a model from any of the trials with a single API call and then deploy that model for online or batch prediction using [Inference Pipelines](https://docs.aws.amazon.com/sagemaker/latest/dg/inference-pipelines.html). For this notebook, we deploy only the best performing trial for inference.

# %% [markdown]
# The best candidate is the one we're really interested in.

# %%
best_candidate = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)['BestCandidate']
best_candidate_identifier = best_candidate['CandidateName']

print("Candidate name: " + best_candidate_identifier)
print("Metric name: " + best_candidate['FinalAutoMLJobObjectiveMetric']['MetricName'])
print("Metric value: " + str(best_candidate['FinalAutoMLJobObjectiveMetric']['Value']))
# Out:
# Candidate name: tuning-job-1-c43b4a2c9b5945c7bd-023-45c91245
# Metric name: validation:accuracy
# Metric value: 0.8139100074768066

# %%
best_candidate
# Out:
# {'CandidateName': 'tuning-job-1-c43b4a2c9b5945c7bd-023-45c91245',
#  'FinalAutoMLJobObjectiveMetric': {'MetricName': 'validation:accuracy',
#   'Value': 0.8139100074768066},
#  'ObjectiveStatus': 'Succeeded',
#  'CandidateSteps': [{'CandidateStepType': 'AWS::SageMaker::ProcessingJob',
#    'CandidateStepArn': 'arn:aws:sagemaker:us-east-1:835319576252:processing-job/db-1-f068ce5d99184a55b5b97cb12879bd3eea77451833b44b0ab019da7f96',
#    'CandidateStepName': 'db-1-f068ce5d99184a55b5b97cb12879bd3eea77451833b44b0ab019da7f96'},
#   {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#    'CandidateStepArn': 'arn:aws:sagemaker:us-east-1:835319576252:training-job/automl-dm--dpp4-1-01941bd2159c4b9aae49a0516bdc64555fa315f4c3244',
#    'CandidateStepName': 'automl-dm--dpp4-1-01941bd2159c4b9aae49a0516bdc64555fa315f4c3244'},
#   {'CandidateStepType': 'AWS::SageMaker::TransformJob',
#    'CandidateStepArn': 'arn:aws:sagemaker:us-east-1:835319576252:transform-job/automl-dm--dpp4-rpb-1-d2c1b8dc94c04efc8dca220db121ad11774e8b7dc',
#    'CandidateStepName': 'automl-dm--dpp4-rpb-1-d2c1b8dc94c04efc8dca220db121ad11774e8b7dc'},
#   {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#    'CandidateStepArn': 'arn:aws:sagemaker:us-east-1:835319576252:training-job/tuning-job-1-c43b4a2c9b5945c7bd-023-45c91245',
#    'CandidateStepName': 'tuning-job-1-c43b4a2c9b5945c7bd-023-45c91245'}],
#  'CandidateStatus': 'Completed',
#  'InferenceContainers': [{'Image': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:0.1.0-cpu-py3',
#    'ModelDataUrl': 's3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/data-processor-models/automl-dm--dpp4-1-01941bd2159c4b9aae49a0516bdc64555fa315f4c3244/output/model.tar.gz',
#    'Environment': {'AUTOML_SPARSE_ENCODE_RECORDIO_PROTOBUF': '1',
#     'AUTOML_TRANSFORM_MODE': 'feature-transform',
#     'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'application/x-recordio-protobuf',
#     'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#     'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}},
#   {'Image': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:0.90-1-cpu-py3',
#    'ModelDataUrl': 's3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/tuning/automl-dm--dpp4-xgb/tuning-job-1-c43b4a2c9b5945c7bd-023-45c91245/output/model.tar.gz',
#    'Environment': {'MAX_CONTENT_LENGTH': '20971520',
#     'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv'}},
#   {'Image': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:0.1.0-cpu-py3',
#    'ModelDataUrl': 's3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/data-processor-models/automl-dm--dpp4-1-01941bd2159c4b9aae49a0516bdc64555fa315f4c3244/output/model.tar.gz',
#    'Environment': {'AUTOML_TRANSFORM_MODE': 'inverse-label-transform',
#     'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#     'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#     'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}}],
#  'CreationTime': datetime.datetime(2020, 2, 23, 6, 49, 21, 112000, tzinfo=tzlocal()),
#  'LastModifiedTime': datetime.datetime(2020, 2, 23, 6, 49, 21, 112000, tzinfo=tzlocal())}

# %% [markdown]
# We can see the containers and models composing the Inference Pipeline.

# %%
for container in best_candidate['InferenceContainers']:
    print(container['Image'])
    print(container['ModelDataUrl'])
    print('======================')
# Out:
# 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:0.1.0-cpu-py3
# s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/data-processor-models/automl-dm--dpp4-1-01941bd2159c4b9aae49a0516bdc64555fa315f4c3244/output/model.tar.gz
# ======================
# 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:0.90-1-cpu-py3
# s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/tuning/automl-dm--dpp4-xgb/tuning-job-1-c43b4a2c9b5945c7bd-023-45c91245/output/model.tar.gz
# ======================
# 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:0.1.0-cpu-py3
# s3://sagemaker-us-east-1-835319576252/xgboost-reviews/autopilot/output/automl-dm-23-06-15-57/data-processor-models/automl-dm--dpp4-1-01941bd2159c4b9aae49a0516bdc64555fa315f4c3244/output/model.tar.gz
# ======================

# %%
model_name = 'automl-dm-model-' + timestamp_suffix

model_arn = sm.create_model(Containers=best_candidate['InferenceContainers'],
                            ModelName=model_name,
                            ExecutionRoleArn=role)

print('Best candidate model ARN: ', model_arn['ModelArn'])
# Out:
# Best candidate model ARN:  arn:aws:sagemaker:us-east-1:835319576252:model/automl-dm-model-23-06-15-57

# %% [markdown]
# Let's deploy the pipeline.

# %%
# EndpointConfig name
timestamp_suffix = strftime('%d-%H-%M-%S', gmtime())
epc_name = 'automl-dm-epc-' + timestamp_suffix

# Endpoint name
ep_name = 'automl-dm-ep-' + timestamp_suffix
variant_name = 'automl-dm-variant-' + timestamp_suffix

print(ep_name)
print(variant_name)
# Out:
# automl-dm-ep-23-06-50-10
# automl-dm-variant-23-06-50-10

# %%
ep_config = sm.create_endpoint_config(EndpointConfigName = epc_name,
                                      ProductionVariants=[{'InstanceType':'ml.m4.xlarge',
                                                           'InitialInstanceCount':1,
                                                           'ModelName':model_name,
                                                           'VariantName':variant_name}])

create_endpoint_response = sm.create_endpoint(EndpointName=ep_name,
                                              EndpointConfigName=epc_name)
print(create_endpoint_response['EndpointArn'])
# Out:
# arn:aws:sagemaker:us-east-1:835319576252:endpoint/automl-dm-ep-23-06-50-10

# %%
# %%time
sm.get_waiter('endpoint_in_service').wait(EndpointName=ep_name)
# Out:
# CPU times: user 11.5 ms, sys: 1.03 ms, total: 12.5 ms
# Wall time: 158 ms

# %%
resp = sm.describe_endpoint(EndpointName=ep_name)
status = resp['EndpointStatus']

print("Arn: " + resp['EndpointArn'])
print("Status: " + status)
# Out:
# Arn: arn:aws:sagemaker:us-east-1:835319576252:endpoint/automl-dm-ep-23-06-50-10
# Status: InService

# %% [markdown]
# ## Scoring the Best Candidate
# Let's predict and score the validation set. We'll compute metrics ourselves just for fun.

# %%
sm_rt = boto3.Session().client('runtime.sagemaker', region_name=region)

# %%
#ep_name = ''

csv_line_predict_positive = """I loved it!  I wish there was a new season..."""
response = sm_rt.invoke_endpoint(EndpointName=ep_name, ContentType='text/csv', Accept='text/csv', Body=csv_line_predict_positive)

response_body = response['Body'].read().decode("utf-8").strip()
response_body
# Out:
# '1'

# %%
csv_line_predict_negative = """This isn't good.  Complete waste of time."""
response = sm_rt.invoke_endpoint(EndpointName=ep_name, ContentType='text/csv', Accept='text/csv', Body=csv_line_predict_negative)

response_body = response['Body'].read().decode("utf-8").strip()
response_body
# Out:
# '0'

# %%
for review_body in test['review_body']:
    print(review_body)
# Out:
# Love these mysteries
# This is a review by my son, who is 6, so take it with a grain of salt:  &#34;It's the worst movie in the whole entire world because it's so annoying to hear and watch.  (It's so annoying) because it supposed to be annoying.  I recommend that you should not watch this movie.&#34;
# Love Tom Selic all the cast is great and the story line beleavable , can't wait for the fall season to begin
# So so
# This is not the actual movie, so unless you just want previews of all the best parts. Dont bother. I realize now that it was behind the scenes, but it bored me to tears. Only watched the first 1/4.
# Apparently for anyone who has worked on a reality TV show, as the creator has, this show has unparalleled authenticity.  Shiri Appleby and Constance Zimmer have fabulous chemistry for their dysfunctional, effective partnership.  Don't know how this show ended up on Lifetime, but it's to Lifetime what Breaking Bad was to AMC.
# It's an all around wonderful sisterly love movie
# Tortuously slow and nonsensical; mention of &#34;Schroeder's Cat&#34; and palaver about other theoretical physics terminology does not amount to &#34;science&#34;. This is silly science-fiction delivered as drawn out melodrama which is simply not entertaining. The minimal amount of weak &#34;special effects&#34; amount to no more that computer screen graphics displays, oscillating lights, fading in & out and vanishing. Whoop-dee-doo. Decent acting and mildly satisfying closure to the feeble premise keep this from getting a 1-star rating.
# we were disappointed. for such a dynamic man, this documentary was NOT!
# This movie races along trying to get every page in the script giving little time for the actors to act or for the audience to understand.
# Of the BEST series I've seen ! !
# Highly anticipated viewing this movie and was more then a bit dissapointed. Movie never really got going...was anticipating much more action given advertising. Ending was odd as well.
# 3 and 5 year old like this have played it several times:)
# to much blood. and killing.
# This documentary is so focused on fast talk that it fails to consider any other aspect of competitive college debate - such as the quality and nature of the arguments advanced, the controversy over discussions of race, the application of academic theories about communication (post-modernism, post-structuralism, deconstructionism, other &#34;isms&#34;), etc. The obsession with the strangeness of watching debaters who talk fast misses what is most valuable about college debate, namely that it teaches kids the research and critical thinking skills to engage with complicated and abstract ideas, as well as what actually threatens to undercut these valuable lessons. Ms. Tolchinsky does not seem to understand the arguments in and about competitive debate, so she returns again and again to the not-particularly-important question of whether the debaters are talking too fast. College debate has its weaknesses, but I don't think fast talk is one of them.
# A TV classic. Of course, a bit dated and predictable. A nostalgia watch.
# Not exceptional.

# %%
test['review_body'].shape
# Out:
# (151,)

# %%
responses = [int(sm_rt.invoke_endpoint(EndpointName=ep_name, ContentType='text/csv', Accept='text/csv', Body=review_body.replace(',', ' '))['Body'].read().decode("utf-8").strip())
             for review_body in test['review_body']]

# %%
tp = 0
fn = 0
tn = 0
fp = 0

# TODO:  Compare to test['is_positive_sentiment']
for index, response in enumerate(responses):
    if (test.iloc[index]['is_positive_sentiment'] == 1):
        if response == 1:
            # True positive
            tp = tp + 1
        else:
            # False negative
            fn = fn + 1
    else:
        if (test.iloc[index]['is_positive_sentiment'] == 0):
            # True negative
            tn = tn + 1
        else:
            # False positive
            fp = fp + 1

# %%
#Confusion matrix
print ("%d %d" % (tn, fp))
print ("%d %d" % (fn, tp))

accuracy  = (tp + tn) / (tp + tn + fp + fn)
precision = tp / (tp + fp)
recall    = tn / (tn + fn)
f1        = (2 * precision * recall)/(precision + recall)

print ("accuracy:\t%.4f\nprecision:\t%.4f\nrecall:\t\t%.4f\nf1:\t\t%.4f" % (accuracy, precision, recall, f1))
# Out:
# 73 0
# 23 55
# accuracy:	0.8477
# precision:	1.0000
# recall:		0.7604
# f1:		0.8639
