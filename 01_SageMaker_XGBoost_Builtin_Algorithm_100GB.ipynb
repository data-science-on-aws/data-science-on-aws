# %%
import time
import uuid
import boto3
import sagemaker

sess = sagemaker.Session()
region = boto3.Session().region_name
bucket = sess.default_bucket()
role = sagemaker.get_execution_role()

# %%
model_training_s3_uri = 's3://dsoaws/nyc-taxi-orig-cleaned-dropped-parquet-all-years-multiple-files-100GB/'
#model_training_s3_uri = 's3://dsoaws/nyc-taxi-orig-cleaned-dropped-parquet-all-years-multiple-files-100GB-all/' # doesn't pick up the 01-

# %% [markdown]
# ### Configure the algorithm and training job
#
# The Training Job hyperparameters are set. For more information on XGBoost Hyperparameters,
# see https://xgboost.readthedocs.io/en/latest/parameter.html.

# %%
container = sagemaker.image_uris.retrieve("xgboost", region, "1.5-1")

output_content_type = "parquet"

train_content_type = (
    "application/x-parquet" if output_content_type.upper() == "PARQUET"
    else "text/csv"
)
train_input = sagemaker.inputs.TrainingInput(
    s3_data=model_training_s3_uri,
    content_type=train_content_type,
    distribution='ShardedByS3Key',
#    input_mode='FastFile'
)

hyperparameters = {
    "eta": "0.2",
    "gamma": "4",
    "max_depth": "5",
    "min_child_weight": "6",
    "num_round": "50",
    "objective": "reg:squarederror",
    "subsample": "0.7"
}

# %% [markdown]
# ### Start the Training Job
#
# The TrainingJob configurations are set using the SageMaker Python SDK Estimator, and which is fit using
# the training data from the Processing Job that was run earlier.

# %%
estimator = sagemaker.estimator.Estimator(
    container,
    role,
    hyperparameters=hyperparameters,
    instance_count=12,
    instance_type="ml.m5.24xlarge",
    volume_size=200,
#    input_mode='FastFile'
)

# %%
import time
import sagemaker

# XX minutes - m5.24xlarge (12 nodes) - 100GB
training_job_results = estimator.fit({"train": train_input})
print(training_job_results)
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2023-03-13-03-46-33-690
# 2023-03-13 03:46:34 Starting - Starting the training job...
# 2023-03-13 03:46:49 Starting - Preparing the instances for training.........
# 2023-03-13 03:48:19 Downloading - Downloading input data...
# 2023-03-13 03:48:55 Training - Training image download completed. Training in progress....[2023-03-13 03:49:21.504 ip-10-0-174-0.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-03-13 03:49:21.560 ip-10-0-174-0.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-03-13:03:49:21:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-03-13:03:49:21:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-03-13:03:49:21:INFO] No GPUs detected (normal if no gpus installed)
# [2023-03-13:03:49:21:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-03-13:03:49:21:INFO] Determined 0 GPU(s) available on the instance.
# [2023-03-13:03:49:21:INFO] files path: /opt/ml/input/data/train/01
# [2023-03-13 03:49:23.271 ip-10-0-187-194.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-03-13 03:49:23.326 ip-10-0-187-194.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-03-13:03:49:23:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-03-13:03:49:23:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-03-13:03:49:23:INFO] No GPUs detected (normal if no gpus installed)
# [2023-03-13:03:49:23:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-03-13:03:49:23:INFO] Determined 0 GPU(s) available on the instance.
# [2023-03-13:03:49:23:INFO] files path: /opt/ml/input/data/train/01
# [2023-03-13 03:49:26.251 ip-10-0-188-145.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-03-13 03:49:26.308 ip-10-0-188-145.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-03-13:03:49:26:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-03-13:03:49:26:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-03-13:03:49:26:INFO] No GPUs detected (normal if no gpus installed)
# [2023-03-13:03:49:26:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-03-13:03:49:26:INFO] Determined 0 GPU(s) available on the instance.
# [2023-03-13:03:49:26:INFO] files path: /opt/ml/input/data/train/01
# [2023-03-13 03:49:29.437 ip-10-0-146-88.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-03-13 03:49:29.493 ip-10-0-146-88.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-03-13 03:49:27.146 ip-10-0-173-143.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-03-13 03:49:27.201 ip-10-0-173-143.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-03-13:03:49:27:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-03-13:03:49:27:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-03-13:03:49:27:INFO] No GPUs detected (normal if no gpus installed)
# [2023-03-13:03:49:27:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-03-13:03:49:27:INFO] Determined 0 GPU(s) available on the instance.
# [2023-03-13:03:49:27:INFO] files path: /opt/ml/input/data/train/01
# [2023-03-13 03:49:25.786 ip-10-0-182-56.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-03-13 03:49:25.842 ip-10-0-182-56.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-03-13:03:49:26:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-03-13:03:49:26:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-03-13:03:49:26:INFO] No GPUs detected (normal if no gpus installed)
# [2023-03-13:03:49:26:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-03-13:03:49:26:INFO] Determined 0 GPU(s) available on the instance.
# [2023-03-13:03:49:26:INFO] files path: /opt/ml/input/data/train/01
# [2023-03-13 03:49:27.011 ip-10-0-148-79.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-03-13 03:49:27.065 ip-10-0-148-79.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-03-13:03:49:27:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-03-13:03:49:27:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-03-13:03:49:27:INFO] No GPUs detected (normal if no gpus installed)
# [2023-03-13:03:49:27:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-03-13:03:49:27:INFO] Determined 0 GPU(s) available on the instance.
# [2023-03-13:03:49:27:INFO] files path: /opt/ml/input/data/train/01
# [2023-03-13:03:49:29:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-03-13:03:49:29:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-03-13:03:49:29:INFO] No GPUs detected (normal if no gpus installed)
# [2023-03-13:03:49:29:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-03-13:03:49:29:INFO] Determined 0 GPU(s) available on the instance.
# [2023-03-13:03:49:29:INFO] files path: /opt/ml/input/data/train/01
# [2023-03-13 03:49:27.773 ip-10-0-184-186.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-03-13 03:49:27.830 ip-10-0-184-186.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-03-13:03:49:28:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-03-13:03:49:28:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-03-13:03:49:28:INFO] No GPUs detected (normal if no gpus installed)
# [2023-03-13:03:49:28:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-03-13:03:49:28:INFO] Determined 0 GPU(s) available on the instance.
# [2023-03-13:03:49:28:INFO] files path: /opt/ml/input/data/train/01
# [2023-03-13 03:49:29.181 ip-10-0-165-195.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-03-13 03:49:29.238 ip-10-0-165-195.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-03-13:03:49:29:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-03-13:03:49:29:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-03-13:03:49:29:INFO] No GPUs detected (normal if no gpus installed)
# [2023-03-13:03:49:29:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-03-13:03:49:29:INFO] Determined 0 GPU(s) available on the instance.
# [2023-03-13:03:49:29:INFO] files path: /opt/ml/input/data/train/01
# [2023-03-13 03:49:27.470 ip-10-0-131-82.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-03-13 03:49:27.527 ip-10-0-131-82.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-03-13:03:49:27:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-03-13:03:49:27:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-03-13:03:49:27:INFO] No GPUs detected (normal if no gpus installed)
# [2023-03-13:03:49:27:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-03-13:03:49:27:INFO] Determined 0 GPU(s) available on the instance.
# [2023-03-13:03:49:27:INFO] files path: /opt/ml/input/data/train/01
# [2023-03-13 03:49:28.392 ip-10-0-146-63.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-03-13 03:49:28.448 ip-10-0-146-63.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-03-13:03:49:28:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-03-13:03:49:28:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-03-13:03:49:28:INFO] No GPUs detected (normal if no gpus installed)
# [2023-03-13:03:49:28:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-03-13:03:49:28:INFO] Determined 0 GPU(s) available on the instance.
# [2023-03-13:03:49:28:INFO] files path: /opt/ml/input/data/train/01
# [2023-03-13:03:49:34:INFO] Distributed node training with 12 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12']
# [2023-03-13:03:49:34:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-13:03:49:34:INFO] Sleeping for 3 sec before retrying
# [2023-03-13:03:49:36:INFO] Distributed node training with 12 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12']
# [2023-03-13:03:49:36:INFO] start listen on algo-1:9099
# [2023-03-13:03:49:36:INFO] Rabit slave environment: {'DMLC_TRACKER_URI': 'algo-1', 'DMLC_TRACKER_PORT': 9099}
# [2023-03-13:03:49:36:INFO] Connected to RabitTracker.
# [2023-03-13:03:49:36:INFO] No data received from connection ('10.0.187.194', 43584). Closing.
# [2023-03-13:03:49:37:INFO] No data received from connection ('10.0.174.0', 60870). Closing.
# [2023-03-13:03:49:37:INFO] Connected to RabitTracker.
# [2023-03-13:03:49:38:INFO] Distributed node training with 12 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12']
# [2023-03-13:03:49:38:INFO] Connected to RabitTracker.
# [2023-03-13:03:49:38:INFO] No data received from connection ('10.0.182.56', 32980). Closing.
# [2023-03-13:03:49:39:INFO] Distributed node training with 12 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12']
# [2023-03-13:03:49:39:INFO] Connected to RabitTracker.
# [2023-03-13:03:49:39:INFO] No data received from connection ('10.0.188.145', 37244). Closing.
# [2023-03-13:03:49:40:INFO] No data received from connection ('10.0.148.79', 46378). Closing.
# [2023-03-13:03:49:40:INFO] Distributed node training with 12 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12']
# [2023-03-13:03:49:40:INFO] Connected to RabitTracker.
# [2023-03-13:03:49:41:INFO] No data received from connection ('10.0.173.143', 45198). Closing.
# [2023-03-13:03:49:41:INFO] Distributed node training with 12 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12']
# [2023-03-13:03:49:41:INFO] Connected to RabitTracker.
# [2023-03-13:03:49:41:INFO] Distributed node training with 12 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12']
# [2023-03-13:03:49:41:INFO] Connected to RabitTracker.
# [2023-03-13:03:49:41:INFO] Distributed node training with 12 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12']
# [2023-03-13:03:49:41:INFO] Connected to RabitTracker.
# [2023-03-13:03:49:41:INFO] No data received from connection ('10.0.184.186', 35634). Closing.
# [2023-03-13:03:49:41:INFO] No data received from connection ('10.0.131.82', 36028). Closing.
# [2023-03-13:03:49:41:INFO] No data received from connection ('10.0.146.63', 47822). Closing.
# [2023-03-13:03:49:41:INFO] Distributed node training with 12 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12']
# [2023-03-13:03:49:41:INFO] Connected to RabitTracker.
# [2023-03-13:03:49:42:INFO] Distributed node training with 12 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12']
# [2023-03-13:03:49:42:INFO] Connected to RabitTracker.
# [2023-03-13:03:49:42:INFO] No data received from connection ('10.0.165.195', 36402). Closing.
# [2023-03-13:03:49:42:INFO] No data received from connection ('10.0.146.88', 42864). Closing.
# [2023-03-13:03:49:42:INFO] Distributed node training with 12 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12']
# [2023-03-13:03:49:42:INFO] Connected to RabitTracker.
# [2023-03-13 03:49:41.724 ip-10-0-169-188.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-03-13 03:49:41.780 ip-10-0-169-188.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-03-13:03:49:42:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-03-13:03:49:42:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-03-13:03:49:42:INFO] No GPUs detected (normal if no gpus installed)
# [2023-03-13:03:49:42:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-03-13:03:49:42:INFO] Determined 0 GPU(s) available on the instance.
# [2023-03-13:03:49:42:INFO] files path: /opt/ml/input/data/train/01
# [2023-03-13:03:49:55:INFO] No data received from connection ('10.0.169.188', 47536). Closing.
# [03:49:55] task NULL got new rank 0
# [03:49:55] task NULL got new rank 2
# [2023-03-13:03:49:55:INFO] Distributed node training with 12 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12']
# [2023-03-13:03:49:55:INFO] Connected to RabitTracker.
# [03:49:55] task NULL got new rank 6
# [03:49:55] task NULL got new rank 4
# [03:49:55] task NULL got new rank 1
# [03:49:55] task NULL got new rank 8
# [2023-03-13:03:49:55:INFO] Recieve start signal from 10.0.131.82; assign rank 0
# [2023-03-13:03:49:55:INFO] Recieve start signal from 10.0.146.63; assign rank 1
# [2023-03-13:03:49:55:INFO] Recieve start signal from 10.0.146.88; assign rank 2
# [2023-03-13:03:49:55:INFO] Recieve start signal from 10.0.148.79; assign rank 3
# [2023-03-13:03:49:55:INFO] Recieve start signal from 10.0.165.195; assign rank 4
# [2023-03-13:03:49:55:INFO] Recieve start signal from 10.0.169.188; assign rank 5
# [2023-03-13:03:49:55:INFO] Recieve start signal from 10.0.173.143; assign rank 6
# [2023-03-13:03:49:55:INFO] Recieve start signal from 10.0.174.0; assign rank 7
# [2023-03-13:03:49:55:INFO] Recieve start signal from 10.0.182.56; assign rank 8
# [2023-03-13:03:49:56:INFO] Recieve start signal from 10.0.184.186; assign rank 9
# [03:49:56] task NULL got new rank 10
# [2023-03-13:03:49:56:INFO] Recieve start signal from 10.0.187.194; assign rank 10
# [03:49:55] task NULL got new rank 3
# [03:49:55] task NULL got new rank 7
# [2023-03-13:03:49:56:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-13:03:49:56:INFO] Sleeping for 3 sec before retrying
# [03:49:55] task NULL got new rank 5
# [2023-03-13:03:49:56:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-13:03:49:56:INFO] Sleeping for 3 sec before retrying
# [03:49:56] task NULL got new rank 11
# [2023-03-13:03:49:56:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-13:03:49:56:INFO] Sleeping for 3 sec before retrying
# [2023-03-13:03:49:56:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-13:03:49:56:INFO] Sleeping for 3 sec before retrying
# [2023-03-13:03:49:56:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-13:03:49:56:INFO] Sleeping for 3 sec before retrying
# [03:49:55] task NULL got new rank 9
# [2023-03-13:03:49:56:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-13:03:49:56:INFO] Sleeping for 3 sec before retrying
# [2023-03-13:03:49:56:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-13:03:49:56:INFO] Sleeping for 3 sec before retrying
# [2023-03-13:03:49:56:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-13:03:49:56:INFO] Sleeping for 3 sec before retrying
# [2023-03-13:03:49:56:INFO] Recieve start signal from 10.0.188.145; assign rank 11
# [2023-03-13:03:49:56:INFO] @tracker All of 12 nodes getting started
# [2023-03-13:03:49:56:INFO] @tracker All nodes finishes job
# [2023-03-13:03:49:56:INFO] @tracker 0.22693324089050293 secs between node start and job finish
# [2023-03-13:03:49:56:INFO] start listen on algo-1:9100
# [2023-03-13:03:49:56:INFO] Rabit slave environment: {'DMLC_TRACKER_URI': 'algo-1', 'DMLC_TRACKER_PORT': 9100}
# [2023-03-13:03:49:56:INFO] Connected to RabitTracker.
# [2023-03-13:03:49:56:INFO] No data received from connection ('10.0.187.194', 59088). Closing.
# [2023-03-13:03:49:56:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-13:03:49:56:INFO] Sleeping for 3 sec before retrying
# [2023-03-13:03:49:56:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-13:03:49:56:INFO] Sleeping for 3 sec before retrying
# [2023-03-13:03:49:56:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-13:03:49:56:INFO] Sleeping for 3 sec before retrying
# [2023-03-13:03:49:59:INFO] Connected to RabitTracker.
# [2023-03-13:03:49:59:INFO] Connected to RabitTracker.
# [2023-03-13:03:49:59:INFO] Connected to RabitTracker.
# [2023-03-13:03:49:59:INFO] Connected to RabitTracker.
# [2023-03-13:03:49:59:INFO] Connected to RabitTracker.
# [2023-03-13:03:49:59:INFO] Connected to RabitTracker.
# [2023-03-13:03:49:59:INFO] Connected to RabitTracker.
# [03:49:59] task NULL got new rank 1
# [2023-03-13:03:49:59:INFO] Connected to RabitTracker.
# [2023-03-13:03:49:59:INFO] Connected to RabitTracker.
# [03:49:59] task NULL got new rank 3
# [2023-03-13:03:49:59:INFO] Train matrix has 86155793 rows and 11 columns
# [2023-03-13 03:49:59.935 ip-10-0-148-79.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-03-13 03:49:59.935 ip-10-0-148-79.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-03-13 03:49:59.936 ip-10-0-148-79.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-03-13 03:49:59.936 ip-10-0-148-79.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-03-13:03:49:59:INFO] Debug hook created from config
# [2023-03-13:03:49:59:INFO] Connected to RabitTracker.
# [03:50:00] task NULL got new rank 7
# [2023-03-13:03:50:00:INFO] Train matrix has 88083621 rows and 11 columns
# [2023-03-13 03:50:00.288 ip-10-0-174-0.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-03-13 03:50:00.288 ip-10-0-174-0.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-03-13 03:50:00.289 ip-10-0-174-0.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-03-13 03:50:00.289 ip-10-0-174-0.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-03-13:03:50:00:INFO] Debug hook created from config
# [03:50:00] task NULL got new rank 11
# [2023-03-13:03:50:00:INFO] Train matrix has 89430648 rows and 11 columns
# [2023-03-13 03:50:00.553 ip-10-0-188-145.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-03-13 03:50:00.554 ip-10-0-188-145.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-03-13 03:50:00.555 ip-10-0-188-145.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-03-13 03:50:00.555 ip-10-0-188-145.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-03-13:03:50:00:INFO] Debug hook created from config
# [03:50:00] task NULL got new rank 9
# [2023-03-13:03:50:00:INFO] Train matrix has 84870586 rows and 11 columns
# [2023-03-13 03:50:00.464 ip-10-0-184-186.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-03-13 03:50:00.465 ip-10-0-184-186.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-03-13 03:50:00.466 ip-10-0-184-186.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-03-13 03:50:00.466 ip-10-0-184-186.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-03-13:03:50:00:INFO] Debug hook created from config
# [03:50:00] task NULL got new rank 8
# [2023-03-13:03:50:00:INFO] Train matrix has 88772824 rows and 11 columns
# [2023-03-13 03:50:00.553 ip-10-0-182-56.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-03-13 03:50:00.554 ip-10-0-182-56.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-03-13 03:50:00.555 ip-10-0-182-56.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-03-13 03:50:00.555 ip-10-0-182-56.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-03-13:03:50:00:INFO] Debug hook created from config
# [2023-03-13:03:49:59:INFO] No data received from connection ('10.0.188.145', 41006). Closing.
# [2023-03-13:03:49:59:INFO] No data received from connection ('10.0.131.82', 34508). Closing.
# [2023-03-13:03:49:59:INFO] No data received from connection ('10.0.184.186', 44306). Closing.
# [2023-03-13:03:49:59:INFO] No data received from connection ('10.0.182.56', 45048). Closing.
# [2023-03-13:03:49:59:INFO] No data received from connection ('10.0.169.188', 36594). Closing.
# [2023-03-13:03:49:59:INFO] No data received from connection ('10.0.146.63', 36864). Closing.
# [2023-03-13:03:49:59:INFO] No data received from connection ('10.0.165.195', 53494). Closing.
# [2023-03-13:03:49:59:INFO] No data received from connection ('10.0.173.143', 41178). Closing.
# [2023-03-13:03:49:59:INFO] No data received from connection ('10.0.148.79', 40676). Closing.
# [2023-03-13:03:49:59:INFO] No data received from connection ('10.0.146.88', 43142). Closing.
# [2023-03-13:03:49:59:INFO] No data received from connection ('10.0.174.0', 51572). Closing.
# [2023-03-13:03:49:59:INFO] Recieve start signal from 10.0.131.82; assign rank 0
# [2023-03-13:03:49:59:INFO] Recieve start signal from 10.0.146.63; assign rank 1
# [2023-03-13:03:49:59:INFO] Recieve start signal from 10.0.146.88; assign rank 2
# [2023-03-13:03:49:59:INFO] Recieve start signal from 10.0.148.79; assign rank 3
# [2023-03-13:03:49:59:INFO] Recieve start signal from 10.0.165.195; assign rank 4
# [2023-03-13:03:50:00:INFO] Recieve start signal from 10.0.169.188; assign rank 5
# [2023-03-13:03:50:00:INFO] Recieve start signal from 10.0.173.143; assign rank 6
# [2023-03-13:03:50:00:INFO] Recieve start signal from 10.0.174.0; assign rank 7
# [2023-03-13:03:49:59:INFO] Connected to RabitTracker.
# [03:49:59] task NULL got new rank 0
# [03:49:59] task NULL got new rank 2
# [2023-03-13:03:49:59:INFO] Train matrix has 89107061 rows and 11 columns
# [2023-03-13 03:49:59.934 ip-10-0-146-88.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-03-13 03:49:59.935 ip-10-0-146-88.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-03-13 03:49:59.936 ip-10-0-146-88.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-03-13 03:49:59.936 ip-10-0-146-88.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-03-13:03:49:59:INFO] Debug hook created from config
# [03:49:59] task NULL got new rank 5
# [2023-03-13:03:50:00:INFO] Train matrix has 88897004 rows and 11 columns
# [2023-03-13 03:50:00.201 ip-10-0-169-188.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-03-13 03:50:00.202 ip-10-0-169-188.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-03-13 03:50:00.203 ip-10-0-169-188.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-03-13 03:50:00.203 ip-10-0-169-188.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-03-13:03:50:00:INFO] Debug hook created from config
# [03:50:00] task NULL got new rank 6
# [2023-03-13:03:50:00:INFO] Train matrix has 84772322 rows and 11 columns
# [2023-03-13 03:50:00.202 ip-10-0-173-143.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-03-13 03:50:00.202 ip-10-0-173-143.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-03-13 03:50:00.203 ip-10-0-173-143.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-03-13 03:50:00.203 ip-10-0-173-143.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-03-13:03:50:00:INFO] Debug hook created from config
# [03:49:59] task NULL got new rank 4
# [2023-03-13:03:50:00:INFO] Train matrix has 88170273 rows and 11 columns
# [2023-03-13 03:50:00.023 ip-10-0-165-195.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-03-13 03:50:00.023 ip-10-0-165-195.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-03-13 03:50:00.024 ip-10-0-165-195.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-03-13 03:50:00.024 ip-10-0-165-195.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-03-13:03:50:00:INFO] Debug hook created from config
# [2023-03-13:03:50:00:INFO] Train matrix has 88141204 rows and 11 columns
# [2023-03-13 03:50:00.201 ip-10-0-146-63.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-03-13 03:50:00.201 ip-10-0-146-63.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-03-13 03:50:00.202 ip-10-0-146-63.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-03-13 03:50:00.203 ip-10-0-146-63.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-03-13:03:50:00:INFO] Debug hook created from config
# [2023-03-13:03:50:00:INFO] Recieve start signal from 10.0.182.56; assign rank 8
# [2023-03-13:03:50:00:INFO] Recieve start signal from 10.0.184.186; assign rank 9
# [03:50:00] task NULL got new rank 10
# [2023-03-13:03:50:00:INFO] Recieve start signal from 10.0.187.194; assign rank 10
# [2023-03-13:03:50:00:INFO] Recieve start signal from 10.0.188.145; assign rank 11
# [2023-03-13:03:50:00:INFO] @tracker All of 12 nodes getting started
# [2023-03-13:03:50:00:INFO] Train matrix has 88856050 rows and 11 columns
# [2023-03-13 03:50:00.553 ip-10-0-187-194.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-03-13 03:50:00.554 ip-10-0-187-194.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-03-13 03:50:00.555 ip-10-0-187-194.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-03-13 03:50:00.555 ip-10-0-187-194.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-03-13:03:50:00:INFO] Debug hook created from config
# [2023-03-13:03:50:00:INFO] Train matrix has 88781379 rows and 11 columns
# [2023-03-13 03:50:00.552 ip-10-0-131-82.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-03-13 03:50:00.553 ip-10-0-131-82.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-03-13 03:50:00.554 ip-10-0-131-82.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-03-13 03:50:00.554 ip-10-0-131-82.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-03-13:03:50:00:INFO] Debug hook created from config
# [2023-03-13 03:50:49.428 ip-10-0-146-88.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-03-13 03:50:49.428 ip-10-0-169-188.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-03-13 03:50:49.428 ip-10-0-188-145.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-03-13 03:50:49.428 ip-10-0-173-143.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-03-13 03:50:49.428 ip-10-0-165-195.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-03-13 03:50:49.428 ip-10-0-146-63.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-03-13 03:50:49.428 ip-10-0-182-56.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-03-13 03:50:49.428 ip-10-0-131-82.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-03-13 03:50:49.428 ip-10-0-174-0.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-03-13 03:50:49.429 ip-10-0-184-186.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-03-13 03:50:49.428 ip-10-0-187-194.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-03-13:03:50:49:INFO] [0]#011train-rmse:173.79295
# [2023-03-13 03:50:49.428 ip-10-0-148-79.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-03-13:03:51:26:INFO] [1]#011train-rmse:163.90968
# [2023-03-13:03:52:03:INFO] [2]#011train-rmse:156.79402
# [2023-03-13:03:52:40:INFO] [3]#011train-rmse:152.25229
# [2023-03-13:03:53:17:INFO] [4]#011train-rmse:148.46484
# [2023-03-13:03:53:53:INFO] [5]#011train-rmse:145.83226
# [2023-03-13:03:54:30:INFO] [6]#011train-rmse:144.23024
# [2023-03-13:03:55:06:INFO] [7]#011train-rmse:142.85547
# [2023-03-13:03:55:43:INFO] [8]#011train-rmse:142.10323
# [2023-03-13:03:56:20:INFO] [9]#011train-rmse:141.52278
# [2023-03-13:03:56:56:INFO] [10]#011train-rmse:141.33417
# [2023-03-13:03:57:33:INFO] [11]#011train-rmse:140.83365
# [2023-03-13:03:58:10:INFO] [12]#011train-rmse:140.71344
# [2023-03-13:03:58:46:INFO] [13]#011train-rmse:140.47159
# [2023-03-13:03:59:23:INFO] [14]#011train-rmse:140.17937
# [2023-03-13:03:59:59:INFO] [15]#011train-rmse:140.15216
# [2023-03-13:04:00:35:INFO] [16]#011train-rmse:140.04967
# [2023-03-13:04:01:11:INFO] [17]#011train-rmse:140.03528
# [2023-03-13:04:01:47:INFO] [18]#011train-rmse:139.86868
# [2023-03-13:04:02:24:INFO] [19]#011train-rmse:139.73424
# [2023-03-13:04:02:59:INFO] [20]#011train-rmse:139.61005
# [2023-03-13:04:03:36:INFO] [21]#011train-rmse:139.60319
# [2023-03-13:04:04:12:INFO] [22]#011train-rmse:139.32922
# [2023-03-13:04:04:50:INFO] [23]#011train-rmse:139.25456
# [2023-03-13:04:05:26:INFO] [24]#011train-rmse:139.19997
# [2023-03-13:04:06:02:INFO] [25]#011train-rmse:139.20136
# [2023-03-13:04:06:39:INFO] [26]#011train-rmse:139.18962
# [2023-03-13:04:07:15:INFO] [27]#011train-rmse:139.14746
# [2023-03-13:04:07:51:INFO] [28]#011train-rmse:139.13702
# [2023-03-13:04:08:27:INFO] [29]#011train-rmse:139.12666
# [2023-03-13:04:09:03:INFO] [30]#011train-rmse:139.11505
# [2023-03-13:04:09:39:INFO] [31]#011train-rmse:139.05824
# [2023-03-13:04:10:16:INFO] [32]#011train-rmse:139.04884
# [2023-03-13:04:10:52:INFO] [33]#011train-rmse:139.00874
# [2023-03-13:04:11:28:INFO] [34]#011train-rmse:139.00397
# [2023-03-13:04:12:04:INFO] [35]#011train-rmse:138.99561
# [2023-03-13:04:12:40:INFO] [36]#011train-rmse:138.98007
# [2023-03-13:04:13:17:INFO] [37]#011train-rmse:138.95621
# [2023-03-13:04:13:54:INFO] [38]#011train-rmse:138.95671
# [2023-03-13:04:14:30:INFO] [39]#011train-rmse:138.97020
# [2023-03-13:04:15:07:INFO] [40]#011train-rmse:138.94386
# [2023-03-13:04:15:43:INFO] [41]#011train-rmse:138.90268
# [2023-03-13:04:16:19:INFO] [42]#011train-rmse:138.89128
# [2023-03-13:04:16:56:INFO] [43]#011train-rmse:138.85515
# [2023-03-13:04:17:32:INFO] [44]#011train-rmse:138.82297
# [2023-03-13:04:18:08:INFO] [45]#011train-rmse:138.82266
# [2023-03-13:04:18:44:INFO] [46]#011train-rmse:138.82672
# [2023-03-13:04:19:22:INFO] [47]#011train-rmse:138.80734
# [2023-03-13:04:19:58:INFO] [48]#011train-rmse:138.79768
# [2023-03-13:04:20:37:INFO] [49]#011train-rmse:138.78795
# [2023-03-13:04:20:37:INFO] @tracker All nodes finishes job
# [2023-03-13:04:20:37:INFO] @tracker 1836.6658444404602 secs between node start and job finish
#
# 2023-03-13 04:20:51 Uploading - Uploading generated training model
# 2023-03-13 04:20:51 Completed - Training job completed
# Training seconds: 23436
# Billable seconds: 23436
# None
