# %% [markdown]
# # Set the All Python Dependencies

# %%
# !python --version

# %%
# !pip list

# %% [markdown]
# # Pip

# %%
# !pip install -q pip --upgrade
# !pip install -q wrapt --upgrade --ignore-installed

# %% [markdown]
# # AWS CLI

# %%
# !pip install -q awscli==1.18.137

# %% [markdown]
# # AWS Python SDK (boto3)

# %%
# !pip install -q boto3==1.14.60

# %% [markdown]
# # SageMaker

# %%
# !pip install -q sagemaker==2.5.5
# !pip install -q smdebug==0.9.3
# !pip install -q sagemaker-experiments==0.1.24

# %% [markdown]
# # StepFunctions
# _This is commented out for now since stepfunctions==1.1.1 does not yet support SageMaker 2.x SDK (only up to 1.x)_

# %%
#!pip install stepfunctions==1.1.x

# %% [markdown]
# # PyTorch

# %%
# !pip install -q torch==1.5.0

# %% [markdown]
# # TensorFlow

# %%
# !pip install -q tensorflow==2.1.0

# %% [markdown]
# # Hugging Face Transformers (BERT)

# %%
# !pip install -q transformers==2.8.0

# %% [markdown]
# # TorchServe

# %%
# !pip install -q torchserve==0.1.1
# !pip install -q torch-model-archiver==0.1.1

# %% [markdown]
# # PyAthena

# %%
# !pip install -q PyAthena==1.10.7

# %% [markdown]
# # Redshift

# %%
# !pip install -q SQLAlchemy==1.3.13

# %% [markdown]
# # AWS Data Wrangler

# %%
# !pip install -q awswrangler==1.9.3

# %% [markdown]
# # Summarize

# %%
# !python --version

# %%
# !pip list
