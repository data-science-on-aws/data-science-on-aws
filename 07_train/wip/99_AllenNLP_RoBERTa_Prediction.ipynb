# %% [markdown]
# * https://demo.allennlp.org/sentiment-analysis/MjI4MTQzNw==
# * https://github.com/allenai/allennlp/tree/master/allennlp/interpret/saliency_interpreters
# * https://github.com/allenai/allennlp/blob/master/allennlp/interpret/saliency_interpreters/simple_gradient.py

# %%
# !python --version

# %%
# !pip uninstall -y allennlp
# !pip uninstall -y allennlp-models
# !pip uninstall -y enum34

# %%
# !pip install git+https://github.com/allenai/allennlp-models.git@6a81154dc1df37131dde1e8ba734df0fdf1cfb92
# Out:
# Collecting git+https://github.com/allenai/allennlp-models.git@6a81154dc1df37131dde1e8ba734df0fdf1cfb92
#   Cloning https://github.com/allenai/allennlp-models.git (to revision 6a81154dc1df37131dde1e8ba734df0fdf1cfb92) to /tmp/pip-req-build-5vfc79np
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: word2number>=1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp-models==1.2.0) (1.1)
# Requirement already satisfied: nltk in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp-models==1.2.0) (3.4.5)
# Requirement already satisfied: conllu==4.2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp-models==1.2.0) (4.2.1)
# Requirement already satisfied: ftfy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp-models==1.2.0) (5.8)
# Collecting allennlp@ git+https://github.com/allenai/allennlp.git@master
#   Cloning https://github.com/allenai/allennlp.git (to revision master) to /tmp/pip-install-lo51xgn8/allennlp
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: py-rouge==1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp-models==1.2.0) (1.1)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from nltk->allennlp-models==1.2.0) (1.14.0)
# Requirement already satisfied: wcwidth in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from ftfy->allennlp-models==1.2.0) (0.1.8)
# Requirement already satisfied: spacy<2.4,>=2.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (2.2.4)
# Requirement already satisfied: jsonnet>=0.10.0; sys_platform != "win32" in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (0.16.0)
# Requirement already satisfied: tqdm>=4.19 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (4.42.1)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (1.18.1)
# Requirement already satisfied: filelock<3.1,>=3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (3.0.12)
# Requirement already satisfied: torch<1.8.0,>=1.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (1.6.0)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (1.4.1)
# Requirement already satisfied: pytest in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (5.3.5)
# Requirement already satisfied: overrides==3.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (3.1.0)
# Requirement already satisfied: tensorboardX>=1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (2.1)
# Requirement already satisfied: boto3<2.0,>=1.14 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (1.14.60)
# Requirement already satisfied: requests>=2.18 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (2.22.0)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (0.7)
# Requirement already satisfied: jsonpickle in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (1.4.1)
# Requirement already satisfied: transformers<3.5,>=3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (3.4.0)
# Requirement already satisfied: scikit-learn in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (0.23.1)
# Requirement already satisfied: h5py in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (2.10.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<2.4,>=2.1.0->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (1.0.3)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<2.4,>=2.1.0->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (1.0.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<2.4,>=2.1.0->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<2.4,>=2.1.0->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (2.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<2.4,>=2.1.0->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (1.0.4)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<2.4,>=2.1.0->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (45.2.0.post20200210)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<2.4,>=2.1.0->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (1.1.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<2.4,>=2.1.0->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (3.0.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<2.4,>=2.1.0->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (0.8.0)
# Requirement already satisfied: thinc==7.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<2.4,>=2.1.0->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (7.4.0)
# Requirement already satisfied: future in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from torch<1.8.0,>=1.6.0->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (0.18.2)
# Requirement already satisfied: py>=1.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pytest->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (1.8.1)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pytest->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (20.1)
# Requirement already satisfied: attrs>=17.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pytest->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (19.3.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pytest->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (8.2.0)
# Requirement already satisfied: pluggy<1.0,>=0.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pytest->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (0.13.1)
# Requirement already satisfied: importlib-metadata>=0.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pytest->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (1.5.0)
# Requirement already satisfied: protobuf>=3.8.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorboardX>=1.2->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (3.11.4)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3<2.0,>=1.14->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (0.10.0)
# Requirement already satisfied: botocore<1.18.0,>=1.17.60 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3<2.0,>=1.14->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (1.17.60)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3<2.0,>=1.14->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (0.3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests>=2.18->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (2020.6.20)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests>=2.18->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests>=2.18->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (1.25.10)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests>=2.18->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (2.8)
# Requirement already satisfied: sacremoses in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from transformers<3.5,>=3.1->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (0.0.43)
# Requirement already satisfied: sentencepiece!=0.1.92 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from transformers<3.5,>=3.1->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (0.1.94)
# Requirement already satisfied: tokenizers==0.9.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from transformers<3.5,>=3.1->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (0.9.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from transformers<3.5,>=3.1->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (2020.10.28)
# Requirement already satisfied: joblib>=0.11 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from scikit-learn->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (0.14.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from scikit-learn->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (2.1.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from packaging->pytest->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (2.4.6)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata>=0.12->pytest->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (2.2.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.18.0,>=1.17.60->boto3<2.0,>=1.14->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (2.8.1)
# Requirement already satisfied: docutils<0.16,>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.18.0,>=1.17.60->boto3<2.0,>=1.14->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (0.15.2)
# Requirement already satisfied: click in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sacremoses->transformers<3.5,>=3.1->allennlp@ git+https://github.com/allenai/allennlp.git@master->allennlp-models==1.2.0) (7.0)
# Building wheels for collected packages: allennlp-models, allennlp
#   Building wheel for allennlp-models (PEP 517) ... done
#   Created wheel for allennlp-models: filename=allennlp_models-1.2.0-py3-none-any.whl size=342128 sha256=ede0f09abde9ca294b8da971651d0716149a00bd91b909b64099553ded90e626
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/b8/f5/3a/b866e3e358b225c68fa4028de88451d739547329500ebdc523
#   Building wheel for allennlp (PEP 517) ... done
#   Created wheel for allennlp: filename=allennlp-1.2.0-py3-none-any.whl size=500795 sha256=c904c126ea29c38d9a7a1cfbf189be4dedff8e1f4dfae3e7814f0e51713d1afd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-h4wbsmya/wheels/4f/31/cc/283226e9be9504e3ef0cb77695fc0262763b5654ad0b59353a
# Successfully built allennlp-models allennlp
# Installing collected packages: allennlp, allennlp-models
# Successfully installed allennlp-1.2.0 allennlp-models-1.2.0

# %%
# !pip install git+https://github.com/allenai/allennlp.git@92a844a7b1d99839428f4e3e3302f27c2f06bc7f
# Out:
# Collecting git+https://github.com/allenai/allennlp.git@92a844a7b1d99839428f4e3e3302f27c2f06bc7f
#   Cloning https://github.com/allenai/allennlp.git (to revision 92a844a7b1d99839428f4e3e3302f27c2f06bc7f) to /tmp/pip-req-build-b90vhz9r
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied (use --upgrade to upgrade): allennlp==1.2.0 from git+https://github.com/allenai/allennlp.git@92a844a7b1d99839428f4e3e3302f27c2f06bc7f in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages
# Requirement already satisfied: dataclasses; python_version < "3.7" in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp==1.2.0) (0.7)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp==1.2.0) (1.4.1)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp==1.2.0) (1.18.1)
# Requirement already satisfied: pytest in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp==1.2.0) (5.3.5)
# Requirement already satisfied: overrides==3.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp==1.2.0) (3.1.0)
# Requirement already satisfied: requests>=2.18 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp==1.2.0) (2.22.0)
# Requirement already satisfied: spacy<2.4,>=2.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp==1.2.0) (2.2.4)
# Requirement already satisfied: jsonnet>=0.10.0; sys_platform != "win32" in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp==1.2.0) (0.16.0)
# Requirement already satisfied: scikit-learn in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp==1.2.0) (0.23.1)
# Requirement already satisfied: nltk in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp==1.2.0) (3.4.5)
# Requirement already satisfied: tqdm>=4.19 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp==1.2.0) (4.42.1)
# Requirement already satisfied: jsonpickle in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp==1.2.0) (1.4.1)
# Requirement already satisfied: boto3<2.0,>=1.14 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp==1.2.0) (1.14.60)
# Requirement already satisfied: transformers<3.5,>=3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp==1.2.0) (3.4.0)
# Requirement already satisfied: torch<1.8.0,>=1.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp==1.2.0) (1.6.0)
# Requirement already satisfied: filelock<3.1,>=3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp==1.2.0) (3.0.12)
# Requirement already satisfied: h5py in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp==1.2.0) (2.10.0)
# Requirement already satisfied: tensorboardX>=1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from allennlp==1.2.0) (2.1)
# Requirement already satisfied: py>=1.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pytest->allennlp==1.2.0) (1.8.1)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pytest->allennlp==1.2.0) (20.1)
# Requirement already satisfied: attrs>=17.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pytest->allennlp==1.2.0) (19.3.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pytest->allennlp==1.2.0) (8.2.0)
# Requirement already satisfied: pluggy<1.0,>=0.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pytest->allennlp==1.2.0) (0.13.1)
# Requirement already satisfied: wcwidth in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pytest->allennlp==1.2.0) (0.1.8)
# Requirement already satisfied: importlib-metadata>=0.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pytest->allennlp==1.2.0) (1.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests>=2.18->allennlp==1.2.0) (2020.6.20)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests>=2.18->allennlp==1.2.0) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests>=2.18->allennlp==1.2.0) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests>=2.18->allennlp==1.2.0) (1.25.10)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<2.4,>=2.1.0->allennlp==1.2.0) (0.4.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<2.4,>=2.1.0->allennlp==1.2.0) (1.0.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<2.4,>=2.1.0->allennlp==1.2.0) (3.0.4)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<2.4,>=2.1.0->allennlp==1.2.0) (45.2.0.post20200210)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<2.4,>=2.1.0->allennlp==1.2.0) (0.8.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<2.4,>=2.1.0->allennlp==1.2.0) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<2.4,>=2.1.0->allennlp==1.2.0) (1.0.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<2.4,>=2.1.0->allennlp==1.2.0) (2.0.4)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<2.4,>=2.1.0->allennlp==1.2.0) (1.1.3)
# Requirement already satisfied: thinc==7.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<2.4,>=2.1.0->allennlp==1.2.0) (7.4.0)
# Requirement already satisfied: joblib>=0.11 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from scikit-learn->allennlp==1.2.0) (0.14.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from scikit-learn->allennlp==1.2.0) (2.1.0)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from nltk->allennlp==1.2.0) (1.14.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3<2.0,>=1.14->allennlp==1.2.0) (0.10.0)
# Requirement already satisfied: botocore<1.18.0,>=1.17.60 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3<2.0,>=1.14->allennlp==1.2.0) (1.17.60)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3<2.0,>=1.14->allennlp==1.2.0) (0.3.3)
# Requirement already satisfied: sacremoses in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from transformers<3.5,>=3.1->allennlp==1.2.0) (0.0.43)
# Requirement already satisfied: tokenizers==0.9.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from transformers<3.5,>=3.1->allennlp==1.2.0) (0.9.2)
# Requirement already satisfied: sentencepiece!=0.1.92 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from transformers<3.5,>=3.1->allennlp==1.2.0) (0.1.94)
# Requirement already satisfied: protobuf in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from transformers<3.5,>=3.1->allennlp==1.2.0) (3.11.4)
# Requirement already satisfied: regex!=2019.12.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from transformers<3.5,>=3.1->allennlp==1.2.0) (2020.10.28)
# Requirement already satisfied: future in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from torch<1.8.0,>=1.6.0->allennlp==1.2.0) (0.18.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from packaging->pytest->allennlp==1.2.0) (2.4.6)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata>=0.12->pytest->allennlp==1.2.0) (2.2.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.18.0,>=1.17.60->boto3<2.0,>=1.14->allennlp==1.2.0) (2.8.1)
# Requirement already satisfied: docutils<0.16,>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.18.0,>=1.17.60->boto3<2.0,>=1.14->allennlp==1.2.0) (0.15.2)
# Requirement already satisfied: click in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sacremoses->transformers<3.5,>=3.1->allennlp==1.2.0) (7.0)
# Building wheels for collected packages: allennlp
#   Building wheel for allennlp (PEP 517) ... done
#   Created wheel for allennlp: filename=allennlp-1.2.0-py3-none-any.whl size=500795 sha256=56f82eed89208d89c2c50644776d44602a58a578381cbb4bc161c14e8b93769f
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/23/63/bd/cda823525f56c922bee55fe838039df00aa2f09fae87a3687b
# Successfully built allennlp

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# absl-py                            0.11.0
# alabaster                          0.7.12
# allennlp                           1.2.0
# allennlp-models                    1.2.0
# anaconda-client                    1.7.2
# anaconda-project                   0.8.3
# argh                               0.26.2
# asn1crypto                         1.3.0
# astor                              0.8.1
# astroid                            2.4.2
# astropy                            4.0
# astunparse                         1.6.3
# atomicwrites                       1.3.0
# attrs                              19.3.0
# Automat                            20.2.0
# autopep8                           1.4.4
# autovizwidget                      0.16.0
# awscli                             1.18.137
# awswrangler                        1.9.3
# Babel                              2.8.0
# backcall                           0.1.0
# backports.shutil-get-terminal-size 1.0.0
# bcrypt                             3.2.0
# beautifulsoup4                     4.8.2
# bitarray                           1.2.1
# bkcharts                           0.2
# bleach                             3.2.1
# blis                               0.4.1
# bokeh                              1.4.0
# boto                               2.49.0
# boto3                              1.14.60
# botocore                           1.17.60
# Bottleneck                         1.3.2
# cached-property                    1.5.2
# cachetools                         4.1.1
# catalogue                          1.0.0
# certifi                            2020.6.20
# cffi                               1.14.0
# chardet                            3.0.4
# Click                              7.0
# cloudpickle                        1.3.0
# clyent                             1.2.2
# colorama                           0.4.3
# conllu                             4.2.1
# contextlib2                        0.6.0.post1
# cryptography                       2.8
# cycler                             0.10.0
# cymem                              2.0.4
# Cython                             0.29.15
# cytoolz                            0.10.1
# dask                               2.11.0
# dataclasses                        0.7
# decorator                          4.4.1
# defusedxml                         0.6.0
# diff-match-patch                   20181111
# dill                               0.3.2
# distributed                        2.11.0
# distro                             1.5.0
# dm-tree                            0.1.5
# docker                             4.3.1
# docker-compose                     1.27.4
# dockerpty                          0.4.1
# docopt                             0.6.2
# docutils                           0.15.2
# en-core-web-sm                     2.2.5
# entrypoints                        0.3
# enum-compat                        0.0.3
# environment-kernels                1.1.1
# et-xmlfile                         1.0.1
# fastcache                          1.1.0
# filelock                           3.0.12
# flake8                             3.7.9
# flaky                              3.7.0
# Flask                              1.1.1
# fsspec                             0.6.2
# ftfy                               5.8
# future                             0.18.2
# gast                               0.3.3
# gevent                             1.4.0
# glob2                              0.7
# gmpy2                              2.0.8
# google-auth                        1.23.0
# google-auth-oauthlib               0.4.2
# google-pasta                       0.2.0
# googleapis-common-protos           1.52.0
# greenlet                           0.4.15
# grpcio                             1.33.2
# h5py                               2.10.0
# hdijupyterutils                    0.16.0
# HeapDict                           1.0.1
# html5lib                           1.0.1
# hypothesis                         5.5.4
# idna                               2.8
# imageio                            2.6.1
# imagesize                          1.2.0
# importlib-metadata                 1.5.0
# importlib-resources                3.3.0
# intervaltree                       3.0.2
# ipykernel                          5.1.4
# ipyparallel                        6.3.0
# ipython                            7.12.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.5.1
# isort                              4.3.21
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.14.1
# jeepney                            0.4.2
# Jinja2                             2.11.1
# jmespath                           0.10.0
# joblib                             0.14.1
# json5                              0.9.1
# jsonnet                            0.16.0
# jsonpickle                         1.4.1
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     5.3.4
# jupyter-console                    6.1.0
# jupyter-core                       4.6.1
# jupyterlab                         1.2.6
# jupyterlab-server                  1.0.6
# Keras-Applications                 1.0.8
# Keras-Preprocessing                1.1.2
# keyring                            21.1.0
# kiwisolver                         1.1.0
# lazy-object-proxy                  1.4.3
# libarchive-c                       2.8
# lief                               0.9.0
# llvmlite                           0.31.0
# locket                             0.2.0
# lxml                               4.5.0
# Markdown                           3.3.3
# MarkupSafe                         1.1.1
# matplotlib                         3.2.1
# mccabe                             0.6.1
# mistune                            0.8.4
# mkl-fft                            1.0.15
# mkl-random                         1.1.0
# mkl-service                        2.3.0
# mock                               4.0.1
# more-itertools                     8.2.0
# mpmath                             1.1.0
# msgpack                            0.6.1
# multipledispatch                   0.6.0
# murmurhash                         1.0.4
# nb-conda                           2.2.1
# nb-conda-kernels                   2.2.4
# nbconvert                          5.6.1
# nbformat                           5.0.4
# networkx                           2.4
# nltk                               3.4.5
# nose                               1.3.7
# notebook                           6.0.3
# numba                              0.48.0
# numexpr                            2.7.1
# numpy                              1.18.1
# numpydoc                           0.9.2
# nvidia-ml-py                       10.418.84
# oauthlib                           3.1.0
# olefile                            0.46
# opencv-python                      4.2.0.32
# openpyxl                           3.0.3
# opt-einsum                         3.3.0
# overrides                          3.1.0
# packaging                          20.1
# pandas                             1.0.1
# pandocfilters                      1.4.2
# paramiko                           2.7.2
# parso                              0.5.2
# partd                              1.1.0
# path                               13.1.0
# pathlib2                           2.3.5
# pathtools                          0.1.2
# patsy                              0.5.1
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             7.2.0
# pip                                20.2.4
# pkginfo                            1.5.0.1
# plac                               1.1.3
# plotly                             4.11.0
# pluggy                             0.13.1
# ply                                3.11
# preshed                            3.0.4
# prometheus-client                  0.7.1
# promise                            2.3
# prompt-toolkit                     3.0.3
# protobuf                           3.11.4
# protobuf3-to-dict                  0.1.5
# psutil                             5.6.7
# psycopg2                           2.7.5
# psycopg2-binary                    2.8.6
# PTable                             0.9.2
# ptyprocess                         0.6.0
# py                                 1.8.1
# py-rouge                           1.1
# py4j                               0.10.7
# pyarrow                            1.0.1
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.8
# PyAthena                           1.10.7
# pycodestyle                        2.5.0
# pycosat                            0.6.3
# pycparser                          2.19
# pycrypto                           2.6.1
# pycurl                             7.43.0.5
# pydocstyle                         4.0.1
# pyflakes                           2.1.1
# pygal                              2.4.0
# Pygments                           2.5.2
# pykerberos                         1.2.1
# pylint                             2.5.3
# PyMySQL                            0.10.1
# PyNaCl                             1.4.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          19.1.0
# pyparsing                          2.4.6
# pyrsistent                         0.15.7
# PySocks                            1.7.1
# pyspark                            2.3.4
# pytest                             5.3.5
# pytest-arraydiff                   0.3
# pytest-astropy                     0.8.0
# pytest-astropy-header              0.1.2
# pytest-doctestplus                 0.5.0
# pytest-openfiles                   0.4.0
# pytest-remotedata                  0.3.2
# python-dateutil                    2.8.1
# python-dotenv                      0.14.0
# python-jsonrpc-server              0.3.4
# python-language-server             0.31.7
# pytz                               2019.3
# PyWavelets                         1.1.1
# pyxdg                              0.26
# PyYAML                             5.3.1
# pyzmq                              18.1.1
# QDarkStyle                         2.8
# QtAwesome                          0.6.1
# qtconsole                          4.6.0
# QtPy                               1.9.0
# regex                              2020.10.28
# requests                           2.22.0
# requests-kerberos                  0.12.0
# requests-oauthlib                  1.3.0
# responses                          0.12.0
# retrying                           1.3.3
# rope                               0.16.0
# rsa                                4.5
# Rtree                              0.9.3
# ruamel-yaml                        0.15.87
# s3fs                               0.4.2
# s3transfer                         0.3.3
# sacremoses                         0.0.43
# sagemaker                          2.9.2
# sagemaker-experiments              0.1.24
# sagemaker-pyspark                  1.4.1
# sagemaker-tensorflow               2.3.0.1.0.0
# scikit-image                       0.16.2
# scikit-learn                       0.23.1
# scipy                              1.4.1
# seaborn                            0.10.0
# SecretStorage                      3.1.2
# semantic-version                   2.8.5
# Send2Trash                         1.5.0
# sentencepiece                      0.1.94
# setuptools                         45.2.0.post20200210
# simplegeneric                      0.8.1
# singledispatch                     3.4.0.3
# six                                1.14.0
# smdebug                            0.9.3
# smdebug-rulesconfig                0.1.5
# snowballstemmer                    2.0.0
# sortedcollections                  1.1.2
# sortedcontainers                   2.1.0
# soupsieve                          1.9.5
# spacy                              2.2.4
# sparkmagic                         0.15.0
# Sphinx                             3.0.4
# sphinxcontrib-applehelp            1.0.1
# sphinxcontrib-devhelp              1.0.1
# sphinxcontrib-htmlhelp             1.0.2
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.2
# sphinxcontrib-serializinghtml      1.1.3
# sphinxcontrib-websupport           1.2.0
# spyder                             4.0.1
# spyder-kernels                     1.8.1
# SQLAlchemy                         1.3.13
# sqlalchemy-redshift                0.8.1
# srsly                              1.0.3
# statsmodels                        0.11.0
# stepfunctions                      2.0.0rc1
# sympy                              1.5.1
# tables                             3.6.1
# tblib                              1.6.0
# tenacity                           6.2.0
# tensorboard                        2.3.0
# tensorboard-plugin-wit             1.7.0
# tensorboardX                       2.1
# tensorflow                         2.3.0
# tensorflow-datasets                4.0.0
# tensorflow-estimator               2.3.0
# tensorflow-metadata                0.24.0
# tensorflow-recommenders            0.2.0
# termcolor                          1.1.0
# terminado                          0.8.3
# testpath                           0.4.4
# texttable                          1.6.3
# thinc                              7.4.0
# threadpoolctl                      2.1.0
# tokenizers                         0.9.2
# toml                               0.10.1
# toolz                              0.10.0
# torch                              1.6.0
# torch-model-archiver               0.1.1
# torchserve                         0.1.1
# tornado                            6.0.3
# tqdm                               4.42.1
# traitlets                          4.3.3
# transformers                       3.4.0
# typed-ast                          1.4.1
# typing-extensions                  3.7.4.3
# ujson                              1.35
# unicodecsv                         0.14.1
# urllib3                            1.25.10
# wasabi                             0.8.0
# watchdog                           0.10.2
# wcwidth                            0.1.8
# webencodings                       0.5.1
# websocket-client                   0.57.0
# Werkzeug                           1.0.0
# wheel                              0.34.2
# widgetsnbextension                 3.5.1
# word2number                        1.1
# wrapt                              1.12.1
# wurlitzer                          2.0.0
# xlrd                               1.2.0
# XlsxWriter                         1.2.7
# xlwt                               1.3.0
# yapf                               0.28.0
# zict                               1.0.0
# zipp                               2.2.0

# %%
from allennlp.predictors.predictor import Predictor

predictor = Predictor.from_path("https://storage.googleapis.com/allennlp-public-models/sst-roberta-large-2020.06.08.tar.gz")

# %%
print(predictor)
# Out:
# <allennlp.predictors.text_classifier.TextClassifierPredictor object at 0x7fb8b4462400>

# %%
from pprint import pprint

sentence = "a very well-made, funny and entertaining picture."

response = predictor.predict(
    sentence=sentence
)

pprint(response)
# Out:
# {'label': '1',
#  'logits': [4.985845565795898, -3.7536513805389404],
#  'probs': [0.9998399019241333, 0.0001601087424205616],
#  'token_ids': [0,
#                102,
#                5525,
#                3056,
#                12,
#                7078,
#                6,
#                18317,
#                2855,
#                463,
#                1342,
#                2399,
#                8173,
#                37587,
#                4,
#                2],
#  'tokens': ['<s>',
#             'a',
#             'very',
#             'well',
#             '-',
#             'made',
#             ',',
#             'fun',
#             'ny',
#             'and',
#             'ent',
#             'ert',
#             'aining',
#             'picture',
#             '.',
#             '</s>']}

# %% [markdown]
# # Interpret

# %%
inputs = {"sentence": sentence}
print(inputs)
# Out:
# {'sentence': 'a very well-made, funny and entertaining picture.'}

# %% [markdown]
# # Simple Gradient

# %%
from allennlp.interpret.saliency_interpreters import SimpleGradient

simple_gradient_interpreter = SimpleGradient(predictor)

# %%
from pprint import pprint

simple_gradient_interpretation = simple_gradient_interpreter.saliency_interpret_from_json(inputs)

pprint(simple_gradient_interpretation)
# Out:
# {'instance_1': {'grad_input_1': [0.279369560845839,
#                                  0.0600904935186349,
#                                  0.15987346870624614,
#                                  0.1570943687784923,
#                                  0.08467084570121039,
#                                  0.10174642009873701,
#                                  0.006892518284195784,
#                                  0.014679348240742502,
#                                  0.041306962003984725,
#                                  0.07055409182832174,
#                                  0.023721910808594447]}}

# %% [markdown]
# # Smooth Gradient

# %%
from allennlp.interpret.saliency_interpreters import SmoothGradient

smooth_gradient_interpreter = SmoothGradient(predictor)

# %%
from pprint import pprint

smooth_gradient_interpretation = smooth_gradient_interpreter.saliency_interpret_from_json(inputs)

pprint(smooth_gradient_interpretation)
# Out:
# {'instance_1': {'grad_input_1': [0.12429378531073447,
#                                  0.2711864406779661,
#                                  0.04519774011299435,
#                                  0.02824858757062147,
#                                  0.22598870056497175,
#                                  0.0,
#                                  0.1807909604519774,
#                                  0.011299435028248588,
#                                  0.022598870056497175,
#                                  0.0,
#                                  0.0903954802259887]}}

# %% [markdown]
# # Integrated Gradient

# %%
from allennlp.interpret.saliency_interpreters import IntegratedGradient

integrated_gradient_interpreter = IntegratedGradient(predictor)

# %%
from pprint import pprint

integrated_gradient_interpretation = integrated_gradient_interpreter.saliency_interpret_from_json(inputs)

pprint(integrated_gradient_interpretation)
# Out:
# {'instance_1': {'grad_input_1': [0.10338538634781776,
#                                  0.19893729477254535,
#                                  0.008472852427212439,
#                                  0.0005615125409780962,
#                                  0.01615882936970941,
#                                  0.19841675479930443,
#                                  0.06983715792756516,
#                                  0.02557800239689324,
#                                  0.06044705677145928,
#                                  0.16507210055696683,
#                                  0.1531329783765724]}}
