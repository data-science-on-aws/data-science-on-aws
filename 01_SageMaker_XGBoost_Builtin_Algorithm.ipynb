# %%
import time
import uuid
import boto3
import sagemaker

sess = sagemaker.Session()
region = boto3.Session().region_name
bucket = sess.default_bucket()
role = sagemaker.get_execution_role()

# %%
model_training_s3_uri = 's3://dsoaws/nyc-taxi-orig-cleaned-dropped-parquet-per-year-multiple-files/'

# %% [markdown]
# ### Configure the algorithm and training job
#
# The Training Job hyperparameters are set. For more information on XGBoost Hyperparameters,
# see https://xgboost.readthedocs.io/en/latest/parameter.html.

# %%
container = sagemaker.image_uris.retrieve("xgboost", region, "1.5-1")

output_content_type = "parquet"

train_content_type = (
    "application/x-parquet" if output_content_type.upper() == "PARQUET"
    else "text/csv"
)
train_input = sagemaker.inputs.TrainingInput(
    s3_data=model_training_s3_uri,
    content_type=train_content_type,
    distribution='ShardedByS3Key',
    input_mode='FastFile'
)

hyperparameters = {
    "eta": "0.2",
    "gamma": "4",
    "max_depth": "5",
    "min_child_weight": "6",
    "num_round": "50",
    "objective": "reg:squarederror",
    "subsample": "0.7"
}

# %% [markdown]
# ### Start the Training Job
#
# The TrainingJob configurations are set using the SageMaker Python SDK Estimator, and which is fit using
# the training data from the Processing Job that was run earlier.

# %%
estimator = sagemaker.estimator.Estimator(
    container,
    role,
    hyperparameters=hyperparameters,
    instance_count=6,
    instance_type="ml.m5.24xlarge",
    volume_size=200,
)

# %%
import time
import sagemaker

training_job_results = estimator.fit({"train": train_input})
print(training_job_results)
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2023-03-07-21-04-44-198
# 2023-03-07 21:04:44 Starting - Starting the training job...
# 2023-03-07 21:05:09 Starting - Preparing the instances for training.........
# 2023-03-07 21:06:43 Downloading - Downloading input data
# 2023-03-07 21:06:43 Training - Downloading the training image...
# 2023-03-07 21:06:53 Training - Training image download completed. Training in progress...[2023-03-07 21:07:27.527 ip-10-2-198-255.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-03-07 21:07:27.583 ip-10-2-198-255.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-03-07:21:07:27:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-03-07:21:07:27:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-03-07:21:07:27:INFO] No GPUs detected (normal if no gpus installed)
# [2023-03-07:21:07:27:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-03-07:21:07:27:INFO] Determined 0 GPU(s) available on the instance.
# [2023-03-07:21:07:27:INFO] files path: /opt/ml/input/data/train/year=2012
# [2023-03-07 21:07:27.035 ip-10-2-217-151.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-03-07 21:07:27.090 ip-10-2-217-151.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-03-07:21:07:27:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-03-07:21:07:27:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-03-07:21:07:27:INFO] No GPUs detected (normal if no gpus installed)
# [2023-03-07:21:07:27:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-03-07:21:07:27:INFO] Determined 0 GPU(s) available on the instance.
# [2023-03-07:21:07:27:INFO] files path: /opt/ml/input/data/train/year=2012
# [2023-03-07 21:07:27.677 ip-10-2-250-227.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-03-07 21:07:27.733 ip-10-2-250-227.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-03-07:21:07:28:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-03-07:21:07:28:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-03-07:21:07:28:INFO] No GPUs detected (normal if no gpus installed)
# [2023-03-07:21:07:28:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-03-07:21:07:28:INFO] Determined 0 GPU(s) available on the instance.
# [2023-03-07:21:07:28:INFO] files path: /opt/ml/input/data/train/year=2012
# [2023-03-07 21:07:28.058 ip-10-2-193-186.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-03-07 21:07:28.113 ip-10-2-193-186.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-03-07:21:07:28:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-03-07:21:07:28:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-03-07:21:07:28:INFO] No GPUs detected (normal if no gpus installed)
# [2023-03-07:21:07:28:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-03-07:21:07:28:INFO] Determined 0 GPU(s) available on the instance.
# [2023-03-07:21:07:28:INFO] files path: /opt/ml/input/data/train/year=2012
# [2023-03-07 21:07:28.207 ip-10-2-241-223.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-03-07 21:07:28.266 ip-10-2-241-223.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-03-07:21:07:28:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-03-07:21:07:28:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-03-07:21:07:28:INFO] No GPUs detected (normal if no gpus installed)
# [2023-03-07:21:07:28:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-03-07:21:07:28:INFO] Determined 0 GPU(s) available on the instance.
# [2023-03-07:21:07:28:INFO] files path: /opt/ml/input/data/train/year=2012
# [2023-03-07 21:07:27.640 ip-10-2-215-13.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-03-07 21:07:27.697 ip-10-2-215-13.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-03-07:21:07:27:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-03-07:21:07:27:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-03-07:21:07:27:INFO] No GPUs detected (normal if no gpus installed)
# [2023-03-07:21:07:27:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-03-07:21:07:27:INFO] Determined 0 GPU(s) available on the instance.
# [2023-03-07:21:07:27:INFO] files path: /opt/ml/input/data/train/year=2012
# [2023-03-07:21:07:32:INFO] Distributed node training with 6 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6']
# [2023-03-07:21:07:32:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-07:21:07:32:INFO] Sleeping for 3 sec before retrying
# [2023-03-07:21:07:32:INFO] Distributed node training with 6 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6']
# [2023-03-07:21:07:32:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-07:21:07:32:INFO] Sleeping for 3 sec before retrying
# [2023-03-07:21:07:32:INFO] Distributed node training with 6 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6']
# [2023-03-07:21:07:32:INFO] start listen on algo-1:9099
# [2023-03-07:21:07:32:INFO] Rabit slave environment: {'DMLC_TRACKER_URI': 'algo-1', 'DMLC_TRACKER_PORT': 9099}
# [2023-03-07:21:07:32:INFO] Connected to RabitTracker.
# [2023-03-07:21:07:32:INFO] No data received from connection ('10.2.217.151', 51468). Closing.
# [2023-03-07:21:07:33:INFO] No data received from connection ('10.2.241.223', 52674). Closing.
# [2023-03-07:21:07:33:INFO] No data received from connection ('10.2.193.186', 59506). Closing.
# [2023-03-07:21:07:33:INFO] No data received from connection ('10.2.250.227', 49818). Closing.
# [2023-03-07:21:07:33:INFO] Distributed node training with 6 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6']
# [2023-03-07:21:07:33:INFO] Connected to RabitTracker.
# [2023-03-07:21:07:33:INFO] Distributed node training with 6 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6']
# [2023-03-07:21:07:33:INFO] Connected to RabitTracker.
# [2023-03-07:21:07:33:INFO] Distributed node training with 6 hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6']
# [2023-03-07:21:07:33:INFO] Connected to RabitTracker.
# [2023-03-07:21:07:35:INFO] No data received from connection ('10.2.215.13', 33554). Closing.
# [2023-03-07:21:07:35:INFO] No data received from connection ('10.2.198.255', 40352). Closing.
# [2023-03-07:21:07:35:INFO] Connected to RabitTracker.
# [21:07:36] task NULL got new rank 2
# [2023-03-07:21:07:36:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-07:21:07:36:INFO] Sleeping for 3 sec before retrying
# [2023-03-07:21:07:35:INFO] Connected to RabitTracker.
# [21:07:35] task NULL got new rank 1
# [2023-03-07:21:07:36:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-07:21:07:36:INFO] Sleeping for 3 sec before retrying
# [2023-03-07:21:07:35:INFO] Recieve start signal from 10.2.193.186; assign rank 0
# [2023-03-07:21:07:35:INFO] Recieve start signal from 10.2.198.255; assign rank 1
# [2023-03-07:21:07:36:INFO] Recieve start signal from 10.2.215.13; assign rank 2
# [21:07:36] task NULL got new rank 3
# [2023-03-07:21:07:36:INFO] Recieve start signal from 10.2.217.151; assign rank 3
# [2023-03-07:21:07:36:INFO] Recieve start signal from 10.2.241.223; assign rank 4
# [2023-03-07:21:07:36:INFO] Recieve start signal from 10.2.250.227; assign rank 5
# [2023-03-07:21:07:36:INFO] @tracker All of 6 nodes getting started
# [2023-03-07:21:07:36:INFO] @tracker All nodes finishes job
# [2023-03-07:21:07:36:INFO] @tracker 0.08945512771606445 secs between node start and job finish
# [2023-03-07:21:07:36:INFO] start listen on algo-1:9100
# [2023-03-07:21:07:36:INFO] Rabit slave environment: {'DMLC_TRACKER_URI': 'algo-1', 'DMLC_TRACKER_PORT': 9100}
# [2023-03-07:21:07:36:INFO] Connected to RabitTracker.
# [2023-03-07:21:07:36:INFO] No data received from connection ('10.2.217.151', 42446). Closing.
# [21:07:36] task NULL got new rank 5
# [2023-03-07:21:07:36:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-07:21:07:36:INFO] Sleeping for 3 sec before retrying
# [21:07:35] task NULL got new rank 0
# [2023-03-07:21:07:36:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-07:21:07:36:INFO] Sleeping for 3 sec before retrying
# [21:07:36] task NULL got new rank 4
# [2023-03-07:21:07:36:INFO] Failed to connect to RabitTracker on attempt 0
# [2023-03-07:21:07:36:INFO] Sleeping for 3 sec before retrying
# [2023-03-07:21:07:39:INFO] Connected to RabitTracker.
# [2023-03-07:21:07:39:INFO] Connected to RabitTracker.
# [21:07:39] task NULL got new rank 1
# [2023-03-07:21:07:39:INFO] No data received from connection ('10.2.241.223', 34750). Closing.
# [2023-03-07:21:07:39:INFO] No data received from connection ('10.2.250.227', 38248). Closing.
# [2023-03-07:21:07:39:INFO] No data received from connection ('10.2.198.255', 46840). Closing.
# [2023-03-07:21:07:39:INFO] No data received from connection ('10.2.215.13', 52340). Closing.
# [2023-03-07:21:07:39:INFO] No data received from connection ('10.2.193.186', 36752). Closing.
# [2023-03-07:21:07:39:INFO] Recieve start signal from 10.2.193.186; assign rank 0
# [2023-03-07:21:07:39:INFO] Recieve start signal from 10.2.198.255; assign rank 1
# [2023-03-07:21:07:39:INFO] Recieve start signal from 10.2.215.13; assign rank 2
# [21:07:39] task NULL got new rank 3
# [2023-03-07:21:07:39:INFO] Connected to RabitTracker.
# [2023-03-07:21:07:39:INFO] Connected to RabitTracker.
# [21:07:39] task NULL got new rank 0
# [2023-03-07:21:07:39:INFO] Connected to RabitTracker.
# [21:07:39] task NULL got new rank 4
# [2023-03-07:21:07:40:INFO] Train matrix has 27527251 rows and 10 columns
# [2023-03-07 21:07:40.010 ip-10-2-241-223.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-03-07 21:07:40.010 ip-10-2-241-223.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-03-07 21:07:40.011 ip-10-2-241-223.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-03-07 21:07:40.011 ip-10-2-241-223.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-03-07:21:07:40:INFO] Debug hook created from config
# [21:07:39] task NULL got new rank 2
# [2023-03-07:21:07:39:INFO] Train matrix has 30906432 rows and 10 columns
# [2023-03-07 21:07:39.834 ip-10-2-215-13.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-03-07 21:07:39.835 ip-10-2-215-13.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-03-07 21:07:39.836 ip-10-2-215-13.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-03-07 21:07:39.836 ip-10-2-215-13.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-03-07:21:07:39:INFO] Debug hook created from config
# [2023-03-07:21:07:39:INFO] Train matrix has 30924780 rows and 10 columns
# [2023-03-07 21:07:39.834 ip-10-2-198-255.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-03-07 21:07:39.835 ip-10-2-198-255.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-03-07 21:07:39.836 ip-10-2-198-255.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-03-07 21:07:39.836 ip-10-2-198-255.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-03-07:21:07:39:INFO] Debug hook created from config
# [2023-03-07:21:07:39:INFO] Recieve start signal from 10.2.217.151; assign rank 3
# [2023-03-07:21:07:39:INFO] Recieve start signal from 10.2.241.223; assign rank 4
# [2023-03-07:21:07:39:INFO] Train matrix has 30814280 rows and 10 columns
# [2023-03-07 21:07:39.922 ip-10-2-217-151.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-03-07 21:07:39.922 ip-10-2-217-151.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-03-07 21:07:39.923 ip-10-2-217-151.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-03-07 21:07:39.923 ip-10-2-217-151.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-03-07:21:07:39:INFO] Debug hook created from config
# [2023-03-07:21:07:40:INFO] Recieve start signal from 10.2.250.227; assign rank 5
# [2023-03-07:21:07:40:INFO] @tracker All of 6 nodes getting started
# [21:07:39] task NULL got new rank 5
# [2023-03-07:21:07:40:INFO] Train matrix has 30712581 rows and 10 columns
# [2023-03-07 21:07:40.010 ip-10-2-250-227.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-03-07 21:07:40.010 ip-10-2-250-227.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-03-07 21:07:40.011 ip-10-2-250-227.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-03-07 21:07:40.011 ip-10-2-250-227.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-03-07:21:07:40:INFO] Debug hook created from config
# [2023-03-07:21:07:40:INFO] Train matrix has 27643581 rows and 10 columns
# [2023-03-07 21:07:40.009 ip-10-2-193-186.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-03-07 21:07:40.010 ip-10-2-193-186.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-03-07 21:07:40.011 ip-10-2-193-186.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-03-07 21:07:40.011 ip-10-2-193-186.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-03-07:21:07:40:INFO] Debug hook created from config
# [2023-03-07 21:07:55.681 ip-10-2-193-186.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-03-07 21:07:55.679 ip-10-2-241-223.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-03-07 21:07:55.679 ip-10-2-217-151.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-03-07:21:07:55:INFO] [0]#011train-rmse:13.25386
# [2023-03-07 21:07:55.679 ip-10-2-250-227.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-03-07 21:07:55.679 ip-10-2-215-13.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-03-07 21:07:55.679 ip-10-2-198-255.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-03-07:21:08:07:INFO] [1]#011train-rmse:10.69262
# [2023-03-07:21:08:19:INFO] [2]#011train-rmse:8.65917
# [2023-03-07:21:08:32:INFO] [3]#011train-rmse:7.04562
# [2023-03-07:21:08:44:INFO] [4]#011train-rmse:5.78051
# [2023-03-07:21:08:56:INFO] [5]#011train-rmse:4.79099
# [2023-03-07:21:09:08:INFO] [6]#011train-rmse:4.02530
# [2023-03-07:21:09:20:INFO] [7]#011train-rmse:3.43791
# [2023-03-07:21:09:32:INFO] [8]#011train-rmse:3.00127
# [2023-03-07:21:09:44:INFO] [9]#011train-rmse:2.68063
# [2023-03-07:21:09:57:INFO] [10]#011train-rmse:2.45046
# [2023-03-07:21:10:09:INFO] [11]#011train-rmse:2.28455
# [2023-03-07:21:10:21:INFO] [12]#011train-rmse:2.16912
# [2023-03-07:21:10:33:INFO] [13]#011train-rmse:2.09001
# [2023-03-07:21:10:46:INFO] [14]#011train-rmse:2.03538
# [2023-03-07:21:10:58:INFO] [15]#011train-rmse:1.99865
# [2023-03-07:21:11:10:INFO] [16]#011train-rmse:1.97223
# [2023-03-07:21:11:22:INFO] [17]#011train-rmse:1.95471
# [2023-03-07:21:11:34:INFO] [18]#011train-rmse:1.94122
# [2023-03-07:21:11:47:INFO] [19]#011train-rmse:1.93250
# [2023-03-07:21:11:59:INFO] [20]#011train-rmse:1.92580
# [2023-03-07:21:12:11:INFO] [21]#011train-rmse:1.92025
# [2023-03-07:21:12:24:INFO] [22]#011train-rmse:1.91664
# [2023-03-07:21:12:36:INFO] [23]#011train-rmse:1.91443
# [2023-03-07:21:12:48:INFO] [24]#011train-rmse:1.91258
# [2023-03-07:21:13:00:INFO] [25]#011train-rmse:1.91082
# [2023-03-07:21:13:13:INFO] [26]#011train-rmse:1.90991
# [2023-03-07:21:13:25:INFO] [27]#011train-rmse:1.90789
# [2023-03-07:21:13:37:INFO] [28]#011train-rmse:1.90671
# [2023-03-07:21:13:49:INFO] [29]#011train-rmse:1.90632
# [2023-03-07:21:14:02:INFO] [30]#011train-rmse:1.90356
# [2023-03-07:21:14:14:INFO] [31]#011train-rmse:1.90288
# [2023-03-07:21:14:27:INFO] [32]#011train-rmse:1.90116
# [2023-03-07:21:14:39:INFO] [33]#011train-rmse:1.90091
# [2023-03-07:21:14:51:INFO] [34]#011train-rmse:1.89879
# [2023-03-07:21:15:03:INFO] [35]#011train-rmse:1.89782
# [2023-03-07:21:15:16:INFO] [36]#011train-rmse:1.89773
