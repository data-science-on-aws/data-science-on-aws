# %%
import ray
import raydp

ray.shutdown()
ray.init(address="127.0.0.1:6379")

configs={
    "spark.driver.extraJavaOptions": "--add-opens=java.base/sun.nio.ch=ALL-UNNAMED --add-opens=java.base/java.lang=ALL-UNNAMED --add-opens=java.base/java.util=ALL-UNNAMED"
}

raydp.stop_spark()
spark = raydp.init_spark(
  app_name = "example",
  num_executors = 1,
  executor_cores = 1,
  executor_memory = "1GB",
  configs = configs
)

df_from_csv = spark.read.option('delimiter', ',') \
                        .option('header', True) \
                        .csv('./data/train/part-algo-1-womens_clothing_ecommerce_reviews.csv')

print(df_from_csv)

df_from_csv.groupBy("sentiment").count().show()
# Out:
# Picked up JAVA_TOOL_OPTIONS: -Dlog4j2.formatMsgNoLookups=true
# WARNING: sun.reflect.Reflection.getCallerClass is not supported. This will impact performance.
# 2022-05-21 17:34:46,835 Thread-1 INFO Log4j appears to be running in a Servlet environment, but there's no log4j-web module available. If you want better web container support, please add the log4j-web JAR to your web archive or server lib directory.
# 2022-05-21 17:34:46,849 Thread-1 INFO Log4j appears to be running in a Servlet environment, but there's no log4j-web module available. If you want better web container support, please add the log4j-web JAR to your web archive or server lib directory.
# 2022-05-21 17:34:47,722 WARN NativeCodeLoader [Thread-1]: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2022-05-21 17:34:47,791 INFO SecurityManager [Thread-1]: Changing view acls to: cfregly
# 2022-05-21 17:34:47,791 INFO SecurityManager [Thread-1]: Changing modify acls to: cfregly
# 2022-05-21 17:34:47,792 INFO SecurityManager [Thread-1]: Changing view acls groups to:
# 2022-05-21 17:34:47,792 INFO SecurityManager [Thread-1]: Changing modify acls groups to:
# 2022-05-21 17:34:47,792 INFO SecurityManager [Thread-1]: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(cfregly); groups with view permissions: Set(); users  with modify permissions: Set(cfregly); groups with modify permissions: Set()
# 2022-05-21 17:34:48,019 INFO Utils [Thread-1]: Successfully started service 'RAY_RPC_ENV' on port 64114.
# Picked up JAVA_TOOL_OPTIONS: -Dlog4j2.formatMsgNoLookups=true
# Picked up JAVA_TOOL_OPTIONS: -Dlog4j2.formatMsgNoLookups=true
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/Users/cfregly/miniconda3/lib/python3.9/site-packages/ray/jars/ray_dist.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/slf4j-log4j12-1.7.30.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# WARNING: sun.reflect.Reflection.getCallerClass is not supported. This will impact performance.
# 2022-05-21 17:34:49,159 WARN NativeCodeLoader [main]: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# log4j:WARN No appenders could be found for logger (org.apache.htrace.core.Tracer).
# log4j:WARN Please initialize the log4j system properly.
# log4j:WARN See http://logging.apache.org/log4j/1.2/faq.html#noconfig for more info.
# 2022-05-21 17:34:49,448 INFO SparkContext [Thread-3]: Running Spark version 3.2.1
# 2022-05-21 17:34:49,470 INFO ResourceUtils [Thread-3]: ==============================================================
# 2022-05-21 17:34:49,470 INFO ResourceUtils [Thread-3]: No custom resources configured for spark.driver.
# 2022-05-21 17:34:49,471 INFO ResourceUtils [Thread-3]: ==============================================================
# 2022-05-21 17:34:49,471 INFO SparkContext [Thread-3]: Submitted application: example
# 2022-05-21 17:34:49,489 INFO ResourceProfile [Thread-3]: Default ResourceProfile created, executor resources: Map(cores -> name: cores, amount: 1, script: , vendor: , memory -> name: memory, amount: 1073741824, script: , vendor: , offHeap -> name: offHeap, amount: 0, script: , vendor: ), task resources: Map(cpus -> name: cpus, amount: 1.0)
# 2022-05-21 17:34:49,496 INFO ResourceProfile [Thread-3]: Limiting resource is cpus at 1 tasks per executor
# 2022-05-21 17:34:49,497 INFO ResourceProfileManager [Thread-3]: Added ResourceProfile id: 0
# 2022-05-21 17:34:49,536 INFO SecurityManager [Thread-3]: Changing view acls to: cfregly
# 2022-05-21 17:34:49,536 INFO SecurityManager [Thread-3]: Changing modify acls to: cfregly
# 2022-05-21 17:34:49,537 INFO SecurityManager [Thread-3]: Changing view acls groups to:
# 2022-05-21 17:34:49,537 INFO SecurityManager [Thread-3]: Changing modify acls groups to:
# 2022-05-21 17:34:49,537 INFO SecurityManager [Thread-3]: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(cfregly); groups with view permissions: Set(); users  with modify permissions: Set(cfregly); groups with modify permissions: Set()
# 2022-05-21 17:34:49,694 INFO Utils [Thread-3]: Successfully started service 'sparkDriver' on port 64122.
# 2022-05-21 17:34:49,717 INFO SparkEnv [Thread-3]: Registering MapOutputTracker
# 2022-05-21 17:34:49,740 INFO SparkEnv [Thread-3]: Registering BlockManagerMaster
# 2022-05-21 17:34:49,757 INFO BlockManagerMasterEndpoint [Thread-3]: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 2022-05-21 17:34:49,757 INFO BlockManagerMasterEndpoint [Thread-3]: BlockManagerMasterEndpoint up
# 2022-05-21 17:34:49,760 INFO SparkEnv [Thread-3]: Registering BlockManagerMasterHeartbeat
# 2022-05-21 17:34:49,776 INFO DiskBlockManager [Thread-3]: Created local directory at /private/var/folders/50/1dlms49d3013ybsdl_k9nph0m05pfl/T/blockmgr-bb6bf7af-7a9c-4465-a177-42bb7203ad48
# 2022-05-21 17:34:49,790 INFO MemoryStore [Thread-3]: MemoryStore started with capacity 434.4 MiB
# 2022-05-21 17:34:49,804 INFO SparkEnv [Thread-3]: Registering OutputCommitCoordinator
# 2022-05-21 17:34:49,886 INFO log [Thread-3]: Logging initialized @1700ms to org.sparkproject.jetty.util.log.Slf4jLog
# 2022-05-21 17:34:49,944 INFO Server [Thread-3]: jetty-9.4.43.v20210629; built: 2021-06-30T11:07:22.254Z; git: 526006ecfa3af7f1a27ef3a288e2bef7ea9dd7e8; jvm 16+36-2231
# 2022-05-21 17:34:49,966 INFO Server [Thread-3]: Started @1785ms
# 2022-05-21 17:34:49,994 INFO AbstractConnector [Thread-3]: Started ServerConnector@136a9e19{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# 2022-05-21 17:34:49,995 INFO Utils [Thread-3]: Successfully started service 'SparkUI' on port 4040.
# 2022-05-21 17:34:50,009 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@2aec6530{/jobs,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,010 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@406bed70{/jobs/json,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,011 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@27cd1e49{/jobs/job,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,012 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@34a8f288{/jobs/job/json,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,012 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@50d58fff{/stages,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,013 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@1c5a9da5{/stages/json,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,013 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@5ece06fc{/stages/stage,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,014 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@2b041a31{/stages/stage/json,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,015 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@3d08cae1{/stages/pool,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,015 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@438d4cfa{/stages/pool/json,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,016 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@72453b69{/storage,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,017 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@b970c44{/storage/json,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,017 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@548cac34{/storage/rdd,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,018 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@666c7c3e{/storage/rdd/json,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,018 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@12baa298{/environment,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,019 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@17674174{/environment/json,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,019 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@41c770dc{/executors,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,020 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@49511ca{/executors/json,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,020 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@d942326{/executors/threadDump,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,021 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@2c3146db{/executors/threadDump/json,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,027 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@853967d{/static,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,028 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@6d6d8de0{/,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,029 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@628ffb8e{/api,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,029 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@5a01d2fd{/jobs/job/kill,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,030 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@1e919d96{/stages/stage/kill,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,031 INFO SparkUI [Thread-3]: Bound SparkUI to 0.0.0.0, and started at http://127.0.0.1:4040
# 2022-05-21 17:34:50,040 INFO SparkContext [Thread-3]: Added JAR /Users/cfregly/miniconda3/lib/python3.9/site-packages/raydp/jars/raydp-0.4.2.jar at spark://127.0.0.1:64122/jars/raydp-0.4.2.jar with timestamp 1653168889442
# 2022-05-21 17:34:50,121 INFO RayCoarseGrainedSchedulerBackend$AppMasterClient [dispatcher-event-loop-7]: Registering to app master ray://RAY_APP_MASTER@127.0.0.1:64114...
# 2022-05-21 17:34:50,152 INFO TransportClientFactory [netty-rpc-connection-0]: Successfully created connection to /127.0.0.1:64114 after 20 ms (0 ms spent in bootstraps)
# 2022-05-21 17:34:50,275 INFO RayAppMaster$RayAppMasterEndpoint [dispatcher-event-loop-7]: Registering app example
# 2022-05-21 17:34:50,277 INFO RayAppMaster$RayAppMasterEndpoint [dispatcher-event-loop-7]: Registered app example with ID app-20220521173450-0000
# 2022-05-21 17:34:50,287 INFO Utils [Thread-3]: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 64128.
# 2022-05-21 17:34:50,287 INFO NettyBlockTransferService [Thread-3]: Server created on 127.0.0.1:64128
# 2022-05-21 17:34:50,289 INFO BlockManager [Thread-3]: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 2022-05-21 17:34:50,293 INFO BlockManagerMaster [Thread-3]: Registering BlockManager BlockManagerId(driver, 127.0.0.1, 64128, None)
# 2022-05-21 17:34:50,295 INFO BlockManagerMasterEndpoint [dispatcher-BlockManagerMaster]: Registering block manager 127.0.0.1:64128 with 434.4 MiB RAM, BlockManagerId(driver, 127.0.0.1, 64128, None)
# 2022-05-21 17:34:50,297 INFO BlockManagerMaster [Thread-3]: Registered BlockManager BlockManagerId(driver, 127.0.0.1, 64128, None)
# 2022-05-21 17:34:50,298 INFO BlockManager [Thread-3]: Initialized BlockManager: BlockManagerId(driver, 127.0.0.1, 64128, None)
# 2022-05-21 17:34:50,384 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@5cd63b1b{/metrics/json,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,399 INFO RayCoarseGrainedSchedulerBackend [Thread-3]: SchedulerBackend is ready for scheduling beginning after reached minRegisteredResourcesRatio: 0.0
# 2022-05-21 17:34:50,542 INFO SharedState [Thread-3]: Setting hive.metastore.warehouse.dir ('null') to the value of spark.sql.warehouse.dir.
# 2022-05-21 17:34:50,544 INFO SharedState [Thread-3]: Warehouse path is 'file:/Users/cfregly/oreilly_book.main/wip/ray/datasets/spark-warehouse'.
# 2022-05-21 17:34:50,555 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@7faa284d{/SQL,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,555 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@143ef046{/SQL/json,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,556 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@1b75013b{/SQL/execution,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,557 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@2a39e998{/SQL/execution/json,null,AVAILABLE,@Spark}
# 2022-05-21 17:34:50,558 INFO ContextHandler [Thread-3]: Started o.s.j.s.ServletContextHandler@539625d8{/static/sql,null,AVAILABLE,@Spark}
# (raylet) 2022-05-21 17:34:50,860	INFO context.py:70 -- Exec'ing worker with command: java -cp /Users/cfregly/miniconda3/lib/python3.9/site-packages/ray/jars/*: -Dray.address=127.0.0.1:6379 -Dray.raylet.node-manager-port=57983 -Dray.object-store.socket-name=/tmp/ray/session_2022-05-21_17-16-02_694694_24517/sockets/plasma_store -Dray.raylet.socket-name=/tmp/ray/session_2022-05-21_17-16-02_694694_24517/sockets/raylet -Dray.redis.password=5241590000000000 -Dray.node-ip=127.0.0.1 -Dray.home=/Users/cfregly/miniconda3/lib/python3.9/site-packages/ray/../.. -Dray.logging.dir=/tmp/ray/session_2022-05-21_17-16-02_694694_24517/logs -Dray.session-dir=/tmp/ray/session_2022-05-21_17-16-02_694694_24517 -Dray.job.code-search-path=/Users/cfregly/miniconda3/lib/python3.9/site-packages/raydp/jars/raydp-0.4.2.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/ray/jars/ray_dist.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/dropwizard-metrics-hadoop-metrics2-reporter-0.1.2.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/logging-interceptor-3.12.12.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/hive-shims-2.3.9.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/spark-launcher_2.12-3.2.1.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/jakarta.xml.bind-api-2.3.2.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/kubernetes-model-policy-5.4.1.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/blas-2.2.1.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/commons-io-2.8.0.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/spark-repl_2.12-3.2.1.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/jaxb-runtime-2.3.2.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/aircompressor-0.21.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/minlog-1.3.0.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/kubernetes-client-5.4.1.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/hive-exec-2.3.9-core.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/javolution-5.5.1.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/spark-tags_2.12-3.2.1-tests.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/jersey-common-2.34.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/jta-1.1.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/metrics-jvm-4.2.0.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/threeten-extra-1.5.0.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/JTransforms-3.1.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/snappy-java-1.1.8.4.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/httpcore-4.4.14.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/datanucleus-api-jdo-4.2.4.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/joda-time-2.10.10.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/kubernetes-model-apiextensions-5.4.1.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/arrow-vector-2.0.0.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/orc-core-1.6.12.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/spark-core_2.12-3.2.1.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/javax.jdo-3.2.0-m3.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/htrace-core4-4.1.0-incubating.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/json4s-ast_2.12-3.7.0-M11.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/spark-network-common_2.12-3.2.1.jar:/Users/cfregly/miniconda3/lib/python3.9/site- ...
# 2022-05-21 17:34:51,132 INFO InMemoryFileIndex [Thread-3]: It took 36 ms to list leaf files for 1 paths.
# 2022-05-21 17:34:51,184 INFO InMemoryFileIndex [Thread-3]: It took 1 ms to list leaf files for 1 paths.
# (raylet) Picked up JAVA_TOOL_OPTIONS: -Dlog4j2.formatMsgNoLookups=true
# 2022-05-21 17:34:52,850 INFO FileSourceStrategy [Thread-3]: Pushed Filters:
# 2022-05-21 17:34:52,851 INFO FileSourceStrategy [Thread-3]: Post-Scan Filters: (length(trim(value#0, None)) > 0)
# 2022-05-21 17:34:52,853 INFO FileSourceStrategy [Thread-3]: Output Data Schema: struct<value: string>
# 2022-05-21 17:34:53,253 INFO CodeGenerator [Thread-3]: Code generated in 147.300498 ms
# 2022-05-21 17:34:53,279 INFO MemoryStore [Thread-3]: Block broadcast_0 stored as values in memory (estimated size 712.0 B, free 434.4 MiB)
# 2022-05-21 17:34:53,561 INFO MemoryStore [Thread-3]: Block broadcast_0_piece0 stored as bytes in memory (estimated size 33.5 KiB, free 434.4 MiB)
# 2022-05-21 17:34:53,563 INFO BlockManagerInfo [dispatcher-BlockManagerMaster]: Added broadcast_0_piece0 in memory on 127.0.0.1:64128 (size: 33.5 KiB, free: 434.4 MiB)
# 2022-05-21 17:34:53,566 INFO SparkContext [Thread-3]: Created broadcast 0 from csv at NativeMethodAccessorImpl.java:0
# 2022-05-21 17:34:53,573 INFO FileSourceScanExec [Thread-3]: Planning scan with bin packing, max size: 4547128 bytes, open cost is considered as scanning 4194304 bytes.
# 2022-05-21 17:34:53,650 INFO SparkContext [Thread-3]: Starting job: csv at NativeMethodAccessorImpl.java:0
# 2022-05-21 17:34:53,663 INFO DAGScheduler [dag-scheduler-event-loop]: Got job 0 (csv at NativeMethodAccessorImpl.java:0) with 1 output partitions
# 2022-05-21 17:34:53,663 INFO DAGScheduler [dag-scheduler-event-loop]: Final stage: ResultStage 0 (csv at NativeMethodAccessorImpl.java:0)
# 2022-05-21 17:34:53,663 INFO DAGScheduler [dag-scheduler-event-loop]: Parents of final stage: List()
# 2022-05-21 17:34:53,664 INFO DAGScheduler [dag-scheduler-event-loop]: Missing parents: List()
# 2022-05-21 17:34:53,667 INFO DAGScheduler [dag-scheduler-event-loop]: Submitting ResultStage 0 (MapPartitionsRDD[3] at csv at NativeMethodAccessorImpl.java:0), which has no missing parents
# 2022-05-21 17:34:53,714 INFO MemoryStore [dag-scheduler-event-loop]: Block broadcast_1 stored as values in memory (estimated size 11.6 KiB, free 434.4 MiB)
# 2022-05-21 17:34:53,719 INFO MemoryStore [dag-scheduler-event-loop]: Block broadcast_1_piece0 stored as bytes in memory (estimated size 5.8 KiB, free 434.3 MiB)
# 2022-05-21 17:34:53,720 INFO BlockManagerInfo [dispatcher-BlockManagerMaster]: Added broadcast_1_piece0 in memory on 127.0.0.1:64128 (size: 5.8 KiB, free: 434.4 MiB)
# 2022-05-21 17:34:53,720 INFO SparkContext [dag-scheduler-event-loop]: Created broadcast 1 from broadcast at DAGScheduler.scala:1478
# 2022-05-21 17:34:53,733 INFO DAGScheduler [dag-scheduler-event-loop]: Submitting 1 missing tasks from ResultStage 0 (MapPartitionsRDD[3] at csv at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0))
# 2022-05-21 17:34:53,734 INFO TaskSchedulerImpl [dag-scheduler-event-loop]: Adding task set 0.0 with 1 tasks resource profile 0
# [Stage 0:>                                                          (0 + 0) / 1]
# 2022-05-21 17:35:08,749 WARN TaskSchedulerImpl [task-starvation-timer]: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 2022-05-21 17:35:23,749 WARN TaskSchedulerImpl [task-starvation-timer]: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 2022-05-21 17:35:38,749 WARN TaskSchedulerImpl [task-starvation-timer]: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/Users/cfregly/miniconda3/lib/python3.9/site-packages/py4j/clientserver.py", line 475, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
# RuntimeError: reentrant call inside <_io.BufferedReader name=125>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/cfregly/miniconda3/lib/python3.9/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/Users/cfregly/miniconda3/lib/python3.9/site-packages/py4j/clientserver.py", line 503, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/Users/cfregly/miniconda3/lib/python3.9/site-packages/py4j/clientserver.py", line 475, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/Users/cfregly/miniconda3/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/context.py", line 292, in signal_handler
#     self.cancelAllJobs()
#   File "/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/context.py", line 1195, in cancelAllJobs
#     self._jsc.sc().cancelAllJobs()
#   File "/Users/cfregly/miniconda3/lib/python3.9/site-packages/py4j/java_gateway.py", line 1321, in __call__
#     return_value = get_return_value(
#   File "/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/sql/utils.py", line 111, in deco
#     return f(*a, **kw)
#   File "/Users/cfregly/miniconda3/lib/python3.9/site-packages/py4j/protocol.py", line 334, in get_return_value
#     raise Py4JError(
# py4j.protocol.Py4JError: An error occurred while calling o30.sc
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/cfregly/miniconda3/lib/python3.9/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/Users/cfregly/miniconda3/lib/python3.9/site-packages/py4j/clientserver.py", line 503, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# ---------------------------------------------------------------------------
# Py4JError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 20>()
#      11 raydp.stop_spark()
#      12 spark = raydp.init_spark(
#      13   app_name = "example",
#      14   num_executors = 1,
#    (...)
#      17   configs = configs
#      18 )
# ---> 20 df_from_csv = spark.read.option('delimiter', ',') \
#      21                         .option('header', True) \
#      22                         .csv('./data/train/part-algo-1-womens_clothing_ecommerce_reviews.csv')
#      24 print(df_from_csv)
#      26 df_from_csv.groupBy("sentiment").count().show()
#
# File ~/miniconda3/lib/python3.9/site-packages/pyspark/sql/readwriter.py:410, in DataFrameReader.csv(self, path, schema, sep, encoding, quote, escape, comment, header, inferSchema, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace, nullValue, nanValue, positiveInf, negativeInf, dateFormat, timestampFormat, maxColumns, maxCharsPerColumn, maxMalformedLogPerPartition, mode, columnNameOfCorruptRecord, multiLine, charToEscapeQuoteEscaping, samplingRatio, enforceSchema, emptyValue, locale, lineSep, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter, unescapedQuoteHandling)
#     408     path = [path]
#     409 if type(path) == list:
# --> 410     return self._df(self._jreader.csv(self._spark._sc._jvm.PythonUtils.toSeq(path)))
#     411 elif isinstance(path, RDD):
#     412     def func(iterator):
#
# File ~/miniconda3/lib/python3.9/site-packages/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1315 command = proto.CALL_COMMAND_NAME +\
#    1316     self.command_header +\
#    1317     args_command +\
#    1318     proto.END_COMMAND_PART
#    1320 answer = self.gateway_client.send_command(command)
# -> 1321 return_value = get_return_value(
#    1322     answer, self.gateway_client, self.target_id, self.name)
#    1324 for temp_arg in temp_args:
#    1325     temp_arg._detach()
#
# File ~/miniconda3/lib/python3.9/site-packages/pyspark/sql/utils.py:111, in capture_sql_exception.<locals>.deco(*a, **kw)
#     109 def deco(*a, **kw):
#     110     try:
# --> 111         return f(*a, **kw)
#     112     except py4j.protocol.Py4JJavaError as e:
#     113         converted = convert_exception(e.java_exception)
#
# File ~/miniconda3/lib/python3.9/site-packages/py4j/protocol.py:334, in get_return_value(answer, gateway_client, target_id, name)
#     330             raise Py4JError(
#     331                 "An error occurred while calling {0}{1}{2}. Trace:\n{3}\n".
#     332                 format(target_id, ".", name, value))
#     333     else:
# --> 334         raise Py4JError(
#     335             "An error occurred while calling {0}{1}{2}".
#     336             format(target_id, ".", name))
#     337 else:
#     338     type = answer[1]
#
# Py4JError: An error occurred while calling o64.csv

# %%
raydp.stop_spark()
# Out:
# 2022-05-21 17:35:45,881 INFO AbstractConnector [Thread-20]: Stopped Spark@136a9e19{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# 2022-05-21 17:35:45,882 INFO SparkUI [Thread-20]: Stopped Spark web UI at http://127.0.0.1:4040
# 2022-05-21 17:35:45,884 INFO DAGScheduler [Thread-3]: Job 0 failed: csv at NativeMethodAccessorImpl.java:0, took 52.232614 s
# 2022-05-21 17:35:45,884 INFO DAGScheduler [Thread-20]: ResultStage 0 (csv at NativeMethodAccessorImpl.java:0) failed in 52.206 s due to Stage cancelled because SparkContext was shut down
# 2022-05-21 17:35:45,885 INFO RayCoarseGrainedSchedulerBackend [Thread-20]: Shutting down all executors
# 2022-05-21 17:35:45,886 INFO CoarseGrainedSchedulerBackend$DriverEndpoint [dispatcher-CoarseGrainedScheduler]: Asking each executor to shut down
# 2022-05-21 17:35:45,894 INFO MapOutputTrackerMasterEndpoint [dispatcher-event-loop-7]: MapOutputTrackerMasterEndpoint stopped!
# 2022-05-21 17:35:45,910 INFO MemoryStore [Thread-20]: MemoryStore cleared
# 2022-05-21 17:35:45,911 INFO BlockManager [Thread-20]: BlockManager stopped
# 2022-05-21 17:35:45,914 INFO BlockManagerMaster [Thread-20]: BlockManagerMaster stopped
# 2022-05-21 17:35:45,915 INFO OutputCommitCoordinator$OutputCommitCoordinatorEndpoint [dispatcher-event-loop-11]: OutputCommitCoordinator stopped!
# 2022-05-21 17:35:45,929 INFO SparkContext [Thread-20]: Successfully stopped SparkContext
# 2022-05-21 17:35:45,993 INFO RayAppMaster [Thread-1]: Stopping RayAppMaster
# (raylet) 2022-05-21 17:35:59,498	INFO context.py:70 -- Exec'ing worker with command: java -cp /Users/cfregly/miniconda3/lib/python3.9/site-packages/ray/jars/*: -Dray.address=127.0.0.1:6379 -Dray.raylet.node-manager-port=57983 -Dray.object-store.socket-name=/tmp/ray/session_2022-05-21_17-16-02_694694_24517/sockets/plasma_store -Dray.raylet.socket-name=/tmp/ray/session_2022-05-21_17-16-02_694694_24517/sockets/raylet -Dray.redis.password=5241590000000000 -Dray.node-ip=127.0.0.1 -Dray.home=/Users/cfregly/miniconda3/lib/python3.9/site-packages/ray/../.. -Dray.logging.dir=/tmp/ray/session_2022-05-21_17-16-02_694694_24517/logs -Dray.session-dir=/tmp/ray/session_2022-05-21_17-16-02_694694_24517 -Dray.job.code-search-path=/Users/cfregly/miniconda3/lib/python3.9/site-packages/raydp/jars/raydp-0.4.2.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/ray/jars/ray_dist.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/dropwizard-metrics-hadoop-metrics2-reporter-0.1.2.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/logging-interceptor-3.12.12.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/hive-shims-2.3.9.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/spark-launcher_2.12-3.2.1.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/jakarta.xml.bind-api-2.3.2.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/kubernetes-model-policy-5.4.1.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/blas-2.2.1.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/commons-io-2.8.0.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/spark-repl_2.12-3.2.1.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/jaxb-runtime-2.3.2.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/aircompressor-0.21.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/minlog-1.3.0.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/kubernetes-client-5.4.1.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/hive-exec-2.3.9-core.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/javolution-5.5.1.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/spark-tags_2.12-3.2.1-tests.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/jersey-common-2.34.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/jta-1.1.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/metrics-jvm-4.2.0.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/threeten-extra-1.5.0.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/JTransforms-3.1.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/snappy-java-1.1.8.4.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/httpcore-4.4.14.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/datanucleus-api-jdo-4.2.4.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/joda-time-2.10.10.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/kubernetes-model-apiextensions-5.4.1.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/arrow-vector-2.0.0.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/orc-core-1.6.12.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/spark-core_2.12-3.2.1.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/javax.jdo-3.2.0-m3.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/htrace-core4-4.1.0-incubating.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/json4s-ast_2.12-3.7.0-M11.jar:/Users/cfregly/miniconda3/lib/python3.9/site-packages/pyspark/jars/spark-network-common_2.12-3.2.1.jar:/Users/cfregly/miniconda3/lib/python3.9/site- ...
# (raylet) Picked up JAVA_TOOL_OPTIONS: -Dlog4j2.formatMsgNoLookups=true
