# %%
import time
import uuid
import boto3
import sagemaker

sess = sagemaker.Session()
region = boto3.Session().region_name
bucket = sess.default_bucket()
role = sagemaker.get_execution_role()

# %%
model_training_s3_uri = 's3://dsoaws/nyc-taxi-orig-cleaned-dropped-parquet-all-years-multiple-files-100GB/'

# %%
from sagemaker.session import Session
from sagemaker.inputs import TrainingInput
from sagemaker.xgboost.estimator import XGBoost


instance_type = "ml.m5.24xlarge"
output_content_type = "parquet"

train_content_type = (
    "application/x-parquet" if output_content_type.upper() == "PARQUET"
    else "text/csv"
)
train_input = sagemaker.inputs.TrainingInput(
    s3_data=model_training_s3_uri,
    content_type=train_content_type,
    distribution='ShardedByS3Key',
#    input_mode='FastFile'
)

# %%
hyperparameters = {
    "eta": "0.2",
    "gamma": "4",
    "max_depth": "5",
    "min_child_weight": "6",
    "num_round": "50",
    "objective": "reg:squarederror",
    "subsample": "0.7",
#    "verbosity": "2",
    "content_type":"parquet",
}

# %%
from sagemaker.pytorch import PyTorch

# PyTorch Image is used to enable distributed training
estimator = PyTorch(
    source_dir="code",
    entry_point="xgboost-ray-nyctaxi-parquet.py",
    role=role,
    instance_count=2, 
    instance_type="ml.m5.24xlarge",
    framework_version="1.13",
    hyperparameters=hyperparameters,
    py_version="py39",
    volume_size=1024,    
)
estimator.fit({"train": train_input})
# Out:
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: pytorch-training-2023-03-14-15-59-53-087
# 2023-03-14 15:59:53 Starting - Starting the training job...
# 2023-03-14 16:00:21 Starting - Preparing the instances for training......
# 2023-03-14 16:01:16 Downloading - Downloading input data........................
# 2023-03-14 16:05:18 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2023-03-14 16:05:19,296 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2023-03-14 16:05:19,298 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2023-03-14 16:05:19,300 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2023-03-14 16:05:19,309 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2023-03-14 16:05:19,311 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2023-03-14 16:05:19,531 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /opt/conda/bin/python3.9 -m pip install -r requirements.txt
# bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2023-03-14 16:05:19,334 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2023-03-14 16:05:19,335 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2023-03-14 16:05:19,337 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2023-03-14 16:05:19,347 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2023-03-14 16:05:19,349 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2023-03-14 16:05:19,559 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /opt/conda/bin/python3.9 -m pip install -r requirements.txt
# Collecting ray[default]
# Downloading ray-2.3.0-cp39-cp39-manylinux2014_x86_64.whl (58.6 MB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 MB 35.8 MB/s eta 0:00:00
# Collecting xgboost_ray
# Downloading xgboost_ray-0.1.15-py3-none-any.whl (138 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.1/138.1 kB 40.1 MB/s eta 0:00:00
# Collecting ray[default]
# Downloading ray-2.3.0-cp39-cp39-manylinux2014_x86_64.whl (58.6 MB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 MB 34.3 MB/s eta 0:00:00
# Collecting xgboost_ray
# Downloading xgboost_ray-0.1.15-py3-none-any.whl (138 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.1/138.1 kB 34.9 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.9/site-packages (from ray[default]->-r requirements.txt (line 1)) (8.1.2)
# Collecting frozenlist
# Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 37.1 MB/s eta 0:00:00
# Collecting filelock
# Downloading filelock-3.9.1-py3-none-any.whl (9.7 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (from ray[default]->-r requirements.txt (line 1)) (2.28.2)
# Collecting aiosignal
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting virtualenv>=20.0.24
# Downloading virtualenv-20.21.0-py3-none-any.whl (8.7 MB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 123.8 MB/s eta 0:00:00
# Requirement already satisfied: attrs in /opt/conda/lib/python3.9/site-packages (from ray[default]->-r requirements.txt (line 1)) (22.2.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.9/site-packages (from ray[default]->-r requirements.txt (line 1)) (5.4.1)
# Collecting filelock
# Downloading filelock-3.9.1-py3-none-any.whl (9.7 kB)
# Collecting grpcio>=1.32.0
# Downloading grpcio-1.51.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 110.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19.3 in /opt/conda/lib/python3.9/site-packages (from ray[default]->-r requirements.txt (line 1)) (1.23.5)
# Collecting jsonschema
# Downloading jsonschema-4.17.3-py3-none-any.whl (90 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 kB 31.2 MB/s eta 0:00:00
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /opt/conda/lib/python3.9/site-packages (from ray[default]->-r requirements.txt (line 1)) (3.20.2)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.9/site-packages (from ray[default]->-r requirements.txt (line 1)) (5.4.1)
# Collecting msgpack<2.0.0,>=1.0.0
# Downloading msgpack-1.0.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (322 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 kB 58.7 MB/s eta 0:00:00
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (from ray[default]->-r requirements.txt (line 1)) (2.28.2)
# Collecting virtualenv>=20.0.24
# Downloading virtualenv-20.21.0-py3-none-any.whl (8.7 MB)
# Collecting grpcio>=1.32.0
# Downloading grpcio-1.51.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 88.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19.3 in /opt/conda/lib/python3.9/site-packages (from ray[default]->-r requirements.txt (line 1)) (1.23.5)
# Collecting msgpack<2.0.0,>=1.0.0
# Downloading msgpack-1.0.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (322 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 kB 60.9 MB/s eta 0:00:00
# Collecting jsonschema
# Downloading jsonschema-4.17.3-py3-none-any.whl (90 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 kB 28.9 MB/s eta 0:00:00
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /opt/conda/lib/python3.9/site-packages (from ray[default]->-r requirements.txt (line 1)) (3.20.2)
# Collecting gpustat>=1.0.0
# Downloading gpustat-1.0.0.tar.gz (90 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.5/90.5 kB 27.8 MB/s eta 0:00:00
# Preparing metadata (setup.py): started
# Preparing metadata (setup.py): finished with status 'done'
# Collecting opencensus
# Downloading opencensus-0.11.2-py2.py3-none-any.whl (128 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 31.5 MB/s eta 0:00:00
# Requirement already satisfied: smart-open in /opt/conda/lib/python3.9/site-packages (from ray[default]->-r requirements.txt (line 1)) (5.2.1)
# Collecting aiohttp>=3.7
# Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 96.6 MB/s eta 0:00:00
# Collecting prometheus-client>=0.7.1
# Downloading prometheus_client-0.16.0-py3-none-any.whl (122 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.5/122.5 kB 36.9 MB/s eta 0:00:00
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 113.6 MB/s eta 0:00:00
# Collecting frozenlist
# Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 42.0 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.9/site-packages (from ray[default]->-r requirements.txt (line 1)) (8.1.2)
# Requirement already satisfied: attrs in /opt/conda/lib/python3.9/site-packages (from ray[default]->-r requirements.txt (line 1)) (22.2.0)
# Collecting aiosignal
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: pydantic in /opt/conda/lib/python3.9/site-packages (from ray[default]->-r requirements.txt (line 1)) (1.10.4)
# Collecting py-spy>=0.2.0
# Downloading py_spy-0.3.14-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 113.2 MB/s eta 0:00:00
# Collecting gpustat>=1.0.0
# Downloading gpustat-1.0.0.tar.gz (90 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.5/90.5 kB 27.8 MB/s eta 0:00:00
# Preparing metadata (setup.py): started
# Preparing metadata (setup.py): finished with status 'done'
# Collecting opencensus
# Downloading opencensus-0.11.2-py2.py3-none-any.whl (128 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 25.3 MB/s eta 0:00:00
# Requirement already satisfied: smart-open in /opt/conda/lib/python3.9/site-packages (from ray[default]->-r requirements.txt (line 1)) (5.2.1)
# Collecting aiohttp-cors
# Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Collecting aiohttp>=3.7
# Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 90.2 MB/s eta 0:00:00
# Collecting py-spy>=0.2.0
# Downloading py_spy-0.3.14-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 123.9 MB/s eta 0:00:00
# Collecting colorful
# Downloading colorful-0.5.5-py2.py3-none-any.whl (201 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 kB 47.7 MB/s eta 0:00:00
# Requirement already satisfied: pydantic in /opt/conda/lib/python3.9/site-packages (from ray[default]->-r requirements.txt (line 1)) (1.10.4)
# Collecting aiohttp-cors
# Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.9/site-packages (from ray[default]->-r requirements.txt (line 1)) (0.9.0)
# Collecting tensorboardX>=1.9
# Downloading tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 34.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /opt/conda/lib/python3.9/site-packages (from ray[default]->-r requirements.txt (line 1)) (1.5.3)
# Collecting xgboost>=0.90
# Downloading xgboost-1.7.4-py3-none-manylinux2014_x86_64.whl (193.6 MB)
# Collecting prometheus-client>=0.7.1
# Downloading prometheus_client-0.16.0-py3-none-any.whl (122 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.5/122.5 kB 34.6 MB/s eta 0:00:00
# Collecting colorful
# Downloading colorful-0.5.5-py2.py3-none-any.whl (201 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 kB 40.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /opt/conda/lib/python3.9/site-packages (from ray[default]->-r requirements.txt (line 1)) (1.5.3)
# Collecting tensorboardX>=1.9
# Downloading tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 32.1 MB/s eta 0:00:00
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.9/site-packages (from ray[default]->-r requirements.txt (line 1)) (0.9.0)
# Collecting xgboost>=0.90
# Downloading xgboost-1.7.4-py3-none-manylinux2014_x86_64.whl (193.6 MB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 MB 11.1 MB/s eta 0:00:00
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 MB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /opt/conda/lib/python3.9/site-packages (from xgboost_ray->-r requirements.txt (line 3)) (23.0)
# Collecting wrapt>=1.12.1
# Downloading wrapt-1.15.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (78 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 26.8 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp>=3.7->ray[default]->-r requirements.txt (line 1)) (2.1.1)
# Collecting async-timeout<5.0,>=4.0.0a3
# Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
# Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 53.2 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
# Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.9/site-packages (from xgboost_ray->-r requirements.txt (line 3)) (23.0)
# Collecting wrapt>=1.12.1
# Downloading wrapt-1.15.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (78 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 23.0 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
# Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp>=3.7->ray[default]->-r requirements.txt (line 1)) (2.1.1)
# Collecting yarl<2.0,>=1.0
# Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 54.1 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
# Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 25.8 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.7 in /opt/conda/lib/python3.9/site-packages (from gpustat>=1.0.0->ray[default]->-r requirements.txt (line 1)) (1.16.0)
# Collecting nvidia-ml-py<=11.495.46,>=11.450.129
# Downloading nvidia_ml_py-11.495.46-py3-none-any.whl (25 kB)
# Requirement already satisfied: psutil>=5.6.0 in /opt/conda/lib/python3.9/site-packages (from gpustat>=1.0.0->ray[default]->-r requirements.txt (line 1)) (5.9.4)
# Collecting blessed>=1.17.1
# Downloading blessed-1.20.0-py2.py3-none-any.whl (58 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 13.8 MB/s eta 0:00:00
# Collecting platformdirs<4,>=2.4
# Downloading platformdirs-3.1.1-py3-none-any.whl (14 kB)
# Collecting distlib<1,>=0.3.6
# Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 kB 62.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /opt/conda/lib/python3.9/site-packages (from xgboost>=0.90->xgboost_ray->-r requirements.txt (line 3)) (1.10.0)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 28.3 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.7 in /opt/conda/lib/python3.9/site-packages (from gpustat>=1.0.0->ray[default]->-r requirements.txt (line 1)) (1.16.0)
# Collecting nvidia-ml-py<=11.495.46,>=11.450.129
# Downloading nvidia_ml_py-11.495.46-py3-none-any.whl (25 kB)
# Requirement already satisfied: psutil>=5.6.0 in /opt/conda/lib/python3.9/site-packages (from gpustat>=1.0.0->ray[default]->-r requirements.txt (line 1)) (5.9.4)
# Collecting blessed>=1.17.1
# Downloading blessed-1.20.0-py2.py3-none-any.whl (58 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 20.1 MB/s eta 0:00:00
# Collecting platformdirs<4,>=2.4
# Downloading platformdirs-3.1.1-py3-none-any.whl (14 kB)
# Collecting distlib<1,>=0.3.6
# Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 kB 70.0 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /opt/conda/lib/python3.9/site-packages (from xgboost>=0.90->xgboost_ray->-r requirements.txt (line 3)) (1.10.0)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
# Downloading pyrsistent-0.19.3-py3-none-any.whl (57 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 18.7 MB/s eta 0:00:00
# Collecting google-api-core<3.0.0,>=1.0.0
# Downloading google_api_core-2.11.0-py3-none-any.whl (120 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.3/120.3 kB 28.7 MB/s eta 0:00:00
# Collecting opencensus-context>=0.1.3
# Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.9/site-packages (from pandas->ray[default]->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas->ray[default]->-r requirements.txt (line 1)) (2022.7.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.9/site-packages (from pydantic->ray[default]->-r requirements.txt (line 1)) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests->ray[default]->-r requirements.txt (line 1)) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests->ray[default]->-r requirements.txt (line 1)) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests->ray[default]->-r requirements.txt (line 1)) (1.26.14)
# Requirement already satisfied: wcwidth>=0.1.4 in /opt/conda/lib/python3.9/site-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default]->-r requirements.txt (line 1)) (0.2.6)
# Collecting googleapis-common-protos<2.0dev,>=1.56.2
# Downloading googleapis_common_protos-1.58.0-py2.py3-none-any.whl (223 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.0/223.0 kB 45.1 MB/s eta 0:00:00
# Collecting google-auth<3.0dev,>=2.14.1
# Downloading google_auth-2.16.2-py2.py3-none-any.whl (177 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.2/177.2 kB 48.8 MB/s eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0
# Downloading cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.9/site-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]->-r requirements.txt (line 1)) (4.7.2)
# Collecting pyasn1-modules>=0.2.1
# Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 43.3 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]->-r requirements.txt (line 1)) (0.4.8)
# Building wheels for collected packages: gpustat
# Building wheel for gpustat (setup.py): started
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
# Downloading pyrsistent-0.19.3-py3-none-any.whl (57 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 18.3 MB/s eta 0:00:00
# Collecting opencensus-context>=0.1.3
# Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Collecting google-api-core<3.0.0,>=1.0.0
# Downloading google_api_core-2.11.0-py3-none-any.whl (120 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.3/120.3 kB 32.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.9/site-packages (from pandas->ray[default]->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas->ray[default]->-r requirements.txt (line 1)) (2022.7.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.9/site-packages (from pydantic->ray[default]->-r requirements.txt (line 1)) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests->ray[default]->-r requirements.txt (line 1)) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests->ray[default]->-r requirements.txt (line 1)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests->ray[default]->-r requirements.txt (line 1)) (2022.12.7)
# Requirement already satisfied: wcwidth>=0.1.4 in /opt/conda/lib/python3.9/site-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default]->-r requirements.txt (line 1)) (0.2.6)
# Collecting google-auth<3.0dev,>=2.14.1
# Downloading google_auth-2.16.2-py2.py3-none-any.whl (177 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.2/177.2 kB 43.8 MB/s eta 0:00:00
# Collecting googleapis-common-protos<2.0dev,>=1.56.2
# Downloading googleapis_common_protos-1.58.0-py2.py3-none-any.whl (223 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.0/223.0 kB 49.9 MB/s eta 0:00:00
# Collecting pyasn1-modules>=0.2.1
# Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 40.0 MB/s eta 0:00:00
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.9/site-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]->-r requirements.txt (line 1)) (4.7.2)
# Collecting cachetools<6.0,>=2.0.0
# Downloading cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]->-r requirements.txt (line 1)) (0.4.8)
# Building wheels for collected packages: gpustat
# Building wheel for gpustat (setup.py): started
# Building wheel for gpustat (setup.py): finished with status 'done'
# Created wheel for gpustat: filename=gpustat-1.0.0-py3-none-any.whl size=19867 sha256=4aa667485e9bc32af15a229d113d058631c156cd9613f729a0f260d5ed7e3b5e
# Stored in directory: /root/.cache/pip/wheels/ce/13/aa/145d9d670feb2cf4a0691b9a3552aafc8a1b49c5162a0f379d
# Successfully built gpustat
# Building wheel for gpustat (setup.py): finished with status 'done'
# Created wheel for gpustat: filename=gpustat-1.0.0-py3-none-any.whl size=19867 sha256=12edb212af6679ddcc7e6717d4cc29eecd43bc1ba2467b6a715350403ee3679a
# Stored in directory: /root/.cache/pip/wheels/ce/13/aa/145d9d670feb2cf4a0691b9a3552aafc8a1b49c5162a0f379d
# Successfully built gpustat
# Installing collected packages: py-spy, opencensus-context, nvidia-ml-py, msgpack, distlib, colorful, wrapt, tensorboardX, pyrsistent, pyasn1-modules, prometheus-client, platformdirs, multidict, grpcio, googleapis-common-protos, frozenlist, filelock, cachetools, blessed, async-timeout, yarl, xgboost, virtualenv, jsonschema, gpustat, google-auth, aiosignal, ray, google-api-core, aiohttp, xgboost_ray, opencensus, aiohttp-cors
# Installing collected packages: py-spy, opencensus-context, nvidia-ml-py, msgpack, distlib, colorful, wrapt, tensorboardX, pyrsistent, pyasn1-modules, prometheus-client, platformdirs, multidict, grpcio, googleapis-common-protos, frozenlist, filelock, cachetools, blessed, async-timeout, yarl, xgboost, virtualenv, jsonschema, gpustat, google-auth, aiosignal, ray, google-api-core, aiohttp, xgboost_ray, opencensus, aiohttp-cors
