# %% [markdown]
# # Visualize full Amazon Customer Reviews Dataset with Spark and AWS Glue Interactive Sessions
# In this notebook, we will query the full reviews data.

# %% [markdown]
# # Dataset Column Descriptions
#
# - `marketplace`: 2-letter country code (in this case all "US").
# - `customer_id`: Random identifier that can be used to aggregate reviews written by a single author.
# - `review_id`: A unique ID for the review.
# - `product_id`: The Amazon Standard Identification Number (ASIN).  `http://www.amazon.com/dp/<ASIN>` links to the product's detail page.
# - `product_parent`: The parent of that ASIN.  Multiple ASINs (color or format variations of the same product) can roll up into a single parent.
# - `product_title`: Title description of the product.
# - `product_category`: Broad product category that can be used to group reviews (in this case digital videos).
# - `star_rating`: The review's rating (1 to 5 stars).
# - `helpful_votes`: Number of helpful votes for the review.
# - `total_votes`: Number of total votes the review received.
# - `vine`: Was the review written as part of the [Vine](https://www.amazon.com/gp/vine/help) program?
# - `verified_purchase`: Was the review from a verified purchase?
# - `review_headline`: The title of the review itself.
# - `review_body`: The text of the review.
# - `review_date`: The date the review was written.
# - `year`: The year derived from the review date.

# %%
# %stop_session
# Out:
# Stopping session: c5044b6e-3ec9-4f9d-b1be-add8a895e46f
# Stopped session.

# %%
# %additional_python_modules seaborn,psutil
# %number_of_workers 10
# Out:
# Additional python modules to be included:
# seaborn
# psutil
# Previous number of workers: 5
# Setting new number of workers to: 10

# %%
spark
# Out:
# Authenticating with environment variables and user-defined glue_role_arn: arn:aws:iam::079002598131:role/service-role/AmazonSageMaker-ExecutionRole-20220804T150518
# Trying to create a Glue session for the kernel.
# Worker Type: G.1X
# Number of Workers: 10
# Session ID: 238c4c47-5947-44ff-b794-c287e833ff41
# Job Type: glueetl
# Applying the following default arguments:
# --glue_kernel_version 0.37.0
# --enable-glue-datacatalog true
# --additional-python-modules seaborn,psutil
# Waiting for session 238c4c47-5947-44ff-b794-c287e833ff41 to get into ready status...
# Session 238c4c47-5947-44ff-b794-c287e833ff41 has been created.
# <pyspark.sql.session.SparkSession object at 0x7fc5120ee5d0>

# %% [markdown]
# # Set Seaborn Parameters

# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

sns.set_style = "seaborn-whitegrid"

sns.set(
    rc={
        "font.style": "normal",
        "axes.facecolor": "white",
        "grid.color": ".8",
        "grid.linestyle": "-",
        "figure.facecolor": "white",
        "figure.titlesize": 20,
        "text.color": "black",
        "xtick.color": "black",
        "ytick.color": "black",
        "axes.labelcolor": "black",
        "axes.grid": True,
        "axes.labelsize": 10,
        "xtick.labelsize": 10,
        "font.size": 10,
        "ytick.labelsize": 10,
    }
)

# %% [markdown]
# # Helper Code to Display Values on Bars

# %%
def show_values_barplot(axs, space):
    def _show_on_plot(ax):
        for p in ax.patches:
            _x = p.get_x() + p.get_width() + float(space)
            _y = p.get_y() + p.get_height()
            value = round(float(p.get_width()), 2)
            ax.text(_x, _y, value, ha="left")

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _show_on_plot(ax)
    else:
        _show_on_plot(axs)

# %% [markdown]
# # Set Glue Database and Table names to query

# %%
database_name = "default"
table_name = "amazon_reviews_parquet"

# %% [markdown]
# # 1. Which Product Categories are Highest Rated by Average Rating?
# ## _This query takes a minute or two.  Please be patient._

# %%
df = spark.sql("""SELECT product_category, AVG(star_rating) AS avg_star_rating 
    FROM {}.{} 
    GROUP BY product_category 
    ORDER BY avg_star_rating DESC""".format(database_name, table_name)
)
df.show(50, truncate=False)
# Out:
# +------------------------+------------------+
# |product_category        |avg_star_rating   |
# +------------------------+------------------+
# |Gift_Card               |4.731363105858364 |
# |Digital_Music_Purchase  |4.636945897383845 |
# |Music                   |4.440540705473373 |
# |Books                   |4.340540167594962 |
# |Digital_Ebook_Purchase  |4.312491185831222 |
# |Grocery                 |4.3122209651867776|
# |Video_DVD               |4.307379993803094 |
# |Tools                   |4.26214078611011  |
# |Musical_Instruments     |4.251038036164822 |
# |Automotive              |4.246242829469048 |
# |Shoes                   |4.2414026795449224|
# |Outdoors                |4.239963115827751 |
# |Sports                  |4.229078730400938 |
# |Luggage                 |4.223774961905526 |
# |Toys                    |4.218104581238039 |
# |Digital_Video_Download  |4.207548770783551 |
# |Kitchen                 |4.20729367860571  |
# |Video                   |4.20092865030212  |
# |Beauty                  |4.187224635589001 |
# |Home_Improvement        |4.182261666996131 |
# |Home                    |4.1785132920622035|
# |Baby                    |4.164214487790478 |
# |Health_&_Personal_Care  |4.161769909446729 |
# |Jewelry                 |4.144090266004357 |
# |Pet_Products            |4.143657113028479 |
# |Watches                 |4.140102367791976 |
# |Camera                  |4.130621179490526 |
# |Apparel                 |4.105233930306817 |
# |Lawn_and_Garden         |4.093072570558454 |
# |PC                      |4.088439919438485 |
# |Furniture               |4.083872539490592 |
# |Office_Products         |4.072724600234801 |
# |Video_Games             |4.060589907801332 |
# |Electronics             |4.036143941340712 |
# |Mobile_Apps             |4.0350316122744765|
# |Personal_Care_Appliances|3.9783471379461504|
# |Home_Entertainment      |3.9091972569584508|
# |Wireless                |3.892277254145134 |
# |Digital_Video_Games     |3.8531262248076406|
# |Mobile_Electronics      |3.763966945292367 |
# |Major_Appliances        |3.71618455949887  |
# |Software                |3.5673316088678444|
# |Digital_Software        |3.5393303553935973|
# +------------------------+------------------+

# %%
# Store number of categories for later
num_categories = df.toPandas().shape[0]

 # Store average star ratings for later
average_star_ratings = df.toPandas()

# %% [markdown]
# ## Visualization

# %%
plt.clf()

# Create plot
barplot = sns.barplot(y="product_category", x="avg_star_rating", data=df.toPandas(), saturation=1)

if num_categories < 10:
    sns.set(rc={"figure.figsize": (10.0, 5.0)})

# Set title and x-axis ticks
plt.title("Average Rating by Product Category")
plt.xticks([1, 2, 3, 4, 5], ["1-Star", "2-Star", "3-Star", "4-Star", "5-Star"])

# Helper code to show actual values afters bars
show_values_barplot(barplot, 0.1)

plt.xlabel("Average Rating")
plt.ylabel("Product Category")

# Export plot if needed
plt.tight_layout()
# plt.savefig('avg_ratings_per_category.png', dpi=300)

# Show graphic
#plt.show(barplot)
plt.show()

# %matplot plt

# %% [markdown]
# # 2. Which Product Categories Have the Most Reviews?
# ## _This query takes a minute or two.  Please be patient._
#
# Note that in this cell, you are using PySpark syntax to process the data in your Glue table while the previous section was using Spark SQL.

# %%
from pyspark.sql import functions as f
df_raw = spark.sql("SELECT * FROM {}.{}".format(database_name, table_name))
df = (
    df_raw
    .select("product_category", "star_rating")
    .groupBy("product_category")
    .agg(f.count("star_rating").alias("count_star_rating"))
    .orderBy("count_star_rating", ascending=False)
)

df.show(50, truncate=False)
# Out:
# +------------------------+-----------------+
# |product_category        |count_star_rating|
# +------------------------+-----------------+
# |Books                   |20726160         |
# |Digital_Ebook_Purchase  |19180765         |
# |Wireless                |9038249          |
# |Video_DVD               |7135819          |
# |PC                      |7004337          |
# |Mobile_Apps             |6807166          |
# |Home                    |6228567          |
# |Music                   |6177781          |
# |Apparel                 |5906460          |
# |Health_&_Personal_Care  |5332883          |
# |Digital_Video_Download  |5173743          |
# |Beauty                  |5115721          |
# |Toys                    |4981601          |
# |Kitchen                 |4882831          |
# |Sports                  |4860054          |
# |Shoes                   |4379475          |
# |Automotive              |3516476          |
# |Electronics             |3120938          |
# |Office_Products         |2646491          |
# |Pet_Products            |2643670          |
# |Home_Improvement        |2640654          |
# |Lawn_and_Garden         |2559261          |
# |Grocery                 |2402478          |
# |Outdoors                |2305596          |
# |Digital_Music_Purchase  |1852184          |
# |Camera                  |1838760          |
# |Video_Games             |1808486          |
# |Jewelry                 |1767753          |
# |Baby                    |1764893          |
# |Tools                   |1748610          |
# |Watches                 |978042           |
# |Musical_Instruments     |920729           |
# |Furniture               |792214           |
# |Home_Entertainment      |743700           |
# |Video                   |437409           |
# |Luggage                 |349132           |
# |Software                |342135           |
# |Gift_Card               |149086           |
# |Digital_Video_Games     |145431           |
# |Mobile_Electronics      |105159           |
# |Digital_Software        |102084           |
# |Major_Appliances        |96901            |
# |Personal_Care_Appliances|86686            |
# +------------------------+-----------------+

# %%
# Store counts for later
count_ratings = df.toPandas()["count_star_rating"]

# Store max ratings for later
max_ratings = df.toPandas()["count_star_rating"].max()

# %% [markdown]
# ## Visualization

# %%
plt.clf()

# Create Seaborn barplot
barplot = sns.barplot(y="product_category", x="count_star_rating", data=df.toPandas(), saturation=1)

if num_categories < 10:
    sns.set(rc={"figure.figsize": (10.0, 5.0)})

# Set title
plt.title("Number of Ratings per Product Category for Subset of Product Categories")

# Set x-axis ticks to match scale
if max_ratings > 200000:
    plt.xticks([100000, 1000000, 5000000, 10000000, 15000000, 20000000], ["100K", "1m", "5m", "10m", "15m", "20m"])
    plt.xlim(0, 20000000)
elif max_ratings <= 200000:
    plt.xticks([50000, 100000, 150000, 200000], ["50K", "100K", "150K", "200K"])
    plt.xlim(0, 200000)

plt.xlabel("Number of Ratings")
plt.ylabel("Product Category")

plt.tight_layout()

# Export plot if needed
# plt.savefig('ratings_per_category.png', dpi=300)

# Show the barplot
plt.show()

# %matplot plt

# %% [markdown]
# # 3. When did each product category become available in the Amazon catalog based on the date of the first review?
# ## _This query takes a minute or two.  Please be patient._

# %%
# SQL statement
df = spark.sql("""
    SELECT product_category, MIN(year) AS first_review_year
    FROM {}.{}
    WHERE year >= 1995
    GROUP BY product_category
    ORDER BY first_review_year 
""".format(database_name, table_name)
)

df.show(50, truncate=False)
# Out:
# +------------------------+-----------------+
# |product_category        |first_review_year|
# +------------------------+-----------------+
# |Video                   |1995             |
# |Books                   |1995             |
# |Music                   |1995             |
# |Video_DVD               |1996             |
# |Sports                  |1997             |
# |Video_Games             |1997             |
# |Toys                    |1997             |
# |Pet_Products            |1998             |
# |Software                |1998             |
# |Camera                  |1998             |
# |Wireless                |1998             |
# |Office_Products         |1998             |
# |Home_Entertainment      |1998             |
# |Home                    |1998             |
# |Health_&_Personal_Care  |1999             |
# |PC                      |1999             |
# |Outdoors                |1999             |
# |Electronics             |1999             |
# |Musical_Instruments     |1999             |
# |Lawn_and_Garden         |1999             |
# |Grocery                 |1999             |
# |Baby                    |1999             |
# |Tools                   |1999             |
# |Digital_Ebook_Purchase  |1999             |
# |Home_Improvement        |1999             |
# |Shoes                   |1999             |
# |Automotive              |1999             |
# |Personal_Care_Appliances|2000             |
# |Major_Appliances        |2000             |
# |Digital_Video_Download  |2000             |
# |Apparel                 |2000             |
# |Digital_Music_Purchase  |2000             |
# |Beauty                  |2000             |
# |Furniture               |2000             |
# |Kitchen                 |2000             |
# |Jewelry                 |2001             |
# |Mobile_Electronics      |2001             |
# |Watches                 |2001             |
# |Luggage                 |2002             |
# |Gift_Card               |2004             |
# |Digital_Video_Games     |2006             |
# |Digital_Software        |2008             |
# |Mobile_Apps             |2010             |
# +------------------------+-----------------+

# %%
def get_x_y(df):
    """ Get X and Y coordinates; return tuple """
    series = df["first_review_year"].value_counts().sort_index()
    # new_series = series.reindex(range(1,21)).fillna(0).astype(int)
    return series.index, series.values

# %%
X, Y = get_x_y(df.toPandas())
print(X)
print(Y)
# Out:
# Int64Index([1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2004, 2006, 2008,
#             2010],
#            dtype='int64')
# [ 3  1  3  7 13  8  3  1  1  1  1  1]

# %% [markdown]
# ## Visualization

# %%
plt.clf()

fig = plt.figure(figsize=(12, 5))
ax = plt.gca()

ax.set_title("Number Of First Product Category Reviews Per Year for Subset of Categories")
ax.set_xlabel("Year")
ax.set_ylabel("Count")


ax.plot(X, Y, color="black", linewidth=2, marker="o")
ax.fill_between(X, [0] * len(X), Y, facecolor="lightblue")

ax.locator_params(integer=True)

ax.set_xticks(range(1995, 2016, 1))
ax.set_yticks(range(0, max(Y) + 2, 1))

plt.xticks(rotation=45)

# fig.savefig('first_reviews_per_year.png', dpi=300)
plt.show()

# %matplot plt

# %% [markdown]
# # 4. What is the breakdown of ratings (1-5) per product category?
# ## _This query takes a minute or two.  Please be patient._

# %%
# SQL statement
df = spark.sql("""
    SELECT product_category, star_rating, COUNT(*) AS count_reviews
    FROM {}.{}
    GROUP BY  product_category, star_rating
    ORDER BY  product_category ASC, star_rating DESC, count_reviews
""".format(database_name, table_name)
)

df.show(50, truncate=False)
# Out:
# +----------------------+-----------+-------------+
# |product_category      |star_rating|count_reviews|
# +----------------------+-----------+-------------+
# |Apparel               |5          |3320651      |
# |Apparel               |4          |1147254      |
# |Apparel               |3          |623483       |
# |Apparel               |2          |369608       |
# |Apparel               |1          |445464       |
# |Automotive            |5          |2301688      |
# |Automotive            |4          |526898       |
# |Automotive            |3          |240023       |
# |Automotive            |2          |147843       |
# |Automotive            |1          |300024       |
# |Baby                  |5          |1078545      |
# |Baby                  |4          |289129       |
# |Baby                  |3          |150753       |
# |Baby                  |2          |101427       |
# |Baby                  |1          |145039       |
# |Beauty                |5          |3254946      |
# |Beauty                |4          |741443       |
# |Beauty                |3          |398405       |
# |Beauty                |2          |264029       |
# |Beauty                |1          |456898       |
# |Books                 |5          |13662131     |
# |Books                 |4          |3546319      |
# |Books                 |3          |1543611      |
# |Books                 |2          |861867       |
# |Books                 |1          |1112232      |
# |Camera                |5          |1085596      |
# |Camera                |4          |344163       |
# |Camera                |3          |144596       |
# |Camera                |2          |92396        |
# |Camera                |1          |172009       |
# |Digital_Ebook_Purchase|5          |11612150     |
# |Digital_Ebook_Purchase|4          |4311745      |
# |Digital_Ebook_Purchase|3          |1701301      |
# |Digital_Ebook_Purchase|2          |749678       |
# |Digital_Ebook_Purchase|1          |805891       |
# |Digital_Music_Purchase|5          |1467877      |
# |Digital_Music_Purchase|4          |231676       |
# |Digital_Music_Purchase|3          |70507        |
# |Digital_Music_Purchase|2          |28743        |
# |Digital_Music_Purchase|1          |53381        |
# |Digital_Software      |5          |46410        |
# |Digital_Software      |4          |16693        |
# |Digital_Software      |3          |8308         |
# |Digital_Software      |2          |6890         |
# |Digital_Software      |1          |23783        |
# |Digital_Video_Download|5          |3122980      |
# |Digital_Video_Download|4          |984221       |
# |Digital_Video_Download|3          |449260       |
# |Digital_Video_Download|2          |251930       |
# |Digital_Video_Download|1          |365352       |
# +----------------------+-----------+-------------+
# only showing top 50 rows

# %% [markdown]
# ## Prepare for Stacked Percentage Horizontal Bar Plot Showing Proportion of Star Ratings per Product Category

# %%
# Create grouped DataFrames by category and by star rating
grouped_category = df.toPandas().groupby("product_category")
grouped_star = df.toPandas().groupby("star_rating")

# Create sum of ratings per star rating
df_sum = df.toPandas().groupby(["star_rating"]).sum()

# Calculate total number of star ratings
total = df_sum["count_reviews"].sum()
print(total)
# Out:
# 160796570

# %%
# Create dictionary of product categories and array of star rating distribution per category
distribution = {}
count_reviews_per_star = []
i = 0

for category, ratings in grouped_category:
    count_reviews_per_star = []
    for star in ratings["star_rating"]:
        count_reviews_per_star.append(ratings.at[i, "count_reviews"])
        i = i + 1
    distribution[category] = count_reviews_per_star

# Check if distribution has been created succesfully
print(distribution)
# Out:
# {'Apparel': [3320651, 1147254, 623483, 369608, 445464], 'Automotive': [2301688, 526898, 240023, 147843, 300024], 'Baby': [1078545, 289129, 150753, 101427, 145039], 'Beauty': [3254946, 741443, 398405, 264029, 456898], 'Books': [13662131, 3546319, 1543611, 861867, 1112232], 'Camera': [1085596, 344163, 144596, 92396, 172009], 'Digital_Ebook_Purchase': [11612150, 4311745, 1701301, 749678, 805891], 'Digital_Music_Purchase': [1467877, 231676, 70507, 28743, 53381], 'Digital_Software': [46410, 16693, 8308, 6890, 23783], 'Digital_Video_Download': [3122980, 984221, 449260, 251930, 365352], 'Digital_Video_Games': [80677, 20406, 11629, 7749, 24970], 'Electronics': [1796672, 542181, 240859, 180668, 360558], 'Furniture': [447763, 153678, 73574, 43853, 73346], 'Gift_Card': [129709, 9859, 3156, 1569, 4793], 'Grocery': [1662278, 293389, 161497, 105265, 180049], 'Health_&_Personal_Care': [3359016, 782025, 400572, 278066, 513204], 'Home': [3897623, 960326, 500884, 324345, 545389], 'Home_Entertainment': [395254, 138172, 60898, 46242, 103134], 'Home_Improvement': [1660254, 419488, 189490, 124792, 246630], 'Jewelry': [1081479, 270579, 159735, 100852, 155108], 'Kitchen': [3129752, 732976, 350188, 242361, 427554], 'Lawn_and_Garden': [1546990, 401137, 194777, 135055, 281302], 'Luggage': [216857, 61488, 27872, 17887, 25028], 'Major_Appliances': [49704, 15158, 6718, 5475, 19846], 'Mobile_Apps': [3747383, 1375672, 614333, 314750, 755028], 'Mobile_Electronics': [52373, 18112, 9754, 7320, 17600], 'Music': [4296015, 1018968, 405541, 202861, 254396], 'Musical_Instruments': [582772, 161623, 68231, 40906, 67197], 'Office_Products': [1586632, 419489, 194113, 138717, 307540], 'Outdoors': [1436837, 418103, 179395, 109599, 161662], 'PC': [4166576, 1185891, 520947, 366603, 764320], 'Personal_Care_Appliances': [49310, 13782, 7107, 5381, 11106], 'Pet_Products': [1645587, 381294, 216639, 151284, 248866], 'Shoes': [2647584, 850452, 405263, 243424, 232752], 'Software': [154057, 58696, 30693, 24672, 74017], 'Sports': [3046077, 838841, 381388, 229890, 363858], 'Tools': [1118325, 300861, 126637, 75055, 127732], 'Toys': [3160447, 788495, 395143, 233754, 403762], 'Video': [263744, 81794, 39030, 21697, 31144], 'Video_DVD': [4702079, 1138174, 540591, 296845, 458130], 'Video_Games': [1040615, 321861, 155496, 95999, 194515], 'Watches': [582164, 176290, 80381, 52864, 86343], 'Wireless': [4845345, 1507668, 818151, 600436, 1266649]}

# %%
# Sort distribution by average rating per category
sorted_distribution = {}

average_star_ratings.iloc[:, 0]
for index, value in average_star_ratings.iloc[:, 0].items():
    sorted_distribution[value] = distribution[value]

# %%
df_sorted_distribution_pct = pd.DataFrame(sorted_distribution).transpose().apply(
    lambda num_ratings: num_ratings/sum(num_ratings)*100, axis=1
)
df_sorted_distribution_pct.columns=['5', '4', '3', '2', '1']
df_sorted_distribution_pct
# Out:
#                                   5          4          3         2          1
# Gift_Card                 87.002804   6.612962   2.116899  1.052413   3.214923
# Digital_Music_Purchase    79.251144  12.508261   3.806695  1.551844   2.882057
# Music                     69.539775  16.494078   6.564509  3.283720   4.117919
# Books                     65.917329  17.110352   7.447646  4.158354   5.366320
# Digital_Ebook_Purchase    60.540599  22.479526   8.869829  3.908489   4.201558
# Grocery                   69.190145  12.211933   6.722101  4.381518   7.494304
# Video_DVD                 65.894034  15.950152   7.575739  4.159929   6.420146
# Tools                     63.955084  17.205723   7.242152  4.292266   7.304774
# Musical_Instruments       63.294628  17.553808   7.410541  4.442784   7.298239
# Automotive                65.454392  14.983694   6.825669  4.204294   8.531951
# Shoes                     60.454370  19.419040   9.253689  5.558292   5.314610
# Outdoors                  62.319548  18.134270   7.780851  4.753608   7.011723
# Sports                    62.675785  17.259911   7.847403  4.730194   7.486707
# Luggage                   62.113184  17.611677   7.983227  5.123277   7.168635
# Toys                      63.442395  15.828144   7.932048  4.692347   8.105065
# Digital_Video_Download    60.362101  19.023384   8.683462  4.869395   7.061657
# Kitchen                   64.097078  15.011292   7.171823  4.963534   8.756273
# Video                     60.296885  18.699661   8.922999  4.960346   7.120110
# Beauty                    63.626339  14.493421   7.787856  5.161130   8.931253
# Home_Improvement          62.872834  15.885762   7.175874  4.725799   9.339732
# Home                      62.576561  15.418089   8.041721  5.207378   8.756252
# Baby                      61.111070  16.382240   8.541764  5.746921   8.218005
# Health_&_Personal_Care    62.986868  14.664207   7.511359  5.214178   9.623388
# Jewelry                   61.178174  15.306380   9.036047  5.705096   8.774303
# Pet_Products              62.246309  14.422905   8.194631  5.722499   9.413656
# Watches                   59.523415  18.024788   8.218563  5.405085   8.828148
# Camera                    59.039570  18.717125   7.863778  5.024908   9.354619
# Apparel                   56.220663  19.423716  10.555951  6.257691   7.541979
# Lawn_and_Garden           60.446746  15.673939   7.610674  5.277109  10.991532
# PC                        59.485659  16.930810   7.437492  5.233943  10.912096
# Furniture                 56.520460  19.398546   9.287137  5.535499   9.258357
# Office_Products           59.952292  15.850762   7.334731  5.241544  11.620671
# Video_Games               57.540672  17.797262   8.598131  5.308252  10.755682
# Electronics               57.568334  17.372373   7.717520  5.788901  11.552873
# Mobile_Apps               55.050560  20.209174   9.024798  4.623804  11.091664
# Personal_Care_Appliances  56.883464  15.898761   8.198556  6.207461  12.811757
# Home_Entertainment        53.146968  18.578997   8.188517  6.217830  13.867689
# Wireless                  53.609333  16.680974   9.052096  6.643278  14.014318
# Digital_Video_Games       55.474417  14.031396   7.996232  5.328300  17.169654
# Mobile_Electronics        49.803631  17.223443   9.275478  6.960888  16.736561
# Major_Appliances          51.293588  15.642769   6.932849  5.650096  20.480697
# Software                  45.028132  17.155801   8.971020  7.211189  21.633858
# Digital_Software          45.462560  16.352220   8.138396  6.749344  23.297481

# %% [markdown]
# ## Visualization

# %%
plt.clf()

categories = df_sorted_distribution_pct.index

# Plot bars
if len(categories) > 10:
    plt.figure(figsize=(10,10))
else: 
    plt.figure(figsize=(10,5))

df_sorted_distribution_pct.plot(kind="barh", 
                                stacked=True, 
                                edgecolor='white',
                                width=1.0,
                                color=['green', 
                                       'orange', 
                                       'blue', 
                                       'purple', 
                                       'red'])

plt.title("Distribution of Reviews Per Rating Per Category", 
          fontsize='16')

plt.legend(bbox_to_anchor=(1.04,1), 
           loc="upper left",
           labels=['5-Star Ratings', 
                   '4-Star Ratings', 
                   '3-Star Ratings', 
                   '2-Star Ratings', 
                   '1-Star Ratings'])

plt.xlabel("% Breakdown of Star Ratings", fontsize='14')
plt.gca().invert_yaxis()
plt.tight_layout()

plt.show()

# %matplot plt

# %% [markdown]
# # 5. How Many Reviews per Star Rating? (5, 4, 3, 2, 1)
# ## _This query takes a minute or two.  Please be patient._

# %%
# SQL statement
df = spark.sql("""
    SELECT star_rating, COUNT(*) AS count_reviews
    FROM {}.{}
    GROUP BY star_rating
    ORDER BY star_rating DESC, count_reviews 
""".format(database_name, table_name)
)

df.show()
# Out:
# +-----------+-------------+
# |star_rating|count_reviews|
# +-----------+-------------+
# |          5|     99530924|
# |          4|     27996469|
# |          3|     12900929|
# |          2|      7700647|
# |          1|     12667601|
# +-----------+-------------+

# %%
plt.clf()

chart = df.toPandas().plot.bar(
    x="star_rating", y="count_reviews", rot="0", figsize=(10, 5), title="Review Count by Star Ratings", legend=False
)

plt.xlabel("Star Rating")
plt.ylabel("Review Count")

plt.show()

# %matplot plt

# %% [markdown]
# # 6. How Did Star Ratings Change Over Time?
# Is there a drop-off point for certain product categories throughout the year?

# %% [markdown]
# ## Average Star Rating Across All Product Categories
# ## _This query takes a minute or two.  Please be patient._

# %%
# SQL statement
df = spark.sql("""
    SELECT year, ROUND(AVG(star_rating),4) AS avg_rating
    FROM {}.{}
    WHERE year >= 1995
    GROUP BY year
    ORDER BY year
""".format(database_name, table_name)
)

df.show(50, truncate=False)
# Out:
# +----+----------+
# |year|avg_rating|
# +----+----------+
# |1995|4.6204    |
# |1996|4.6111    |
# |1997|4.4348    |
# |1998|4.361     |
# |1999|4.2886    |
# |2000|4.2629    |
# |2001|4.2037    |
# |2002|4.1698    |
# |2003|4.128     |
# |2004|4.0695    |
# |2005|4.0734    |
# |2006|4.1061    |
# |2007|4.1733    |
# |2008|4.1312    |
# |2009|4.1171    |
# |2010|4.076     |
# |2011|4.0571    |
# |2012|4.1271    |
# |2013|4.2077    |
# |2014|4.2358    |
# |2015|4.2549    |
# +----+----------+

# %%
df.toPandas()["year"] = pd.to_datetime(df.toPandas()["year"], format="%Y").dt.year

# %% [markdown]
# ## Visualization

# %%
plt.clf()

fig = plt.gcf()
fig.set_size_inches(12, 5)

fig.suptitle("Average Star Rating Over Time (Across Subset of Product Categories)")

ax = plt.gca()
# ax = plt.gca().set_xticks(df['year'])
ax.locator_params(integer=True)
ax.set_xticks(df.toPandas()["year"].unique())

df.toPandas().plot(kind="line", x="year", y="avg_rating", color="red", ax=ax)

# plt.xticks(range(1995, 2016, 1))
# plt.yticks(range(0,6,1))
plt.xlabel("Years")
plt.ylabel("Average Star Rating")
plt.xticks(rotation=45)

# fig.savefig('average-rating.png', dpi=300)
plt.show()

# %matplot plt

# %% [markdown]
# ## Average Star Rating Per Product Categories Across Time
# ## _This query takes a minute or two.  Please be patient._

# %%
# SQL statement
df = spark.sql("""
    SELECT product_category, year, ROUND(AVG(star_rating), 4) AS avg_rating_category
    FROM {}.{}
    WHERE year >= 1995
    GROUP BY product_category, year
    ORDER BY year 
""".format(database_name, table_name)
)

df.show(50, truncate=False)
# Out:
# +----------------------+----+-------------------+
# |product_category      |year|avg_rating_category|
# +----------------------+----+-------------------+
# |Music                 |1995|5.0                |
# |Video                 |1995|5.0                |
# |Books                 |1995|4.6114             |
# |Music                 |1996|4.6                |
# |Video_DVD             |1996|4.0                |
# |Books                 |1996|4.6135             |
# |Video                 |1996|3.8333             |
# |Music                 |1997|4.6794             |
# |Video_DVD             |1997|4.6667             |
# |Video                 |1997|4.4697             |
# |Video_Games           |1997|3.5                |
# |Sports                |1997|4.0                |
# |Toys                  |1997|4.0                |
# |Books                 |1997|4.4341             |
# |Software              |1998|2.6667             |
# |Pet_Products          |1998|2.5                |
# |Office_Products       |1998|4.5                |
# |Toys                  |1998|4.375              |
# |Wireless              |1998|4.5                |
# |Video_Games           |1998|4.3077             |
# |Video                 |1998|4.4179             |
# |Camera                |1998|5.0                |
# |Sports                |1998|2.0                |
# |Home                  |1998|4.4                |
# |Books                 |1998|4.3014             |
# |Music                 |1998|4.5456             |
# |Home_Entertainment    |1998|5.0                |
# |Video_DVD             |1998|4.2628             |
# |Grocery               |1999|5.0                |
# |Music                 |1999|4.4561             |
# |Video_Games           |1999|4.1349             |
# |Lawn_and_Garden       |1999|4.5                |
# |Health_&_Personal_Care|1999|4.0                |
# |Wireless              |1999|4.1471             |
# |Office_Products       |1999|3.8852             |
# |Video_DVD             |1999|4.0912             |
# |Pet_Products          |1999|4.0                |
# |Outdoors              |1999|5.0                |
# |Electronics           |1999|3.9044             |
# |Musical_Instruments   |1999|4.5                |
# |Sports                |1999|4.4821             |
# |PC                    |1999|3.7917             |
# |Software              |1999|3.6471             |
# |Baby                  |1999|4.5536             |
# |Home                  |1999|4.1429             |
# |Digital_Ebook_Purchase|1999|5.0                |
# |Home_Improvement      |1999|4.4324             |
# |Books                 |1999|4.2177             |
# |Shoes                 |1999|3.3333             |
# |Toys                  |1999|4.5267             |
# +----------------------+----+-------------------+
# only showing top 50 rows

# %% [markdown]
# ## Visualization

# %%
def plot_categories(df):
    df_categories = df["product_category"].unique()
    for category in df_categories:
        # print(category)
        df_plot = df.loc[df["product_category"] == category]
        df_plot.plot(
            kind="line",
            x="year",
            y="avg_rating_category",
            c=np.random.rand(
                3,
            ),
            ax=ax,
            label=category,
        )

# %%
plt.clf()

fig = plt.gcf()
fig.set_size_inches(12, 5)

fig.suptitle("Average Star Rating Over Time Across Subset Of Categories")

ax = plt.gca()

ax.locator_params(integer=True)
ax.set_xticks(df.toPandas()["year"].unique())

plot_categories(df.toPandas())

plt.xlabel("Year")
plt.ylabel("Average Star Rating")
plt.legend(bbox_to_anchor=(0, -0.15, 1, 0), loc=2, ncol=2, mode="expand", borderaxespad=0)

# fig.savefig('average_rating_category_all_data.png', dpi=300)
plt.show()

# %matplot plt

# %% [markdown]
# # 7. Which Star Ratings (1-5) are Most Helpful?
# ## _This query takes a minute or two.  Please be patient._

# %%
# SQL statement
df = spark.sql("""
    SELECT star_rating, AVG(helpful_votes) AS avg_helpful_votes
    FROM {}.{}
    GROUP BY  star_rating
    ORDER BY  star_rating ASC
""".format(database_name, table_name)
)

df.show()
# Out:
# +-----------+------------------+
# |star_rating| avg_helpful_votes|
# +-----------+------------------+
# |          1| 3.832321447446916|
# |          2| 2.570054308423695|
# |          3|2.0687386156454313|
# |          4|1.6800495805381743|
# |          5|1.6912020931303722|
# +-----------+------------------+

# %% [markdown]
# ## Visualization

# %%
plt.clf()

chart = df.toPandas().plot.bar(
    x="star_rating", y="avg_helpful_votes", rot="0", figsize=(10, 5), title="Helpfulness Of Star Ratings", legend=False
)

plt.xlabel("Star Rating")
plt.ylabel("Average Helpful Votes")

plt.show()

# %matplot plt

# %% [markdown]
# # 8. Which Products have Most Helpful Reviews?  How Long are the Most Helpful Reviews?
# ## _This query takes a minute or two.  Please be patient._

# %%
# SQL statement
df = spark.sql("""
    SELECT product_title, helpful_votes, star_rating,
           LENGTH(review_body) AS review_body_length,
           SUBSTR(review_body, 1, 100) AS review_body_substr
    FROM {}.{}
    ORDER BY helpful_votes DESC LIMIT 10 
""".format(database_name, table_name)
)

df.show(50, truncate=False)
# Out:
# +----------------------------------------------------------------------------------------+-------------+-----------+------------------+----------------------------------------------------------------------------------------------------+
# |product_title                                                                           |helpful_votes|star_rating|review_body_length|review_body_substr                                                                                  |
# +----------------------------------------------------------------------------------------+-------------+-----------+------------------+----------------------------------------------------------------------------------------------------+
# |Kindle: Amazon's Original Wireless Reading Device (1st generation)                      |47524        |5          |12906             |This is less a \\"pros and cons\\" review than a hopefully useful commentary about the Kindle compar|
# |BIC Cristal For Her Ball Pen, 1.0mm, Black, 16ct (MSLP16-Blk)                           |41393        |5          |863               |Someone has answered my gentle prayers and FINALLY designed a pen that I can use all month long! I u|
# |The Mountain Kids 100% Cotton Three Wolf Moon T-Shirt                                   |41278        |5          |1566              |This item has wolves on it which makes it intrinsically sweet and worth 5 stars by itself, but once |
# |Kindle Keyboard 3G, Free 3G + Wi-Fi, 6" E Ink Display                                   |31924        |5          |23069             |UPDATE NOVEMBER 2011:<br /><br />My review is now over a year old, as is the \\"Kindle Keyboard\\" a|
# |Kindle Fire HD 7", Dolby Audio, Dual-Band Wi-Fi                                         |31417        |4          |13594             |I've been an iPad user since the original came out. I also have an iPad 3. I have worked in IT for t|
# |Kindle Fire (Previous Generation - 1st)                                                 |28611        |4          |29778             |UPDATE November 2012 - With the [[ASIN:B007T36PSM Kindle Fire HD]] out now, I highly recommend it ov|
# |Fifty Shades of Grey: Book One of the Fifty Shades Trilogy (Fifty Shades of Grey Series)|27550        |2          |2849              |I really don't like writing bad reviews. I admire people who have the courage to put pen to paper an|
# |Fifty Shades of Grey: Book One of the Fifty Shades Trilogy (Fifty Shades of Grey Series)|27550        |2          |2849              |I really don't like writing bad reviews. I admire people who have the courage to put pen to paper an|
# |Wheelmate Laptop Steering Wheel Desk                                                    |26132        |5          |572               |My husband Brad always warns me not to try and update my Facebook page while I'm driving. \\"You'll |
# |Kindle Wireless Reading Device (6" Display, U.S. Wireless)                              |24714        |1          |10222             |I was DELIGHTED to upgrade my Kindle 1 to K2...until I got down to using it every day.<br /><br />Ha|
# +----------------------------------------------------------------------------------------+-------------+-----------+------------------+----------------------------------------------------------------------------------------------------+

# %% [markdown]
# # 9. What is the Ratio of Positive (5, 4) to Negative (3, 2 ,1) Reviews?
# ## _This query takes a minute or two.  Please be patient._

# %%
# SQL statement
df = spark.sql("""
    SELECT (CAST(positive_review_count AS DOUBLE) / CAST(negative_review_count AS DOUBLE)) AS positive_to_negative_sentiment_ratio
    FROM (
      SELECT count(*) AS positive_review_count
      FROM {}.{}
      WHERE star_rating >= 4

    ), (
      SELECT count(*) AS negative_review_count
      FROM {}.{}
      WHERE star_rating < 4 
    )
""".format(database_name, table_name, database_name, table_name)
)

df.show()
# Out:
# +------------------------------------+
# |positive_to_negative_sentiment_ratio|
# +------------------------------------+
# |                  3.8331995107663768|
# +------------------------------------+

# %% [markdown]
# # 10. Which Customers are Abusing the Review System by Repeatedly Reviewing the Same Product?  What Was Their Average Star Rating for Each Product?
# ## _This query takes a minute or two.  Please be patient._

# %%
# SQL statement
df = spark.sql("""
    SELECT customer_id, product_category, product_title, 
    ROUND(AVG(star_rating),4) AS avg_star_rating, COUNT(*) AS review_count 
    FROM {}.{} 
    GROUP BY customer_id, product_category, product_title 
    HAVING COUNT(*) > 1 
    ORDER BY review_count DESC
    LIMIT 50
""".format(database_name, table_name)
)

df.show(50, truncate=False)
# Out:
# +-----------+----------------------+---------------------------------------------------------------------------------------+---------------+------------+
# |customer_id|product_category      |product_title                                                                          |avg_star_rating|review_count|
# +-----------+----------------------+---------------------------------------------------------------------------------------+---------------+------------+
# |38118182   |Video_DVD             |Pearl Harbor                                                                           |4.2308         |260         |
# |33132919   |Video_DVD             |Shania Twain - Up (Live in Chicago)                                                    |5.0            |220         |
# |52895956   |Books                 |Frankenstein                                                                           |3.0299         |201         |
# |29088361   |Music                 |In The Zone                                                                            |4.9672         |122         |
# |23974294   |Video_DVD             |Shania Twain - Up (Live in Chicago)                                                    |5.0            |114         |
# |50432389   |Music                 |In The Zone                                                                            |5.0            |100         |
# |50440254   |Music                 |The Beatles 1                                                                          |5.0            |94          |
# |43622173   |Music                 |Sinner                                                                                 |4.9756         |82          |
# |32330663   |Music                 |Reprise                                                                                |5.0            |82          |
# |2840168    |Camera                |(Create a generic Title per Amazons guidelines)                                        |5.0            |78          |
# |23999101   |Video_DVD             |Shania Twain - Up (Live in Chicago)                                                    |5.0            |76          |
# |50891233   |Video_DVD             |Shania Twain - Up (Live in Chicago)                                                    |5.0            |74          |
# |23969117   |Video_DVD             |Shania Twain - Up (Live in Chicago)                                                    |4.1818         |66          |
# |52773547   |Music                 |Oops!... I Did It Again                                                                |5.0            |64          |
# |50894327   |Digital_Music_Purchase|pitch: a' = 443 Hz                                                                     |1.0313         |64          |
# |51903243   |Video_DVD             |Lost in Translation                                                                    |1.0            |54          |
# |52895956   |Books                 |Fahrenheit 451                                                                         |5.0            |52          |
# |14539589   |Music                 |Soundtrack                                                                             |5.0            |49          |
# |48199647   |Digital_Ebook_Purchase|2010 ABNA Quarterfinalist 11                                                           |4.2979         |47          |
# |50310728   |Books                 |Seductive Poison: A Jonestown Survivor's Story of Life and Death in The Peoples Temple |5.0            |46          |
# |49974934   |Books                 |Goose Hunting: Improving Your Skills                                                   |5.0            |45          |
# |50719680   |Music                 |Rainbow                                                                                |5.0            |44          |
# |50440254   |Music                 |Rubber Soul (1990)                                                                     |5.0            |44          |
# |52895956   |Books                 |The Razor's Edge                                                                       |5.0            |44          |
# |24349371   |Video_DVD             |Shania Twain - Up (Live in Chicago)                                                    |4.9545         |44          |
# |35799690   |Music                 |Rubber Soul (1990)                                                                     |1.9048         |42          |
# |49629036   |Books                 |Dead Poets Society                                                                     |3.9048         |42          |
# |50440254   |Music                 |Revolver                                                                               |5.0            |42          |
# |52895956   |Books                 |A Princess of Mars                                                                     |5.0            |41          |
# |50736950   |Music                 |Greatest Hits                                                                          |3.9268         |41          |
# |35799690   |Music                 |Sgt. Pepper's Lonely Hearts Club Band                                                  |1.95           |40          |
# |6215457    |Camera                |(Create a generic Title per Amazons guidelines)                                        |5.0            |40          |
# |51410940   |Books                 |ELECTRONIC PUBLISHING: The Definitive Guide, 2003 Ed.                                  |5.0            |38          |
# |50440254   |Music                 |Magical Mystery Tour                                                                   |5.0            |38          |
# |35799690   |Music                 |The Beatles (The White Album)                                                          |2.1053         |38          |
# |50345651   |Music                 |Very Best of                                                                           |5.0            |38          |
# |50736950   |Music                 |Ultimate Collection                                                                    |4.7838         |37          |
# |49669148   |Books                 |Downriver (Turtleback School & Library Binding Edition) (Laurel-Leaf Books)            |4.1111         |36          |
# |34871301   |Video_DVD             |From Hell (Two-Disc Special Edition)                                                   |5.0            |36          |
# |51283859   |Books                 |Blonde: A Novel                                                                        |1.0            |36          |
# |35799690   |Music                 |Revolver                                                                               |2.1111         |36          |
# |35087745   |Music                 |Britney                                                                                |5.0            |36          |
# |52773547   |Music                 |So Real                                                                                |1.0            |35          |
# |19390454   |Digital_Ebook_Purchase|2010 ABNA Quarterfinalist 11                                                           |4.0            |35          |
# |50310728   |Books                 |Seductive Poison: A Jonestown Survivor's Story of Life and Death in the People's Temple|5.0            |35          |
# |19650457   |Music                 |Real Life                                                                              |5.0            |35          |
# |34462751   |Music                 |One Heart                                                                              |5.0            |35          |
# |50205849   |Music                 |Ultimate Collection                                                                    |4.6176         |34          |
# |35799690   |Music                 |Abbey Road                                                                             |2.3529         |34          |
# |33049536   |Music                 |TP-2.com                                                                               |5.0            |34          |
# +-----------+----------------------+---------------------------------------------------------------------------------------+---------------+------------+
