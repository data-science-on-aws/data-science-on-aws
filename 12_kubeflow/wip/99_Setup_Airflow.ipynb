# %%
# %%bash
#
# source ~/.bash_profile
#
# export AIRFLOW_HOME=~/airflow
# echo "export AIRFLOW_HOME=${AIRFLOW_HOME}" | tee -a ~/.bash_profile
# Out:
# export AIRFLOW_HOME=/home/ec2-user/airflow

# %%
# %%bash
#
# source ~/.bash_profile
#
# pip install apache-airflow
# Out:
# Collecting apache-airflow
#   Downloading apache_airflow-1.10.12-py2.py3-none-any.whl (4.7 MB)
# Collecting flask-appbuilder~=2.2; python_version >= "3.6"
#   Downloading Flask_AppBuilder-2.3.4-py3-none-any.whl (1.7 MB)
# Requirement already satisfied: psutil<6.0.0,>=4.2.0 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from apache-airflow) (5.7.0)
# Requirement already satisfied: pygments<3.0,>=2.0.1 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from apache-airflow) (2.6.1)
# Collecting email-validator
#   Downloading email_validator-1.1.1-py2.py3-none-any.whl (17 kB)
# Collecting cattrs~=1.0
#   Downloading cattrs-1.0.0-py2.py3-none-any.whl (14 kB)
# Collecting tzlocal<2.0.0,>=1.4
#   Downloading tzlocal-1.5.1.tar.gz (16 kB)
# Collecting flask-caching<1.4.0,>=1.3.3
#   Downloading Flask_Caching-1.3.3-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs~=19.3 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from apache-airflow) (19.3.0)
# Requirement already satisfied: future<0.19,>=0.16.0 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from apache-airflow) (0.18.2)
# Collecting tabulate<0.9,>=0.7.5
#   Using cached tabulate-0.8.7-py3-none-any.whl (24 kB)
# Collecting sqlalchemy-jsonfield~=0.9; python_version >= "3.5"
#   Downloading SQLAlchemy_JSONField-0.9.0-py2.py3-none-any.whl (10 kB)
# Collecting argcomplete~=1.10
#   Downloading argcomplete-1.12.0-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: requests<3,>=2.20.0 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from apache-airflow) (2.23.0)
# Collecting markdown<3.0,>=2.5.2
#   Downloading Markdown-2.6.11-py2.py3-none-any.whl (78 kB)
# Collecting setproctitle<2,>=1.1.8
#   Downloading setproctitle-1.1.10.tar.gz (24 kB)
# Collecting python-daemon>=2.1.1
#   Downloading python_daemon-2.2.4-py2.py3-none-any.whl (35 kB)
# Requirement already satisfied: python-dateutil<3,>=2.3 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from apache-airflow) (2.8.1)
# Collecting werkzeug<1.0.0
#   Downloading Werkzeug-0.16.1-py2.py3-none-any.whl (327 kB)
# Collecting python-nvd3~=0.15.0
#   Downloading python-nvd3-0.15.0.tar.gz (31 kB)
# Collecting gunicorn<21.0,>=19.5.0
#   Downloading gunicorn-20.0.4-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: cached-property~=1.5 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from apache-airflow) (1.5.1)
# Collecting dill<0.4,>=0.2.2
#   Downloading dill-0.3.2.zip (177 kB)
# Collecting flask-wtf<0.15,>=0.14.2
#   Downloading Flask_WTF-0.14.3-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: typing-extensions>=3.7.4; python_version < "3.8" in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from apache-airflow) (3.7.4.1)
# Collecting python-slugify<5.0,>=3.0.0
#   Downloading python-slugify-4.0.1.tar.gz (11 kB)
# Collecting iso8601>=0.1.12
#   Downloading iso8601-0.1.12-py2.py3-none-any.whl (12 kB)
# Collecting json-merge-patch==0.2
#   Downloading json-merge-patch-0.2.tar.gz (3.1 kB)
# Collecting graphviz>=0.12
#   Downloading graphviz-0.14.1-py2.py3-none-any.whl (18 kB)
# Collecting alembic<2.0,>=1.0
#   Downloading alembic-1.4.2.tar.gz (1.1 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting flask-admin==1.5.4
#   Downloading Flask-Admin-1.5.4.tar.gz (1.7 MB)
# Collecting flask-login<0.5,>=0.3
#   Downloading Flask-Login-0.4.1.tar.gz (14 kB)
# Collecting zope.deprecation<5.0,>=4.0
#   Downloading zope.deprecation-4.4.0-py2.py3-none-any.whl (10 kB)
# Collecting flask-swagger<0.3,>=0.2.13
#   Downloading flask-swagger-0.2.14.tar.gz (8.6 kB)
# Collecting configparser<3.6.0,>=3.5.0
#   Downloading configparser-3.5.3-py3-none-any.whl (21 kB)
# Collecting thrift>=0.9.2
#   Downloading thrift-0.13.0.tar.gz (59 kB)
# Requirement already satisfied: unicodecsv>=0.14.1 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from apache-airflow) (0.14.1)
# Collecting pendulum==1.4.4
#   Downloading pendulum-1.4.4.tar.gz (74 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting colorlog==4.0.2
#   Downloading colorlog-4.0.2-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: sqlalchemy~=1.3 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from apache-airflow) (1.3.15)
# Collecting tenacity==4.12.0
#   Downloading tenacity-4.12.0-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: jsonschema~=3.0 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from apache-airflow) (3.2.0)
# Requirement already satisfied: lazy-object-proxy~=1.3 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from apache-airflow) (1.4.3)
# Collecting funcsigs<2.0.0,>=1.0.0
#   Downloading funcsigs-1.0.2-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: jinja2<2.12.0,>=2.10.1 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from apache-airflow) (2.11.1)
# Requirement already satisfied: pandas<2.0,>=0.17.1 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from apache-airflow) (1.0.3)
# Collecting croniter<0.4,>=0.3.17
#   Downloading croniter-0.3.34-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: flask<2.0,>=1.1.0 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from apache-airflow) (1.1.1)
# Collecting marshmallow-enum<2,>=1.4.1
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Collecting prison<1.0.0,>=0.1.3
#   Downloading prison-0.1.3-py2.py3-none-any.whl (5.8 kB)
# Collecting marshmallow<3.0.0,>=2.18.0
#   Downloading marshmallow-2.21.0-py2.py3-none-any.whl (50 kB)
# Collecting Flask-Babel<2,>=1
#   Downloading Flask_Babel-1.0.0-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: click<8,>=6.7 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from flask-appbuilder~=2.2; python_version >= "3.6"->apache-airflow) (7.1.1)
# Collecting apispec[yaml]<2,>=1.1.1
#   Downloading apispec-1.3.3-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: colorama<1,>=0.3.9 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from flask-appbuilder~=2.2; python_version >= "3.6"->apache-airflow) (0.4.3)
# Collecting sqlalchemy-utils<1,>=0.32.21
#   Downloading SQLAlchemy-Utils-0.36.8.tar.gz (138 kB)
# Collecting Flask-OpenID<2,>=1.2.5
#   Downloading Flask-OpenID-1.2.5.tar.gz (43 kB)
# Collecting marshmallow-sqlalchemy<1,>=0.16.1
#   Downloading marshmallow_sqlalchemy-0.23.1-py2.py3-none-any.whl (18 kB)
# Collecting Flask-SQLAlchemy<3,>=2.4
#   Downloading Flask_SQLAlchemy-2.4.4-py2.py3-none-any.whl (17 kB)
# Collecting Flask-JWT-Extended<4,>=3.18
#   Downloading Flask-JWT-Extended-3.24.1.tar.gz (31 kB)
# Collecting PyJWT>=1.7.1
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: idna>=2.0.0 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from email-validator->apache-airflow) (2.9)
# Collecting dnspython>=1.15.0
#   Downloading dnspython-2.0.0-py3-none-any.whl (208 kB)
# Requirement already satisfied: pytz in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from tzlocal<2.0.0,>=1.4->apache-airflow) (2019.3)
# Requirement already satisfied: importlib-metadata<2,>=0.23; python_version == "3.7" in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from argcomplete~=1.10->apache-airflow) (1.5.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.20.0->apache-airflow) (1.25.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.20.0->apache-airflow) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.20.0->apache-airflow) (2020.4.5.2)
# Requirement already satisfied: docutils in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from python-daemon>=2.1.1->apache-airflow) (0.15.2)
# Collecting lockfile>=0.10
#   Downloading lockfile-0.12.2-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from python-daemon>=2.1.1->apache-airflow) (46.1.3.post20200330)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from python-dateutil<3,>=2.3->apache-airflow) (1.14.0)
# Requirement already satisfied: itsdangerous in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from flask-wtf<0.15,>=0.14.2->apache-airflow) (1.1.0)
# Collecting WTForms
#   Downloading WTForms-2.3.3-py2.py3-none-any.whl (169 kB)
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Collecting Mako
#   Downloading Mako-1.1.3-py2.py3-none-any.whl (75 kB)
# Collecting python-editor>=0.3
#   Downloading python_editor-1.0.4-py3-none-any.whl (4.9 kB)
# Requirement already satisfied: PyYAML>=5.1 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from flask-swagger<0.3,>=0.2.13->apache-airflow) (5.3.1)
# Collecting pytzdata>=2018.3.0.0
#   Downloading pytzdata-2020.1-py2.py3-none-any.whl (489 kB)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from jsonschema~=3.0->apache-airflow) (0.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from jinja2<2.12.0,>=2.10.1->apache-airflow) (1.1.1)
# Requirement already satisfied: numpy>=1.13.3 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from pandas<2.0,>=0.17.1->apache-airflow) (1.18.1)
# Collecting natsort
#   Downloading natsort-7.0.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: Babel>=2.3 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from Flask-Babel<2,>=1->flask-appbuilder~=2.2; python_version >= "3.6"->apache-airflow) (2.8.0)
# Collecting python3-openid>=2.0
#   Downloading python3_openid-3.2.0-py3-none-any.whl (133 kB)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from importlib-metadata<2,>=0.23; python_version == "3.7"->argcomplete~=1.10->apache-airflow) (2.2.0)
# Requirement already satisfied: defusedxml in /home/ec2-user/anaconda3/lib/python3.7/site-packages (from python3-openid>=2.0->Flask-OpenID<2,>=1.2.5->flask-appbuilder~=2.2; python_version >= "3.6"->apache-airflow) (0.6.0)
# Building wheels for collected packages: tzlocal, setproctitle, python-nvd3, dill, python-slugify, json-merge-patch, alembic, flask-admin, flask-login, flask-swagger, thrift, pendulum, sqlalchemy-utils, Flask-OpenID, Flask-JWT-Extended
#   Building wheel for tzlocal (setup.py): started
#   Building wheel for tzlocal (setup.py): finished with status 'done'
#   Created wheel for tzlocal: filename=tzlocal-1.5.1-py3-none-any.whl size=17543 sha256=f0ff4b5378a2da2769e476a884b23dcb93d2b5789f07d907bde90c064f403687
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/6a/76/b4/f97e26f8f60b5b2b1287415f1202e2b34a97775cead74072be
#   Building wheel for setproctitle (setup.py): started
#   Building wheel for setproctitle (setup.py): finished with status 'done'
#   Created wheel for setproctitle: filename=setproctitle-1.1.10-cp37-cp37m-linux_x86_64.whl size=26020 sha256=91ce3a14348ee7a0152b6c9cc178c4aa09942e555e11fe92249e29759c549f87
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/02/79/9a/ad2d16e975ac2a43458abc7f87089779308c3018f92bff11b4
#   Building wheel for python-nvd3 (setup.py): started
#   Building wheel for python-nvd3 (setup.py): finished with status 'done'
#   Created wheel for python-nvd3: filename=python_nvd3-0.15.0-py3-none-any.whl size=38153 sha256=30bb3a37022b4b15f27a9ff9fd2436da5ec0a0b55dff1671bddbad6313621030
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/42/0e/a4/5290cd4d309d756617f4d8eedd60813653d606e21ccaf7f286
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.2-py3-none-any.whl size=78912 sha256=2338a547db093f0d1ae64b5d63f758cc37560985acf6e25b86675280d8bb9d7e
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/72/6b/d5/5548aa1b73b8c3d176ea13f9f92066b02e82141549d90e2100
#   Building wheel for python-slugify (setup.py): started
#   Building wheel for python-slugify (setup.py): finished with status 'done'
#   Created wheel for python-slugify: filename=python_slugify-4.0.1-py2.py3-none-any.whl size=6767 sha256=216d0a68dd9b529d34357a3385ab97908d30374e7ff33d3279263d7ab7c51ebf
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/48/1b/6f/5c1cfab22eacbe0095fc619786da6571b55253653c71324b5c
#   Building wheel for json-merge-patch (setup.py): started
#   Building wheel for json-merge-patch (setup.py): finished with status 'done'
#   Created wheel for json-merge-patch: filename=json_merge_patch-0.2-py3-none-any.whl size=4393 sha256=2b13d24fb9092495a6cd8fbd38288cd531b250924d440701d3c6305d0a5bec1a
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/e2/0e/dc/22a77318fe07bfdde46e434ca3a8133fb5016f396700ad7021
#   Building wheel for alembic (PEP 517): started
#   Building wheel for alembic (PEP 517): finished with status 'done'
#   Created wheel for alembic: filename=alembic-1.4.2-py2.py3-none-any.whl size=159540 sha256=c6d24f7a14d2a8616e15f41139d55b6448a8a332fb7e2379cb33a78f1049c26e
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/4e/b5/00/f93fe1c90b3d501774e91e2e99987f49d16019e40e4bd3afc3
#   Building wheel for flask-admin (setup.py): started
#   Building wheel for flask-admin (setup.py): finished with status 'done'
#   Created wheel for flask-admin: filename=Flask_Admin-1.5.4-py3-none-any.whl size=1865025 sha256=0dd94bb73405fa38c4525e7b39e8b7b9b74e7de6450b93de965871dd0eb51407
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/f9/71/7e/5a0e31a65d8f244dec9c3febd3ef18a38d7fe4767fdf709011
#   Building wheel for flask-login (setup.py): started
#   Building wheel for flask-login (setup.py): finished with status 'done'
#   Created wheel for flask-login: filename=Flask_Login-0.4.1-py2.py3-none-any.whl size=15935 sha256=bdedd34e00db6eba9379cae031ee2411efde4a51a6e4d2e8edb3faf02504635c
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/6b/b8/33/1da5a5d39e093a68d81848aa44fd70e3cd0193e6f2d5641052
#   Building wheel for flask-swagger (setup.py): started
#   Building wheel for flask-swagger (setup.py): finished with status 'done'
#   Created wheel for flask-swagger: filename=flask_swagger-0.2.14-py3-none-any.whl size=7266 sha256=4ad9d69c337ad851024d2bacd93054a3f8d56a17106cf6b1f88440dd7b751321
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/26/31/14/a8dcde240ba2a1e052d0d3a45e09c7d2843922474c8c163d5c
#   Building wheel for thrift (setup.py): started
#   Building wheel for thrift (setup.py): finished with status 'done'
#   Created wheel for thrift: filename=thrift-0.13.0-cp37-cp37m-linux_x86_64.whl size=389766 sha256=63db00154ce7c3490b50c1bc342864cecd583e5c9fc43fa2ebe1d93c0ce6556a
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/79/35/5a/19f5dadf91f62bd783aaa8385f700de9bc14772e09ab0f006a
#   Building wheel for pendulum (PEP 517): started
#   Building wheel for pendulum (PEP 517): finished with status 'done'
#   Created wheel for pendulum: filename=pendulum-1.4.4-cp37-cp37m-linux_x86_64.whl size=123195 sha256=933f67e2a0c0caea5e84c6aab9f5253fef0c66d2771450b3d732f345ff4fe945
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/41/d4/fa/31df9cc56ee41572a4dfc1be7dfc87df59a5d6a7fd03e97eab
#   Building wheel for sqlalchemy-utils (setup.py): started
#   Building wheel for sqlalchemy-utils (setup.py): finished with status 'done'
#   Created wheel for sqlalchemy-utils: filename=SQLAlchemy_Utils-0.36.8-py2.py3-none-any.whl size=93221 sha256=212a6ef5a7db020beeee58f60bc70022eabacb12eaa5f08ee12cd3120186d859
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/29/c3/6b/495f824c202b91e5dc231e802afa062910f229ad2131588a96
#   Building wheel for Flask-OpenID (setup.py): started
#   Building wheel for Flask-OpenID (setup.py): finished with status 'done'
#   Created wheel for Flask-OpenID: filename=Flask_OpenID-1.2.5-py3-none-any.whl size=9120 sha256=534afb7464e00bf994fbdda69f5b51028374a7736ac2f8c23ba8187a1cc7b5c7
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/65/7b/bb/26e83746ed4bf0e29b5fdbcfe04a65c1f9b2d007dafebd35a3
#   Building wheel for Flask-JWT-Extended (setup.py): started
#   Building wheel for Flask-JWT-Extended (setup.py): finished with status 'done'
#   Created wheel for Flask-JWT-Extended: filename=Flask_JWT_Extended-3.24.1-py2.py3-none-any.whl size=21513 sha256=fa141a987ee2ec8affd9d17f5a20729691065cd3a21f369b3d71b1d85b324801
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/5d/e6/e4/0327f91fde6e288d17757185e957e91e89d06bd2dd6dd365b8
# Successfully built tzlocal setproctitle python-nvd3 dill python-slugify json-merge-patch alembic flask-admin flask-login flask-swagger thrift pendulum sqlalchemy-utils Flask-OpenID Flask-JWT-Extended
# Installing collected packages: marshmallow, marshmallow-enum, prison, Flask-Babel, WTForms, flask-wtf, apispec, sqlalchemy-utils, python3-openid, Flask-OpenID, dnspython, email-validator, flask-login, marshmallow-sqlalchemy, Flask-SQLAlchemy, werkzeug, PyJWT, Flask-JWT-Extended, flask-appbuilder, cattrs, tzlocal, flask-caching, tabulate, sqlalchemy-jsonfield, argcomplete, markdown, setproctitle, lockfile, python-daemon, text-unidecode, python-slugify, python-nvd3, gunicorn, dill, iso8601, json-merge-patch, graphviz, Mako, python-editor, alembic, flask-admin, zope.deprecation, flask-swagger, configparser, thrift, pytzdata, pendulum, colorlog, tenacity, funcsigs, natsort, croniter, apache-airflow
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 1.0.1
#     Uninstalling Werkzeug-1.0.1:
#       Successfully uninstalled Werkzeug-1.0.1
# Successfully installed Flask-Babel-1.0.0 Flask-JWT-Extended-3.24.1 Flask-OpenID-1.2.5 Flask-SQLAlchemy-2.4.4 Mako-1.1.3 PyJWT-1.7.1 WTForms-2.3.3 alembic-1.4.2 apache-airflow-1.10.12 apispec-1.3.3 argcomplete-1.12.0 cattrs-1.0.0 colorlog-4.0.2 configparser-3.5.3 croniter-0.3.34 dill-0.3.2 dnspython-2.0.0 email-validator-1.1.1 flask-admin-1.5.4 flask-appbuilder-2.3.4 flask-caching-1.3.3 flask-login-0.4.1 flask-swagger-0.2.14 flask-wtf-0.14.3 funcsigs-1.0.2 graphviz-0.14.1 gunicorn-20.0.4 iso8601-0.1.12 json-merge-patch-0.2 lockfile-0.12.2 markdown-2.6.11 marshmallow-2.21.0 marshmallow-enum-1.5.1 marshmallow-sqlalchemy-0.23.1 natsort-7.0.1 pendulum-1.4.4 prison-0.1.3 python-daemon-2.2.4 python-editor-1.0.4 python-nvd3-0.15.0 python-slugify-4.0.1 python3-openid-3.2.0 pytzdata-2020.1 setproctitle-1.1.10 sqlalchemy-jsonfield-0.9.0 sqlalchemy-utils-0.36.8 tabulate-0.8.7 tenacity-4.12.0 text-unidecode-1.3 thrift-0.13.0 tzlocal-1.5.1 werkzeug-0.16.1 zope.deprecation-4.4.0
# WARNING: You are using pip version 20.0.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
# %%bash
#
# source ~/.bash_profile
#
# airflow initdb
# Out:
# DB: sqlite:////home/ec2-user/airflow/airflow.db
# [2020-09-09 22:50:49,453] {db.py:378} INFO - Creating tables
# Done.
# /home/ec2-user/anaconda3/lib/python3.7/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Running upgrade  -> e3a246e0dc1, current schema
# INFO  [alembic.runtime.migration] Running upgrade e3a246e0dc1 -> 1507a7289a2f, create is_encrypted
# /home/ec2-user/anaconda3/lib/python3.7/site-packages/alembic/ddl/sqlite.py:41: UserWarning: Skipping unsupported ALTER for creation of implicit constraintPlease refer to the batch mode feature which allows for SQLite migrations using a copy-and-move strategy.
#   "Skipping unsupported ALTER for "
# INFO  [alembic.runtime.migration] Running upgrade 1507a7289a2f -> 13eb55f81627, maintain history for compatibility with earlier migrations
# INFO  [alembic.runtime.migration] Running upgrade 13eb55f81627 -> 338e90f54d61, More logging into task_instance
# INFO  [alembic.runtime.migration] Running upgrade 338e90f54d61 -> 52d714495f0, job_id indices
# INFO  [alembic.runtime.migration] Running upgrade 52d714495f0 -> 502898887f84, Adding extra to Log
# INFO  [alembic.runtime.migration] Running upgrade 502898887f84 -> 1b38cef5b76e, add dagrun
# INFO  [alembic.runtime.migration] Running upgrade 1b38cef5b76e -> 2e541a1dcfed, task_duration
# INFO  [alembic.runtime.migration] Running upgrade 2e541a1dcfed -> 40e67319e3a9, dagrun_config
# INFO  [alembic.runtime.migration] Running upgrade 40e67319e3a9 -> 561833c1c74b, add password column to user
# INFO  [alembic.runtime.migration] Running upgrade 561833c1c74b -> 4446e08588, dagrun start end
# INFO  [alembic.runtime.migration] Running upgrade 4446e08588 -> bbc73705a13e, Add notification_sent column to sla_miss
# INFO  [alembic.runtime.migration] Running upgrade bbc73705a13e -> bba5a7cfc896, Add a column to track the encryption state of the 'Extra' field in connection
# INFO  [alembic.runtime.migration] Running upgrade bba5a7cfc896 -> 1968acfc09e3, add is_encrypted column to variable table
# INFO  [alembic.runtime.migration] Running upgrade 1968acfc09e3 -> 2e82aab8ef20, rename user table
# INFO  [alembic.runtime.migration] Running upgrade 2e82aab8ef20 -> 211e584da130, add TI state index
# INFO  [alembic.runtime.migration] Running upgrade 211e584da130 -> 64de9cddf6c9, add task fails journal table
# INFO  [alembic.runtime.migration] Running upgrade 64de9cddf6c9 -> f2ca10b85618, add dag_stats table
# INFO  [alembic.runtime.migration] Running upgrade f2ca10b85618 -> 4addfa1236f1, Add fractional seconds to mysql tables
# INFO  [alembic.runtime.migration] Running upgrade 4addfa1236f1 -> 8504051e801b, xcom dag task indices
# INFO  [alembic.runtime.migration] Running upgrade 8504051e801b -> 5e7d17757c7a, add pid field to TaskInstance
# INFO  [alembic.runtime.migration] Running upgrade 5e7d17757c7a -> 127d2bf2dfa7, Add dag_id/state index on dag_run table
# INFO  [alembic.runtime.migration] Running upgrade 127d2bf2dfa7 -> cc1e65623dc7, add max tries column to task instance
# /home/ec2-user/anaconda3/lib/python3.7/site-packages/airflow/models/dag.py:1342: PendingDeprecationWarning: The requested task could not be added to the DAG because a task with task_id create_tag_template_field_result is already in the DAG. Starting in Airflow 2.0, trying to overwrite a task will raise an exception.
#   category=PendingDeprecationWarning)
# INFO  [alembic.runtime.migration] Running upgrade cc1e65623dc7 -> bdaa763e6c56, Make xcom value column a large binary
# INFO  [alembic.runtime.migration] Running upgrade bdaa763e6c56 -> 947454bf1dff, add ti job_id index
# INFO  [alembic.runtime.migration] Running upgrade 947454bf1dff -> d2ae31099d61, Increase text size for MySQL (not relevant for other DBs' text types)
# INFO  [alembic.runtime.migration] Running upgrade d2ae31099d61 -> 0e2a74e0fc9f, Add time zone awareness
# INFO  [alembic.runtime.migration] Running upgrade d2ae31099d61 -> 33ae817a1ff4, kubernetes_resource_checkpointing
# INFO  [alembic.runtime.migration] Running upgrade 33ae817a1ff4 -> 27c6a30d7c24, kubernetes_resource_checkpointing
# INFO  [alembic.runtime.migration] Running upgrade 27c6a30d7c24 -> 86770d1215c0, add kubernetes scheduler uniqueness
# INFO  [alembic.runtime.migration] Running upgrade 86770d1215c0, 0e2a74e0fc9f -> 05f30312d566, merge heads
# INFO  [alembic.runtime.migration] Running upgrade 05f30312d566 -> f23433877c24, fix mysql not null constraint
# INFO  [alembic.runtime.migration] Running upgrade f23433877c24 -> 856955da8476, fix sqlite foreign key
# INFO  [alembic.runtime.migration] Running upgrade 856955da8476 -> 9635ae0956e7, index-faskfail
# INFO  [alembic.runtime.migration] Running upgrade 9635ae0956e7 -> dd25f486b8ea, add idx_log_dag
# INFO  [alembic.runtime.migration] Running upgrade dd25f486b8ea -> bf00311e1990, add index to taskinstance
# INFO  [alembic.runtime.migration] Running upgrade 9635ae0956e7 -> 0a2a5b66e19d, add task_reschedule table
# INFO  [alembic.runtime.migration] Running upgrade 0a2a5b66e19d, bf00311e1990 -> 03bc53e68815, merge_heads_2
# INFO  [alembic.runtime.migration] Running upgrade 03bc53e68815 -> 41f5f12752f8, add superuser field
# INFO  [alembic.runtime.migration] Running upgrade 41f5f12752f8 -> c8ffec048a3b, add fields to dag
# INFO  [alembic.runtime.migration] Running upgrade c8ffec048a3b -> dd4ecb8fbee3, Add schedule interval to dag
# INFO  [alembic.runtime.migration] Running upgrade dd4ecb8fbee3 -> 939bb1e647c8, task reschedule fk on cascade delete
# INFO  [alembic.runtime.migration] Running upgrade 939bb1e647c8 -> 6e96a59344a4, Make TaskInstance.pool not nullable
# INFO  [alembic.runtime.migration] Running upgrade 6e96a59344a4 -> d38e04c12aa2, add serialized_dag table
# Revision ID: d38e04c12aa2
# Revises: 6e96a59344a4
# Create Date: 2019-08-01 14:39:35.616417
# INFO  [alembic.runtime.migration] Running upgrade d38e04c12aa2 -> b3b105409875, add root_dag_id to DAG
# INFO  [alembic.runtime.migration] Running upgrade 6e96a59344a4 -> 74effc47d867, change datetime to datetime2(6) on MSSQL tables
# INFO  [alembic.runtime.migration] Running upgrade 939bb1e647c8 -> 004c1210f153, increase queue name size limit
# INFO  [alembic.runtime.migration] Running upgrade c8ffec048a3b -> a56c9515abdc, Remove dag_stat table
# INFO  [alembic.runtime.migration] Running upgrade a56c9515abdc, 004c1210f153, 74effc47d867, b3b105409875 -> 08364691d074, Merge the four heads back together
# INFO  [alembic.runtime.migration] Running upgrade 08364691d074 -> fe461863935f, increase_length_for_connection_password
# INFO  [alembic.runtime.migration] Running upgrade fe461863935f -> 7939bcff74ba, Add DagTags table
# INFO  [alembic.runtime.migration] Running upgrade 7939bcff74ba -> a4c2fd67d16b, add pool_slots field to task_instance
# INFO  [alembic.runtime.migration] Running upgrade a4c2fd67d16b -> 852ae6c715af, Add RenderedTaskInstanceFields table
# INFO  [alembic.runtime.migration] Running upgrade 852ae6c715af -> 952da73b5eff, add dag_code table
# INFO  [alembic.runtime.migration] Running upgrade 952da73b5eff -> a66efa278eea, Add Precision to execution_date in RenderedTaskInstanceFields table
# INFO  [alembic.runtime.migration] Running upgrade a66efa278eea -> da3f683c3a5a, Add dag_hash Column to serialized_dag table

# %%
# %%bash
#
# source ~/.bash_profile
#
# #nohup airflow webserver -p 8080 &
# Out:
# Process is interrupted.

# %%
# %%bash
#
# source ~/.bash_profile
#
# #nohup airflow scheduler &
# Out:
# Process is interrupted.

# %% [markdown]
# Navigate to the following url:
#
# https://workshop.notebook.[your-region].sagemaker.aws/proxy/8080/  <== MAKE SURE YOU INCLUDE THE TRAILING SLASH
